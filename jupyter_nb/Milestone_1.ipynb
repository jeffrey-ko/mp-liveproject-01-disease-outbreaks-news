# %% [markdown]
# ## Parsing the News Headlines ##

# %% [markdown]
# ## Objective ##
#
# Find any city and/or country names mentioned in each of the news headlines.

# %%
import pandas as pd

# %% [markdown]
# ## Workflow #1 ##
# Load in the headline data and examine it for any data quality issues.
# - Use any library/data structure to read in the headlines.
# - Read through some of the headlines and identify potential problems.

# %%
headline_file = open('data/headlines.txt', 'r')

# %%
headlines = [line.strip()
             for line in headline_file.readlines()]

# %%
num_headlines = len(headlines)
print(f"{num_headlines} headlines have been loaded")
# Out:
# 650 headlines have been loaded

# %%
headlines
# Out:
# ['Zika Outbreak Hits Miami',
#  'Could Zika Reach New York City?',
#  'First Case of Zika in Miami Beach',
#  'Mystery Virus Spreads in Recife, Brazil',
#  'Dallas man comes down with case of Zika',
#  'Trinidad confirms first Zika case',
#  'Zika Concerns are Spreading in Houston',
#  'Geneve Scientists Battle to Find Cure',
#  'The CDC in Atlanta is Growing Worried',
#  'Zika Infested Monkeys in Sao Paulo',
#  'Brownsville teen contracts Zika virus',
#  'Mosquito control efforts in St. Louis take new tactics with Zika threat',
#  'San Juan reports 1st U.S. Zika-related death amid outbreak',
#  'Flu outbreak in Galveston, Texas',
#  'Zika alert â€“ Manila now threatened',
#  'Zika afflicts 7 in Iloilo City',
#  'New Los Angeles Hairstyle goes Viral',
#  'Louisiana Zika cases up to 26',
#  'Orlando volunteers aid Zika research',
#  'Zika infects pregnant woman in Cebu',
#  "Chicago's First Zika Case Confirmed",
#  'Tampa Bay Area Zika Case Count Climbs',
#  'Bad Water Leads to Sickness in Flint, Michigan',
#  'Baltimore plans for Zika virus',
#  'London Health Unit Tracks Mad Cow Disease',
#  "Zika cases in Vietnam's Ho Chi Minh City surge",
#  'Philadelphia experts track pandemic',
#  'Flu season hits Boston',
#  'Scientists in Paris to look for answers',
#  'Key Zika Findings in San Diego Institute',
#  'Thailand-Zika Virus in Bangkok',
#  'Beijing team cracks Zika secret',
#  'Zika spreading to Salvador',
#  'Kuala Lumpur is Hit By Zika Threat',
#  'First Zika case confirmed in Yangon',
#  'Tallahassee Doctors Discuss Zika Virus',
#  'Zika Virus Reaches San Francisco',
#  'New Vaccine on Trial in Bethesda District',
#  'Townsville Zika tests inconclusive',
#  'Mandaluyong City under Siege by Virus',
#  'Hepatitis E re-emerges in Santa Rosa',
#  'Zika worries in San Salvador',
#  'Zika virus reported in Cleveland',
#  'More Zika patients reported in Austin',
#  'Zika outbreak in Piracicaba, Brazil',
#  'Lima tries to address Zika Concerns',
#  'More people in Toronto are infected with Hepatitis E every year',
#  '18 new Zika Cases in Bogota',
#  'Spanish Flu Sighted in Antigua',
#  'Brisbane is infested with Meningitis',
#  'Cholera outbreak in Dakar',
#  'Zika Virus Transmission Detected in Havana',
#  'Zika symtomps spotted in Key West',
#  'Case of Measles Reported in Vancouver',
#  'Seattle scientists get $500,000 grant to pursue Zika vaccine New 7:50 pm',
#  'Nashville takes precautions against Zika',
#  'Saint Croix under Zika threat',
#  'Fort Collins Encounters Severe Symptoms of Gonorrhea',
#  'Zika surfaces in Klang, Malaysia',
#  'Rumors about Meningitis spreading in Guatemala City have been refuted',
#  'Madison lab developing vaccine against Zika virus [The Wisconsin State Journal]',
#  'New Zika Case Confirmed in Sarasota County',
#  'Lower Hospitalization in Entebbe after Rabies Vaccine becomes Mandatory',
#  'Carnival under threat in Rio De Janeiro due to Zika outbreak',
#  'Second Zika Paitient in Brasilia',
#  'Jacksonville man hit by Zika',
#  'Schools in Shenzhen Closed Due to Malaria Outbreak',
#  'Caracas patient dies',
#  'More Quezon City Zika Transmissions',
#  'Schools in Sydney Closed Due to Respiratory Syncytial Virus Outbreak',
#  "Mumbai's Health Minister warns of more Zika cases",
#  'Pune woman diagnosed with Zika',
#  'Hospitals in Hanoi fill up with Zika patients',
#  'Zika case reported in Oton',
#  'Authorities are Worried about the Spread of Bronchitis in Silver Spring',
#  'Zika: Delhi for strict monitoring',
#  'Hillsborough uses innovative trap against Zika 20 minutes ago',
#  'Belize City under threat from Zika',
#  'Student sick in Campinas, Brazil',
#  'More Zika cases in Soyapango',
#  'Authorities are Worried about the Spread of Mad Cow Disease in Rome',
#  'Seoul confirms 14th Zika infection',
#  'Hepatitis B Vaccine is now Required in Quebec',
#  'Zika outbreak spreads to Mexico City',
#  'Rochester authorities confirmed the spread of Dengue',
#  'El Paso fighting Zika',
#  'Visitor to Cucuta contracts Zika',
#  'Zika now spreading through Jakarta',
#  'Maka City Experiences Influenza Outbreak',
#  'Salt Lake City tests new cure for Respiratory Syncytial Virus',
#  'Zika San Antonio Patient Speaks Out',
#  'Ebola outbreak in Kampala',
#  'Precautionary Zika measures in Rockhampton',
#  'Zika arrives in Tegucigalpa',
#  'New Zika Case Confirmed in Belo Horizonte',
#  'Case of Hepatitis E Reported in Melbourne',
#  'First Columbus Zika case',
#  'New medicine wipes out Tuberculosis in Taipei',
#  'Zika Patient in Seminole, Florida',
#  'Antipolo under threat from Zika Virus',
#  'Spreading Zika reaches Bacoor',
#  'Can Zika make it here to Vero Beach?',
#  'Zika afflicts patient in Calamba',
#  'Hollywood Outbreak Film Premieres',
#  'Petaling Jaya man ill from Zika',
#  'Malaria is Spreading in Johannesburg',
#  'Authorities are Worried about the Spread of Norovirus in Buenos Aires',
#  'Guangzhou Patient in Critical Condition after Contracting Swine Flu',
#  'Doral hit by Deadly Virus',
#  'Tokyo Encounters Severe Symptoms of Meningitis',
#  'Rabies Exposure in Hamilton',
#  'Authorities are Worried about the Spread of Influenza in Savannah',
#  'Zika Outbreak in Hyderabad',
#  'Birmingham Residents Recieve Rabies vaccine',
#  'Is Zika virus in Majuro?',
#  'Spreading Zika ruining Cancun fun',
#  'Cancun hit by Outbreak of Party Fever!',
#  'HIV has Arrived in Fairfax',
#  'Spanish Flu Outbreak in Barcelona',
#  'Santa Barbara tests new cure for Hepatitis C',
#  'Spring break ruined by Zika in Fort Lauderdale',
#  'Villavicencio under Zika threat',
#  'Two more Zika cases confirmed in Laredo',
#  'New Delhi Addressing Zika Concerns',
#  'New Zika Case in Kota Kinabalu, Malaysia',
#  'New medicine wipes out West Nile Virus in Ventura',
#  'Meningitis re-emerges in Nassau',
#  'Zika reaches Johor Bahru, Malaysia',
#  'Nha Trang Zika Outbreak',
#  'First Zika Case in Cincinnati',
#  'Molo Cholera Spread Causing Concern',
#  'Norovirus Exposure in Hong Kong',
#  '19 new Zika Cases in Sengkang',
#  'Zika cases concern Charlotte residents',
#  'Batangas Tourism Takes a Hit as Virus Spreads',
#  'Johannesburg Patient in Critical Condition after Contracting Pneumonia',
#  'Outbreak of Zika in Bacolod City',
#  'Respiratory Syncytial Virus Keeps Spreading in Masaya',
#  'Spike of Pneumonia Cases in Springfield',
#  'More Zika patients reported in Mcallen',
#  'Zika case reported in Jupiter',
#  'Zika virus confirmed in Westchester',
#  'Authorities are Worried about the Spread of Tuberculosis in Abuja',
#  'Rumors about Hepatitis D Spreading in San Juan Capistrano have been Refuted',
#  'The Spread of Measles in Spokane has been Confirmed',
#  'Zika alert for Rio Grande Valley residents',
#  'Zika symptoms spotted in Colombo',
#  'West Nile Virus Outbreak in Louisville',
#  'New details in Baton Rouge cop killings',
#  'Hepatitis B has not Left Florence',
#  'More Zika patients reported in Pensacola',
#  'Outbreak of Zika in Corpus Christi',
#  'How to Avoid Rhinovirus in Lemon Grove',
#  'Rumors about Rotavirus spreading in Huntsville have been refuted',
#  'Rhinovirus has Arrived in Athens',
#  'Outbreak of Zika in Panama City',
#  'West Nile Virus Outbreak in Saint Johns',
#  'Measles has not Left Brooklyn',
#  'Escondido neighborhood to get sprayed for Zika virus',
#  'Zika in Belmont, Belmont worry',
#  'Influenza has not Left Sacramento',
#  'Veracruz hit by Zika Concerns',
#  'Case of Mumps Reported in Dayton',
#  'Authorities are Worried about the Spread of Dengue in Kingston',
#  'Gainesville Deals with Disease Concerns',
#  'Montevideo Encounters Severe Symptoms of Rotavirus',
#  'Varicella Keeps Spreading in Detroit',
#  'Arhus is infested with Bronchitis',
#  'Zika Troubles come to Niteroi',
#  'Zika cases in Singapore reach 393',
#  'Manhattan Residents Recieve HIV vaccine',
#  'Zika arrives in Miri',
#  'Rumors about Dengue Spreading in Syracuse have been Refuted',
#  'Will Norovirus vaccine help Raleigh?',
#  'Lower Hospitalization in Auckland after Hepatitis D Vaccine becomes Mandatory',
#  'How to Avoid Gonorrhea in Shreveport',
#  'Ithaca is infested with Dengue',
#  'Will MCD vaccine help Strasbourg?',
#  'New medicine wipes out Measles in Fresno',
#  'BREAKING â€“ Zika in Missoula',
#  'Zika arrives in Santos',
#  'Sick Livestock Leads to Serious Trouble for Belfort',
#  'Hepatitis E has not Left Libreville',
#  'New medicine wipes out Chikungunya in Tucson',
#  'Norovirus has Arrived in Winnipeg',
#  'Hepatitis B Comes to Kansas City',
#  'More Patients in Cambridge are Getting Diagnosed with Chickenpox',
#  'Chikungunya Exposure in Toledo',
#  'Is Lafayette prepared to combat Zika?',
#  'Mecca tests new cure for Chikungunya',
#  'Zika arrives in San Benito',
#  'Syphilis Outbreak in Harrisburg',
#  'Zika Arrives in North Miami',
#  'Urbana Encounters Severe Symptoms of Meningitis',
#  'Pittsburgh Residents Recieve Norovirus vaccine',
#  'Chikungunya Hits Denver',
#  'Zika case recorded in Tunapuna Â»',
#  'Spike of Respiratory Syncytial Virus Cases in Mandalay',
#  'HIV Keeps Spreading in Boulder',
#  'More Zika patients reported in Joao Pessoa',
#  'Will Tuberculosis vaccine help Rockville?',
#  'Mad Cow Disease Re-emerges in Chatham',
#  'Zika Virus Arrives in Ontario',
#  'Mad Cow Disease Hits Naples',
#  'More Zika patients reported in Davao',
#  'The Spread of Chikungunya in Arcadia has been Confirmed',
#  'Oxford tests new cure for HIV',
#  'Outbreak of Zika in Stephenville',
#  'Providence Encounters Severe Symptoms of Dengue',
#  'Tests negative on Windsor Zika carriers',
#  'Zika battle outlined at Valdosta meeting',
#  'Zika case reported in Coral Gables',
#  'Hepatitis C Outbreak in Danbury',
#  'Chickenpox has Arrived in Chula Vista',
#  'Syphilis Hits Jefferson',
#  'Will HIV vaccine help Las Vegas?',
#  'Zika arrives in West Palm Beach',
#  'Mobile authorities confirmed the spread of Bronchitis',
#  'Zika spreads to Daytona Beach',
#  'Lausanne Residents Recieve Meningitis vaccine',
#  'Rhinovirus Comes to San Jose',
#  'Spike of Chlamydia Cases in Farmington',
#  'Authorities are Worried about the Spread of Rotavirus in Union',
#  'Rumors about Hepatitis D spreading in Albany have been refuted',
#  'Zika symptoms spotted in Bello',
#  'Will Meningitis vaccine help Hamburg?',
#  'Madera Patient in Critical Condition after Contracting Rabies',
#  'Zika Virus Detected in Lubbock',
#  'Malaria re-emerges in Boise',
#  'Varicella re-emerges in Lagos',
#  'Vericella spreading in Ibadan',
#  'Schools in Birmingham Closed Due to Measles Outbreak',
#  'How to Avoid Hepatitis B in Waldorf',
#  'More people in Mclean are infected with Hepatitis A every year',
#  'Malaria Exposure in Sussex',
#  'Tuberculosis Outbreak in Newark',
#  "Zika Virus Sparks 'International Concern'",
#  'Spike of Chlamydia Cases in Berlin',
#  'Zika-carrying mosquitoes discovered in Ardmore',
#  'Zika Mosquitoes May Have Bred in Bromeliads, Florida Officials Say',
#  'More Livestock in Fontainebleau are infected with Mad Cow Disease',
#  'Frisco Woman Tests Positive For Zika Virus',
#  'Authorities are Worried about the Spread of Norovirus in Dubai',
#  'Benton Residents Recieve Pneumonia vaccine',
#  'Case of Hepatitis A Reported in Calgary',
#  'Zika Outbreak in Pinewood',
#  'Will Swine Flu vaccine help Ljubljana?',
#  'Bronchitis re-emerges in Tehran',
#  'Greenwich Establishes Zika Task Force',
#  'Mad Cow case in Murcia',
#  'Mad Cow Disease Spreads to Margate',
#  'Zika Strikes St. Petersburg',
#  'Will West Nile Virus vaccine help Parsons?',
#  'Will the Mad Cow Outbreak Reach Vienna?',
#  'More Patients in Orange are Getting Diagnosed with Chickenpox',
#  'Lower Hospitalization in Richmond after Mumps Vaccine becomes Mandatory',
#  'Meningitis re-emerges in Medina',
#  'Yulee takes a hit from Spreading Sickness',
#  'Four cases of Zika in Hidalgo County',
#  'Zika symptoms spotted in Hollywood',
#  'Zika arrives in Oaxaca',
#  'More people in Durham are infected with Chlamydia every year',
#  'Authorities are Worried about the Spread of Gonorrhea in Taoyuan City',
#  'Swine Flu re-emerges in La Jolla',
#  'Tuberculosis Outbreak in Hartford',
#  'Rumors about Mumps Spreading in New Bedford have been Refuted',
#  'Respiratory Syncytial Virus Vaccine is now Required in Tulsa',
#  'More people in Indianapolis are infected with Norovirus every year',
#  'Lower Hospitalization in Dhaka after Measles Vaccine becomes Mandatory',
#  'Albany Residents Recieve Respiratory Syncytial Virus vaccine',
#  'The Spread of Chikungunya in Davidson has been Confirmed',
#  'Rotavirus Vaccine is now Required in Starkville',
#  'Schools in Yaounde Closed Due to Mumps Outbreak',
#  'More people in Nadi are infected with HIV every year',
#  'Tocumen tests new cure for Hepatitis A',
#  'Phnom Penh hit by Zika Threat',
#  'Zika Troubles come to Harlingen',
#  'Zika spreads to Barranquilla',
#  'Milwaukee authorities confirmed the spread of Rhinovirus',
#  'Mad Cow Disease Hits Rotterdam',
#  'Zika symptoms spotted in Arlington',
#  'West Nile Virus Hits Yogyakarta',
#  'More Patients in Dublin are Getting Diagnosed with Bronchitis',
#  'Rumors about Tuberculosis Spreading in Baud have been Refuted',
#  'Rumors about West Nile Virus Spreading in Salem have been Refuted',
#  'St. Catharines Patient in Critical Condition after Contracting Dengue',
#  'Zika case reported in Los Fresnos',
#  'More Zika patients reported in Camacari',
#  'Outbreak of Zika in Pasig City',
#  'Zika Troubles come to Kampong Cham',
#  'Zika case reported in Rizal',
#  'Zika Spreads to Palm Beach Gardens',
#  'More people in Saint Petersburg are infected with Varicella every year',
#  'Spike of Herpes Cases in Meriden',
#  'Zika case reported in Abilene',
#  'Outbreak of Zika in Palm Springs',
#  'Halifax is infested with Swine Flu',
#  'Zika arrives in Natal',
#  'Herpes Keeps Spreading in Rochester',
#  'Zika case reported in Phetchabun',
#  'How to Avoid Pneumonia in Bullhead City',
#  'West Nile Virus re-emerges in Wellington',
#  'Rumors about Pneumonia spreading in Ottawa have been refuted',
#  'Meningitis re-emerges in Summerville',
#  'Pneumonia Symptoms Spread all over Bloomington',
#  'More Patients in Stuttgart are Getting Diagnosed with Rabies',
#  'Schools in Glasgow Closed Due to Hepatitis B Outbreak',
#  'Phoenix Residents Recieve Syphilis vaccine',
#  'More people in Boucau are infected with HIV every year',
#  'Spanish flu spreading in Madrid',
#  'Rabies Hits Madrid',
#  'Zika Outbreak in Weslaco',
#  'How to Avoid Chlamydia in Santiago',
#  'Rotavirus Vaccine is now Required in Las Cumbres',
#  'Mumps Symptoms Spread all over Jefferson',
#  'Mad Cow Outbreak Spreading in Ennis',
#  'Southampton Patient in Critical Condition after Contracting Tuberculosis',
#  'The Spread of Rhinovirus in Boardman has been Confirmed',
#  'Richland Center is infested with Hepatitis B',
#  'Authorities are Worried about the Spread of Chickenpox in Richmond',
#  'Chikungunya re-emerges in Kobe',
#  'Malaria Vaccine is now Required in Schenectady',
#  'Hepatitis D has Arrived in Grenoble',
#  'West Nile Virus Symptoms Spread all over Yerevan',
#  'Zika Outbreak in Sincelejo',
#  'Rumors about HIV spreading in Montpellier have been refuted',
#  'Praia tests new cure for Pneumonia',
#  'Bronchitis Outbreak in Manhasset',
#  'Lower Hospitalization in Lakewood after Hepatitis B Vaccine becomes Mandatory',
#  'Zika spreads to Kuching',
#  'Spike of Rotavirus Cases in Omaha',
#  'Tuberculosis re-emerges in Silver Springs',
#  'Will West Nile Virus vaccine help Coronado?',
#  'Zika case confirmed in Lorain',
#  'Chickenpox Hits Simpsonville',
#  'Framingham Residents Receive Measles vaccine',
#  'Rumors about Mad Cow Disease Brighton have been Refuted',
#  'Zika case reported in Jacobina',
#  'Bridgeport authorities confirmed the spread of West Nile Virus',
#  'Zika Troubles come to Padre Las Casas',
#  'Measles Vaccine is now Required in Wailuku',
#  'Zika symptoms spotted in Surat',
#  'Rumors about Influenza Spreading in Dobbs Ferry have been Refuted',
#  'More contaminated cattle reported in Bedford',
#  'Zika in Tamarac!',
#  'Will Measles vaccine help Milford?',
#  'Spike of Norovirus Cases in Huddersfield',
#  'Rhinovirus Hits Bakersfield',
#  'Lower Hospitalization in Papeete after Measles Vaccine becomes Mandatory',
#  'Zika arrives in Udon Thani',
#  'Spike of Dengue Cases in Stockholm',
#  'More people in Berkeley are infected with Swine Flu every year',
#  'Outbreak of Zika in Destin',
#  'Zika only the latest mosquito-borne threat to New Orleans',
#  'Will Swine Flu vaccine help Annapolis?',
#  'Lower Hospitalization in Monroe after Hepatitis D Vaccine becomes Mandatory',
#  'New medicine wipes out Dengue in Saginaw',
#  'Spike of Rhinovirus Cases in Sevierville',
#  'Duisburg up in Arms over Mad Cow Disease',
#  'New medicine wipes out Mumps in Saint Charles',
#  'Case of Chikungunya Reported in Gaithersburg',
#  'How to Avoid Respiratory Syncytial Virus in San Bernardino',
#  'Laventille authorities confirmed the spread of Rhinovirus',
#  'More Zika patients reported in Waco',
#  'Will Herpes vaccine help Newcastle?',
#  'Erie County sets Zika traps',
#  'More people in Huron are infected with Dengue every year',
#  'How to Avoid Norovirus in Greenville',
#  'More Zika patients reported in Calumpang',
#  'Zika symptoms spotted in Quisqueya',
#  'Rumors about Hepatitis D Spreading in Montreal have been Refuted',
#  'Zika symptoms spotted in Fortaleza',
#  'Rumors about Bronchitis spreading in Bundaberg have been refuted',
#  'Hepatitis A re-emerges in Stamford',
#  'Schools in Huntington Closed Due to Rotavirus Outbreak',
#  'Will Mad Cow Vaccine Help Bristol?',
#  'Chickenpox Comes to Stillwater',
#  'The Spread of Meningitis in Imperial has been Confirmed',
#  'Will Tuberculosis vaccine help Cherry Creek?',
#  'Gympie Patient in Critical Condition after Contracting Chlamydia',
#  'Case of Measles Reported in Springdale',
#  'Norwalk Encounters Severe Symptoms of Malaria',
#  'Zika arrives in Orange City',
#  'Pilsen Encounters Severe Symptoms of Malaria',
#  'Will Hepatitis B vaccine help La Paz?',
#  'Zika Outbreak in Puducherry',
#  'More Zika patients reported in Carrollton',
#  'Will Rabies vaccine help Tangier?',
#  'Zika symptoms spotted in Iquitos',
#  'West Nile Virus Exposure in Racine',
#  'The Spread of Hepatitis E in Lansing has been Confirmed',
#  'West Nile Virus Exposure in Alpharetta',
#  'Pedro Juan Caballero Encounters Severe Symptoms of Pneumonia',
#  'More Zika patients reported in Melbourne',
#  'Zika Troubles come to La Libertad',
#  'Herpes Vaccine is now Required in Mattoon',
#  'Kent is infested with Rabies',
#  'Zika symptoms spotted in Bonita Springs',
#  'The Spread of Malaria in Brazzaville has been Confirmed',
#  'More Zika patients reported in Fort Myers',
#  'Zika spreads to Lewisville',
#  'Ogden is infested with Gonorrhea',
#  'Fort Hood Reports its First Zika Patient',
#  'Huzhou Residents Receive Hepatitis B vaccine',
#  'New medicine wipes out Rabies in Newburgh',
#  'Iowa City Encounters Severe Symptoms of Rhinovirus',
#  'Spike of Rabies Cases in Managua',
#  'Outbreak of Zika in Santa Elena',
#  'Mumps Hits Howard Beach',
#  'The Spread of Gonorrhea in Reno has been Confirmed',
#  'How to Avoid Rhinovirus in Plainfield',
#  'Rumors about Varicella spreading in Carlsbad have been refuted',
#  'Scranton authorities confirmed the spread of Gonorrhea',
#  'Mad Cow Disease Disastrous to Brussels',
#  'Zika spreads to Olinda',
#  'Hallandale Beach a Victim of Zika Outbreak',
#  'Rhinovirus re-emerges in Storrs',
#  'Germantown authorities confirmed the spread of Chickenpox',
#  'Rumors about Rotavirus spreading in North Platte have been refuted',
#  'Spike of Hepatitis C Cases in Golden',
#  'Authorities are Worried about the Spread of Hepatitis D in Ganja',
#  'Dengue Exposure in Kathmandu',
#  'Tuberculosis has Arrived in Fairfield',
#  'Outbreak of Zika in Kozhikode',
#  'Bronchitis Symptoms Spread all over Santa Fe',
#  'More Patients in Alexandria are Getting Diagnosed with Mumps',
#  'Pneumonia Exposure in Alhambra',
#  'Hepatitis C re-emerges in Damascus',
#  'Lower Hospitalization in Pekanbaru after Rotavirus Vaccine becomes Mandatory',
#  'Spike of Meningitis Cases in Druid Hills',
#  'Schools in Bentonville Closed Due to Hepatitis B Outbreak',
#  'Hepatitis E Hits Hammond',
#  'Schools in Bridgeton Closed Due to Mumps Outbreak',
#  'Biloxi Residents Recieve Chlamydia vaccine',
#  'Case of Mad Cow Disease Reported in Hilden',
#  'Rumors about Rabies Spreading in Khartoum have been Refuted',
#  'Harare is infested with Pneumonia',
#  'Zika symptoms spotted in Sibu',
#  'Zika arrives in Quezon',
#  'More Patients in Crawfordsville are Getting Diagnosed with Rabies',
#  'Spike of Hepatitis B Cases in Greenville',
#  'Authorities are Worried about the Spread of Hepatitis D in Akron',
#  'More Zika patients reported in Nuevo Laredo',
#  'Bronchitis Keeps Spreading in San Mateo',
#  'Zika arrives in Boca Raton',
#  'Bradenton Experiences Zika Troubles',
#  'Chlamydia Symptoms Spread all over University City',
#  'Wisconsin Rapids Patient in Critical Condition after Contracting Chickenpox',
#  'Zika spreads to Kissimmee',
#  'Herpes Symptoms Spread all over Fremont',
#  'Spike of Pneumonia Cases in The Bronx',
#  'Authorities are Worried about the Spread of Hepatitis D in North Bay',
#  'The Spread of Herpes in Baku has been Confirmed',
#  'Will Measles vaccine help Sochi?',
#  'Tuberculosis Symptoms Spread all over Caguas',
#  'HIV has Arrived in Tacoma',
#  'Malaria re-emerges in Nashua',
#  'Arvada is infested with Syphilis',
#  'Spike of Syphilis Cases in West Monroe',
#  'More Zika patients reported in Ribeirao Preto',
#  'Martinsville tests new cure for Measles',
#  'Deerfield tests new cure for Measles',
#  'Contaminated Meat Brings Trouble for Bonn Farmers',
#  'More Patients in Magnolia are Getting Diagnosed with Malaria',
#  'Hepatitis A re-emerges in Foster City',
#  'How to Avoid Tuberculosis in Santa Monica',
#  'Zika reported in Fort Pierce',
#  'Authorities are Worried about the Spread of Syphilis in Pyongyang',
#  'Zika spreads to Winter Park',
#  'Durango is infested with Hepatitis B',
#  'Hepatitis A has not Left Staten Island',
#  'Mpika authorities confirmed the spread of Chikungunya',
#  'Gladstone Encounters Severe Symptoms of Dengue',
#  'Mad Cow Disease Hits London',
#  'New Milford Patient in Critical Condition after Contracting Respiratory Syncytial Virus',
#  'More people in Palo Alto are infected with HIV every year',
#  'HIV Symptoms Spread all over Hinthada',
#  'Zika symptoms spotted in Quito',
#  'Vineland authorities confirmed the spread of Chlamydia',
#  'Sulu, Zamboanga brace for Zika',
#  'More Zika patients reported in Custodia',
#  'Tupelo Residents Recieve Syphilis vaccine',
#  'Rumors about Syphilis spreading in Penal have been refuted',
#  'Spanish Flu Outbreak in Lisbon',
#  'Spanish Flu Spreading through Madrid',
#  'Barcelona Struck by Spanish Flu',
#  'Spanish Flu Outbreak in Lisbon',
#  'Spanish Flu Spreading through Madrid',
#  'Barcelona Struck by Spanish Flu',
#  'The Spread of Dengue in Yakima has been Confirmed',
#  'Tuberculosis Hits Luanda',
#  'Will West Nile Virus vaccine help Dumai?',
#  'Rumors about Chlamydia spreading in Redmond have been refuted',
#  'Case of Varicella Reported in Concord',
#  'Zika virus case reported in Rockland',
#  'Zika investigators coming to Mankato',
#  'Toms River Encounters Severe Symptoms of Respiratory Syncytial Virus',
#  'The Spread of Malaria in Zanzibar has been Confirmed',
#  "Malaria Outbreak Hits Zanzibar's Tourist Industry",
#  'Tourist Perishes from Malaria in Arusha',
#  'Herpes Symptoms Spread all over New Kingston',
#  'More people in Yokohama are infected with Norovirus every year',
#  'More people in Kitwe are infected with Respiratory Syncytial Virus every year',
#  'Hepatitis D Keeps Spreading in Bismarck',
#  'Varicella Outbreak in Minot',
#  'Malaria has Arrived in Terrebonne',
#  'Chikungunya Keeps Spreading in North Vancouver',
#  'Authorities are Worried about the Spread of Chickenpox in Hemet',
#  'Fort Belvoir tests new cure for Hepatitis C',
#  'More people in Oak Brook are infected with Respiratory Syncytial Virus every year',
#  'Rumors about Hepatitis C spreading in Darien have been refuted',
#  'The Spread of West Nile Virus in Fairfield has been Confirmed',
#  'Princeton Encounters Severe Symptoms of Dengue',
#  'Norovirus Keeps Spreading in Copenhagen',
#  'Wuhan is infested with Varicella',
#  'Zika spreads to San Luis Potosi',
#  'Outbreak of Zika in Hutchins',
#  'Spike of Norovirus Cases in Canberra',
#  'Zika Troubles come to Greater Noida',
#  'Lower Hospitalization in Palm Springs after Hepatitis A Vaccine becomes Mandatory',
#  'Longwood volunteers spreading Zika awareness',
#  'Outbreak of Zika in Leesburg',
#  'Authorities are Worried about the Spread of Tuberculosis in Cantu',
#  'Zika symptoms spotted in Quixere',
#  'New medicine wipes out HIV in Kihei',
#  'Sangre Grande Residents Recieve Gonorrhea vaccine',
#  'Outbreak of Zika in Colombo',
#  'Will Rotavirus vaccine help Addis Ababa?',
#  'Stony Brook University experts discuss Zika virus',
#  'Lower Hospitalization in Janesville after Varicella Vaccine becomes Mandatory',
#  'Rabies Outbreak in Altus',
#  'Miami resident suggests Zika precautions',
#  'Zika Troubles come to Jaen',
#  'Hepatitis B Exposure in Edinburgh',
#  'Zika case reported in Reynosa',
#  'Schools in Tulare Closed Due to Mumps Outbreak',
#  'More Zika patients reported in Chennai',
#  'Hepatitis D Keeps Spreading in Danvers',
#  'Authorities a Miami',
#  'Zika case reported in Medellin',
#  'Spike of Tuberculosis Cases in Albuquerque',
#  'More people in Cranford are infected with Hepatitis A every year',
#  'West Nile Virus Hits Monroe',
#  'Pneumonia Outbreak in Springville',
#  'Zika arrives in San Onofre',
#  'Lung Cancer Rates Increasing in Moscow',
#  'Rumors about Rotavirus Spreading in Joliet have been Refuted',
#  'More Zika patients reported in Chanthaburi',
#  'Lawrenceville is infested with Dengue',
#  'Zika Reported in Ciudad Acuna',
#  'Zika case reported in Limoeiro',
#  'Ibadan tests new cure for Malaria',
#  'Gonorrhea has Arrived in Avon Lake',
#  'Pneumonia has not Left Kinshasa',
#  'Respiratory Syncytial Virus Hits Henderson',
#  'More Zika patients reported in Lakeland',
#  'Malaria Vaccine is now Required in Winona',
#  'More Patients in Canton are Getting Diagnosed with Norovirus',
#  'Ronkonkoma is infested with Chickenpox',
#  'Kedougou tests new cure for Hepatitis C',
#  'Gonorrhea Exposure in Norwalk',
#  'How to Avoid Rhinovirus in Medford',
#  'Hepatitis D Symptoms Spread all over Evansville',
#  'New medicine wipes out Herpes in Bossier City',
#  'Pneumonia Exposure in San Jose',
#  'Authorities are Worried about the Spread of Mad Cow Disease in Edinburgh',
#  'Duluth Patient in Critical Condition after Contracting Rotavirus',
#  'Measles Hits Davos',
#  'Norfolk tests new cure for Herpes',
#  'More Zika patients reported in Botucatu',
#  'Manassas Encounters Severe Symptoms of Measles',
#  'Fayetteville authorities confirmed the spread of HIV',
#  'Varicella Exposure in Cambridge',
#  'Hepatitis A Vaccine is now Required in Fukushima',
#  'Zika Outbreak in South Miami',
#  'Hepatitis D Symptoms Spread all over North Bethesda',
#  'Panama Cityâ€™s first Zika related death',
#  'West Nile Virus has Arrived in Dongguan',
#  'Zika arrives in Belmopan',
#  'Zika seminars in Yuma County',
#  'Rumors about Hepatitis E Spreading in Morristown have been Refuted',
#  'Mumps Outbreak in Joplin',
#  'Spike of Hepatitis E Cases in Morehead City',
#  'Authorities are Worried about the Spread of Mumps in Corona',
#  'Schools in Danville Closed Due to Tuberculosis Outbreak',
#  'Outbreak of Zika in Alvorada',
#  'Marquette tests new cure for Hepatitis A',
#  'Norovirus Vaccine is now Required in Anaheim',
#  'Zika Outbreak in Manaus',
#  'Zika spreads to Caucasia',
#  'Case of Malaria Reported in Aurora',
#  'Manchester Residents Recieve Influenza vaccine',
#  'Zika spreads to Kamphaeng Phet',
#  'Rotavirus Vaccine is now Required in Labasa',
#  'The Spread of Hepatitis E in Fargo has been Confirmed',
#  'Zika Outbreak in Mexicali',
#  'West Nile Virus Keeps Spreading in Hauppauge',
#  'Bronchitis Keeps Spreading in Hayward',
#  'Schools in Coamo Closed Due to Rhinovirus Outbreak',
#  'Zika arrives in Dangriga',
#  'Zika spreads to Plant City',
#  'Chlamydia Exposure in Sanaa',
#  'Zika Reported in North Miami Beach',
#  'More Patients in Kensington are Getting Diagnosed with Varicella',
#  'More Patients in Maynard are Getting Diagnosed with Syphilis',
#  'Case of West Nile Virus Reported in Riverside',
#  'Northfield Encounters Severe Symptoms of Herpes',
#  'The Spread of Respiratory Syncytial Virus in Monroe has been Confirmed',
#  'How to Avoid Hepatitis B in Trenton',
#  'Zika Reported in Ilopango',
#  'Barstow Patient in Critical Condition after Contracting Herpes',
#  'Hepatitis D Exposure in Aswan',
#  'Will Gonorrhea vaccine help East Moline?',
#  'New medicine wipes out Influenza in Redlands',
#  'How to Avoid Contaminated Meat when Visiting Basel',
#  'More Zika patients reported in Kampong Speu',
#  'Alameda Residents Recieve Rabies vaccine',
#  'Mad Cow Disease Detected in Lyon',
#  'Memphis Encounters Severe Symptoms of Swine Flu',
#  'Zika Troubles come to Delray Beach',
#  'How to Avoid Chikungunya in Hampton',
#  'Zika Reported in Sao Jose',
#  'Case of Norovirus Reported in Stratford',
#  'How to Avoid Hepatitis E in South Bend',
#  'Hepatitis C Outbreak in Bethlehem',
#  'Davenport is infested with Dengue',
#  'Rumors about Swine Flu spreading in Suzhou have been refuted',
#  'Malaria Vaccine is now Required in Elyria',
#  'Zika case reported in Antioquia',
#  'Case of Swine Flu Reported in Tbilisi',
#  'Chikungunya has not Left Pismo Beach',
#  'Zika spreads to La Joya',
#  'Influenza Keeps Spreading in Suffolk',
#  'More people in Allentown are infected with Chlamydia every year',
#  'Mad Cow Disease re-emerges in Bedford',
#  'Authorities are Worried about the Spread of Hepatitis B in Yiwu',
#  'Zika Outbreak in Yurimaguas',
#  'Dengue Outbreak in Easton',
#  'Varicella has Arrived in Milton',
#  'New medicine wipes out Meningitis in Sevilla',
#  'Authorities are Worried about the Spread of Varicella in Clovis',
#  'More Zika patients reported in Fort Worth',
#  'Zika symptoms spotted in Boynton Beach',
#  'Outbreak of Zika in Portoviejo',
#  'Influenza Exposure in Muscat',
#  'Rumors about Rabies spreading in Jerusalem have been refuted',
#  'More Zika patients reported in Indang',
#  'Suva authorities confirmed the spread of Rotavirus',
#  'More Zika patients reported in Bella Vista',
#  'Zika Outbreak in Wichita Falls']

# %%
headlines.sort()

# %%
headlines
# Out:
# ['18 new Zika Cases in Bogota',
#  '19 new Zika Cases in Sengkang',
#  'Alameda Residents Recieve Rabies vaccine',
#  'Albany Residents Recieve Respiratory Syncytial Virus vaccine',
#  'Antipolo under threat from Zika Virus',
#  'Arhus is infested with Bronchitis',
#  'Arvada is infested with Syphilis',
#  'Authorities a Miami',
#  'Authorities are Worried about the Spread of Bronchitis in Silver Spring',
#  'Authorities are Worried about the Spread of Chickenpox in Hemet',
#  'Authorities are Worried about the Spread of Chickenpox in Richmond',
#  'Authorities are Worried about the Spread of Dengue in Kingston',
#  'Authorities are Worried about the Spread of Gonorrhea in Taoyuan City',
#  'Authorities are Worried about the Spread of Hepatitis B in Yiwu',
#  'Authorities are Worried about the Spread of Hepatitis D in Akron',
#  'Authorities are Worried about the Spread of Hepatitis D in Ganja',
#  'Authorities are Worried about the Spread of Hepatitis D in North Bay',
#  'Authorities are Worried about the Spread of Influenza in Savannah',
#  'Authorities are Worried about the Spread of Mad Cow Disease in Edinburgh',
#  'Authorities are Worried about the Spread of Mad Cow Disease in Rome',
#  'Authorities are Worried about the Spread of Mumps in Corona',
#  'Authorities are Worried about the Spread of Norovirus in Buenos Aires',
#  'Authorities are Worried about the Spread of Norovirus in Dubai',
#  'Authorities are Worried about the Spread of Rotavirus in Union',
#  'Authorities are Worried about the Spread of Syphilis in Pyongyang',
#  'Authorities are Worried about the Spread of Tuberculosis in Abuja',
#  'Authorities are Worried about the Spread of Tuberculosis in Cantu',
#  'Authorities are Worried about the Spread of Varicella in Clovis',
#  'BREAKING â€“ Zika in Missoula',
#  'Bad Water Leads to Sickness in Flint, Michigan',
#  'Baltimore plans for Zika virus',
#  'Barcelona Struck by Spanish Flu',
#  'Barcelona Struck by Spanish Flu',
#  'Barstow Patient in Critical Condition after Contracting Herpes',
#  'Batangas Tourism Takes a Hit as Virus Spreads',
#  'Beijing team cracks Zika secret',
#  'Belize City under threat from Zika',
#  'Benton Residents Recieve Pneumonia vaccine',
#  'Biloxi Residents Recieve Chlamydia vaccine',
#  'Birmingham Residents Recieve Rabies vaccine',
#  'Bradenton Experiences Zika Troubles',
#  'Bridgeport authorities confirmed the spread of West Nile Virus',
#  'Brisbane is infested with Meningitis',
#  'Bronchitis Keeps Spreading in Hayward',
#  'Bronchitis Keeps Spreading in San Mateo',
#  'Bronchitis Outbreak in Manhasset',
#  'Bronchitis Symptoms Spread all over Santa Fe',
#  'Bronchitis re-emerges in Tehran',
#  'Brownsville teen contracts Zika virus',
#  'Can Zika make it here to Vero Beach?',
#  'Cancun hit by Outbreak of Party Fever!',
#  'Caracas patient dies',
#  'Carnival under threat in Rio De Janeiro due to Zika outbreak',
#  'Case of Chikungunya Reported in Gaithersburg',
#  'Case of Hepatitis A Reported in Calgary',
#  'Case of Hepatitis E Reported in Melbourne',
#  'Case of Mad Cow Disease Reported in Hilden',
#  'Case of Malaria Reported in Aurora',
#  'Case of Measles Reported in Springdale',
#  'Case of Measles Reported in Vancouver',
#  'Case of Mumps Reported in Dayton',
#  'Case of Norovirus Reported in Stratford',
#  'Case of Swine Flu Reported in Tbilisi',
#  'Case of Varicella Reported in Concord',
#  'Case of West Nile Virus Reported in Riverside',
#  "Chicago's First Zika Case Confirmed",
#  'Chickenpox Comes to Stillwater',
#  'Chickenpox Hits Simpsonville',
#  'Chickenpox has Arrived in Chula Vista',
#  'Chikungunya Exposure in Toledo',
#  'Chikungunya Hits Denver',
#  'Chikungunya Keeps Spreading in North Vancouver',
#  'Chikungunya has not Left Pismo Beach',
#  'Chikungunya re-emerges in Kobe',
#  'Chlamydia Exposure in Sanaa',
#  'Chlamydia Symptoms Spread all over University City',
#  'Cholera outbreak in Dakar',
#  'Contaminated Meat Brings Trouble for Bonn Farmers',
#  'Could Zika Reach New York City?',
#  'Dallas man comes down with case of Zika',
#  'Davenport is infested with Dengue',
#  'Deerfield tests new cure for Measles',
#  'Dengue Exposure in Kathmandu',
#  'Dengue Outbreak in Easton',
#  'Doral hit by Deadly Virus',
#  'Duisburg up in Arms over Mad Cow Disease',
#  'Duluth Patient in Critical Condition after Contracting Rotavirus',
#  'Durango is infested with Hepatitis B',
#  'Ebola outbreak in Kampala',
#  'El Paso fighting Zika',
#  'Erie County sets Zika traps',
#  'Escondido neighborhood to get sprayed for Zika virus',
#  'Fayetteville authorities confirmed the spread of HIV',
#  'First Case of Zika in Miami Beach',
#  'First Columbus Zika case',
#  'First Zika Case in Cincinnati',
#  'First Zika case confirmed in Yangon',
#  'Flu outbreak in Galveston, Texas',
#  'Flu season hits Boston',
#  'Fort Belvoir tests new cure for Hepatitis C',
#  'Fort Collins Encounters Severe Symptoms of Gonorrhea',
#  'Fort Hood Reports its First Zika Patient',
#  'Four cases of Zika in Hidalgo County',
#  'Framingham Residents Receive Measles vaccine',
#  'Frisco Woman Tests Positive For Zika Virus',
#  'Gainesville Deals with Disease Concerns',
#  'Geneve Scientists Battle to Find Cure',
#  'Germantown authorities confirmed the spread of Chickenpox',
#  'Gladstone Encounters Severe Symptoms of Dengue',
#  'Gonorrhea Exposure in Norwalk',
#  'Gonorrhea has Arrived in Avon Lake',
#  'Greenwich Establishes Zika Task Force',
#  'Guangzhou Patient in Critical Condition after Contracting Swine Flu',
#  'Gympie Patient in Critical Condition after Contracting Chlamydia',
#  'HIV Keeps Spreading in Boulder',
#  'HIV Symptoms Spread all over Hinthada',
#  'HIV has Arrived in Fairfax',
#  'HIV has Arrived in Tacoma',
#  'Halifax is infested with Swine Flu',
#  'Hallandale Beach a Victim of Zika Outbreak',
#  'Harare is infested with Pneumonia',
#  'Hepatitis A Vaccine is now Required in Fukushima',
#  'Hepatitis A has not Left Staten Island',
#  'Hepatitis A re-emerges in Foster City',
#  'Hepatitis A re-emerges in Stamford',
#  'Hepatitis B Comes to Kansas City',
#  'Hepatitis B Exposure in Edinburgh',
#  'Hepatitis B Vaccine is now Required in Quebec',
#  'Hepatitis B has not Left Florence',
#  'Hepatitis C Outbreak in Bethlehem',
#  'Hepatitis C Outbreak in Danbury',
#  'Hepatitis C re-emerges in Damascus',
#  'Hepatitis D Exposure in Aswan',
#  'Hepatitis D Keeps Spreading in Bismarck',
#  'Hepatitis D Keeps Spreading in Danvers',
#  'Hepatitis D Symptoms Spread all over Evansville',
#  'Hepatitis D Symptoms Spread all over North Bethesda',
#  'Hepatitis D has Arrived in Grenoble',
#  'Hepatitis E Hits Hammond',
#  'Hepatitis E has not Left Libreville',
#  'Hepatitis E re-emerges in Santa Rosa',
#  'Herpes Keeps Spreading in Rochester',
#  'Herpes Symptoms Spread all over Fremont',
#  'Herpes Symptoms Spread all over New Kingston',
#  'Herpes Vaccine is now Required in Mattoon',
#  'Hillsborough uses innovative trap against Zika 20 minutes ago',
#  'Hollywood Outbreak Film Premieres',
#  'Hospitals in Hanoi fill up with Zika patients',
#  'How to Avoid Chikungunya in Hampton',
#  'How to Avoid Chlamydia in Santiago',
#  'How to Avoid Contaminated Meat when Visiting Basel',
#  'How to Avoid Gonorrhea in Shreveport',
#  'How to Avoid Hepatitis B in Trenton',
#  'How to Avoid Hepatitis B in Waldorf',
#  'How to Avoid Hepatitis E in South Bend',
#  'How to Avoid Norovirus in Greenville',
#  'How to Avoid Pneumonia in Bullhead City',
#  'How to Avoid Respiratory Syncytial Virus in San Bernardino',
#  'How to Avoid Rhinovirus in Lemon Grove',
#  'How to Avoid Rhinovirus in Medford',
#  'How to Avoid Rhinovirus in Plainfield',
#  'How to Avoid Tuberculosis in Santa Monica',
#  'Huzhou Residents Receive Hepatitis B vaccine',
#  'Ibadan tests new cure for Malaria',
#  'Influenza Exposure in Muscat',
#  'Influenza Keeps Spreading in Suffolk',
#  'Influenza has not Left Sacramento',
#  'Iowa City Encounters Severe Symptoms of Rhinovirus',
#  'Is Lafayette prepared to combat Zika?',
#  'Is Zika virus in Majuro?',
#  'Ithaca is infested with Dengue',
#  'Jacksonville man hit by Zika',
#  'Johannesburg Patient in Critical Condition after Contracting Pneumonia',
#  'Kedougou tests new cure for Hepatitis C',
#  'Kent is infested with Rabies',
#  'Key Zika Findings in San Diego Institute',
#  'Kuala Lumpur is Hit By Zika Threat',
#  'Lausanne Residents Recieve Meningitis vaccine',
#  'Laventille authorities confirmed the spread of Rhinovirus',
#  'Lawrenceville is infested with Dengue',
#  'Lima tries to address Zika Concerns',
#  'London Health Unit Tracks Mad Cow Disease',
#  'Longwood volunteers spreading Zika awareness',
#  'Louisiana Zika cases up to 26',
#  'Lower Hospitalization in Auckland after Hepatitis D Vaccine becomes Mandatory',
#  'Lower Hospitalization in Dhaka after Measles Vaccine becomes Mandatory',
#  'Lower Hospitalization in Entebbe after Rabies Vaccine becomes Mandatory',
#  'Lower Hospitalization in Janesville after Varicella Vaccine becomes Mandatory',
#  'Lower Hospitalization in Lakewood after Hepatitis B Vaccine becomes Mandatory',
#  'Lower Hospitalization in Monroe after Hepatitis D Vaccine becomes Mandatory',
#  'Lower Hospitalization in Palm Springs after Hepatitis A Vaccine becomes Mandatory',
#  'Lower Hospitalization in Papeete after Measles Vaccine becomes Mandatory',
#  'Lower Hospitalization in Pekanbaru after Rotavirus Vaccine becomes Mandatory',
#  'Lower Hospitalization in Richmond after Mumps Vaccine becomes Mandatory',
#  'Lung Cancer Rates Increasing in Moscow',
#  'Mad Cow Disease Detected in Lyon',
#  'Mad Cow Disease Disastrous to Brussels',
#  'Mad Cow Disease Hits London',
#  'Mad Cow Disease Hits Naples',
#  'Mad Cow Disease Hits Rotterdam',
#  'Mad Cow Disease Re-emerges in Chatham',
#  'Mad Cow Disease Spreads to Margate',
#  'Mad Cow Disease re-emerges in Bedford',
#  'Mad Cow Outbreak Spreading in Ennis',
#  'Mad Cow case in Murcia',
#  'Madera Patient in Critical Condition after Contracting Rabies',
#  'Madison lab developing vaccine against Zika virus [The Wisconsin State Journal]',
#  'Maka City Experiences Influenza Outbreak',
#  'Malaria Exposure in Sussex',
#  "Malaria Outbreak Hits Zanzibar's Tourist Industry",
#  'Malaria Vaccine is now Required in Elyria',
#  'Malaria Vaccine is now Required in Schenectady',
#  'Malaria Vaccine is now Required in Winona',
#  'Malaria has Arrived in Terrebonne',
#  'Malaria is Spreading in Johannesburg',
#  'Malaria re-emerges in Boise',
#  'Malaria re-emerges in Nashua',
#  'Manassas Encounters Severe Symptoms of Measles',
#  'Manchester Residents Recieve Influenza vaccine',
#  'Mandaluyong City under Siege by Virus',
#  'Manhattan Residents Recieve HIV vaccine',
#  'Marquette tests new cure for Hepatitis A',
#  'Martinsville tests new cure for Measles',
#  'Measles Hits Davos',
#  'Measles Vaccine is now Required in Wailuku',
#  'Measles has not Left Brooklyn',
#  'Mecca tests new cure for Chikungunya',
#  'Memphis Encounters Severe Symptoms of Swine Flu',
#  'Meningitis re-emerges in Medina',
#  'Meningitis re-emerges in Nassau',
#  'Meningitis re-emerges in Summerville',
#  'Miami resident suggests Zika precautions',
#  'Milwaukee authorities confirmed the spread of Rhinovirus',
#  'Mobile authorities confirmed the spread of Bronchitis',
#  'Molo Cholera Spread Causing Concern',
#  'Montevideo Encounters Severe Symptoms of Rotavirus',
#  'More Livestock in Fontainebleau are infected with Mad Cow Disease',
#  'More Patients in Alexandria are Getting Diagnosed with Mumps',
#  'More Patients in Cambridge are Getting Diagnosed with Chickenpox',
#  'More Patients in Canton are Getting Diagnosed with Norovirus',
#  'More Patients in Crawfordsville are Getting Diagnosed with Rabies',
#  'More Patients in Dublin are Getting Diagnosed with Bronchitis',
#  'More Patients in Kensington are Getting Diagnosed with Varicella',
#  'More Patients in Magnolia are Getting Diagnosed with Malaria',
#  'More Patients in Maynard are Getting Diagnosed with Syphilis',
#  'More Patients in Orange are Getting Diagnosed with Chickenpox',
#  'More Patients in Stuttgart are Getting Diagnosed with Rabies',
#  'More Quezon City Zika Transmissions',
#  'More Zika cases in Soyapango',
#  'More Zika patients reported in Austin',
#  'More Zika patients reported in Bella Vista',
#  'More Zika patients reported in Botucatu',
#  'More Zika patients reported in Calumpang',
#  'More Zika patients reported in Camacari',
#  'More Zika patients reported in Carrollton',
#  'More Zika patients reported in Chanthaburi',
#  'More Zika patients reported in Chennai',
#  'More Zika patients reported in Custodia',
#  'More Zika patients reported in Davao',
#  'More Zika patients reported in Fort Myers',
#  'More Zika patients reported in Fort Worth',
#  'More Zika patients reported in Indang',
#  'More Zika patients reported in Joao Pessoa',
#  'More Zika patients reported in Kampong Speu',
#  'More Zika patients reported in Lakeland',
#  'More Zika patients reported in Mcallen',
#  'More Zika patients reported in Melbourne',
#  'More Zika patients reported in Nuevo Laredo',
#  'More Zika patients reported in Pensacola',
#  'More Zika patients reported in Ribeirao Preto',
#  'More Zika patients reported in Waco',
#  'More contaminated cattle reported in Bedford',
#  'More people in Allentown are infected with Chlamydia every year',
#  'More people in Berkeley are infected with Swine Flu every year',
#  'More people in Boucau are infected with HIV every year',
#  'More people in Cranford are infected with Hepatitis A every year',
#  'More people in Durham are infected with Chlamydia every year',
#  'More people in Huron are infected with Dengue every year',
#  'More people in Indianapolis are infected with Norovirus every year',
#  'More people in Kitwe are infected with Respiratory Syncytial Virus every year',
#  'More people in Mclean are infected with Hepatitis A every year',
#  'More people in Nadi are infected with HIV every year',
#  'More people in Oak Brook are infected with Respiratory Syncytial Virus every year',
#  'More people in Palo Alto are infected with HIV every year',
#  'More people in Saint Petersburg are infected with Varicella every year',
#  'More people in Toronto are infected with Hepatitis E every year',
#  'More people in Yokohama are infected with Norovirus every year',
#  'Mosquito control efforts in St. Louis take new tactics with Zika threat',
#  'Mpika authorities confirmed the spread of Chikungunya',
#  "Mumbai's Health Minister warns of more Zika cases",
#  'Mumps Hits Howard Beach',
#  'Mumps Outbreak in Joplin',
#  'Mumps Symptoms Spread all over Jefferson',
#  'Mystery Virus Spreads in Recife, Brazil',
#  'Nashville takes precautions against Zika',
#  'New Delhi Addressing Zika Concerns',
#  'New Los Angeles Hairstyle goes Viral',
#  'New Milford Patient in Critical Condition after Contracting Respiratory Syncytial Virus',
#  'New Vaccine on Trial in Bethesda District',
#  'New Zika Case Confirmed in Belo Horizonte',
#  'New Zika Case Confirmed in Sarasota County',
#  'New Zika Case in Kota Kinabalu, Malaysia',
#  'New details in Baton Rouge cop killings',
#  'New medicine wipes out Chikungunya in Tucson',
#  'New medicine wipes out Dengue in Saginaw',
#  'New medicine wipes out HIV in Kihei',
#  'New medicine wipes out Herpes in Bossier City',
#  'New medicine wipes out Influenza in Redlands',
#  'New medicine wipes out Measles in Fresno',
#  'New medicine wipes out Meningitis in Sevilla',
#  'New medicine wipes out Mumps in Saint Charles',
#  'New medicine wipes out Rabies in Newburgh',
#  'New medicine wipes out Tuberculosis in Taipei',
#  'New medicine wipes out West Nile Virus in Ventura',
#  'Nha Trang Zika Outbreak',
#  'Norfolk tests new cure for Herpes',
#  'Norovirus Exposure in Hong Kong',
#  'Norovirus Keeps Spreading in Copenhagen',
#  'Norovirus Vaccine is now Required in Anaheim',
#  'Norovirus has Arrived in Winnipeg',
#  'Northfield Encounters Severe Symptoms of Herpes',
#  'Norwalk Encounters Severe Symptoms of Malaria',
#  'Ogden is infested with Gonorrhea',
#  'Orlando volunteers aid Zika research',
#  'Outbreak of Zika in Alvorada',
#  'Outbreak of Zika in Bacolod City',
#  'Outbreak of Zika in Colombo',
#  'Outbreak of Zika in Corpus Christi',
#  'Outbreak of Zika in Destin',
#  'Outbreak of Zika in Hutchins',
#  'Outbreak of Zika in Kozhikode',
#  'Outbreak of Zika in Leesburg',
#  'Outbreak of Zika in Palm Springs',
#  'Outbreak of Zika in Panama City',
#  'Outbreak of Zika in Pasig City',
#  'Outbreak of Zika in Portoviejo',
#  'Outbreak of Zika in Santa Elena',
#  'Outbreak of Zika in Stephenville',
#  'Oxford tests new cure for HIV',
#  'Panama Cityâ€™s first Zika related death',
#  'Pedro Juan Caballero Encounters Severe Symptoms of Pneumonia',
#  'Petaling Jaya man ill from Zika',
#  'Philadelphia experts track pandemic',
#  'Phnom Penh hit by Zika Threat',
#  'Phoenix Residents Recieve Syphilis vaccine',
#  'Pilsen Encounters Severe Symptoms of Malaria',
#  'Pittsburgh Residents Recieve Norovirus vaccine',
#  'Pneumonia Exposure in Alhambra',
#  'Pneumonia Exposure in San Jose',
#  'Pneumonia Outbreak in Springville',
#  'Pneumonia Symptoms Spread all over Bloomington',
#  'Pneumonia has not Left Kinshasa',
#  'Praia tests new cure for Pneumonia',
#  'Precautionary Zika measures in Rockhampton',
#  'Princeton Encounters Severe Symptoms of Dengue',
#  'Providence Encounters Severe Symptoms of Dengue',
#  'Pune woman diagnosed with Zika',
#  'Rabies Exposure in Hamilton',
#  'Rabies Hits Madrid',
#  'Rabies Outbreak in Altus',
#  'Respiratory Syncytial Virus Hits Henderson',
#  'Respiratory Syncytial Virus Keeps Spreading in Masaya',
#  'Respiratory Syncytial Virus Vaccine is now Required in Tulsa',
#  'Rhinovirus Comes to San Jose',
#  'Rhinovirus Hits Bakersfield',
#  'Rhinovirus has Arrived in Athens',
#  'Rhinovirus re-emerges in Storrs',
#  'Richland Center is infested with Hepatitis B',
#  'Rochester authorities confirmed the spread of Dengue',
#  'Ronkonkoma is infested with Chickenpox',
#  'Rotavirus Vaccine is now Required in Labasa',
#  'Rotavirus Vaccine is now Required in Las Cumbres',
#  'Rotavirus Vaccine is now Required in Starkville',
#  'Rumors about Bronchitis spreading in Bundaberg have been refuted',
#  'Rumors about Chlamydia spreading in Redmond have been refuted',
#  'Rumors about Dengue Spreading in Syracuse have been Refuted',
#  'Rumors about HIV spreading in Montpellier have been refuted',
#  'Rumors about Hepatitis C spreading in Darien have been refuted',
#  'Rumors about Hepatitis D Spreading in Montreal have been Refuted',
#  'Rumors about Hepatitis D Spreading in San Juan Capistrano have been Refuted',
#  'Rumors about Hepatitis D spreading in Albany have been refuted',
#  'Rumors about Hepatitis E Spreading in Morristown have been Refuted',
#  'Rumors about Influenza Spreading in Dobbs Ferry have been Refuted',
#  'Rumors about Mad Cow Disease Brighton have been Refuted',
#  'Rumors about Meningitis spreading in Guatemala City have been refuted',
#  'Rumors about Mumps Spreading in New Bedford have been Refuted',
#  'Rumors about Pneumonia spreading in Ottawa have been refuted',
#  'Rumors about Rabies Spreading in Khartoum have been Refuted',
#  'Rumors about Rabies spreading in Jerusalem have been refuted',
#  'Rumors about Rotavirus Spreading in Joliet have been Refuted',
#  'Rumors about Rotavirus spreading in Huntsville have been refuted',
#  'Rumors about Rotavirus spreading in North Platte have been refuted',
#  'Rumors about Swine Flu spreading in Suzhou have been refuted',
#  'Rumors about Syphilis spreading in Penal have been refuted',
#  'Rumors about Tuberculosis Spreading in Baud have been Refuted',
#  'Rumors about Varicella spreading in Carlsbad have been refuted',
#  'Rumors about West Nile Virus Spreading in Salem have been Refuted',
#  'Saint Croix under Zika threat',
#  'Salt Lake City tests new cure for Respiratory Syncytial Virus',
#  'San Juan reports 1st U.S. Zika-related death amid outbreak',
#  'Sangre Grande Residents Recieve Gonorrhea vaccine',
#  'Santa Barbara tests new cure for Hepatitis C',
#  'Schools in Bentonville Closed Due to Hepatitis B Outbreak',
#  'Schools in Birmingham Closed Due to Measles Outbreak',
#  'Schools in Bridgeton Closed Due to Mumps Outbreak',
#  'Schools in Coamo Closed Due to Rhinovirus Outbreak',
#  'Schools in Danville Closed Due to Tuberculosis Outbreak',
#  'Schools in Glasgow Closed Due to Hepatitis B Outbreak',
#  'Schools in Huntington Closed Due to Rotavirus Outbreak',
#  'Schools in Shenzhen Closed Due to Malaria Outbreak',
#  'Schools in Sydney Closed Due to Respiratory Syncytial Virus Outbreak',
#  'Schools in Tulare Closed Due to Mumps Outbreak',
#  'Schools in Yaounde Closed Due to Mumps Outbreak',
#  'Scientists in Paris to look for answers',
#  'Scranton authorities confirmed the spread of Gonorrhea',
#  'Seattle scientists get $500,000 grant to pursue Zika vaccine New 7:50 pm',
#  'Second Zika Paitient in Brasilia',
#  'Seoul confirms 14th Zika infection',
#  'Sick Livestock Leads to Serious Trouble for Belfort',
#  'Southampton Patient in Critical Condition after Contracting Tuberculosis',
#  'Spanish Flu Outbreak in Barcelona',
#  'Spanish Flu Outbreak in Lisbon',
#  'Spanish Flu Outbreak in Lisbon',
#  'Spanish Flu Sighted in Antigua',
#  'Spanish Flu Spreading through Madrid',
#  'Spanish Flu Spreading through Madrid',
#  'Spanish flu spreading in Madrid',
#  'Spike of Chlamydia Cases in Berlin',
#  'Spike of Chlamydia Cases in Farmington',
#  'Spike of Dengue Cases in Stockholm',
#  'Spike of Hepatitis B Cases in Greenville',
#  'Spike of Hepatitis C Cases in Golden',
#  'Spike of Hepatitis E Cases in Morehead City',
#  'Spike of Herpes Cases in Meriden',
#  'Spike of Meningitis Cases in Druid Hills',
#  'Spike of Norovirus Cases in Canberra',
#  'Spike of Norovirus Cases in Huddersfield',
#  'Spike of Pneumonia Cases in Springfield',
#  'Spike of Pneumonia Cases in The Bronx',
#  'Spike of Rabies Cases in Managua',
#  'Spike of Respiratory Syncytial Virus Cases in Mandalay',
#  'Spike of Rhinovirus Cases in Sevierville',
#  'Spike of Rotavirus Cases in Omaha',
#  'Spike of Syphilis Cases in West Monroe',
#  'Spike of Tuberculosis Cases in Albuquerque',
#  'Spreading Zika reaches Bacoor',
#  'Spreading Zika ruining Cancun fun',
#  'Spring break ruined by Zika in Fort Lauderdale',
#  'St. Catharines Patient in Critical Condition after Contracting Dengue',
#  'Stony Brook University experts discuss Zika virus',
#  'Student sick in Campinas, Brazil',
#  'Sulu, Zamboanga brace for Zika',
#  'Suva authorities confirmed the spread of Rotavirus',
#  'Swine Flu re-emerges in La Jolla',
#  'Syphilis Hits Jefferson',
#  'Syphilis Outbreak in Harrisburg',
#  'Tallahassee Doctors Discuss Zika Virus',
#  'Tampa Bay Area Zika Case Count Climbs',
#  'Tests negative on Windsor Zika carriers',
#  'Thailand-Zika Virus in Bangkok',
#  'The CDC in Atlanta is Growing Worried',
#  'The Spread of Chikungunya in Arcadia has been Confirmed',
#  'The Spread of Chikungunya in Davidson has been Confirmed',
#  'The Spread of Dengue in Yakima has been Confirmed',
#  'The Spread of Gonorrhea in Reno has been Confirmed',
#  'The Spread of Hepatitis E in Fargo has been Confirmed',
#  'The Spread of Hepatitis E in Lansing has been Confirmed',
#  'The Spread of Herpes in Baku has been Confirmed',
#  'The Spread of Malaria in Brazzaville has been Confirmed',
#  'The Spread of Malaria in Zanzibar has been Confirmed',
#  'The Spread of Measles in Spokane has been Confirmed',
#  'The Spread of Meningitis in Imperial has been Confirmed',
#  'The Spread of Respiratory Syncytial Virus in Monroe has been Confirmed',
#  'The Spread of Rhinovirus in Boardman has been Confirmed',
#  'The Spread of West Nile Virus in Fairfield has been Confirmed',
#  'Tocumen tests new cure for Hepatitis A',
#  'Tokyo Encounters Severe Symptoms of Meningitis',
#  'Toms River Encounters Severe Symptoms of Respiratory Syncytial Virus',
#  'Tourist Perishes from Malaria in Arusha',
#  'Townsville Zika tests inconclusive',
#  'Trinidad confirms first Zika case',
#  'Tuberculosis Hits Luanda',
#  'Tuberculosis Outbreak in Hartford',
#  'Tuberculosis Outbreak in Newark',
#  'Tuberculosis Symptoms Spread all over Caguas',
#  'Tuberculosis has Arrived in Fairfield',
#  'Tuberculosis re-emerges in Silver Springs',
#  'Tupelo Residents Recieve Syphilis vaccine',
#  'Two more Zika cases confirmed in Laredo',
#  'Urbana Encounters Severe Symptoms of Meningitis',
#  'Varicella Exposure in Cambridge',
#  'Varicella Keeps Spreading in Detroit',
#  'Varicella Outbreak in Minot',
#  'Varicella has Arrived in Milton',
#  'Varicella re-emerges in Lagos',
#  'Veracruz hit by Zika Concerns',
#  'Vericella spreading in Ibadan',
#  'Villavicencio under Zika threat',
#  'Vineland authorities confirmed the spread of Chlamydia',
#  'Visitor to Cucuta contracts Zika',
#  'West Nile Virus Exposure in Alpharetta',
#  'West Nile Virus Exposure in Racine',
#  'West Nile Virus Hits Monroe',
#  'West Nile Virus Hits Yogyakarta',
#  'West Nile Virus Keeps Spreading in Hauppauge',
#  'West Nile Virus Outbreak in Louisville',
#  'West Nile Virus Outbreak in Saint Johns',
#  'West Nile Virus Symptoms Spread all over Yerevan',
#  'West Nile Virus has Arrived in Dongguan',
#  'West Nile Virus re-emerges in Wellington',
#  'Will Gonorrhea vaccine help East Moline?',
#  'Will HIV vaccine help Las Vegas?',
#  'Will Hepatitis B vaccine help La Paz?',
#  'Will Herpes vaccine help Newcastle?',
#  'Will MCD vaccine help Strasbourg?',
#  'Will Mad Cow Vaccine Help Bristol?',
#  'Will Measles vaccine help Milford?',
#  'Will Measles vaccine help Sochi?',
#  'Will Meningitis vaccine help Hamburg?',
#  'Will Norovirus vaccine help Raleigh?',
#  'Will Rabies vaccine help Tangier?',
#  'Will Rotavirus vaccine help Addis Ababa?',
#  'Will Swine Flu vaccine help Annapolis?',
#  'Will Swine Flu vaccine help Ljubljana?',
#  'Will Tuberculosis vaccine help Cherry Creek?',
#  'Will Tuberculosis vaccine help Rockville?',
#  'Will West Nile Virus vaccine help Coronado?',
#  'Will West Nile Virus vaccine help Dumai?',
#  'Will West Nile Virus vaccine help Parsons?',
#  'Will the Mad Cow Outbreak Reach Vienna?',
#  'Wisconsin Rapids Patient in Critical Condition after Contracting Chickenpox',
#  'Wuhan is infested with Varicella',
#  'Yulee takes a hit from Spreading Sickness',
#  'Zika Arrives in North Miami',
#  'Zika Concerns are Spreading in Houston',
#  'Zika Infested Monkeys in Sao Paulo',
#  'Zika Mosquitoes May Have Bred in Bromeliads, Florida Officials Say',
#  'Zika Outbreak Hits Miami',
#  'Zika Outbreak in Hyderabad',
#  'Zika Outbreak in Manaus',
#  'Zika Outbreak in Mexicali',
#  'Zika Outbreak in Pinewood',
#  'Zika Outbreak in Puducherry',
#  'Zika Outbreak in Sincelejo',
#  'Zika Outbreak in South Miami',
#  'Zika Outbreak in Weslaco',
#  'Zika Outbreak in Wichita Falls',
#  'Zika Outbreak in Yurimaguas',
#  'Zika Patient in Seminole, Florida',
#  'Zika Reported in Ciudad Acuna',
#  'Zika Reported in Ilopango',
#  'Zika Reported in North Miami Beach',
#  'Zika Reported in Sao Jose',
#  'Zika San Antonio Patient Speaks Out',
#  'Zika Spreads to Palm Beach Gardens',
#  'Zika Strikes St. Petersburg',
#  'Zika Troubles come to Delray Beach',
#  'Zika Troubles come to Greater Noida',
#  'Zika Troubles come to Harlingen',
#  'Zika Troubles come to Jaen',
#  'Zika Troubles come to Kampong Cham',
#  'Zika Troubles come to La Libertad',
#  'Zika Troubles come to Niteroi',
#  'Zika Troubles come to Padre Las Casas',
#  'Zika Virus Arrives in Ontario',
#  'Zika Virus Detected in Lubbock',
#  'Zika Virus Reaches San Francisco',
#  "Zika Virus Sparks 'International Concern'",
#  'Zika Virus Transmission Detected in Havana',
#  'Zika afflicts 7 in Iloilo City',
#  'Zika afflicts patient in Calamba',
#  'Zika alert for Rio Grande Valley residents',
#  'Zika alert â€“ Manila now threatened',
#  'Zika arrives in Belmopan',
#  'Zika arrives in Boca Raton',
#  'Zika arrives in Dangriga',
#  'Zika arrives in Miri',
#  'Zika arrives in Natal',
#  'Zika arrives in Oaxaca',
#  'Zika arrives in Orange City',
#  'Zika arrives in Quezon',
#  'Zika arrives in San Benito',
#  'Zika arrives in San Onofre',
#  'Zika arrives in Santos',
#  'Zika arrives in Tegucigalpa',
#  'Zika arrives in Udon Thani',
#  'Zika arrives in West Palm Beach',
#  'Zika battle outlined at Valdosta meeting',
#  'Zika case confirmed in Lorain',
#  'Zika case recorded in Tunapuna Â»',
#  'Zika case reported in Abilene',
#  'Zika case reported in Antioquia',
#  'Zika case reported in Coral Gables',
#  'Zika case reported in Jacobina',
#  'Zika case reported in Jupiter',
#  'Zika case reported in Limoeiro',
#  'Zika case reported in Los Fresnos',
#  'Zika case reported in Medellin',
#  'Zika case reported in Oton',
#  'Zika case reported in Phetchabun',
#  'Zika case reported in Reynosa',
#  'Zika case reported in Rizal',
#  'Zika cases concern Charlotte residents',
#  'Zika cases in Singapore reach 393',
#  "Zika cases in Vietnam's Ho Chi Minh City surge",
#  'Zika in Belmont, Belmont worry',
#  'Zika in Tamarac!',
#  'Zika infects pregnant woman in Cebu',
#  'Zika investigators coming to Mankato',
#  'Zika now spreading through Jakarta',
#  'Zika only the latest mosquito-borne threat to New Orleans',
#  'Zika outbreak in Piracicaba, Brazil',
#  'Zika outbreak spreads to Mexico City',
#  'Zika reaches Johor Bahru, Malaysia',
#  'Zika reported in Fort Pierce',
#  'Zika seminars in Yuma County',
#  'Zika spreading to Salvador',
#  'Zika spreads to Barranquilla',
#  'Zika spreads to Caucasia',
#  'Zika spreads to Daytona Beach',
#  'Zika spreads to Kamphaeng Phet',
#  'Zika spreads to Kissimmee',
#  'Zika spreads to Kuching',
#  'Zika spreads to La Joya',
#  'Zika spreads to Lewisville',
#  'Zika spreads to Olinda',
#  'Zika spreads to Plant City',
#  'Zika spreads to San Luis Potosi',
#  'Zika spreads to Winter Park',
#  'Zika surfaces in Klang, Malaysia',
#  'Zika symptoms spotted in Arlington',
#  'Zika symptoms spotted in Bello',
#  'Zika symptoms spotted in Bonita Springs',
#  'Zika symptoms spotted in Boynton Beach',
#  'Zika symptoms spotted in Colombo',
#  'Zika symptoms spotted in Fortaleza',
#  'Zika symptoms spotted in Hollywood',
#  'Zika symptoms spotted in Iquitos',
#  'Zika symptoms spotted in Quisqueya',
#  'Zika symptoms spotted in Quito',
#  'Zika symptoms spotted in Quixere',
#  'Zika symptoms spotted in Sibu',
#  'Zika symptoms spotted in Surat',
#  'Zika symtomps spotted in Key West',
#  'Zika virus case reported in Rockland',
#  'Zika virus confirmed in Westchester',
#  'Zika virus reported in Cleveland',
#  'Zika worries in San Salvador',
#  'Zika-carrying mosquitoes discovered in Ardmore',
#  'Zika: Delhi for strict monitoring']

# %% [markdown]
# Comments on the cities appearing in each headline:
# - Has to rely on external data to figure out city names
# - There are city names with multiple words
# - City name require case-insensitve matching and accent marks removed

# %% [markdown]
# ## Workflow #2 ##
# Using regular expressions and the cities and countries within the geonamescache library, match any cities/countries within each headline.
# - Make sure to normalize headlines and city/country names by removing accent marks. This can be done with the unidecode library.
# - Watch out for multiple cities in a headline and matches on short words! We want the match to be on the entire city—for example San Marino—and not a partial match—San.

# %%
from unidecode import unidecode
import re

def name_to_regex(name):
    decoded_name = unidecode(name)
    if name != decoded_name:
        regex = fr'\b({name}|{decoded_name})\b'
    else:
        regex = fr'\b{name}\b'
    return re.compile(regex, flags=re.IGNORECASE)

# %%
unidecode('Shibirghān')
# Out:
# 'Shibirghan'

# %%
def get_name_in_text(text, dictionary):
    for regex, name in sorted(dictionary.items(), key=lambda x: x[1]):
        if regex.search(text):
            return name
    return None

# %%
from geonamescache import GeonamesCache
gc = GeonamesCache()

countries = [country['name'] for country in gc.get_countries().values()]
country_to_name = {name_to_regex(name): name for name in countries}

cities = [city['name'] for city in gc.get_cities().values()]
city_to_name = {name_to_regex(name): name for name in cities}

# %%
countries
# Out:
# ['Andorra',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Antigua and Barbuda',
#  'Anguilla',
#  'Albania',
#  'Armenia',
#  'Angola',
#  'Antarctica',
#  'Argentina',
#  'American Samoa',
#  'Austria',
#  'Australia',
#  'Aruba',
#  'Aland Islands',
#  'Azerbaijan',
#  'Bosnia and Herzegovina',
#  'Barbados',
#  'Bangladesh',
#  'Belgium',
#  'Burkina Faso',
#  'Bulgaria',
#  'Bahrain',
#  'Burundi',
#  'Benin',
#  'Saint Barthelemy',
#  'Bermuda',
#  'Brunei',
#  'Bolivia',
#  'Bonaire, Saint Eustatius and Saba ',
#  'Brazil',
#  'Bahamas',
#  'Bhutan',
#  'Bouvet Island',
#  'Botswana',
#  'Belarus',
#  'Belize',
#  'Canada',
#  'Cocos Islands',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Republic of the Congo',
#  'Switzerland',
#  'Ivory Coast',
#  'Cook Islands',
#  'Chile',
#  'Cameroon',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Cabo Verde',
#  'Curacao',
#  'Christmas Island',
#  'Cyprus',
#  'Czechia',
#  'Germany',
#  'Djibouti',
#  'Denmark',
#  'Dominica',
#  'Dominican Republic',
#  'Algeria',
#  'Ecuador',
#  'Estonia',
#  'Egypt',
#  'Western Sahara',
#  'Eritrea',
#  'Spain',
#  'Ethiopia',
#  'Finland',
#  'Fiji',
#  'Falkland Islands',
#  'Micronesia',
#  'Faroe Islands',
#  'France',
#  'Gabon',
#  'United Kingdom',
#  'Grenada',
#  'Georgia',
#  'French Guiana',
#  'Guernsey',
#  'Ghana',
#  'Gibraltar',
#  'Greenland',
#  'Gambia',
#  'Guinea',
#  'Guadeloupe',
#  'Equatorial Guinea',
#  'Greece',
#  'South Georgia and the South Sandwich Islands',
#  'Guatemala',
#  'Guam',
#  'Guinea-Bissau',
#  'Guyana',
#  'Hong Kong',
#  'Heard Island and McDonald Islands',
#  'Honduras',
#  'Croatia',
#  'Haiti',
#  'Hungary',
#  'Indonesia',
#  'Ireland',
#  'Israel',
#  'Isle of Man',
#  'India',
#  'British Indian Ocean Territory',
#  'Iraq',
#  'Iran',
#  'Iceland',
#  'Italy',
#  'Jersey',
#  'Jamaica',
#  'Jordan',
#  'Japan',
#  'Kenya',
#  'Kyrgyzstan',
#  'Cambodia',
#  'Kiribati',
#  'Comoros',
#  'Saint Kitts and Nevis',
#  'North Korea',
#  'South Korea',
#  'Kosovo',
#  'Kuwait',
#  'Cayman Islands',
#  'Kazakhstan',
#  'Laos',
#  'Lebanon',
#  'Saint Lucia',
#  'Liechtenstein',
#  'Sri Lanka',
#  'Liberia',
#  'Lesotho',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'Libya',
#  'Morocco',
#  'Monaco',
#  'Moldova',
#  'Montenegro',
#  'Saint Martin',
#  'Madagascar',
#  'Marshall Islands',
#  'North Macedonia',
#  'Mali',
#  'Myanmar',
#  'Mongolia',
#  'Macao',
#  'Northern Mariana Islands',
#  'Martinique',
#  'Mauritania',
#  'Montserrat',
#  'Malta',
#  'Mauritius',
#  'Maldives',
#  'Malawi',
#  'Mexico',
#  'Malaysia',
#  'Mozambique',
#  'Namibia',
#  'New Caledonia',
#  'Niger',
#  'Norfolk Island',
#  'Nigeria',
#  'Nicaragua',
#  'Netherlands',
#  'Norway',
#  'Nepal',
#  'Nauru',
#  'Niue',
#  'New Zealand',
#  'Oman',
#  'Panama',
#  'Peru',
#  'French Polynesia',
#  'Papua New Guinea',
#  'Philippines',
#  'Pakistan',
#  'Poland',
#  'Saint Pierre and Miquelon',
#  'Pitcairn',
#  'Puerto Rico',
#  'Palestinian Territory',
#  'Portugal',
#  'Palau',
#  'Paraguay',
#  'Qatar',
#  'Reunion',
#  'Romania',
#  'Serbia',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Solomon Islands',
#  'Seychelles',
#  'Sudan',
#  'South Sudan',
#  'Sweden',
#  'Singapore',
#  'Saint Helena',
#  'Slovenia',
#  'Svalbard and Jan Mayen',
#  'Slovakia',
#  'Sierra Leone',
#  'San Marino',
#  'Senegal',
#  'Somalia',
#  'Suriname',
#  'Sao Tome and Principe',
#  'El Salvador',
#  'Sint Maarten',
#  'Syria',
#  'Eswatini',
#  'Turks and Caicos Islands',
#  'Chad',
#  'French Southern Territories',
#  'Togo',
#  'Thailand',
#  'Tajikistan',
#  'Tokelau',
#  'Timor Leste',
#  'Turkmenistan',
#  'Tunisia',
#  'Tonga',
#  'Turkey',
#  'Trinidad and Tobago',
#  'Tuvalu',
#  'Taiwan',
#  'Tanzania',
#  'Ukraine',
#  'Uganda',
#  'United States Minor Outlying Islands',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Vatican',
#  'Saint Vincent and the Grenadines',
#  'Venezuela',
#  'British Virgin Islands',
#  'U.S. Virgin Islands',
#  'Vietnam',
#  'Vanuatu',
#  'Wallis and Futuna',
#  'Samoa',
#  'Yemen',
#  'Mayotte',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe',
#  'Serbia and Montenegro',
#  'Netherlands Antilles']

# %%
cities
# Out:
# ['Andorra la Vella',
#  'Umm Al Quwain City',
#  'Ras Al Khaimah City',
#  'Zayed City',
#  'Khawr Fakkān',
#  'Dubai',
#  'Dibba Al-Fujairah',
#  'Dibba Al-Hisn',
#  'Sharjah',
#  'Ar Ruways',
#  'Al Fujairah City',
#  'Al Ain City',
#  'Ajman City',
#  'Adh Dhayd',
#  'Abu Dhabi',
#  'Khalifah A City',
#  'Bani Yas City',
#  'Musaffah',
#  'Al Shamkhah City',
#  'Reef Al Fujairah City',
#  'Zaranj',
#  'Taloqan',
#  'Shīnḏanḏ',
#  'Shibirghān',
#  'Shahrak',
#  'Sar-e Pul',
#  'Sang-e Chārak',
#  'Aībak',
#  'Rustāq',
#  'Qarqīn',
#  'Qarāwul',
#  'Pul-e Khumrī',
#  'Paghmān',
#  'Nahrīn',
#  'Maymana',
#  'Mehtar Lām',
#  'Mazār-e Sharīf',
#  'Lashkar Gāh',
#  'Kushk',
#  'Kunduz',
#  'Khōst',
#  'Khulm',
#  'Khāsh',
#  'Khanabad',
#  'Karukh',
#  'Kandahār',
#  'Kabul',
#  'Jalālābād',
#  'Jabal os Saraj',
#  'Herāt',
#  'Ghormach',
#  'Ghazni',
#  'Gereshk',
#  'Gardez',
#  'Fayzabad',
#  'Farah',
#  'Kafir Qala',
#  'Charikar',
#  'Baraki Barak',
#  'Bāmyān',
#  'Balkh',
#  'Baghlān',
#  'Ārt Khwājah',
#  'Āsmār',
#  'Asadābād',
#  'Andkhōy',
#  'Bāzārak',
#  'Markaz-e Woluswalī-ye Āchīn',
#  'Saint John’s',
#  'The Valley',
#  'Sarandë',
#  'Pogradec',
#  'Kukës',
#  'Korçë',
#  'Gjirokastër',
#  'Elbasan',
#  'Burrel',
#  'Vlorë',
#  'Tirana',
#  'Shkodër',
#  'Patos Fshat',
#  'Patos',
#  'Lushnjë',
#  'Lezhë',
#  'Laç',
#  'Kuçovë',
#  'Krujë',
#  'Kavajë',
#  'Fier-Çifçi',
#  'Fier',
#  'Durrës',
#  'Berat',
#  'Kapan',
#  'Goris',
#  'Hats’avan',
#  'Artashat',
#  'Ararat',
#  'Yerevan',
#  'Vagharshapat',
#  'Step’anavan',
#  'Spitak',
#  'Sevan',
#  'Masis',
#  'Vanadzor',
#  'Gavarr',
#  'Hrazdan',
#  'Armavir',
#  'Gyumri',
#  'Ashtarak',
#  'Abovyan',
#  'Saurimo',
#  'Lucapa',
#  'Luau',
#  'Uíge',
#  'Soio',
#  "N'zeto",
#  'N’dalatando',
#  'Mbanza Congo',
#  'Malanje',
#  'Luanda',
#  'Caxito',
#  'Cabinda',
#  'Sumbe',
#  'Namibe',
#  'Menongue',
#  'Luena',
#  'Lubango',
#  'Longonjo',
#  'Lobito',
#  'Cuito',
#  'Huambo',
#  'Catumbela',
#  'Catabola',
#  'Camacupa',
#  'Caála',
#  'Benguela',
#  'Zárate',
#  'Wanda',
#  'Villa Ortúzar',
#  'Villa Ocampo',
#  'Villa Lugano',
#  'Villaguay',
#  'Villa Gesell',
#  'Villa de Mayo',
#  'Tortuguitas',
#  'Tigre',
#  'Tandil',
#  'San Vicente',
#  'Santo Tomé',
#  'Santa Elena',
#  'San Pedro',
#  'San Pedro',
#  'San Luis del Palmar',
#  'San Lorenzo',
#  'San Javier',
#  'San Isidro',
#  'Saladas',
#  'Retiro',
#  'Resistencia',
#  'Reconquista',
#  'Quilmes',
#  'Puerto Rico',
#  'Puerto Iguazú',
#  'Puerto Esperanza',
#  'Puerto Eldorado',
#  'Posadas',
#  'Pontevedra',
#  'Pirané',
#  'Pilar',
#  'Paso de los Libres',
#  'Oberá',
#  'Necochea',
#  'Muñiz',
#  'Morón',
#  'Monte Caseros',
#  'Montecarlo',
#  'Merlo',
#  'Mercedes',
#  'Mercedes',
#  'Mar del Plata',
#  'Luján',
#  'Los Polvorines',
#  'La Plata',
#  'La Paz',
#  'Jardín América',
#  'Hurlingham',
#  'Gualeguaychú',
#  'Gualeguay',
#  'Goya',
#  'Gobernador Virasora',
#  'General Pacheco',
#  'General José de San Martín',
#  'Garupá',
#  'Formosa',
#  'Fontana',
#  'Federal',
#  'Esquina',
#  'El Soberbio',
#  'Don Torcuato',
#  'Dolores',
#  'Curuzú Cuatiá',
#  'Corrientes',
#  'Concordia',
#  'Concepción del Uruguay',
#  'Colegiales',
#  'Chajarí',
#  'Campana',
#  'Buenos Aires',
#  'Boedo',
#  'Berazategui',
#  'Belgrano',
#  'Barranqueras',
#  'Barracas',
#  'Balcarce',
#  'Azul',
#  'Avellaneda',
#  'Aristóbulo del Valle',
#  'Zapala',
#  'Yerba Buena',
#  'Villa Regina',
#  'Villa Paula de Sarmiento',
#  'Villa Nueva',
#  'Villa María',
#  'Villa Dolores',
#  'Villa Constitución',
#  'Villa Carlos Paz',
#  'Villa Ángela',
#  'Villa Allende',
#  'Viedma',
#  'Victoria',
#  'Vera',
#  'Venado Tuerto',
#  'Veinticinco de Mayo',
#  'Ushuaia',
#  'Unquillo',
#  'Tres Isletas',
#  'Tres Arroyos',
#  'Trelew',
#  'Termas de Río Hondo',
#  'Tartagal',
#  'Tafí Viejo',
#  'Sunchales',
#  'Santo Tomé',
#  'Santiago del Estero',
#  'Santa Rosa',
#  'Santa Lucía',
#  'Santa Fe',
#  'San Salvador de Jujuy',
#  'San Ramón de la Nueva Orán',
#  'San Rafael',
#  'San Pedro de Jujuy',
#  'San Nicolás de los Arroyos',
#  'San Miguel de Tucumán',
#  'San Martín de los Andes',
#  'San Martín',
#  'San Luis',
#  'San Justo',
#  'San Juan',
#  'San José de Jáchal',
#  'San Jorge',
#  'San Francisco',
#  'San Fernando del Valle de Catamarca',
#  'San Antonio Oeste',
#  'Salta',
#  'Rufino',
#  'Rosario',
#  'Río Tercero',
#  'Río Segundo',
#  'Río Grande',
#  'Río Gallegos',
#  'Río Cuarto',
#  'Río Ceballos',
#  'Rawson',
#  'Rafaela',
#  'Quitilipi',
#  'Punta Alta',
#  'Puerto Madryn',
#  'Presidencia Roque Sáenz Peña',
#  'Pocito',
#  'Plottier',
#  'Pergamino',
#  'Pérez',
#  'Paraná',
#  'Palpalá',
#  'Olavarría',
#  'Nueve de Julio',
#  'Neuquén',
#  'Morteros',
#  'Monteros',
#  'Mendoza',
#  'Marcos Juárez',
#  'Machagai',
#  'Lincoln',
#  'Libertador General San Martín',
#  'Las Breñas',
#  'La Rioja',
#  'La Falda',
#  'La Calera',
#  'Laboulaye',
#  'Junín',
#  'Joaquín V. González',
#  'Jesús María',
#  'Granadero Baigorria',
#  'Gobernador Gálvez',
#  'General Villegas',
#  'General Roca',
#  'General Pinedo',
#  'General Pico',
#  'General Enrique Mosconi',
#  'Gálvez',
#  'Firmat',
#  'Famaillá',
#  'Esquel',
#  'Esperanza',
#  'Embarcación',
#  'Embalse',
#  'El Bolsón',
#  'Diamante',
#  'Deán Funes',
#  'Cutral-Có',
#  'Cruz del Eje',
#  'Crespo',
#  'Cosquín',
#  'Coronel Suárez',
#  'Coronda',
#  'Córdoba',
#  'Comodoro Rivadavia',
#  'Cipolletti',
#  'Cinco Saltos',
#  'Chivilcoy',
#  'Chimbas',
#  'Chilecito',
#  'Charata',
#  'Chacabuco',
#  'Centenario',
#  'Caucete',
#  'Catriel',
#  'Castelli',
#  'Casilda',
#  'Carcarañá',
#  'Capitán Bermúdez',
#  'Cañada de Gómez',
#  'Caleta Olivia',
#  'Bell Ville',
#  'Bella Vista',
#  'Bahía Blanca',
#  'Arroyo Seco',
#  'Arroyito',
#  'Añatuya',
#  'Alta Gracia',
#  'Allen',
#  'Alderetes',
#  'Albardón',
#  'Aguilares',
#  'Balvanera',
#  'Villa Santa Rita',
#  'Villa Mercedes',
#  'San Miguel',
#  'San Carlos de Bariloche',
#  'Adrogué',
#  'Ingeniero Pablo Nogués',
#  'José C. Paz',
#  'Pago Pago',
#  'Wilten',
#  'Wiener Neustadt',
#  'Vienna',
#  'Wetzelsdorf',
#  'Wels',
#  'Weinzierl bei Krems',
#  'Villach',
#  'Telfs',
#  'Straßgang',
#  'Stockerau',
#  'Steyr',
#  'Simmering',
#  'Sankt Pölten',
#  'Sankt Peter',
#  'Sankt Peter',
#  'Sankt Martin',
#  'Salzburg',
#  'Pradl',
#  'Perchtoldsdorf',
#  'Ottakring',
#  'Mödling',
#  'Meidling',
#  'Lustenau',
#  'Linz',
#  'Klosterneuburg',
#  'Klagenfurt am Wörthersee',
#  'Innsbruck',
#  'Innere Stadt',
#  'Hötting',
#  'Hohenems',
#  'Hietzing',
#  'Hernals',
#  'Graz',
#  'Floridsdorf',
#  'Feldkirch',
#  'Eggenberg',
#  'Dornbirn',
#  'Bregenz',
#  'Baden',
#  'Amstetten',
#  'Favoriten',
#  'Donaustadt',
#  'Jakomini',
#  'Lend',
#  'Geidorf',
#  'Sankt Leonhard',
#  'Andritz',
#  'Gries',
#  'Scarborough',
#  'Rockingham',
#  'Perth',
#  'Mount Isa',
#  'Morphett Vale',
#  'Mandurah',
#  'Kwinana',
#  'Gosnells',
#  'Geraldton',
#  'Gawler',
#  'Darwin',
#  'Busselton',
#  'Bunbury',
#  'Alice Springs',
#  'Albany',
#  'Adelaide',
#  'Wodonga',
#  'Wheelers Hill',
#  'Westmead',
#  'Werribee',
#  'Warrnambool',
#  'Warragul',
#  'Wantirna South',
#  'Wangaratta',
#  'Wahroonga',
#  'Upper Coomera',
#  'Truganina',
#  'Traralgon',
#  'Townsville',
#  'Toowoomba',
#  'Thornbury',
#  'Thomastown',
#  'Templestowe',
#  'Tarneit',
#  'Taree',
#  'Tamworth',
#  'Sydney',
#  'Surry Hills',
#  'Surfers Paradise',
#  'Sunbury',
#  'Strathfield',
#  'Springvale',
#  'South Yarra',
#  'Southport',
#  'Shepparton',
#  'Seven Hills',
#  'Seaford',
#  'Saint Kilda',
#  'Saint Ives',
#  'Saint Albans',
#  'Ryde',
#  'Rowville',
#  'Rockhampton',
#  'Rockdale',
#  'Ringwood',
#  'Richmond',
#  'Reservoir',
#  'Quakers Hill',
#  'Preston',
#  'Port Melbourne',
#  'Port Macquarie',
#  'Point Cook',
#  'Pascoe Vale',
#  'Palm Beach',
#  'Pakenham',
#  'Orange',
#  'North Melbourne',
#  'Northcote',
#  'Noble Park',
#  'Newcastle',
#  'Nerang',
#  'Narre Warren',
#  'Narangba',
#  'Mulgrave',
#  'Mount Waverley',
#  'Mount Martha',
#  'Mount Gambier',
#  'Mount Eliza',
#  'Mount Druitt',
#  'Mosman',
#  'Mornington',
#  'Morayfield',
#  'South Morang',
#  'Mooroolbark',
#  'Mitcham',
#  'Miranda',
#  'Mill Park',
#  'Mildura',
#  'Merrylands',
#  'Mernda',
#  'Melbourne',
#  'Mascot',
#  'Maryborough',
#  'Marrickville',
#  'Maroubra',
#  'Manly',
#  'Maitland',
#  'Mackay',
#  'Liverpool',
#  'Lilydale',
#  'Lidcombe',
#  'Launceston',
#  'Lara',
#  'Langwarrin',
#  'Lalor',
#  'Lakemba',
#  'Kogarah',
#  'Keysborough',
#  'Kew',
#  'Kensington',
#  'Hornsby',
#  'Hobart',
#  'Hawthorn South',
#  'Hawthorn',
#  'Hampton Park',
#  'Griffith',
#  'Greenvale',
#  'Greensborough',
#  'Granville',
#  'Goulburn',
#  'Gold Coast',
#  'Glen Waverley',
#  'Glenroy',
#  'Glen Iris',
#  'Glenferrie',
#  'Gladstone',
#  'Geelong',
#  'Frankston East',
#  'Frankston',
#  'Footscray',
#  'Fairfield',
#  'Essendon',
#  'Epping',
#  'Epping',
#  'Engadine',
#  'Eltham',
#  'Eight Mile Plains',
#  'Eastwood',
#  'Earlwood',
#  'Dubbo',
#  'Doreen',
#  'Doncaster East',
#  'Doncaster',
#  'Deer Park',
#  'Deception Bay',
#  'Dandenong',
#  'Croydon',
#  'Cronulla',
#  'Cranbourne',
#  'Craigieburn',
#  'Corio',
#  'Coorparoo',
#  'Coogee',
#  'Coffs Harbour',
#  'Coburg',
#  'Clayton',
#  'Wollongong',
#  'Chatswood',
#  'Cessnock',
#  'Castle Hill',
#  'Carrum Downs',
#  'Carnegie',
#  'Carlton',
#  'Carlingford',
#  'Capalaba',
#  'Canberra',
#  'Camberwell',
#  'Cairns',
#  'Caboolture',
#  'Burwood',
#  'Burnie',
#  'Bundaberg',
#  'Buderim',
#  'Brunswick',
#  'Broken Hill',
#  'Brisbane',
#  'Brighton',
#  'Boronia',
#  'Blacktown',
#  'Bexley',
#  'Berwick',
#  'Bentleigh East',
#  'Bentleigh',
#  'Bendigo',
#  'Baulkham Hills',
#  'Bathurst',
#  'Banora Point',
#  'Bankstown',
#  'Ballarat',
#  'Auburn',
#  'Ashfield',
#  'Armidale',
#  'Albany Creek',
#  'Maroochydore',
#  'Cheltenham',
#  'Randwick',
#  'Dee Why',
#  'Umina Beach',
#  'Palmerston',
#  'Hervey Bay',
#  'Sydney Central Business District',
#  'Kingsford',
#  'Springfield Lakes',
#  'Bracken Ridge',
#  'Kallangur',
#  'North Lakes',
#  'The Gap',
#  'Caroline Springs',
#  'Hoppers Crossing',
#  'Logan City',
#  'Carindale',
#  'Parramatta',
#  'Ferntree Gully',
#  'Adelaide Hills',
#  'Canning Vale',
#  'Glenmore Park',
#  'Southbank',
#  'Helensvale',
#  'Melton West',
#  'Elwood',
#  'Balwyn North',
#  'Malvern East',
#  'Brighton East',
#  'Redbank Plains',
#  'Labrador',
#  'St Albans',
#  'Endeavour Hills',
#  'Kellyville',
#  'Taylors Lakes',
#  'Cherrybrook',
#  'Roxburgh Park',
#  'Prestons',
#  'Wyndham Vale',
#  'Ballajura',
#  'Willetton',
#  'Glenwood',
#  'Cabramatta',
#  'Campsie',
#  'Casula',
#  'Cranebrook',
#  'Greenacre',
#  'Greystanes',
#  'Ellenbrook',
#  'Alexandra Hills',
#  'Calamvale',
#  'Yagoona',
#  'Highton',
#  'Pacific Pines',
#  'Robina',
#  'Paralowie',
#  'Baldivis',
#  'Dianella',
#  'Morley',
#  'Thornlie',
#  'Punchbowl',
#  'Parafield Gardens',
#  'Hillside',
#  'St Clair',
#  'Kirwan',
#  'Bundoora',
#  'Forest Lake',
#  'Sunnybank Hills',
#  'Rochedale South',
#  'Cranbourne East',
#  'Cranbourne North',
#  'Narre Warren South',
#  'Dandenong North',
#  'Frankston South',
#  'Sunshine West',
#  'Altona Meadows',
#  'Hurstville',
#  'West Pennant Hills',
#  'Melbourne City Centre',
#  'Adelaide city centre',
#  'Wollongong city centre',
#  'Tanki Leendert',
#  'San Nicolas',
#  'Oranjestad',
#  'Mariehamn',
#  'Xankandi',
#  'Əhmədbəyli',
#  'Shushi',
#  'Salyan',
#  'Saatlı',
#  'Neftçala',
#  'Nakhchivan',
#  'Lankaran',
#  'Imishli',
#  'Fizuli',
#  'Jalilabad',
#  'Pushkino',
#  'Beylagan',
#  'Astara',
#  'Şirvan',
#  'Ağdam',
#  'Zaqatala',
#  'Zabrat',
#  'Yevlakh',
#  'Yelenendorf',
#  'Xaçmaz',
#  'Ujar',
#  'Terter',
#  'Sumqayıt',
#  'Qaraçuxur',
#  'Shamkhor',
#  'Shamakhi',
#  'Sheki',
#  'Sabunçu',
#  'Sabirabad',
#  'Qusar',
#  'Quba',
#  'Hacıqabul',
#  'Qazax',
#  'Hacı Zeynalabdin',
#  'Mingelchaur',
#  'Maştağa',
#  'Mardakan',
#  'Lökbatan',
#  'Kyurdarmir',
#  'Khirdalan',
#  'Yeni Suraxanı',
#  'Geoktschai',
#  'Hövsan',
#  'Ganja',
#  'Divichibazar',
#  'Buzovna',
#  'Biny Selo',
#  'Barda',
#  'Bilajari',
#  'Baku',
#  'Amirdzhan',
#  'Aghsu',
#  'Ağdaş',
#  'Agdzhabedy',
#  'Bakıxanov',
#  'Zenica',
#  'Visoko',
#  'Velika Kladuša',
#  'Tuzla',
#  'Trebinje',
#  'Travnik',
#  'Sarajevo',
#  'Prijedor',
#  'Mostar',
#  'Gradačac',
#  'Gračanica',
#  'Goražde',
#  'Doboj',
#  'Cazin',
#  'Bugojno',
#  'Brčko',
#  'Bosanska Krupa',
#  'Bijeljina',
#  'Bihać',
#  'Banja Luka',
#  'Konjic',
#  'Bridgetown',
#  'Thākurgaon',
#  'Teknāf',
#  'Tungi',
#  'Sylhet',
#  'Dohār',
#  'Jamālpur',
#  'Shibganj',
#  'Shibganj',
#  'Sātkhira',
#  'Sirajganj',
#  'Netrakona',
#  'Narsingdi',
#  'Sandwīp',
#  'Shāhzādpur',
#  'Rāmganj',
#  'Rājshāhi',
#  'Pirojpur',
#  'Panchagarh',
#  'Patiya',
#  'Parbatipur',
#  'Nārāyanganj',
#  'Nālchiti',
#  'Nāgarpur',
#  'Nageswari',
#  'Mymensingh',
#  'Muktāgācha',
#  'Mirzāpur',
#  'Maulavi Bāzār',
#  'Morrelgonj',
#  'Mehendiganj',
#  'Mathba',
#  'Lalmonirhat',
#  'Lākshām',
#  'Comilla',
#  'Rangpur',
#  'Kushtia',
#  'Kālīganj',
#  'Jhingergācha',
#  'Joypur Hāt',
#  'Ishurdi',
#  'Habiganj',
#  'Gaurnadi',
#  'Gafargaon',
#  'Feni',
#  'Rāipur',
#  'Sarankhola',
#  'Dhaka',
#  'Chilmāri',
#  'Chhāgalnāiya',
#  'Lālmohan',
#  'Khagrachhari',
#  'Chhātak',
#  'Bhātpāra Abhaynagar',
#  'Bherāmāra',
#  'Bhairab Bāzār',
#  'Bāndarban',
#  'Kālia',
#  'Baniachang',
#  'Bājitpur',
#  'Bagerhat',
#  'Badarganj',
#  'Narail',
#  'Tungipāra',
#  'Sonārgaon',
#  'Sarishābāri',
#  'Sakhipur',
#  'Raojān',
#  'Phultala',
#  'Pālang',
#  'Pār Naogaon',
#  'Nabīnagar',
#  'Lakshmīpur',
#  'Kesabpur',
#  'Hājīganj',
#  'Farīdpur',
#  'Dinājpur',
#  'Uttar Char Fasson',
#  'Chittagong',
#  'Char Bhadrāsan',
#  'Bera',
#  'Burhānuddin',
#  'Sātkania',
#  'Cox’s Bāzār',
#  'Khulna',
#  'Bhola',
#  'Barisāl',
#  'Jessore',
#  'Pābna',
#  'Tāngāil',
#  'Bogra',
#  'Pīrgaaj',
#  'Nawābganj',
#  'Mādārīpur',
#  'Sherpur',
#  'Kishorganj',
#  'Manikchari',
#  'Bhāndāria',
#  'Bibir Hat',
#  'Saidpur',
#  'Puthia',
#  'Natore',
#  'Azimpur',
#  'Paltan',
#  'Joymontop',
#  'Zwijndrecht',
#  'Zwevegem',
#  'Zottegem',
#  'Zonhoven',
#  'Zoersel',
#  'Zemst',
#  'Zele',
#  'Zedelgem',
#  'Zaventem',
#  'Wuustwezel',
#  'Willebroek',
#  'Wevelgem',
#  'Wetteren',
#  'Westerlo',
#  'Wervik',
#  'Wavre',
#  'Waterloo',
#  'Waregem',
#  'Walcourt',
#  'Visé',
#  'Vilvoorde',
#  'Verviers',
#  'Turnhout',
#  'Tubize',
#  'Tournai',
#  'Torhout',
#  'Tongeren',
#  'Tienen',
#  'Tielt',
#  'Tessenderlo',
#  'Tervuren',
#  'Temse',
#  'Stekene',
#  'Stabroek',
#  'Soumagne',
#  'Soignies',
#  'Sint-Truiden',
#  'Sint-Pieters-Leeuw',
#  'Sint-Niklaas',
#  'Sint-Kruis',
#  'Sint-Katelijne-Waver',
#  'Sint-Gillis-Waas',
#  'Sint-Genesius-Rode',
#  'Seraing',
#  'Schoten',
#  'Schilde',
#  'Saint-Nicolas',
#  'Saint-Ghislain',
#  'Rotselaar',
#  'Ronse',
#  'Roeselare',
#  'Rixensart',
#  'Riemst',
#  'Ranst',
#  'Quaregnon',
#  'Puurs',
#  'Putte',
#  'Poperinge',
#  'Pont-à-Celles',
#  'Péruwelz',
#  'Peer',
#  'Overijse',
#  'Oupeye',
#  'Oudenaarde',
#  'Oostkamp',
#  'Ostend',
#  'Nivelles',
#  'Ninove',
#  'Nijlen',
#  'Neerpelt',
#  'Namur',
#  'Mouscron',
#  'Mortsel',
#  'Morlanwelz-Mariemont',
#  'Mons',
#  'Mol',
#  'Middelkerke',
#  'Merelbeke',
#  'Menen',
#  'Meise',
#  'Mechelen',
#  'Marche-en-Famenne',
#  'Manage',
#  'Maldegem',
#  'Maasmechelen',
#  'Maaseik',
#  'Louvain-la-Neuve',
#  'Londerzeel',
#  'Lommel',
#  'Lokeren',
#  'Lochristi',
#  'Lille',
#  'Lier',
#  'Liège',
#  'Leuven',
#  'Lessines',
#  'Lede',
#  'Lebbeke',
#  'Lanaken',
#  'La Louvière',
#  'Kortrijk',
#  'Kortenberg',
#  'Kontich',
#  'Koksijde',
#  'Knokke-Heist',
#  'Kasterlee',
#  'Kapellen',
#  'Kalmthout',
#  'Izegem',
#  'Ieper',
#  'Huy',
#  'Houthalen',
#  'Hoogstraten',
#  'Hoboken',
#  'Heusden',
#  'Herzele',
#  'Herve',
#  'Herstal',
#  'Herentals',
#  'Herent',
#  'Helchteren',
#  'Heist-op-den-Berg',
#  'Hasselt',
#  'Harelbeke',
#  'Hamme',
#  'Halle',
#  'Haaltert',
#  'Grimbergen',
#  ...]

# %%
cities.sort()
print(cities)
# Out:
# ["'Ali Sabieh", "'s-Gravenzande", "'s-Hertogenbosch", 'A Coruña', 'A Estrada', 'Aabenraa', 'Aachen', 'Aalborg', 'Aalen', 'Aalsmeer', 'Aalst', 'Aalten', 'Aalter', 'Aarau', 'Aarschot', 'Aba', 'Abadan', 'Abadan', 'Abaetetuba', 'Abaeté', 'Abakaliki', 'Abakan', 'Abancay', 'Abano Terme', 'Abashiri', 'Abasolo', 'Abay', 'Abaza', 'Abbeville', 'Abbiategrasso', 'Abbotsford', 'Abbottabad', 'Abdulino', 'Abengourou', 'Abeokuta', 'Abepura', 'Aberdare', 'Aberdeen', 'Aberdeen', 'Aberdeen', 'Aberdeen', 'Abergele', 'Aberystwyth', 'Abha', 'Abhar', 'Abhayāpuri', 'Abidjan', 'Abiko', 'Abilene', 'Abingdon', 'Abington', 'Abinsk', 'Abnūb', 'Abobo', 'Abohar', 'Aboisso', 'Abomey', 'Abomey-Calavi', 'Abomsa', 'Abony', 'Abou el Hassan', 'Abovyan', 'Abqaiq', 'Abrama', 'Abreu e Lima', 'Abreus', 'Abrīsham', 'Abu Dhabi', 'Abu Jibeha', 'Abucay', 'Abuja', 'Aburi', 'Abuyog', 'Abéché', 'Abū Ghurayb', 'Abū Kabīr', 'Abū Qurqāş', 'Abū Tīj', 'Abū Zabad', 'Abū al Maţāmīr', 'Abū ‘Arīsh', 'Acacías', 'Acajete', 'Acajutla', 'Acaponeta', 'Acapulco de Juárez', 'Acaraú', 'Acarigua', 'Acatlán de Osorio', 'Acatzingo', 'Acayucan', 'Accra', 'Accrington', 'Acerra', 'Achalpur', 'Acharnés', 'Acheng', 'Achern', 'Achhnera', 'Achim', 'Achinsk', 'Achkhoy-Martan', 'Achères', 'Aci Castello', 'Aci Catena', 'Acilia-Castel Fusano-Ostia Antica', 'Acireale', 'Acocks Green', 'Acopiara', 'Acquaviva delle Fonti', 'Acqui Terme', 'Acre', 'Acton', 'Acton', 'Actopan', 'Acworth', 'Acámbaro', 'Ad Darbāsīyah', 'Ad Dasmah', 'Ad Dawādimī', 'Ad Dilam', 'Ad Dilinjāt', 'Ad Dindar', 'Ad Douiem', 'Ad Dujayl', 'Ad Dānā', 'Ad Dīwānīyah', 'Ad-Damazin', 'Ada', 'Adam', 'Adamantina', 'Adampur', 'Adams Morgan', 'Adamstown', 'Adana', 'Adapazarı', 'Addanki', 'Addiet Canna', 'Addis Ababa', 'Addison', 'Addison', 'Adeje', 'Adelaide', 'Adelaide Hills', 'Adelaide city centre', 'Adelanto', 'Adelfia', 'Adelphi', 'Aden', 'Adh Dhayd', 'Adiaké', 'Adilcevaz', 'Adirampattinam', 'Adiwerna', 'Adjud', 'Adjumani', 'Adler', 'Adlershof', 'Adliswil', 'Admiralteisky', 'Ado Odo', 'Ado-Ekiti', 'Adra', 'Adra', 'Adrano', 'Adrar', 'Adrian', 'Adrogué', 'Adwick le Street', 'Adzopé', 'Adıyaman', 'Adūr', 'Affery', 'Affton', 'Afgooye', 'Afif', 'Afikpo', 'Afipskiy', 'Aflao', 'Aflou', 'Afogados da Ingazeira', 'Afragola', 'Afula', 'Afyonkarahisar', 'Afzalgarh', 'Afzalpur', 'Afşin', 'Agadez', 'Agadir', 'Agar', 'Agartala', 'Agawam', 'Agbor', 'Agboville', 'Agde', 'Agdzhabedy', 'Agen', 'Ageoshimo', 'Aghajari', 'Aghsu', 'Agidel’', 'Aginskoye', 'Agios Dimitrios', 'Agios Ioannis Rentis', 'Agnibilékrou', 'Agogo', 'Agoo', 'Agoura', 'Agoura Hills', 'Agra', 'Agrigento', 'Agropoli', 'Agryz', 'Agrínio', 'Agua Dulce', 'Agua Prieta', 'Aguachica', 'Aguada de Pasajeros', 'Aguadas', 'Aguadilla', 'Aguascalientes', 'Aguazul', 'Aguaí', 'Agudos', 'Aguilares', 'Aguilares', 'Agulu', 'Agustín Codazzi', 'Agía Paraskeví', 'Agía Varvára', 'Agüimes', 'Ahar', 'Ahaus', 'Ahfir', 'Ahlat', 'Ahlen', 'Ahmadnagar', 'Ahmadpur', 'Ahmadpur East', 'Ahmadpur Sial', 'Ahmedabad', 'Ahraura', 'Ahrensburg', 'Ahuachapán', 'Ahualulco de Mercado', 'Ahvaz', 'Ahwatukee Foothills', 'Aichach', 'Aigáleo', 'Aiken', 'Aileu', 'Aimorés', 'Ain Sukhna', 'Aioi', 'Airdrie', 'Airdrie', 'Airoli', 'Aistala', 'Aiud', 'Aix-en-Provence', 'Aix-les-Bains', 'Aizawl', 'Ajaccio', 'Ajalpan', 'Ajaokuta', 'Ajax', 'Ajdabiya', 'Ajka', 'Ajman City', 'Ajmer', 'Ajnāla', 'Ajodhya', 'Ajra', 'Ajā', 'Akademgorodok', 'Akademicheskoe', 'Akalkot', 'Akaltara', 'Akashi', 'Akbarpur', 'Akbarpur', 'Akbarābād', 'Akbou', 'Akdağmadeni', 'Aketi', 'Akhaltsikhe', 'Akhisar', 'Akhmīm', 'Akhtubinsk', 'Akhtyrskiy', 'Aki', 'Akim Oda', 'Akita', 'Akivīdu', 'Akkarampalle', 'Akkol’', 'Aklera', 'Akola', 'Akonolinga', 'Akora', 'Akot', 'Akouda', 'Akoupé', 'Akron', 'Aksaray', 'Aksay', 'Aksu', 'Aksu', 'Aktau', 'Aktobe', 'Aku', 'Akune', 'Akure', 'Akureyri', 'Akwanga', 'Akwatia', 'Akyazı', 'Akçaabat', 'Akçakale', 'Akçakoca', 'Akşehir', 'Al Aaroui', 'Al Abyār', 'Al Ain City', 'Al Ajaylat', 'Al Aḩmadī', 'Al Badārī', 'Al Bahah', 'Al Balyanā', 'Al Bawīţī', 'Al Bayda', ' ...

# %%
city_values = gc.get_cities().values()

city_data = [city['name'] for city in city_values]
print(city_data)
# Out:
# ['Andorra la Vella', 'Umm Al Quwain City', 'Ras Al Khaimah City', 'Zayed City', 'Khawr Fakkān', 'Dubai', 'Dibba Al-Fujairah', 'Dibba Al-Hisn', 'Sharjah', 'Ar Ruways', 'Al Fujairah City', 'Al Ain City', 'Ajman City', 'Adh Dhayd', 'Abu Dhabi', 'Khalifah A City', 'Bani Yas City', 'Musaffah', 'Al Shamkhah City', 'Reef Al Fujairah City', 'Zaranj', 'Taloqan', 'Shīnḏanḏ', 'Shibirghān', 'Shahrak', 'Sar-e Pul', 'Sang-e Chārak', 'Aībak', 'Rustāq', 'Qarqīn', 'Qarāwul', 'Pul-e Khumrī', 'Paghmān', 'Nahrīn', 'Maymana', 'Mehtar Lām', 'Mazār-e Sharīf', 'Lashkar Gāh', 'Kushk', 'Kunduz', 'Khōst', 'Khulm', 'Khāsh', 'Khanabad', 'Karukh', 'Kandahār', 'Kabul', 'Jalālābād', 'Jabal os Saraj', 'Herāt', 'Ghormach', 'Ghazni', 'Gereshk', 'Gardez', 'Fayzabad', 'Farah', 'Kafir Qala', 'Charikar', 'Baraki Barak', 'Bāmyān', 'Balkh', 'Baghlān', 'Ārt Khwājah', 'Āsmār', 'Asadābād', 'Andkhōy', 'Bāzārak', 'Markaz-e Woluswalī-ye Āchīn', 'Saint John’s', 'The Valley', 'Sarandë', 'Pogradec', 'Kukës', 'Korçë', 'Gjirokastër', 'Elbasan', 'Burrel', 'Vlorë', 'Tirana', 'Shkodër', 'Patos Fshat', 'Patos', 'Lushnjë', 'Lezhë', 'Laç', 'Kuçovë', 'Krujë', 'Kavajë', 'Fier-Çifçi', 'Fier', 'Durrës', 'Berat', 'Kapan', 'Goris', 'Hats’avan', 'Artashat', 'Ararat', 'Yerevan', 'Vagharshapat', 'Step’anavan', 'Spitak', 'Sevan', 'Masis', 'Vanadzor', 'Gavarr', 'Hrazdan', 'Armavir', 'Gyumri', 'Ashtarak', 'Abovyan', 'Saurimo', 'Lucapa', 'Luau', 'Uíge', 'Soio', "N'zeto", 'N’dalatando', 'Mbanza Congo', 'Malanje', 'Luanda', 'Caxito', 'Cabinda', 'Sumbe', 'Namibe', 'Menongue', 'Luena', 'Lubango', 'Longonjo', 'Lobito', 'Cuito', 'Huambo', 'Catumbela', 'Catabola', 'Camacupa', 'Caála', 'Benguela', 'Zárate', 'Wanda', 'Villa Ortúzar', 'Villa Ocampo', 'Villa Lugano', 'Villaguay', 'Villa Gesell', 'Villa de Mayo', 'Tortuguitas', 'Tigre', 'Tandil', 'San Vicente', 'Santo Tomé', 'Santa Elena', 'San Pedro', 'San Pedro', 'San Luis del Palmar', 'San Lorenzo', 'San Javier', 'San Isidro', 'Saladas', 'Retiro', 'Resistencia', 'Reconquista', 'Quilmes', 'Puerto Rico', 'Puerto Iguazú', 'Puerto Esperanza', 'Puerto Eldorado', 'Posadas', 'Pontevedra', 'Pirané', 'Pilar', 'Paso de los Libres', 'Oberá', 'Necochea', 'Muñiz', 'Morón', 'Monte Caseros', 'Montecarlo', 'Merlo', 'Mercedes', 'Mercedes', 'Mar del Plata', 'Luján', 'Los Polvorines', 'La Plata', 'La Paz', 'Jardín América', 'Hurlingham', 'Gualeguaychú', 'Gualeguay', 'Goya', 'Gobernador Virasora', 'General Pacheco', 'General José de San Martín', 'Garupá', 'Formosa', 'Fontana', 'Federal', 'Esquina', 'El Soberbio', 'Don Torcuato', 'Dolores', 'Curuzú Cuatiá', 'Corrientes', 'Concordia', 'Concepción del Uruguay', 'Colegiales', 'Chajarí', 'Campana', 'Buenos Aires', 'Boedo', 'Berazategui', 'Belgrano', 'Barranqueras', 'Barracas', 'Balcarce', 'Azul', 'Avellaneda', 'Aristóbulo del Valle', 'Zapala', 'Yerba Buena', 'Villa Regina', 'Villa Paula de Sarmiento', 'Villa Nueva', 'Villa María', 'Villa Dolores', 'Villa Constitución', 'Villa Carlos Paz', 'Villa Ángela', 'Villa Allende', 'Viedma', 'Victoria', 'Vera', 'Venado Tuerto', 'Veinticinco de Mayo', 'Ushuaia', 'Unquillo', 'Tres Isletas', 'Tres Arroyos', 'Trelew', 'Termas de Río Hondo', 'Tartagal', 'Tafí Viejo', 'Sunchales', 'Santo Tomé', 'Santiago del Estero', 'Santa Rosa', 'Santa Lucía', 'Santa Fe', 'San Salvador de Jujuy', 'San Ramón de la Nueva Orán', 'San Rafael', 'San Pedro de Jujuy', 'San Nicolás de los Arroyos', 'San Miguel de Tucumán', 'San Martín de los Andes', 'San Martín', 'San Luis', 'San Justo', 'San Juan', 'San José de Jáchal', 'San Jorge', 'San Francisco', 'San Fernando del Valle de Catamarca', 'San Antonio Oeste', 'Salta', 'Rufino', 'Rosario', 'Río Tercero', 'Río Segundo', 'Río Grande', 'Río Gallegos', 'Río Cuarto', 'Río Ceballos', 'Rawson', 'Rafaela', 'Quitilipi', 'Punta Alta', 'Puerto Madryn', 'Presidencia Roque Sáenz Peña', 'Pocito', 'Plottier', 'Pergamino', 'Pérez', 'Paraná', 'Palpalá', 'Olavarría', 'Nueve de Julio', 'Neuquén', 'Morteros', 'Monteros', 'Mendoza', 'Marcos Juárez', 'Machagai', 'Lincoln', 'Libertador Genera ...

# %%
print(country_to_name)
# Out:
# {re.compile('\\bAndorra\\b', re.IGNORECASE): 'Andorra', re.compile('\\bUnited Arab Emirates\\b', re.IGNORECASE): 'United Arab Emirates', re.compile('\\bAfghanistan\\b', re.IGNORECASE): 'Afghanistan', re.compile('\\bAntigua and Barbuda\\b', re.IGNORECASE): 'Antigua and Barbuda', re.compile('\\bAnguilla\\b', re.IGNORECASE): 'Anguilla', re.compile('\\bAlbania\\b', re.IGNORECASE): 'Albania', re.compile('\\bArmenia\\b', re.IGNORECASE): 'Armenia', re.compile('\\bAngola\\b', re.IGNORECASE): 'Angola', re.compile('\\bAntarctica\\b', re.IGNORECASE): 'Antarctica', re.compile('\\bArgentina\\b', re.IGNORECASE): 'Argentina', re.compile('\\bAmerican Samoa\\b', re.IGNORECASE): 'American Samoa', re.compile('\\bAustria\\b', re.IGNORECASE): 'Austria', re.compile('\\bAustralia\\b', re.IGNORECASE): 'Australia', re.compile('\\bAruba\\b', re.IGNORECASE): 'Aruba', re.compile('\\bAland Islands\\b', re.IGNORECASE): 'Aland Islands', re.compile('\\bAzerbaijan\\b', re.IGNORECASE): 'Azerbaijan', re.compile('\\bBosnia and Herzegovina\\b', re.IGNORECASE): 'Bosnia and Herzegovina', re.compile('\\bBarbados\\b', re.IGNORECASE): 'Barbados', re.compile('\\bBangladesh\\b', re.IGNORECASE): 'Bangladesh', re.compile('\\bBelgium\\b', re.IGNORECASE): 'Belgium', re.compile('\\bBurkina Faso\\b', re.IGNORECASE): 'Burkina Faso', re.compile('\\bBulgaria\\b', re.IGNORECASE): 'Bulgaria', re.compile('\\bBahrain\\b', re.IGNORECASE): 'Bahrain', re.compile('\\bBurundi\\b', re.IGNORECASE): 'Burundi', re.compile('\\bBenin\\b', re.IGNORECASE): 'Benin', re.compile('\\bSaint Barthelemy\\b', re.IGNORECASE): 'Saint Barthelemy', re.compile('\\bBermuda\\b', re.IGNORECASE): 'Bermuda', re.compile('\\bBrunei\\b', re.IGNORECASE): 'Brunei', re.compile('\\bBolivia\\b', re.IGNORECASE): 'Bolivia', re.compile('\\bBonaire, Saint Eustatius and Saba \\b', re.IGNORECASE): 'Bonaire, Saint Eustatius and Saba ', re.compile('\\bBrazil\\b', re.IGNORECASE): 'Brazil', re.compile('\\bBahamas\\b', re.IGNORECASE): 'Bahamas', re.compile('\\bBhutan\\b', re.IGNORECASE): 'Bhutan', re.compile('\\bBouvet Island\\b', re.IGNORECASE): 'Bouvet Island', re.compile('\\bBotswana\\b', re.IGNORECASE): 'Botswana', re.compile('\\bBelarus\\b', re.IGNORECASE): 'Belarus', re.compile('\\bBelize\\b', re.IGNORECASE): 'Belize', re.compile('\\bCanada\\b', re.IGNORECASE): 'Canada', re.compile('\\bCocos Islands\\b', re.IGNORECASE): 'Cocos Islands', re.compile('\\bDemocratic Republic of the Congo\\b', re.IGNORECASE): 'Democratic Republic of the Congo', re.compile('\\bCentral African Republic\\b', re.IGNORECASE): 'Central African Republic', re.compile('\\bRepublic of the Congo\\b', re.IGNORECASE): 'Republic of the Congo', re.compile('\\bSwitzerland\\b', re.IGNORECASE): 'Switzerland', re.compile('\\bIvory Coast\\b', re.IGNORECASE): 'Ivory Coast', re.compile('\\bCook Islands\\b', re.IGNORECASE): 'Cook Islands', re.compile('\\bChile\\b', re.IGNORECASE): 'Chile', re.compile('\\bCameroon\\b', re.IGNORECASE): 'Cameroon', re.compile('\\bChina\\b', re.IGNORECASE): 'China', re.compile('\\bColombia\\b', re.IGNORECASE): 'Colombia', re.compile('\\bCosta Rica\\b', re.IGNORECASE): 'Costa Rica', re.compile('\\bCuba\\b', re.IGNORECASE): 'Cuba', re.compile('\\bCabo Verde\\b', re.IGNORECASE): 'Cabo Verde', re.compile('\\bCuracao\\b', re.IGNORECASE): 'Curacao', re.compile('\\bChristmas Island\\b', re.IGNORECASE): 'Christmas Island', re.compile('\\bCyprus\\b', re.IGNORECASE): 'Cyprus', re.compile('\\bCzechia\\b', re.IGNORECASE): 'Czechia', re.compile('\\bGermany\\b', re.IGNORECASE): 'Germany', re.compile('\\bDjibouti\\b', re.IGNORECASE): 'Djibouti', re.compile('\\bDenmark\\b', re.IGNORECASE): 'Denmark', re.compile('\\bDominica\\b', re.IGNORECASE): 'Dominica', re.compile('\\bDominican Republic\\b', re.IGNORECASE): 'Dominican Republic', re.compile('\\bAlgeria\\b', re.IGNORECASE): 'Algeria', re.compile('\\bEcuador\\b', re.IGNORECASE): 'Ecuador', re.compile('\\bEstonia\\b', re.IGNORECASE): 'Estonia', re.compile('\\bEgypt\\b', re.IGNORECASE): 'Egypt', re.compile(' ...

# %%
print(city_to_name)
# Out:
# {re.compile('\\bAndorra la Vella\\b', re.IGNORECASE): 'Andorra la Vella', re.compile('\\bUmm Al Quwain City\\b', re.IGNORECASE): 'Umm Al Quwain City', re.compile('\\bRas Al Khaimah City\\b', re.IGNORECASE): 'Ras Al Khaimah City', re.compile('\\bZayed City\\b', re.IGNORECASE): 'Zayed City', re.compile('\\b(Khawr Fakkān|Khawr Fakkan)\\b', re.IGNORECASE): 'Khawr Fakkān', re.compile('\\bDubai\\b', re.IGNORECASE): 'Dubai', re.compile('\\bDibba Al-Fujairah\\b', re.IGNORECASE): 'Dibba Al-Fujairah', re.compile('\\bDibba Al-Hisn\\b', re.IGNORECASE): 'Dibba Al-Hisn', re.compile('\\bSharjah\\b', re.IGNORECASE): 'Sharjah', re.compile('\\bAr Ruways\\b', re.IGNORECASE): 'Ar Ruways', re.compile('\\bAl Fujairah City\\b', re.IGNORECASE): 'Al Fujairah City', re.compile('\\bAl Ain City\\b', re.IGNORECASE): 'Al Ain City', re.compile('\\bAjman City\\b', re.IGNORECASE): 'Ajman City', re.compile('\\bAdh Dhayd\\b', re.IGNORECASE): 'Adh Dhayd', re.compile('\\bAbu Dhabi\\b', re.IGNORECASE): 'Abu Dhabi', re.compile('\\bKhalifah A City\\b', re.IGNORECASE): 'Khalifah A City', re.compile('\\bBani Yas City\\b', re.IGNORECASE): 'Bani Yas City', re.compile('\\bMusaffah\\b', re.IGNORECASE): 'Musaffah', re.compile('\\bAl Shamkhah City\\b', re.IGNORECASE): 'Al Shamkhah City', re.compile('\\bReef Al Fujairah City\\b', re.IGNORECASE): 'Reef Al Fujairah City', re.compile('\\bZaranj\\b', re.IGNORECASE): 'Zaranj', re.compile('\\bTaloqan\\b', re.IGNORECASE): 'Taloqan', re.compile('\\b(Shīnḏanḏ|Shindand)\\b', re.IGNORECASE): 'Shīnḏanḏ', re.compile('\\b(Shibirghān|Shibirghan)\\b', re.IGNORECASE): 'Shibirghān', re.compile('\\bShahrak\\b', re.IGNORECASE): 'Shahrak', re.compile('\\bSar-e Pul\\b', re.IGNORECASE): 'Sar-e Pul', re.compile('\\b(Sang-e Chārak|Sang-e Charak)\\b', re.IGNORECASE): 'Sang-e Chārak', re.compile('\\b(Aībak|Aibak)\\b', re.IGNORECASE): 'Aībak', re.compile('\\b(Rustāq|Rustaq)\\b', re.IGNORECASE): 'Rustāq', re.compile('\\b(Qarqīn|Qarqin)\\b', re.IGNORECASE): 'Qarqīn', re.compile('\\b(Qarāwul|Qarawul)\\b', re.IGNORECASE): 'Qarāwul', re.compile('\\b(Pul-e Khumrī|Pul-e Khumri)\\b', re.IGNORECASE): 'Pul-e Khumrī', re.compile('\\b(Paghmān|Paghman)\\b', re.IGNORECASE): 'Paghmān', re.compile('\\b(Nahrīn|Nahrin)\\b', re.IGNORECASE): 'Nahrīn', re.compile('\\bMaymana\\b', re.IGNORECASE): 'Maymana', re.compile('\\b(Mehtar Lām|Mehtar Lam)\\b', re.IGNORECASE): 'Mehtar Lām', re.compile('\\b(Mazār-e Sharīf|Mazar-e Sharif)\\b', re.IGNORECASE): 'Mazār-e Sharīf', re.compile('\\b(Lashkar Gāh|Lashkar Gah)\\b', re.IGNORECASE): 'Lashkar Gāh', re.compile('\\bKushk\\b', re.IGNORECASE): 'Kushk', re.compile('\\bKunduz\\b', re.IGNORECASE): 'Kunduz', re.compile('\\b(Khōst|Khost)\\b', re.IGNORECASE): 'Khōst', re.compile('\\bKhulm\\b', re.IGNORECASE): 'Khulm', re.compile('\\b(Khāsh|Khash)\\b', re.IGNORECASE): 'Khāsh', re.compile('\\bKhanabad\\b', re.IGNORECASE): 'Khanabad', re.compile('\\bKarukh\\b', re.IGNORECASE): 'Karukh', re.compile('\\b(Kandahār|Kandahar)\\b', re.IGNORECASE): 'Kandahār', re.compile('\\bKabul\\b', re.IGNORECASE): 'Kabul', re.compile('\\b(Jalālābād|Jalalabad)\\b', re.IGNORECASE): 'Jalālābād', re.compile('\\bJabal os Saraj\\b', re.IGNORECASE): 'Jabal os Saraj', re.compile('\\b(Herāt|Herat)\\b', re.IGNORECASE): 'Herāt', re.compile('\\bGhormach\\b', re.IGNORECASE): 'Ghormach', re.compile('\\bGhazni\\b', re.IGNORECASE): 'Ghazni', re.compile('\\bGereshk\\b', re.IGNORECASE): 'Gereshk', re.compile('\\bGardez\\b', re.IGNORECASE): 'Gardez', re.compile('\\bFayzabad\\b', re.IGNORECASE): 'Fayzabad', re.compile('\\bFarah\\b', re.IGNORECASE): 'Farah', re.compile('\\bKafir Qala\\b', re.IGNORECASE): 'Kafir Qala', re.compile('\\bCharikar\\b', re.IGNORECASE): 'Charikar', re.compile('\\bBaraki Barak\\b', re.IGNORECASE): 'Baraki Barak', re.compile('\\b(Bāmyān|Bamyan)\\b', re.IGNORECASE): 'Bāmyān', re.compile('\\bBalkh\\b', re.IGNORECASE): 'Balkh', re.compile('\\b(Baghlān|Baghlan)\\b', re.IGNORECASE): 'Baghlān', re.compile('\\b(Ārt Khwājah|Art Khwajah)\\b', re.IGNORECASE): 'Ārt Khwājah ...

# %% [markdown]
# ## Workflow #3 ##
# Put the extracted data into a pandas DataFrame with three columns: headline, city, country.

# %%
import pandas as pd

matched_countries = [get_name_in_text(headline, country_to_name) for headline in headlines]
matched_cities = [get_name_in_text(headline, city_to_name) for headline in headlines]
data = {'Headline': headlines, 'City': matched_cities, 'Country': matched_countries}
df = pd.DataFrame(data)

# %%
matched_countries
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Belize',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Brazil',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Malaysia',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Hong Kong',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Panama',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Panama',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Guatemala',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Brazil',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Thailand',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Singapore',
#  'Vietnam',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Brazil',
#  'Mexico',
#  'Malaysia',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Malaysia',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
matched_cities
# Out:
# ['Bogotá',
#  'Sengkang',
#  'Alameda',
#  'Albany',
#  'Antipolo',
#  'Århus',
#  'Arvada',
#  'Miami',
#  'Of',
#  'Hemet',
#  'Of',
#  'Kingston',
#  'Of',
#  'Of',
#  'Akron',
#  'Ganja',
#  'Bay',
#  'Of',
#  'Edinburgh',
#  'Of',
#  'Corona',
#  'Buenos Aires',
#  'Dubai',
#  'Of',
#  'Of',
#  'Abuja',
#  'Cantù',
#  'Clovis',
#  'Missoula',
#  'Flint',
#  'Baltimore',
#  'Barcelona',
#  'Barcelona',
#  'Barstow',
#  'Batangas',
#  'Beijing',
#  'Belize City',
#  'Benton',
#  'Biloxi',
#  'Birmingham',
#  'Bradenton',
#  'Bridgeport',
#  'Brisbane',
#  'Hayward',
#  'San',
#  None,
#  'Santa Fe',
#  'Tehran',
#  'Brownsville',
#  'Vero Beach',
#  'Cancún',
#  'Caracas',
#  'Rio de Janeiro',
#  'Gaithersburg',
#  'Calgary',
#  'Melbourne',
#  'Hilden',
#  'Aurora',
#  'Of',
#  'Of',
#  'Dayton',
#  'Of',
#  'Of',
#  'Concord',
#  'Of',
#  'Chicago',
#  'Stillwater',
#  'Simpsonville',
#  'Chula Vista',
#  'Toledo',
#  'Denver',
#  'North Vancouver',
#  None,
#  'Kobe',
#  'Sanaa',
#  'University',
#  'Dakar',
#  'Bonn',
#  'New York City',
#  'Dallas',
#  'Davenport',
#  'Deerfield',
#  'Kathmandu',
#  'Easton',
#  'Doral',
#  'Duisburg',
#  'Duluth',
#  'Durango',
#  'Kampala',
#  'El Paso',
#  'Erie',
#  'Escondido',
#  'Fayetteville',
#  'Miami',
#  'Columbus',
#  'Cincinnati',
#  'Yangon',
#  'Galveston',
#  'Boston',
#  None,
#  'Fort Collins',
#  'Fort Hood',
#  'Hidalgo',
#  'Framingham',
#  'Frisco',
#  'Gainesville',
#  'Genève',
#  'Germantown',
#  'Gladstone',
#  'Norwalk',
#  'Avon',
#  None,
#  'Guangzhou',
#  None,
#  'Boulder',
#  'Hinthada',
#  'Fairfax',
#  'Tacoma',
#  'Halifax',
#  'Hallandale Beach',
#  'Harare',
#  'Fukushima',
#  'Staten Island',
#  'Foster City',
#  'Stamford',
#  'Kansas City',
#  'Edinburgh',
#  'Québec',
#  'Florence',
#  'Bethlehem',
#  'Danbury',
#  'Damascus',
#  'Aswan',
#  'Bismarck',
#  'Danvers',
#  'Evansville',
#  'Bethesda',
#  'Grenoble',
#  'Hammond',
#  'Libreville',
#  'Santa Rosa',
#  'Rochester',
#  'Fremont',
#  'Kingston',
#  'Mattoon',
#  None,
#  'Hollywood',
#  'Hanoi',
#  'Hampton',
#  'Santiago',
#  'Basel',
#  'Shreveport',
#  'Trenton',
#  'Waldorf',
#  'Bend',
#  'Greenville',
#  'Bullhead City',
#  'San',
#  'Grove',
#  'Medford',
#  'Plainfield',
#  'Santa Monica',
#  'Huzhou',
#  'Ibadan',
#  'Muscat',
#  'Suffolk',
#  'Sacramento',
#  'Iowa City',
#  'Lafayette',
#  'Majuro',
#  'Ithaca',
#  'Hīt',
#  'Johannesburg',
#  'Kédougou',
#  'Kent',
#  'San',
#  'Hīt',
#  'Lausanne',
#  'Laventille',
#  'Lawrenceville',
#  'Lima',
#  'London',
#  None,
#  None,
#  'Auckland',
#  'Dhaka',
#  'Entebbe',
#  'Janesville',
#  'Lakewood',
#  'Monroe',
#  'Palm Springs',
#  'Papeete',
#  'Pekanbaru',
#  'Richmond',
#  'Moscow',
#  'Lyon',
#  'Brussels',
#  'London',
#  'Naples',
#  'Rotterdam',
#  'Chatham',
#  'Margate',
#  'Bedford',
#  'Ennis',
#  'Murcia',
#  'Madera',
#  'Madison',
#  None,
#  None,
#  'Zanzibar',
#  'Elyria',
#  'Schenectady',
#  'Winona',
#  'Terrebonne',
#  'Johannesburg',
#  'Boise',
#  'Nashua',
#  'Manassas',
#  'Manchester',
#  'Mandaluyong City',
#  'Manhattan',
#  'Marquette',
#  None,
#  None,
#  'Wailuku',
#  'Brooklyn',
#  'Mecca',
#  'Memphis',
#  'Medina',
#  'Nassau',
#  'Summerville',
#  'Miami',
#  'Milwaukee',
#  'Mobile',
#  'Molo',
#  'Montevideo',
#  'Fontainebleau',
#  'Alexandria',
#  'Cambridge',
#  'Canton',
#  'Crawfordsville',
#  'Dublin',
#  'Kensington',
#  None,
#  None,
#  'Orange',
#  'Stuttgart',
#  'Quezon',
#  'Soyapango',
#  'Austin',
#  'Bella Vista',
#  'Botucatu',
#  'Calumpang',
#  'Camaçari',
#  'Carrollton',
#  'Chanthaburi',
#  'Chennai',
#  'Custódia',
#  'Davao',
#  'Fort Myers',
#  'Fort Worth',
#  'Indang',
#  'João Pessoa',
#  'Kampong Speu',
#  'Lakeland',
#  'McAllen',
#  'Melbourne',
#  'Laredo',
#  'Pensacola',
#  'Ribeirão',
#  'Waco',
#  'Bedford',
#  'Allentown',
#  'Berkeley',
#  None,
#  'Cranford',
#  'Durham',
#  None,
#  'Indianapolis',
#  'Kitwe',
#  'McLean',
#  'Nadi',
#  None,
#  'Palo',
#  'Petersburg',
#  'Toronto',
#  'Yokohama',
#  'St. Louis',
#  'Mpika',
#  'Mumbai',
#  'Howard',
#  'Joplin',
#  'Jefferson',
#  'Recife',
#  'Nashville',
#  'Delhi',
#  'Goes',
#  'Milford',
#  'Bethesda',
#  'Belo Horizonte',
#  'Sarasota',
#  'Kota',
#  'Baton Rouge',
#  'Tucson',
#  'Saginaw',
#  'Kīhei',
#  'Bossier City',
#  'Redlands',
#  'Fresno',
#  'Sevilla',
#  'Saint Charles',
#  'Newburgh',
#  'Taipei',
#  'Ventura',
#  'Nha Trang',
#  'Norfolk',
#  'Hong Kong',
#  'Copenhagen',
#  'Anaheim',
#  'Winnipeg',
#  'Northfield',
#  'Norwalk',
#  'Ogden',
#  'Orlando',
#  'Of',
#  'Bacolod City',
#  'Colombo',
#  'Corpus Christi',
#  'Of',
#  'Of',
#  'Kozhikode',
#  'Leesburg',
#  'Of',
#  'Of',
#  'Of',
#  'Of',
#  'Of',
#  'Of',
#  'Oxford',
#  'Panamá',
#  'Of',
#  'Man',
#  'Philadelphia',
#  'Hīt',
#  'Phoenix',
#  'Of',
#  'Pittsburgh',
#  'Alhambra',
#  'San',
#  'Springville',
#  'Bloomington',
#  'Kinshasa',
#  'Praia',
#  'Rockhampton',
#  'Of',
#  'Of',
#  'Pune',
#  'Hamilton',
#  'Madrid',
#  'Altus',
#  'Henderson',
#  'Masaya',
#  'Tulsa',
#  'San',
#  'Bakersfield',
#  'Athens',
#  'Storrs',
#  'Richland',
#  'Of',
#  'Ronkonkoma',
#  'Labasa',
#  'Las Cumbres',
#  'Starkville',
#  'Bundaberg',
#  'Redmond',
#  'Syracuse',
#  'Montpellier',
#  'Darien',
#  'Montréal',
#  'San',
#  'Albany',
#  'Morristown',
#  None,
#  'Brighton',
#  'Guatemala City',
#  'Bedford',
#  'Ottawa',
#  'Khartoum',
#  'Jerusalem',
#  'Joliet',
#  'Huntsville',
#  'North Platte',
#  'Suzhou',
#  None,
#  'Baud',
#  'Carlsbad',
#  'Salem',
#  'Croix',
#  'Salt',
#  'San',
#  'Sangre Grande',
#  'Santa Barbara',
#  'Bentonville',
#  'Birmingham',
#  'Bridgeton',
#  None,
#  'Danville',
#  'Glasgow',
#  'Huntington',
#  'Shenzhen',
#  'Sydney',
#  'Tulare',
#  'Yaoundé',
#  'Paris',
#  'Of',
#  'Seattle',
#  'Brasília',
#  'Seoul',
#  'Belfort',
#  'Southampton',
#  'Barcelona',
#  'Lisbon',
#  'Lisbon',
#  None,
#  'Madrid',
#  'Madrid',
#  'Madrid',
#  'Berlin',
#  'Farmington',
#  'Of',
#  'Greenville',
#  'Golden',
#  'Of',
#  'Meriden',
#  'Of',
#  'Canberra',
#  'Huddersfield',
#  'Of',
#  'Of',
#  'Managua',
#  'Mandalay',
#  'Of',
#  'Of',
#  'Monroe',
#  'Albuquerque',
#  'Bacoor',
#  'Cancún',
#  'Fort Lauderdale',
#  'St. Catharines',
#  'University',
#  'Campinas',
#  'Zamboanga',
#  'Of',
#  'La Jolla',
#  'Jefferson',
#  'Harrisburg',
#  'Tallahassee',
#  'Bay',
#  'Windsor',
#  'Bangkok',
#  'Atlanta',
#  'Arcadia',
#  'Of',
#  'Of',
#  'Of',
#  'Fargo',
#  'Lansing',
#  'Baku',
#  'Brazzaville',
#  'Of',
#  'Of',
#  'Imperial',
#  'Monroe',
#  'Boardman',
#  'Fairfield',
#  'Tocumen',
#  'Of',
#  'Of',
#  'Arusha',
#  'Townsville',
#  'Trinidad',
#  'Luanda',
#  'Hartford',
#  'Newark',
#  'Caguas',
#  'Fairfield',
#  'Springs',
#  'Tupelo',
#  'Laredo',
#  'Of',
#  'Cambridge',
#  'Detroit',
#  'Minot',
#  'Milton',
#  'Lagos',
#  'Hīt',
#  'Ibadan',
#  'Villavicencio',
#  'Of',
#  'Cúcuta',
#  'Alpharetta',
#  'Racine',
#  'Monroe',
#  'Yogyakarta',
#  'Hauppauge',
#  'Louisville',
#  None,
#  'Yerevan',
#  'Dongguan',
#  'Wellington',
#  'East Moline',
#  'Las Vegas',
#  'La Paz',
#  'Newcastle',
#  'Strasbourg',
#  'Bristol',
#  'Milford',
#  'Sochi',
#  'Hamburg',
#  'Raleigh',
#  'Tangier',
#  'Addis Ababa',
#  'Annapolis',
#  'Ljubljana',
#  None,
#  'Rockville',
#  'Coronado',
#  'Dumai',
#  None,
#  'Vienna',
#  'Wisconsin Rapids',
#  'Wuhan',
#  'Hīt',
#  'Miami',
#  'Houston',
#  'São Paulo',
#  'Florida',
#  'Miami',
#  'Hyderabad',
#  'Manaus',
#  'Mexicali',
#  'Pinewood',
#  'Puducherry',
#  'Sincelejo',
#  'Miami',
#  'Weslaco',
#  'Wichita',
#  'Yurimaguas',
#  'Florida',
#  'Ciudad Acuña',
#  'Ilopango',
#  'Miami',
#  'São José',
#  'San',
#  'Palm Beach',
#  'Petersburg',
#  'Comé',
#  'Comé',
#  'Comé',
#  'Comé',
#  'Cham',
#  'Comé',
#  'Comé',
#  'Comé',
#  'Ontario',
#  'Lubbock',
#  'San',
#  'Sparks',
#  'Havana',
#  'Iloilo',
#  'Calamba',
#  'Rio Grande',
#  'Manila',
#  'Belmopan',
#  'Boca Raton',
#  None,
#  'Miri',
#  'Natal',
#  'Oaxaca',
#  'Orange',
#  'Quezon',
#  'San',
#  'San',
#  'Santos',
#  'Tegucigalpa',
#  'Udon Thani',
#  'Palm Beach',
#  'Valdosta',
#  'Lorain',
#  'Tunapuna',
#  'Abilene',
#  None,
#  'Coral Gables',
#  'Jacobina',
#  'Jupiter',
#  'Limoeiro',
#  None,
#  'Medellín',
#  None,
#  'Phetchabun',
#  'Reynosa',
#  'Rizal',
#  'Charlotte',
#  'Singapore',
#  'Ho',
#  'Belmont',
#  'Tamarac',
#  None,
#  'Mankato',
#  'Jakarta',
#  'Borne',
#  'Piracicaba',
#  'Mexico',
#  'Johor Bahru',
#  'Fort Pierce',
#  'Yuma',
#  'Salvador',
#  'Barranquilla',
#  'Caucasia',
#  'Daytona Beach',
#  'Kamphaeng Phet',
#  'Kissimmee',
#  'Kuching',
#  None,
#  'Lewisville',
#  'Olinda',
#  'Plant City',
#  'Potosí',
#  'Winter Park',
#  'Klang',
#  'Arlington',
#  'Bello',
#  'Bonita Springs',
#  'Boynton Beach',
#  'Colombo',
#  'Fortaleza',
#  'Hollywood',
#  'Iquitos',
#  'Quisqueya',
#  'Quito',
#  None,
#  'Sibu',
#  'Sūrat',
#  'Key West',
#  'Rockland',
#  'Westchester',
#  'Cleveland',
#  'Salvador',
#  'Ardmore',
#  'Delhi']

# %%
df
# Out:
#                                               Headline         City Country
# 0                          18 new Zika Cases in Bogota       Bogotá    None
# 1                        19 new Zika Cases in Sengkang     Sengkang    None
# 2             Alameda Residents Recieve Rabies vaccine      Alameda    None
# 3    Albany Residents Recieve Respiratory Syncytial...       Albany    None
# 4                Antipolo under threat from Zika Virus     Antipolo    None
# ..                                                 ...          ...     ...
# 645                Zika virus confirmed in Westchester  Westchester    None
# 646                   Zika virus reported in Cleveland    Cleveland    None
# 647                       Zika worries in San Salvador     Salvador    None
# 648     Zika-carrying mosquitoes discovered in Ardmore      Ardmore    None
# 649                  Zika: Delhi for strict monitoring        Delhi    None
#
# [650 rows x 3 columns]

# %% [markdown]
# ## Workflow #4 ##
# Make sure there were no issues with the extraction by sampling some of the headlines and examining the city and country names. One method for finding problems is to look for the most common names and see if there are any issues.

# %%
summary = df[['City', 'Country']].describe()
print(summary)
# Out:
#        City   Country
# count   619        15
# unique  510        10
# top      Of  Malaysia
# freq     45         3

# %%
of_cities = df[df.City == 'Of'][['City', 'Headline']]
ten_of_cities = of_cities.head(10)
print(ten_of_cities.to_string(index=False))
# Out:
# City                                           Headline
#   Of  Authorities are Worried about the Spread of Br...
#   Of  Authorities are Worried about the Spread of Ch...
#   Of  Authorities are Worried about the Spread of Go...
#   Of  Authorities are Worried about the Spread of He...
#   Of  Authorities are Worried about the Spread of In...
#   Of  Authorities are Worried about the Spread of Ma...
#   Of  Authorities are Worried about the Spread of Ro...
#   Of  Authorities are Worried about the Spread of Sy...
#   Of             Case of Measles Reported in Springdale
#   Of              Case of Measles Reported in Vancouver

# %%
def get_cities_in_headline(headline):
    cities_in_headline = set()
    for regex, name in city_to_name.items():
        match = regex.search(headline)
        if match:
            if headline[match.start()].isupper():
                cities_in_headline.add(name)
                
    return list(cities_in_headline)

df['Cities'] = df['Headline'].apply(get_cities_in_headline)
df['Num_cities'] = df['Cities'].apply(len)

# %%
df['Num_cities']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 645    1
# 646    1
# 647    3
# 648    1
# 649    1
# Name: Num_cities, Length: 650, dtype: int64

# %%
df.Num_cities > 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 645    False
# 646    False
# 647     True
# 648    False
# 649    False
# Name: Num_cities, Length: 650, dtype: bool

# %%
df_multiple_cities = df[df.Num_cities > 1]

# %%
df_multiple_cities
# Out:
#                                               Headline            City  \
# 8    Authorities are Worried about the Spread of Br...              Of
# 16   Authorities are Worried about the Spread of He...             Bay
# 34       Batangas Tourism Takes a Hit as Virus Spreads        Batangas
# 44             Bronchitis Keeps Spreading in San Mateo             San
# 49                Can Zika make it here to Vero Beach?      Vero Beach
# ..                                                 ...             ...
# 610  Zika only the latest mosquito-borne threat to ...           Borne
# 612               Zika outbreak spreads to Mexico City          Mexico
# 627                    Zika spreads to San Luis Potosi          Potosí
# 632            Zika symptoms spotted in Bonita Springs  Bonita Springs
# 647                       Zika worries in San Salvador        Salvador
#
#     Country                                    Cities  Num_cities
# 8      None                   [Spring, Silver Spring]           2
# 16     None                          [Bay, North Bay]           2
# 34     None                           [Hīt, Batangas]           2
# 44     None                          [San, San Mateo]           2
# 49     None                         [Vero Beach, Çan]           2
# ..      ...                                       ...         ...
# 610    None           [Orléans, Orleans, New Orleans]           3
# 612  Mexico                     [Mexico City, Mexico]           2
# 627    None  [San, San Luis, San Luis Potosí, Potosí]           4
# 632    None                 [Bonita Springs, Springs]           2
# 647    None             [Salvador, San, San Salvador]           3
#
# [68 rows x 5 columns]

# %%
num_rows, _ = df_multiple_cities.shape

# %%
print(f"{num_rows} headlines match multiple cities")
# Out:
# 68 headlines match multiple cities

# %%
ten_cities = df_multiple_cities[['Cities', 'Headline']].head(10)
print(ten_cities.to_string(index=False))
# Out:
#                         Cities                                           Headline
#        [Spring, Silver Spring]  Authorities are Worried about the Spread of Br...
#               [Bay, North Bay]  Authorities are Worried about the Spread of He...
#                [Hīt, Batangas]      Batangas Tourism Takes a Hit as Virus Spreads
#               [San, San Mateo]            Bronchitis Keeps Spreading in San Mateo
#              [Vero Beach, Çan]               Can Zika make it here to Vero Beach?
#           [Chula Vista, Vista]              Chickenpox has Arrived in Chula Vista
#   [North Vancouver, Vancouver]     Chikungunya Keeps Spreading in North Vancouver
#  [University City, University]  Chlamydia Symptoms Spread all over University ...
#          [York, New York City]                    Could Zika Reach New York City?
#           [Miami Beach, Miami]                  First Case of Zika in Miami Beach

# %%
ten_cities
# Out:
#                            Cities  \
# 8         [Spring, Silver Spring]
# 16               [Bay, North Bay]
# 34                [Hīt, Batangas]
# 44               [San, San Mateo]
# 49              [Vero Beach, Çan]
# 68           [Chula Vista, Vista]
# 71   [North Vancouver, Vancouver]
# 75  [University City, University]
# 78          [York, New York City]
# 93           [Miami Beach, Miami]
#
#                                              Headline
# 8   Authorities are Worried about the Spread of Br...
# 16  Authorities are Worried about the Spread of He...
# 34      Batangas Tourism Takes a Hit as Virus Spreads
# 44            Bronchitis Keeps Spreading in San Mateo
# 49               Can Zika make it here to Vero Beach?
# 68              Chickenpox has Arrived in Chula Vista
# 71     Chikungunya Keeps Spreading in North Vancouver
# 75  Chlamydia Symptoms Spread all over University ...
# 78                    Could Zika Reach New York City?
# 93                  First Case of Zika in Miami Beach

# %%
df['Cities']
# Out:
# 0                           [Bogotá]
# 1                         [Sengkang]
# 2                          [Alameda]
# 3                           [Albany]
# 4                         [Antipolo]
#                    ...
# 645                    [Westchester]
# 646                      [Cleveland]
# 647    [Salvador, San, San Salvador]
# 648                        [Ardmore]
# 649                          [Delhi]
# Name: Cities, Length: 650, dtype: object

# %%
def get_longest_city(cities):
    if cities:
        return max(cities, key=len)
    return None

df['City'] = df['Cities'].apply(get_longest_city)

# %%
df['Cities'].apply(get_longest_city)
# Out:
# 0            Bogotá
# 1          Sengkang
# 2           Alameda
# 3            Albany
# 4          Antipolo
#            ...
# 645     Westchester
# 646       Cleveland
# 647    San Salvador
# 648         Ardmore
# 649           Delhi
# Name: Cities, Length: 650, dtype: object

# %% [markdown]
# Confirm that no erroneous short city-name (4 characters or less) is getting assigned to one of our headlines.

# %%
short_cities = df[df.City.str.len() <= 4][['City', 'Headline']]
print(short_cities.to_string(index=False))
# Out:
#  City                                           Headline
#  Yiwu  Authorities are Worried about the Spread of He...
#  Rome  Authorities are Worried about the Spread of Ma...
#  Kobe                     Chikungunya re-emerges in Kobe
#  Bonn  Contaminated Meat Brings Trouble for Bonn Farmers
#  Erie                        Erie County sets Zika traps
#  Kent                       Kent is infested with Rabies
#  Lima                Lima tries to address Zika Concerns
#  Lyon                   Mad Cow Disease Detected in Lyon
#  Molo                Molo Cholera Spread Causing Concern
#  Waco                More Zika patients reported in Waco
#  Nadi  More people in Nadi are infected with HIV ever...
#  Pune                     Pune woman diagnosed with Zika
#  Baud  Rumors about Tuberculosis Spreading in Baud ha...
#  Suva  Suva authorities confirmed the spread of Rotav...
#  Reno  The Spread of Gonorrhea in Reno has been Confi...
#  Baku    The Spread of Herpes in Baku has been Confirmed
#  Jaén                         Zika Troubles come to Jaen
#  Miri                               Zika arrives in Miri
#  Yuma                       Zika seminars in Yuma County
#  Sibu                      Zika symptoms spotted in Sibu

# %%
df_countries = df[df.Country.notnull()][['City', 'Country', 'Headline']]
print(df_countries.to_string(index=False))
# Out:
#              City    Country                                           Headline
#       Belize City     Belize                 Belize City under threat from Zika
#            Recife     Brazil            Mystery Virus Spreads in Recife, Brazil
#     Kota Kinabalu   Malaysia           New Zika Case in Kota Kinabalu, Malaysia
#         Hong Kong  Hong Kong                    Norovirus Exposure in Hong Kong
#       Panama City     Panama                    Outbreak of Zika in Panama City
#            Panamá     Panama           Panama Cityâ€™s first Zika related death
#    Guatemala City  Guatemala  Rumors about Meningitis spreading in Guatemala...
#          Campinas     Brazil                   Student sick in Campinas, Brazil
#           Bangkok   Thailand                     Thailand-Zika Virus in Bangkok
#         Singapore  Singapore                  Zika cases in Singapore reach 393
#  Ho Chi Minh City    Vietnam     Zika cases in Vietnam's Ho Chi Minh City surge
#        Piracicaba     Brazil                Zika outbreak in Piracicaba, Brazil
#       Mexico City     Mexico               Zika outbreak spreads to Mexico City
#       Johor Bahru   Malaysia                 Zika reaches Johor Bahru, Malaysia
#             Klang   Malaysia                   Zika surfaces in Klang, Malaysia

# %%
df_countries
# Out:
#                  City    Country  \
# 36        Belize City     Belize
# 293            Recife     Brazil
# 301     Kota Kinabalu   Malaysia
# 316         Hong Kong  Hong Kong
# 333       Panama City     Panama
# 339            Panamá     Panama
# 384    Guatemala City  Guatemala
# 450          Campinas     Brazil
# 459           Bangkok   Thailand
# 603         Singapore  Singapore
# 604  Ho Chi Minh City    Vietnam
# 611        Piracicaba     Brazil
# 612       Mexico City     Mexico
# 613       Johor Bahru   Malaysia
# 629             Klang   Malaysia
#
#                                               Headline
# 36                  Belize City under threat from Zika
# 293            Mystery Virus Spreads in Recife, Brazil
# 301           New Zika Case in Kota Kinabalu, Malaysia
# 316                    Norovirus Exposure in Hong Kong
# 333                    Outbreak of Zika in Panama City
# 339           Panama Cityâ€™s first Zika related death
# 384  Rumors about Meningitis spreading in Guatemala...
# 450                   Student sick in Campinas, Brazil
# 459                     Thailand-Zika Virus in Bangkok
# 603                  Zika cases in Singapore reach 393
# 604     Zika cases in Vietnam's Ho Chi Minh City surge
# 611                Zika outbreak in Piracicaba, Brazil
# 612               Zika outbreak spreads to Mexico City
# 613                 Zika reaches Johor Bahru, Malaysia
# 629                   Zika surfaces in Klang, Malaysia

# %%
df[df.Country.isnull()][['City', 'Country', 'Headline']].count()
# Out:
# City        596
# Country       0
# Headline    635
# dtype: int64

# %%
df[df.Country.notnull()][['City', 'Country', 'Headline']].count()
# Out:
# City        15
# Country     15
# Headline    15
# dtype: int64

# %%
df[df.City.str.len() > 0][['City', 'Headline']].describe()
# Out:
#           City                        Headline
# count      611                             611
# unique     577                             608
# top     Monroe  Spanish Flu Outbreak in Lisbon
# freq         4                               2

# %%
df
# Out:
#                                               Headline          City Country  \
# 0                          18 new Zika Cases in Bogota        Bogotá    None
# 1                        19 new Zika Cases in Sengkang      Sengkang    None
# 2             Alameda Residents Recieve Rabies vaccine       Alameda    None
# 3    Albany Residents Recieve Respiratory Syncytial...        Albany    None
# 4                Antipolo under threat from Zika Virus      Antipolo    None
# ..                                                 ...           ...     ...
# 645                Zika virus confirmed in Westchester   Westchester    None
# 646                   Zika virus reported in Cleveland     Cleveland    None
# 647                       Zika worries in San Salvador  San Salvador    None
# 648     Zika-carrying mosquitoes discovered in Ardmore       Ardmore    None
# 649                  Zika: Delhi for strict monitoring         Delhi    None
#
#                             Cities  Num_cities
# 0                         [Bogotá]           1
# 1                       [Sengkang]           1
# 2                        [Alameda]           1
# 3                         [Albany]           1
# 4                       [Antipolo]           1
# ..                             ...         ...
# 645                  [Westchester]           1
# 646                    [Cleveland]           1
# 647  [Salvador, San, San Salvador]           3
# 648                      [Ardmore]           1
# 649                        [Delhi]           1
#
# [650 rows x 5 columns]

# %%
df[['Headline', 'City', 'Country']].describe()
# Out:
#                                     Headline    City   Country
# count                                    650     611        15
# unique                                   647     577        10
# top     Spanish Flu Spreading through Madrid  Monroe  Malaysia
# freq                                       2       4         3

# %%
df_headline_city_country = df[['Headline', 'City', 'Country']]

# %%
print(df_headline_city_country.to_string(index=False))

# %%
df_headline_city_country[df_headline_city_country.City.str.contains("of|Of") > 0]

# %%
df_headline_city_country

# %%
df_unmatched = df_headline_city_country[df_headline_city_country.City.isnull()]
num_unmatched = len(df_unmatched)
print(f"{num_unmatched} headlines contain no city matches.")
print(df_unmatched.head(10)[['Headline']].values)

# %%
gc.cities

# %%
gc.countries
