# %% [markdown]
# ## Parsing the News Headlines ##

# %% [markdown]
# ## Objective ##
#
# Find any city and/or country names mentioned in each of the news headlines.

# %% [markdown]
# ## Workflow #1 ##
# Load in the headline data and examine it for any data quality issues.
# - Use any library/data structure to read in the headlines.
# - Read through some of the headlines and identify potential problems.

# %%
headline_file = open('data/headlines.txt', 'r')

headlines = [line.strip()
             for line in headline_file.readlines()]

num_headlines = len(headlines)

print(f"{num_headlines} headlines have been loaded")
# Out:
# 650 headlines have been loaded

# %%
headlines
# Out:
# ['Zika Outbreak Hits Miami',
#  'Could Zika Reach New York City?',
#  'First Case of Zika in Miami Beach',
#  'Mystery Virus Spreads in Recife, Brazil',
#  'Dallas man comes down with case of Zika',
#  'Trinidad confirms first Zika case',
#  'Zika Concerns are Spreading in Houston',
#  'Geneve Scientists Battle to Find Cure',
#  'The CDC in Atlanta is Growing Worried',
#  'Zika Infested Monkeys in Sao Paulo',
#  'Brownsville teen contracts Zika virus',
#  'Mosquito control efforts in St. Louis take new tactics with Zika threat',
#  'San Juan reports 1st U.S. Zika-related death amid outbreak',
#  'Flu outbreak in Galveston, Texas',
#  'Zika alert â€“ Manila now threatened',
#  'Zika afflicts 7 in Iloilo City',
#  'New Los Angeles Hairstyle goes Viral',
#  'Louisiana Zika cases up to 26',
#  'Orlando volunteers aid Zika research',
#  'Zika infects pregnant woman in Cebu',
#  "Chicago's First Zika Case Confirmed",
#  'Tampa Bay Area Zika Case Count Climbs',
#  'Bad Water Leads to Sickness in Flint, Michigan',
#  'Baltimore plans for Zika virus',
#  'London Health Unit Tracks Mad Cow Disease',
#  "Zika cases in Vietnam's Ho Chi Minh City surge",
#  'Philadelphia experts track pandemic',
#  'Flu season hits Boston',
#  'Scientists in Paris to look for answers',
#  'Key Zika Findings in San Diego Institute',
#  'Thailand-Zika Virus in Bangkok',
#  'Beijing team cracks Zika secret',
#  'Zika spreading to Salvador',
#  'Kuala Lumpur is Hit By Zika Threat',
#  'First Zika case confirmed in Yangon',
#  'Tallahassee Doctors Discuss Zika Virus',
#  'Zika Virus Reaches San Francisco',
#  'New Vaccine on Trial in Bethesda District',
#  'Townsville Zika tests inconclusive',
#  'Mandaluyong City under Siege by Virus',
#  'Hepatitis E re-emerges in Santa Rosa',
#  'Zika worries in San Salvador',
#  'Zika virus reported in Cleveland',
#  'More Zika patients reported in Austin',
#  'Zika outbreak in Piracicaba, Brazil',
#  'Lima tries to address Zika Concerns',
#  'More people in Toronto are infected with Hepatitis E every year',
#  '18 new Zika Cases in Bogota',
#  'Spanish Flu Sighted in Antigua',
#  'Brisbane is infested with Meningitis',
#  'Cholera outbreak in Dakar',
#  'Zika Virus Transmission Detected in Havana',
#  'Zika symtomps spotted in Key West',
#  'Case of Measles Reported in Vancouver',
#  'Seattle scientists get $500,000 grant to pursue Zika vaccine New 7:50 pm',
#  'Nashville takes precautions against Zika',
#  'Saint Croix under Zika threat',
#  'Fort Collins Encounters Severe Symptoms of Gonorrhea',
#  'Zika surfaces in Klang, Malaysia',
#  'Rumors about Meningitis spreading in Guatemala City have been refuted',
#  'Madison lab developing vaccine against Zika virus [The Wisconsin State Journal]',
#  'New Zika Case Confirmed in Sarasota County',
#  'Lower Hospitalization in Entebbe after Rabies Vaccine becomes Mandatory',
#  'Carnival under threat in Rio De Janeiro due to Zika outbreak',
#  'Second Zika Paitient in Brasilia',
#  'Jacksonville man hit by Zika',
#  'Schools in Shenzhen Closed Due to Malaria Outbreak',
#  'Caracas patient dies',
#  'More Quezon City Zika Transmissions',
#  'Schools in Sydney Closed Due to Respiratory Syncytial Virus Outbreak',
#  "Mumbai's Health Minister warns of more Zika cases",
#  'Pune woman diagnosed with Zika',
#  'Hospitals in Hanoi fill up with Zika patients',
#  'Zika case reported in Oton',
#  'Authorities are Worried about the Spread of Bronchitis in Silver Spring',
#  'Zika: Delhi for strict monitoring',
#  'Hillsborough uses innovative trap against Zika 20 minutes ago',
#  'Belize City under threat from Zika',
#  'Student sick in Campinas, Brazil',
#  'More Zika cases in Soyapango',
#  'Authorities are Worried about the Spread of Mad Cow Disease in Rome',
#  'Seoul confirms 14th Zika infection',
#  'Hepatitis B Vaccine is now Required in Quebec',
#  'Zika outbreak spreads to Mexico City',
#  'Rochester authorities confirmed the spread of Dengue',
#  'El Paso fighting Zika',
#  'Visitor to Cucuta contracts Zika',
#  'Zika now spreading through Jakarta',
#  'Maka City Experiences Influenza Outbreak',
#  'Salt Lake City tests new cure for Respiratory Syncytial Virus',
#  'Zika San Antonio Patient Speaks Out',
#  'Ebola outbreak in Kampala',
#  'Precautionary Zika measures in Rockhampton',
#  'Zika arrives in Tegucigalpa',
#  'New Zika Case Confirmed in Belo Horizonte',
#  'Case of Hepatitis E Reported in Melbourne',
#  'First Columbus Zika case',
#  'New medicine wipes out Tuberculosis in Taipei',
#  'Zika Patient in Seminole, Florida',
#  'Antipolo under threat from Zika Virus',
#  'Spreading Zika reaches Bacoor',
#  'Can Zika make it here to Vero Beach?',
#  'Zika afflicts patient in Calamba',
#  'Hollywood Outbreak Film Premieres',
#  'Petaling Jaya man ill from Zika',
#  'Malaria is Spreading in Johannesburg',
#  'Authorities are Worried about the Spread of Norovirus in Buenos Aires',
#  'Guangzhou Patient in Critical Condition after Contracting Swine Flu',
#  'Doral hit by Deadly Virus',
#  'Tokyo Encounters Severe Symptoms of Meningitis',
#  'Rabies Exposure in Hamilton',
#  'Authorities are Worried about the Spread of Influenza in Savannah',
#  'Zika Outbreak in Hyderabad',
#  'Birmingham Residents Recieve Rabies vaccine',
#  'Is Zika virus in Majuro?',
#  'Spreading Zika ruining Cancun fun',
#  'Cancun hit by Outbreak of Party Fever!',
#  'HIV has Arrived in Fairfax',
#  'Spanish Flu Outbreak in Barcelona',
#  'Santa Barbara tests new cure for Hepatitis C',
#  'Spring break ruined by Zika in Fort Lauderdale',
#  'Villavicencio under Zika threat',
#  'Two more Zika cases confirmed in Laredo',
#  'New Delhi Addressing Zika Concerns',
#  'New Zika Case in Kota Kinabalu, Malaysia',
#  'New medicine wipes out West Nile Virus in Ventura',
#  'Meningitis re-emerges in Nassau',
#  'Zika reaches Johor Bahru, Malaysia',
#  'Nha Trang Zika Outbreak',
#  'First Zika Case in Cincinnati',
#  'Molo Cholera Spread Causing Concern',
#  'Norovirus Exposure in Hong Kong',
#  '19 new Zika Cases in Sengkang',
#  'Zika cases concern Charlotte residents',
#  'Batangas Tourism Takes a Hit as Virus Spreads',
#  'Johannesburg Patient in Critical Condition after Contracting Pneumonia',
#  'Outbreak of Zika in Bacolod City',
#  'Respiratory Syncytial Virus Keeps Spreading in Masaya',
#  'Spike of Pneumonia Cases in Springfield',
#  'More Zika patients reported in Mcallen',
#  'Zika case reported in Jupiter',
#  'Zika virus confirmed in Westchester',
#  'Authorities are Worried about the Spread of Tuberculosis in Abuja',
#  'Rumors about Hepatitis D Spreading in San Juan Capistrano have been Refuted',
#  'The Spread of Measles in Spokane has been Confirmed',
#  'Zika alert for Rio Grande Valley residents',
#  'Zika symptoms spotted in Colombo',
#  'West Nile Virus Outbreak in Louisville',
#  'New details in Baton Rouge cop killings',
#  'Hepatitis B has not Left Florence',
#  'More Zika patients reported in Pensacola',
#  'Outbreak of Zika in Corpus Christi',
#  'How to Avoid Rhinovirus in Lemon Grove',
#  'Rumors about Rotavirus spreading in Huntsville have been refuted',
#  'Rhinovirus has Arrived in Athens',
#  'Outbreak of Zika in Panama City',
#  'West Nile Virus Outbreak in Saint Johns',
#  'Measles has not Left Brooklyn',
#  'Escondido neighborhood to get sprayed for Zika virus',
#  'Zika in Belmont, Belmont worry',
#  'Influenza has not Left Sacramento',
#  'Veracruz hit by Zika Concerns',
#  'Case of Mumps Reported in Dayton',
#  'Authorities are Worried about the Spread of Dengue in Kingston',
#  'Gainesville Deals with Disease Concerns',
#  'Montevideo Encounters Severe Symptoms of Rotavirus',
#  'Varicella Keeps Spreading in Detroit',
#  'Arhus is infested with Bronchitis',
#  'Zika Troubles come to Niteroi',
#  'Zika cases in Singapore reach 393',
#  'Manhattan Residents Recieve HIV vaccine',
#  'Zika arrives in Miri',
#  'Rumors about Dengue Spreading in Syracuse have been Refuted',
#  'Will Norovirus vaccine help Raleigh?',
#  'Lower Hospitalization in Auckland after Hepatitis D Vaccine becomes Mandatory',
#  'How to Avoid Gonorrhea in Shreveport',
#  'Ithaca is infested with Dengue',
#  'Will MCD vaccine help Strasbourg?',
#  'New medicine wipes out Measles in Fresno',
#  'BREAKING â€“ Zika in Missoula',
#  'Zika arrives in Santos',
#  'Sick Livestock Leads to Serious Trouble for Belfort',
#  'Hepatitis E has not Left Libreville',
#  'New medicine wipes out Chikungunya in Tucson',
#  'Norovirus has Arrived in Winnipeg',
#  'Hepatitis B Comes to Kansas City',
#  'More Patients in Cambridge are Getting Diagnosed with Chickenpox',
#  'Chikungunya Exposure in Toledo',
#  'Is Lafayette prepared to combat Zika?',
#  'Mecca tests new cure for Chikungunya',
#  'Zika arrives in San Benito',
#  'Syphilis Outbreak in Harrisburg',
#  'Zika Arrives in North Miami',
#  'Urbana Encounters Severe Symptoms of Meningitis',
#  'Pittsburgh Residents Recieve Norovirus vaccine',
#  'Chikungunya Hits Denver',
#  'Zika case recorded in Tunapuna Â»',
#  'Spike of Respiratory Syncytial Virus Cases in Mandalay',
#  'HIV Keeps Spreading in Boulder',
#  'More Zika patients reported in Joao Pessoa',
#  'Will Tuberculosis vaccine help Rockville?',
#  'Mad Cow Disease Re-emerges in Chatham',
#  'Zika Virus Arrives in Ontario',
#  'Mad Cow Disease Hits Naples',
#  'More Zika patients reported in Davao',
#  'The Spread of Chikungunya in Arcadia has been Confirmed',
#  'Oxford tests new cure for HIV',
#  'Outbreak of Zika in Stephenville',
#  'Providence Encounters Severe Symptoms of Dengue',
#  'Tests negative on Windsor Zika carriers',
#  'Zika battle outlined at Valdosta meeting',
#  'Zika case reported in Coral Gables',
#  'Hepatitis C Outbreak in Danbury',
#  'Chickenpox has Arrived in Chula Vista',
#  'Syphilis Hits Jefferson',
#  'Will HIV vaccine help Las Vegas?',
#  'Zika arrives in West Palm Beach',
#  'Mobile authorities confirmed the spread of Bronchitis',
#  'Zika spreads to Daytona Beach',
#  'Lausanne Residents Recieve Meningitis vaccine',
#  'Rhinovirus Comes to San Jose',
#  'Spike of Chlamydia Cases in Farmington',
#  'Authorities are Worried about the Spread of Rotavirus in Union',
#  'Rumors about Hepatitis D spreading in Albany have been refuted',
#  'Zika symptoms spotted in Bello',
#  'Will Meningitis vaccine help Hamburg?',
#  'Madera Patient in Critical Condition after Contracting Rabies',
#  'Zika Virus Detected in Lubbock',
#  'Malaria re-emerges in Boise',
#  'Varicella re-emerges in Lagos',
#  'Vericella spreading in Ibadan',
#  'Schools in Birmingham Closed Due to Measles Outbreak',
#  'How to Avoid Hepatitis B in Waldorf',
#  'More people in Mclean are infected with Hepatitis A every year',
#  'Malaria Exposure in Sussex',
#  'Tuberculosis Outbreak in Newark',
#  "Zika Virus Sparks 'International Concern'",
#  'Spike of Chlamydia Cases in Berlin',
#  'Zika-carrying mosquitoes discovered in Ardmore',
#  'Zika Mosquitoes May Have Bred in Bromeliads, Florida Officials Say',
#  'More Livestock in Fontainebleau are infected with Mad Cow Disease',
#  'Frisco Woman Tests Positive For Zika Virus',
#  'Authorities are Worried about the Spread of Norovirus in Dubai',
#  'Benton Residents Recieve Pneumonia vaccine',
#  'Case of Hepatitis A Reported in Calgary',
#  'Zika Outbreak in Pinewood',
#  'Will Swine Flu vaccine help Ljubljana?',
#  'Bronchitis re-emerges in Tehran',
#  'Greenwich Establishes Zika Task Force',
#  'Mad Cow case in Murcia',
#  'Mad Cow Disease Spreads to Margate',
#  'Zika Strikes St. Petersburg',
#  'Will West Nile Virus vaccine help Parsons?',
#  'Will the Mad Cow Outbreak Reach Vienna?',
#  'More Patients in Orange are Getting Diagnosed with Chickenpox',
#  'Lower Hospitalization in Richmond after Mumps Vaccine becomes Mandatory',
#  'Meningitis re-emerges in Medina',
#  'Yulee takes a hit from Spreading Sickness',
#  'Four cases of Zika in Hidalgo County',
#  'Zika symptoms spotted in Hollywood',
#  'Zika arrives in Oaxaca',
#  'More people in Durham are infected with Chlamydia every year',
#  'Authorities are Worried about the Spread of Gonorrhea in Taoyuan City',
#  'Swine Flu re-emerges in La Jolla',
#  'Tuberculosis Outbreak in Hartford',
#  'Rumors about Mumps Spreading in New Bedford have been Refuted',
#  'Respiratory Syncytial Virus Vaccine is now Required in Tulsa',
#  'More people in Indianapolis are infected with Norovirus every year',
#  'Lower Hospitalization in Dhaka after Measles Vaccine becomes Mandatory',
#  'Albany Residents Recieve Respiratory Syncytial Virus vaccine',
#  'The Spread of Chikungunya in Davidson has been Confirmed',
#  'Rotavirus Vaccine is now Required in Starkville',
#  'Schools in Yaounde Closed Due to Mumps Outbreak',
#  'More people in Nadi are infected with HIV every year',
#  'Tocumen tests new cure for Hepatitis A',
#  'Phnom Penh hit by Zika Threat',
#  'Zika Troubles come to Harlingen',
#  'Zika spreads to Barranquilla',
#  'Milwaukee authorities confirmed the spread of Rhinovirus',
#  'Mad Cow Disease Hits Rotterdam',
#  'Zika symptoms spotted in Arlington',
#  'West Nile Virus Hits Yogyakarta',
#  'More Patients in Dublin are Getting Diagnosed with Bronchitis',
#  'Rumors about Tuberculosis Spreading in Baud have been Refuted',
#  'Rumors about West Nile Virus Spreading in Salem have been Refuted',
#  'St. Catharines Patient in Critical Condition after Contracting Dengue',
#  'Zika case reported in Los Fresnos',
#  'More Zika patients reported in Camacari',
#  'Outbreak of Zika in Pasig City',
#  'Zika Troubles come to Kampong Cham',
#  'Zika case reported in Rizal',
#  'Zika Spreads to Palm Beach Gardens',
#  'More people in Saint Petersburg are infected with Varicella every year',
#  'Spike of Herpes Cases in Meriden',
#  'Zika case reported in Abilene',
#  'Outbreak of Zika in Palm Springs',
#  'Halifax is infested with Swine Flu',
#  'Zika arrives in Natal',
#  'Herpes Keeps Spreading in Rochester',
#  'Zika case reported in Phetchabun',
#  'How to Avoid Pneumonia in Bullhead City',
#  'West Nile Virus re-emerges in Wellington',
#  'Rumors about Pneumonia spreading in Ottawa have been refuted',
#  'Meningitis re-emerges in Summerville',
#  'Pneumonia Symptoms Spread all over Bloomington',
#  'More Patients in Stuttgart are Getting Diagnosed with Rabies',
#  'Schools in Glasgow Closed Due to Hepatitis B Outbreak',
#  'Phoenix Residents Recieve Syphilis vaccine',
#  'More people in Boucau are infected with HIV every year',
#  'Spanish flu spreading in Madrid',
#  'Rabies Hits Madrid',
#  'Zika Outbreak in Weslaco',
#  'How to Avoid Chlamydia in Santiago',
#  'Rotavirus Vaccine is now Required in Las Cumbres',
#  'Mumps Symptoms Spread all over Jefferson',
#  'Mad Cow Outbreak Spreading in Ennis',
#  'Southampton Patient in Critical Condition after Contracting Tuberculosis',
#  'The Spread of Rhinovirus in Boardman has been Confirmed',
#  'Richland Center is infested with Hepatitis B',
#  'Authorities are Worried about the Spread of Chickenpox in Richmond',
#  'Chikungunya re-emerges in Kobe',
#  'Malaria Vaccine is now Required in Schenectady',
#  'Hepatitis D has Arrived in Grenoble',
#  'West Nile Virus Symptoms Spread all over Yerevan',
#  'Zika Outbreak in Sincelejo',
#  'Rumors about HIV spreading in Montpellier have been refuted',
#  'Praia tests new cure for Pneumonia',
#  'Bronchitis Outbreak in Manhasset',
#  'Lower Hospitalization in Lakewood after Hepatitis B Vaccine becomes Mandatory',
#  'Zika spreads to Kuching',
#  'Spike of Rotavirus Cases in Omaha',
#  'Tuberculosis re-emerges in Silver Springs',
#  'Will West Nile Virus vaccine help Coronado?',
#  'Zika case confirmed in Lorain',
#  'Chickenpox Hits Simpsonville',
#  'Framingham Residents Receive Measles vaccine',
#  'Rumors about Mad Cow Disease Brighton have been Refuted',
#  'Zika case reported in Jacobina',
#  'Bridgeport authorities confirmed the spread of West Nile Virus',
#  'Zika Troubles come to Padre Las Casas',
#  'Measles Vaccine is now Required in Wailuku',
#  'Zika symptoms spotted in Surat',
#  'Rumors about Influenza Spreading in Dobbs Ferry have been Refuted',
#  'More contaminated cattle reported in Bedford',
#  'Zika in Tamarac!',
#  'Will Measles vaccine help Milford?',
#  'Spike of Norovirus Cases in Huddersfield',
#  'Rhinovirus Hits Bakersfield',
#  'Lower Hospitalization in Papeete after Measles Vaccine becomes Mandatory',
#  'Zika arrives in Udon Thani',
#  'Spike of Dengue Cases in Stockholm',
#  'More people in Berkeley are infected with Swine Flu every year',
#  'Outbreak of Zika in Destin',
#  'Zika only the latest mosquito-borne threat to New Orleans',
#  'Will Swine Flu vaccine help Annapolis?',
#  'Lower Hospitalization in Monroe after Hepatitis D Vaccine becomes Mandatory',
#  'New medicine wipes out Dengue in Saginaw',
#  'Spike of Rhinovirus Cases in Sevierville',
#  'Duisburg up in Arms over Mad Cow Disease',
#  'New medicine wipes out Mumps in Saint Charles',
#  'Case of Chikungunya Reported in Gaithersburg',
#  'How to Avoid Respiratory Syncytial Virus in San Bernardino',
#  'Laventille authorities confirmed the spread of Rhinovirus',
#  'More Zika patients reported in Waco',
#  'Will Herpes vaccine help Newcastle?',
#  'Erie County sets Zika traps',
#  'More people in Huron are infected with Dengue every year',
#  'How to Avoid Norovirus in Greenville',
#  'More Zika patients reported in Calumpang',
#  'Zika symptoms spotted in Quisqueya',
#  'Rumors about Hepatitis D Spreading in Montreal have been Refuted',
#  'Zika symptoms spotted in Fortaleza',
#  'Rumors about Bronchitis spreading in Bundaberg have been refuted',
#  'Hepatitis A re-emerges in Stamford',
#  'Schools in Huntington Closed Due to Rotavirus Outbreak',
#  'Will Mad Cow Vaccine Help Bristol?',
#  'Chickenpox Comes to Stillwater',
#  'The Spread of Meningitis in Imperial has been Confirmed',
#  'Will Tuberculosis vaccine help Cherry Creek?',
#  'Gympie Patient in Critical Condition after Contracting Chlamydia',
#  'Case of Measles Reported in Springdale',
#  'Norwalk Encounters Severe Symptoms of Malaria',
#  'Zika arrives in Orange City',
#  'Pilsen Encounters Severe Symptoms of Malaria',
#  'Will Hepatitis B vaccine help La Paz?',
#  'Zika Outbreak in Puducherry',
#  'More Zika patients reported in Carrollton',
#  'Will Rabies vaccine help Tangier?',
#  'Zika symptoms spotted in Iquitos',
#  'West Nile Virus Exposure in Racine',
#  'The Spread of Hepatitis E in Lansing has been Confirmed',
#  'West Nile Virus Exposure in Alpharetta',
#  'Pedro Juan Caballero Encounters Severe Symptoms of Pneumonia',
#  'More Zika patients reported in Melbourne',
#  'Zika Troubles come to La Libertad',
#  'Herpes Vaccine is now Required in Mattoon',
#  'Kent is infested with Rabies',
#  'Zika symptoms spotted in Bonita Springs',
#  'The Spread of Malaria in Brazzaville has been Confirmed',
#  'More Zika patients reported in Fort Myers',
#  'Zika spreads to Lewisville',
#  'Ogden is infested with Gonorrhea',
#  'Fort Hood Reports its First Zika Patient',
#  'Huzhou Residents Receive Hepatitis B vaccine',
#  'New medicine wipes out Rabies in Newburgh',
#  'Iowa City Encounters Severe Symptoms of Rhinovirus',
#  'Spike of Rabies Cases in Managua',
#  'Outbreak of Zika in Santa Elena',
#  'Mumps Hits Howard Beach',
#  'The Spread of Gonorrhea in Reno has been Confirmed',
#  'How to Avoid Rhinovirus in Plainfield',
#  'Rumors about Varicella spreading in Carlsbad have been refuted',
#  'Scranton authorities confirmed the spread of Gonorrhea',
#  'Mad Cow Disease Disastrous to Brussels',
#  'Zika spreads to Olinda',
#  'Hallandale Beach a Victim of Zika Outbreak',
#  'Rhinovirus re-emerges in Storrs',
#  'Germantown authorities confirmed the spread of Chickenpox',
#  'Rumors about Rotavirus spreading in North Platte have been refuted',
#  'Spike of Hepatitis C Cases in Golden',
#  'Authorities are Worried about the Spread of Hepatitis D in Ganja',
#  'Dengue Exposure in Kathmandu',
#  'Tuberculosis has Arrived in Fairfield',
#  'Outbreak of Zika in Kozhikode',
#  'Bronchitis Symptoms Spread all over Santa Fe',
#  'More Patients in Alexandria are Getting Diagnosed with Mumps',
#  'Pneumonia Exposure in Alhambra',
#  'Hepatitis C re-emerges in Damascus',
#  'Lower Hospitalization in Pekanbaru after Rotavirus Vaccine becomes Mandatory',
#  'Spike of Meningitis Cases in Druid Hills',
#  'Schools in Bentonville Closed Due to Hepatitis B Outbreak',
#  'Hepatitis E Hits Hammond',
#  'Schools in Bridgeton Closed Due to Mumps Outbreak',
#  'Biloxi Residents Recieve Chlamydia vaccine',
#  'Case of Mad Cow Disease Reported in Hilden',
#  'Rumors about Rabies Spreading in Khartoum have been Refuted',
#  'Harare is infested with Pneumonia',
#  'Zika symptoms spotted in Sibu',
#  'Zika arrives in Quezon',
#  'More Patients in Crawfordsville are Getting Diagnosed with Rabies',
#  'Spike of Hepatitis B Cases in Greenville',
#  'Authorities are Worried about the Spread of Hepatitis D in Akron',
#  'More Zika patients reported in Nuevo Laredo',
#  'Bronchitis Keeps Spreading in San Mateo',
#  'Zika arrives in Boca Raton',
#  'Bradenton Experiences Zika Troubles',
#  'Chlamydia Symptoms Spread all over University City',
#  'Wisconsin Rapids Patient in Critical Condition after Contracting Chickenpox',
#  'Zika spreads to Kissimmee',
#  'Herpes Symptoms Spread all over Fremont',
#  'Spike of Pneumonia Cases in The Bronx',
#  'Authorities are Worried about the Spread of Hepatitis D in North Bay',
#  'The Spread of Herpes in Baku has been Confirmed',
#  'Will Measles vaccine help Sochi?',
#  'Tuberculosis Symptoms Spread all over Caguas',
#  'HIV has Arrived in Tacoma',
#  'Malaria re-emerges in Nashua',
#  'Arvada is infested with Syphilis',
#  'Spike of Syphilis Cases in West Monroe',
#  'More Zika patients reported in Ribeirao Preto',
#  'Martinsville tests new cure for Measles',
#  'Deerfield tests new cure for Measles',
#  'Contaminated Meat Brings Trouble for Bonn Farmers',
#  'More Patients in Magnolia are Getting Diagnosed with Malaria',
#  'Hepatitis A re-emerges in Foster City',
#  'How to Avoid Tuberculosis in Santa Monica',
#  'Zika reported in Fort Pierce',
#  'Authorities are Worried about the Spread of Syphilis in Pyongyang',
#  'Zika spreads to Winter Park',
#  'Durango is infested with Hepatitis B',
#  'Hepatitis A has not Left Staten Island',
#  'Mpika authorities confirmed the spread of Chikungunya',
#  'Gladstone Encounters Severe Symptoms of Dengue',
#  'Mad Cow Disease Hits London',
#  'New Milford Patient in Critical Condition after Contracting Respiratory Syncytial Virus',
#  'More people in Palo Alto are infected with HIV every year',
#  'HIV Symptoms Spread all over Hinthada',
#  'Zika symptoms spotted in Quito',
#  'Vineland authorities confirmed the spread of Chlamydia',
#  'Sulu, Zamboanga brace for Zika',
#  'More Zika patients reported in Custodia',
#  'Tupelo Residents Recieve Syphilis vaccine',
#  'Rumors about Syphilis spreading in Penal have been refuted',
#  'Spanish Flu Outbreak in Lisbon',
#  'Spanish Flu Spreading through Madrid',
#  'Barcelona Struck by Spanish Flu',
#  'Spanish Flu Outbreak in Lisbon',
#  'Spanish Flu Spreading through Madrid',
#  'Barcelona Struck by Spanish Flu',
#  'The Spread of Dengue in Yakima has been Confirmed',
#  'Tuberculosis Hits Luanda',
#  'Will West Nile Virus vaccine help Dumai?',
#  'Rumors about Chlamydia spreading in Redmond have been refuted',
#  'Case of Varicella Reported in Concord',
#  'Zika virus case reported in Rockland',
#  'Zika investigators coming to Mankato',
#  'Toms River Encounters Severe Symptoms of Respiratory Syncytial Virus',
#  'The Spread of Malaria in Zanzibar has been Confirmed',
#  "Malaria Outbreak Hits Zanzibar's Tourist Industry",
#  'Tourist Perishes from Malaria in Arusha',
#  'Herpes Symptoms Spread all over New Kingston',
#  'More people in Yokohama are infected with Norovirus every year',
#  'More people in Kitwe are infected with Respiratory Syncytial Virus every year',
#  'Hepatitis D Keeps Spreading in Bismarck',
#  'Varicella Outbreak in Minot',
#  'Malaria has Arrived in Terrebonne',
#  'Chikungunya Keeps Spreading in North Vancouver',
#  'Authorities are Worried about the Spread of Chickenpox in Hemet',
#  'Fort Belvoir tests new cure for Hepatitis C',
#  'More people in Oak Brook are infected with Respiratory Syncytial Virus every year',
#  'Rumors about Hepatitis C spreading in Darien have been refuted',
#  'The Spread of West Nile Virus in Fairfield has been Confirmed',
#  'Princeton Encounters Severe Symptoms of Dengue',
#  'Norovirus Keeps Spreading in Copenhagen',
#  'Wuhan is infested with Varicella',
#  'Zika spreads to San Luis Potosi',
#  'Outbreak of Zika in Hutchins',
#  'Spike of Norovirus Cases in Canberra',
#  'Zika Troubles come to Greater Noida',
#  'Lower Hospitalization in Palm Springs after Hepatitis A Vaccine becomes Mandatory',
#  'Longwood volunteers spreading Zika awareness',
#  'Outbreak of Zika in Leesburg',
#  'Authorities are Worried about the Spread of Tuberculosis in Cantu',
#  'Zika symptoms spotted in Quixere',
#  'New medicine wipes out HIV in Kihei',
#  'Sangre Grande Residents Recieve Gonorrhea vaccine',
#  'Outbreak of Zika in Colombo',
#  'Will Rotavirus vaccine help Addis Ababa?',
#  'Stony Brook University experts discuss Zika virus',
#  'Lower Hospitalization in Janesville after Varicella Vaccine becomes Mandatory',
#  'Rabies Outbreak in Altus',
#  'Miami resident suggests Zika precautions',
#  'Zika Troubles come to Jaen',
#  'Hepatitis B Exposure in Edinburgh',
#  'Zika case reported in Reynosa',
#  'Schools in Tulare Closed Due to Mumps Outbreak',
#  'More Zika patients reported in Chennai',
#  'Hepatitis D Keeps Spreading in Danvers',
#  'Authorities a Miami',
#  'Zika case reported in Medellin',
#  'Spike of Tuberculosis Cases in Albuquerque',
#  'More people in Cranford are infected with Hepatitis A every year',
#  'West Nile Virus Hits Monroe',
#  'Pneumonia Outbreak in Springville',
#  'Zika arrives in San Onofre',
#  'Lung Cancer Rates Increasing in Moscow',
#  'Rumors about Rotavirus Spreading in Joliet have been Refuted',
#  'More Zika patients reported in Chanthaburi',
#  'Lawrenceville is infested with Dengue',
#  'Zika Reported in Ciudad Acuna',
#  'Zika case reported in Limoeiro',
#  'Ibadan tests new cure for Malaria',
#  'Gonorrhea has Arrived in Avon Lake',
#  'Pneumonia has not Left Kinshasa',
#  'Respiratory Syncytial Virus Hits Henderson',
#  'More Zika patients reported in Lakeland',
#  'Malaria Vaccine is now Required in Winona',
#  'More Patients in Canton are Getting Diagnosed with Norovirus',
#  'Ronkonkoma is infested with Chickenpox',
#  'Kedougou tests new cure for Hepatitis C',
#  'Gonorrhea Exposure in Norwalk',
#  'How to Avoid Rhinovirus in Medford',
#  'Hepatitis D Symptoms Spread all over Evansville',
#  'New medicine wipes out Herpes in Bossier City',
#  'Pneumonia Exposure in San Jose',
#  'Authorities are Worried about the Spread of Mad Cow Disease in Edinburgh',
#  'Duluth Patient in Critical Condition after Contracting Rotavirus',
#  'Measles Hits Davos',
#  'Norfolk tests new cure for Herpes',
#  'More Zika patients reported in Botucatu',
#  'Manassas Encounters Severe Symptoms of Measles',
#  'Fayetteville authorities confirmed the spread of HIV',
#  'Varicella Exposure in Cambridge',
#  'Hepatitis A Vaccine is now Required in Fukushima',
#  'Zika Outbreak in South Miami',
#  'Hepatitis D Symptoms Spread all over North Bethesda',
#  'Panama Cityâ€™s first Zika related death',
#  'West Nile Virus has Arrived in Dongguan',
#  'Zika arrives in Belmopan',
#  'Zika seminars in Yuma County',
#  'Rumors about Hepatitis E Spreading in Morristown have been Refuted',
#  'Mumps Outbreak in Joplin',
#  'Spike of Hepatitis E Cases in Morehead City',
#  'Authorities are Worried about the Spread of Mumps in Corona',
#  'Schools in Danville Closed Due to Tuberculosis Outbreak',
#  'Outbreak of Zika in Alvorada',
#  'Marquette tests new cure for Hepatitis A',
#  'Norovirus Vaccine is now Required in Anaheim',
#  'Zika Outbreak in Manaus',
#  'Zika spreads to Caucasia',
#  'Case of Malaria Reported in Aurora',
#  'Manchester Residents Recieve Influenza vaccine',
#  'Zika spreads to Kamphaeng Phet',
#  'Rotavirus Vaccine is now Required in Labasa',
#  'The Spread of Hepatitis E in Fargo has been Confirmed',
#  'Zika Outbreak in Mexicali',
#  'West Nile Virus Keeps Spreading in Hauppauge',
#  'Bronchitis Keeps Spreading in Hayward',
#  'Schools in Coamo Closed Due to Rhinovirus Outbreak',
#  'Zika arrives in Dangriga',
#  'Zika spreads to Plant City',
#  'Chlamydia Exposure in Sanaa',
#  'Zika Reported in North Miami Beach',
#  'More Patients in Kensington are Getting Diagnosed with Varicella',
#  'More Patients in Maynard are Getting Diagnosed with Syphilis',
#  'Case of West Nile Virus Reported in Riverside',
#  'Northfield Encounters Severe Symptoms of Herpes',
#  'The Spread of Respiratory Syncytial Virus in Monroe has been Confirmed',
#  'How to Avoid Hepatitis B in Trenton',
#  'Zika Reported in Ilopango',
#  'Barstow Patient in Critical Condition after Contracting Herpes',
#  'Hepatitis D Exposure in Aswan',
#  'Will Gonorrhea vaccine help East Moline?',
#  'New medicine wipes out Influenza in Redlands',
#  'How to Avoid Contaminated Meat when Visiting Basel',
#  'More Zika patients reported in Kampong Speu',
#  'Alameda Residents Recieve Rabies vaccine',
#  'Mad Cow Disease Detected in Lyon',
#  'Memphis Encounters Severe Symptoms of Swine Flu',
#  'Zika Troubles come to Delray Beach',
#  'How to Avoid Chikungunya in Hampton',
#  'Zika Reported in Sao Jose',
#  'Case of Norovirus Reported in Stratford',
#  'How to Avoid Hepatitis E in South Bend',
#  'Hepatitis C Outbreak in Bethlehem',
#  'Davenport is infested with Dengue',
#  'Rumors about Swine Flu spreading in Suzhou have been refuted',
#  'Malaria Vaccine is now Required in Elyria',
#  'Zika case reported in Antioquia',
#  'Case of Swine Flu Reported in Tbilisi',
#  'Chikungunya has not Left Pismo Beach',
#  'Zika spreads to La Joya',
#  'Influenza Keeps Spreading in Suffolk',
#  'More people in Allentown are infected with Chlamydia every year',
#  'Mad Cow Disease re-emerges in Bedford',
#  'Authorities are Worried about the Spread of Hepatitis B in Yiwu',
#  'Zika Outbreak in Yurimaguas',
#  'Dengue Outbreak in Easton',
#  'Varicella has Arrived in Milton',
#  'New medicine wipes out Meningitis in Sevilla',
#  'Authorities are Worried about the Spread of Varicella in Clovis',
#  'More Zika patients reported in Fort Worth',
#  'Zika symptoms spotted in Boynton Beach',
#  'Outbreak of Zika in Portoviejo',
#  'Influenza Exposure in Muscat',
#  'Rumors about Rabies spreading in Jerusalem have been refuted',
#  'More Zika patients reported in Indang',
#  'Suva authorities confirmed the spread of Rotavirus',
#  'More Zika patients reported in Bella Vista',
#  'Zika Outbreak in Wichita Falls']

# %%
headlines.sort()

headlines
# Out:
# ['18 new Zika Cases in Bogota',
#  '19 new Zika Cases in Sengkang',
#  'Alameda Residents Recieve Rabies vaccine',
#  'Albany Residents Recieve Respiratory Syncytial Virus vaccine',
#  'Antipolo under threat from Zika Virus',
#  'Arhus is infested with Bronchitis',
#  'Arvada is infested with Syphilis',
#  'Authorities a Miami',
#  'Authorities are Worried about the Spread of Bronchitis in Silver Spring',
#  'Authorities are Worried about the Spread of Chickenpox in Hemet',
#  'Authorities are Worried about the Spread of Chickenpox in Richmond',
#  'Authorities are Worried about the Spread of Dengue in Kingston',
#  'Authorities are Worried about the Spread of Gonorrhea in Taoyuan City',
#  'Authorities are Worried about the Spread of Hepatitis B in Yiwu',
#  'Authorities are Worried about the Spread of Hepatitis D in Akron',
#  'Authorities are Worried about the Spread of Hepatitis D in Ganja',
#  'Authorities are Worried about the Spread of Hepatitis D in North Bay',
#  'Authorities are Worried about the Spread of Influenza in Savannah',
#  'Authorities are Worried about the Spread of Mad Cow Disease in Edinburgh',
#  'Authorities are Worried about the Spread of Mad Cow Disease in Rome',
#  'Authorities are Worried about the Spread of Mumps in Corona',
#  'Authorities are Worried about the Spread of Norovirus in Buenos Aires',
#  'Authorities are Worried about the Spread of Norovirus in Dubai',
#  'Authorities are Worried about the Spread of Rotavirus in Union',
#  'Authorities are Worried about the Spread of Syphilis in Pyongyang',
#  'Authorities are Worried about the Spread of Tuberculosis in Abuja',
#  'Authorities are Worried about the Spread of Tuberculosis in Cantu',
#  'Authorities are Worried about the Spread of Varicella in Clovis',
#  'BREAKING â€“ Zika in Missoula',
#  'Bad Water Leads to Sickness in Flint, Michigan',
#  'Baltimore plans for Zika virus',
#  'Barcelona Struck by Spanish Flu',
#  'Barcelona Struck by Spanish Flu',
#  'Barstow Patient in Critical Condition after Contracting Herpes',
#  'Batangas Tourism Takes a Hit as Virus Spreads',
#  'Beijing team cracks Zika secret',
#  'Belize City under threat from Zika',
#  'Benton Residents Recieve Pneumonia vaccine',
#  'Biloxi Residents Recieve Chlamydia vaccine',
#  'Birmingham Residents Recieve Rabies vaccine',
#  'Bradenton Experiences Zika Troubles',
#  'Bridgeport authorities confirmed the spread of West Nile Virus',
#  'Brisbane is infested with Meningitis',
#  'Bronchitis Keeps Spreading in Hayward',
#  'Bronchitis Keeps Spreading in San Mateo',
#  'Bronchitis Outbreak in Manhasset',
#  'Bronchitis Symptoms Spread all over Santa Fe',
#  'Bronchitis re-emerges in Tehran',
#  'Brownsville teen contracts Zika virus',
#  'Can Zika make it here to Vero Beach?',
#  'Cancun hit by Outbreak of Party Fever!',
#  'Caracas patient dies',
#  'Carnival under threat in Rio De Janeiro due to Zika outbreak',
#  'Case of Chikungunya Reported in Gaithersburg',
#  'Case of Hepatitis A Reported in Calgary',
#  'Case of Hepatitis E Reported in Melbourne',
#  'Case of Mad Cow Disease Reported in Hilden',
#  'Case of Malaria Reported in Aurora',
#  'Case of Measles Reported in Springdale',
#  'Case of Measles Reported in Vancouver',
#  'Case of Mumps Reported in Dayton',
#  'Case of Norovirus Reported in Stratford',
#  'Case of Swine Flu Reported in Tbilisi',
#  'Case of Varicella Reported in Concord',
#  'Case of West Nile Virus Reported in Riverside',
#  "Chicago's First Zika Case Confirmed",
#  'Chickenpox Comes to Stillwater',
#  'Chickenpox Hits Simpsonville',
#  'Chickenpox has Arrived in Chula Vista',
#  'Chikungunya Exposure in Toledo',
#  'Chikungunya Hits Denver',
#  'Chikungunya Keeps Spreading in North Vancouver',
#  'Chikungunya has not Left Pismo Beach',
#  'Chikungunya re-emerges in Kobe',
#  'Chlamydia Exposure in Sanaa',
#  'Chlamydia Symptoms Spread all over University City',
#  'Cholera outbreak in Dakar',
#  'Contaminated Meat Brings Trouble for Bonn Farmers',
#  'Could Zika Reach New York City?',
#  'Dallas man comes down with case of Zika',
#  'Davenport is infested with Dengue',
#  'Deerfield tests new cure for Measles',
#  'Dengue Exposure in Kathmandu',
#  'Dengue Outbreak in Easton',
#  'Doral hit by Deadly Virus',
#  'Duisburg up in Arms over Mad Cow Disease',
#  'Duluth Patient in Critical Condition after Contracting Rotavirus',
#  'Durango is infested with Hepatitis B',
#  'Ebola outbreak in Kampala',
#  'El Paso fighting Zika',
#  'Erie County sets Zika traps',
#  'Escondido neighborhood to get sprayed for Zika virus',
#  'Fayetteville authorities confirmed the spread of HIV',
#  'First Case of Zika in Miami Beach',
#  'First Columbus Zika case',
#  'First Zika Case in Cincinnati',
#  'First Zika case confirmed in Yangon',
#  'Flu outbreak in Galveston, Texas',
#  'Flu season hits Boston',
#  'Fort Belvoir tests new cure for Hepatitis C',
#  'Fort Collins Encounters Severe Symptoms of Gonorrhea',
#  'Fort Hood Reports its First Zika Patient',
#  'Four cases of Zika in Hidalgo County',
#  'Framingham Residents Receive Measles vaccine',
#  'Frisco Woman Tests Positive For Zika Virus',
#  'Gainesville Deals with Disease Concerns',
#  'Geneve Scientists Battle to Find Cure',
#  'Germantown authorities confirmed the spread of Chickenpox',
#  'Gladstone Encounters Severe Symptoms of Dengue',
#  'Gonorrhea Exposure in Norwalk',
#  'Gonorrhea has Arrived in Avon Lake',
#  'Greenwich Establishes Zika Task Force',
#  'Guangzhou Patient in Critical Condition after Contracting Swine Flu',
#  'Gympie Patient in Critical Condition after Contracting Chlamydia',
#  'HIV Keeps Spreading in Boulder',
#  'HIV Symptoms Spread all over Hinthada',
#  'HIV has Arrived in Fairfax',
#  'HIV has Arrived in Tacoma',
#  'Halifax is infested with Swine Flu',
#  'Hallandale Beach a Victim of Zika Outbreak',
#  'Harare is infested with Pneumonia',
#  'Hepatitis A Vaccine is now Required in Fukushima',
#  'Hepatitis A has not Left Staten Island',
#  'Hepatitis A re-emerges in Foster City',
#  'Hepatitis A re-emerges in Stamford',
#  'Hepatitis B Comes to Kansas City',
#  'Hepatitis B Exposure in Edinburgh',
#  'Hepatitis B Vaccine is now Required in Quebec',
#  'Hepatitis B has not Left Florence',
#  'Hepatitis C Outbreak in Bethlehem',
#  'Hepatitis C Outbreak in Danbury',
#  'Hepatitis C re-emerges in Damascus',
#  'Hepatitis D Exposure in Aswan',
#  'Hepatitis D Keeps Spreading in Bismarck',
#  'Hepatitis D Keeps Spreading in Danvers',
#  'Hepatitis D Symptoms Spread all over Evansville',
#  'Hepatitis D Symptoms Spread all over North Bethesda',
#  'Hepatitis D has Arrived in Grenoble',
#  'Hepatitis E Hits Hammond',
#  'Hepatitis E has not Left Libreville',
#  'Hepatitis E re-emerges in Santa Rosa',
#  'Herpes Keeps Spreading in Rochester',
#  'Herpes Symptoms Spread all over Fremont',
#  'Herpes Symptoms Spread all over New Kingston',
#  'Herpes Vaccine is now Required in Mattoon',
#  'Hillsborough uses innovative trap against Zika 20 minutes ago',
#  'Hollywood Outbreak Film Premieres',
#  'Hospitals in Hanoi fill up with Zika patients',
#  'How to Avoid Chikungunya in Hampton',
#  'How to Avoid Chlamydia in Santiago',
#  'How to Avoid Contaminated Meat when Visiting Basel',
#  'How to Avoid Gonorrhea in Shreveport',
#  'How to Avoid Hepatitis B in Trenton',
#  'How to Avoid Hepatitis B in Waldorf',
#  'How to Avoid Hepatitis E in South Bend',
#  'How to Avoid Norovirus in Greenville',
#  'How to Avoid Pneumonia in Bullhead City',
#  'How to Avoid Respiratory Syncytial Virus in San Bernardino',
#  'How to Avoid Rhinovirus in Lemon Grove',
#  'How to Avoid Rhinovirus in Medford',
#  'How to Avoid Rhinovirus in Plainfield',
#  'How to Avoid Tuberculosis in Santa Monica',
#  'Huzhou Residents Receive Hepatitis B vaccine',
#  'Ibadan tests new cure for Malaria',
#  'Influenza Exposure in Muscat',
#  'Influenza Keeps Spreading in Suffolk',
#  'Influenza has not Left Sacramento',
#  'Iowa City Encounters Severe Symptoms of Rhinovirus',
#  'Is Lafayette prepared to combat Zika?',
#  'Is Zika virus in Majuro?',
#  'Ithaca is infested with Dengue',
#  'Jacksonville man hit by Zika',
#  'Johannesburg Patient in Critical Condition after Contracting Pneumonia',
#  'Kedougou tests new cure for Hepatitis C',
#  'Kent is infested with Rabies',
#  'Key Zika Findings in San Diego Institute',
#  'Kuala Lumpur is Hit By Zika Threat',
#  'Lausanne Residents Recieve Meningitis vaccine',
#  'Laventille authorities confirmed the spread of Rhinovirus',
#  'Lawrenceville is infested with Dengue',
#  'Lima tries to address Zika Concerns',
#  'London Health Unit Tracks Mad Cow Disease',
#  'Longwood volunteers spreading Zika awareness',
#  'Louisiana Zika cases up to 26',
#  'Lower Hospitalization in Auckland after Hepatitis D Vaccine becomes Mandatory',
#  'Lower Hospitalization in Dhaka after Measles Vaccine becomes Mandatory',
#  'Lower Hospitalization in Entebbe after Rabies Vaccine becomes Mandatory',
#  'Lower Hospitalization in Janesville after Varicella Vaccine becomes Mandatory',
#  'Lower Hospitalization in Lakewood after Hepatitis B Vaccine becomes Mandatory',
#  'Lower Hospitalization in Monroe after Hepatitis D Vaccine becomes Mandatory',
#  'Lower Hospitalization in Palm Springs after Hepatitis A Vaccine becomes Mandatory',
#  'Lower Hospitalization in Papeete after Measles Vaccine becomes Mandatory',
#  'Lower Hospitalization in Pekanbaru after Rotavirus Vaccine becomes Mandatory',
#  'Lower Hospitalization in Richmond after Mumps Vaccine becomes Mandatory',
#  'Lung Cancer Rates Increasing in Moscow',
#  'Mad Cow Disease Detected in Lyon',
#  'Mad Cow Disease Disastrous to Brussels',
#  'Mad Cow Disease Hits London',
#  'Mad Cow Disease Hits Naples',
#  'Mad Cow Disease Hits Rotterdam',
#  'Mad Cow Disease Re-emerges in Chatham',
#  'Mad Cow Disease Spreads to Margate',
#  'Mad Cow Disease re-emerges in Bedford',
#  'Mad Cow Outbreak Spreading in Ennis',
#  'Mad Cow case in Murcia',
#  'Madera Patient in Critical Condition after Contracting Rabies',
#  'Madison lab developing vaccine against Zika virus [The Wisconsin State Journal]',
#  'Maka City Experiences Influenza Outbreak',
#  'Malaria Exposure in Sussex',
#  "Malaria Outbreak Hits Zanzibar's Tourist Industry",
#  'Malaria Vaccine is now Required in Elyria',
#  'Malaria Vaccine is now Required in Schenectady',
#  'Malaria Vaccine is now Required in Winona',
#  'Malaria has Arrived in Terrebonne',
#  'Malaria is Spreading in Johannesburg',
#  'Malaria re-emerges in Boise',
#  'Malaria re-emerges in Nashua',
#  'Manassas Encounters Severe Symptoms of Measles',
#  'Manchester Residents Recieve Influenza vaccine',
#  'Mandaluyong City under Siege by Virus',
#  'Manhattan Residents Recieve HIV vaccine',
#  'Marquette tests new cure for Hepatitis A',
#  'Martinsville tests new cure for Measles',
#  'Measles Hits Davos',
#  'Measles Vaccine is now Required in Wailuku',
#  'Measles has not Left Brooklyn',
#  'Mecca tests new cure for Chikungunya',
#  'Memphis Encounters Severe Symptoms of Swine Flu',
#  'Meningitis re-emerges in Medina',
#  'Meningitis re-emerges in Nassau',
#  'Meningitis re-emerges in Summerville',
#  'Miami resident suggests Zika precautions',
#  'Milwaukee authorities confirmed the spread of Rhinovirus',
#  'Mobile authorities confirmed the spread of Bronchitis',
#  'Molo Cholera Spread Causing Concern',
#  'Montevideo Encounters Severe Symptoms of Rotavirus',
#  'More Livestock in Fontainebleau are infected with Mad Cow Disease',
#  'More Patients in Alexandria are Getting Diagnosed with Mumps',
#  'More Patients in Cambridge are Getting Diagnosed with Chickenpox',
#  'More Patients in Canton are Getting Diagnosed with Norovirus',
#  'More Patients in Crawfordsville are Getting Diagnosed with Rabies',
#  'More Patients in Dublin are Getting Diagnosed with Bronchitis',
#  'More Patients in Kensington are Getting Diagnosed with Varicella',
#  'More Patients in Magnolia are Getting Diagnosed with Malaria',
#  'More Patients in Maynard are Getting Diagnosed with Syphilis',
#  'More Patients in Orange are Getting Diagnosed with Chickenpox',
#  'More Patients in Stuttgart are Getting Diagnosed with Rabies',
#  'More Quezon City Zika Transmissions',
#  'More Zika cases in Soyapango',
#  'More Zika patients reported in Austin',
#  'More Zika patients reported in Bella Vista',
#  'More Zika patients reported in Botucatu',
#  'More Zika patients reported in Calumpang',
#  'More Zika patients reported in Camacari',
#  'More Zika patients reported in Carrollton',
#  'More Zika patients reported in Chanthaburi',
#  'More Zika patients reported in Chennai',
#  'More Zika patients reported in Custodia',
#  'More Zika patients reported in Davao',
#  'More Zika patients reported in Fort Myers',
#  'More Zika patients reported in Fort Worth',
#  'More Zika patients reported in Indang',
#  'More Zika patients reported in Joao Pessoa',
#  'More Zika patients reported in Kampong Speu',
#  'More Zika patients reported in Lakeland',
#  'More Zika patients reported in Mcallen',
#  'More Zika patients reported in Melbourne',
#  'More Zika patients reported in Nuevo Laredo',
#  'More Zika patients reported in Pensacola',
#  'More Zika patients reported in Ribeirao Preto',
#  'More Zika patients reported in Waco',
#  'More contaminated cattle reported in Bedford',
#  'More people in Allentown are infected with Chlamydia every year',
#  'More people in Berkeley are infected with Swine Flu every year',
#  'More people in Boucau are infected with HIV every year',
#  'More people in Cranford are infected with Hepatitis A every year',
#  'More people in Durham are infected with Chlamydia every year',
#  'More people in Huron are infected with Dengue every year',
#  'More people in Indianapolis are infected with Norovirus every year',
#  'More people in Kitwe are infected with Respiratory Syncytial Virus every year',
#  'More people in Mclean are infected with Hepatitis A every year',
#  'More people in Nadi are infected with HIV every year',
#  'More people in Oak Brook are infected with Respiratory Syncytial Virus every year',
#  'More people in Palo Alto are infected with HIV every year',
#  'More people in Saint Petersburg are infected with Varicella every year',
#  'More people in Toronto are infected with Hepatitis E every year',
#  'More people in Yokohama are infected with Norovirus every year',
#  'Mosquito control efforts in St. Louis take new tactics with Zika threat',
#  'Mpika authorities confirmed the spread of Chikungunya',
#  "Mumbai's Health Minister warns of more Zika cases",
#  'Mumps Hits Howard Beach',
#  'Mumps Outbreak in Joplin',
#  'Mumps Symptoms Spread all over Jefferson',
#  'Mystery Virus Spreads in Recife, Brazil',
#  'Nashville takes precautions against Zika',
#  'New Delhi Addressing Zika Concerns',
#  'New Los Angeles Hairstyle goes Viral',
#  'New Milford Patient in Critical Condition after Contracting Respiratory Syncytial Virus',
#  'New Vaccine on Trial in Bethesda District',
#  'New Zika Case Confirmed in Belo Horizonte',
#  'New Zika Case Confirmed in Sarasota County',
#  'New Zika Case in Kota Kinabalu, Malaysia',
#  'New details in Baton Rouge cop killings',
#  'New medicine wipes out Chikungunya in Tucson',
#  'New medicine wipes out Dengue in Saginaw',
#  'New medicine wipes out HIV in Kihei',
#  'New medicine wipes out Herpes in Bossier City',
#  'New medicine wipes out Influenza in Redlands',
#  'New medicine wipes out Measles in Fresno',
#  'New medicine wipes out Meningitis in Sevilla',
#  'New medicine wipes out Mumps in Saint Charles',
#  'New medicine wipes out Rabies in Newburgh',
#  'New medicine wipes out Tuberculosis in Taipei',
#  'New medicine wipes out West Nile Virus in Ventura',
#  'Nha Trang Zika Outbreak',
#  'Norfolk tests new cure for Herpes',
#  'Norovirus Exposure in Hong Kong',
#  'Norovirus Keeps Spreading in Copenhagen',
#  'Norovirus Vaccine is now Required in Anaheim',
#  'Norovirus has Arrived in Winnipeg',
#  'Northfield Encounters Severe Symptoms of Herpes',
#  'Norwalk Encounters Severe Symptoms of Malaria',
#  'Ogden is infested with Gonorrhea',
#  'Orlando volunteers aid Zika research',
#  'Outbreak of Zika in Alvorada',
#  'Outbreak of Zika in Bacolod City',
#  'Outbreak of Zika in Colombo',
#  'Outbreak of Zika in Corpus Christi',
#  'Outbreak of Zika in Destin',
#  'Outbreak of Zika in Hutchins',
#  'Outbreak of Zika in Kozhikode',
#  'Outbreak of Zika in Leesburg',
#  'Outbreak of Zika in Palm Springs',
#  'Outbreak of Zika in Panama City',
#  'Outbreak of Zika in Pasig City',
#  'Outbreak of Zika in Portoviejo',
#  'Outbreak of Zika in Santa Elena',
#  'Outbreak of Zika in Stephenville',
#  'Oxford tests new cure for HIV',
#  'Panama Cityâ€™s first Zika related death',
#  'Pedro Juan Caballero Encounters Severe Symptoms of Pneumonia',
#  'Petaling Jaya man ill from Zika',
#  'Philadelphia experts track pandemic',
#  'Phnom Penh hit by Zika Threat',
#  'Phoenix Residents Recieve Syphilis vaccine',
#  'Pilsen Encounters Severe Symptoms of Malaria',
#  'Pittsburgh Residents Recieve Norovirus vaccine',
#  'Pneumonia Exposure in Alhambra',
#  'Pneumonia Exposure in San Jose',
#  'Pneumonia Outbreak in Springville',
#  'Pneumonia Symptoms Spread all over Bloomington',
#  'Pneumonia has not Left Kinshasa',
#  'Praia tests new cure for Pneumonia',
#  'Precautionary Zika measures in Rockhampton',
#  'Princeton Encounters Severe Symptoms of Dengue',
#  'Providence Encounters Severe Symptoms of Dengue',
#  'Pune woman diagnosed with Zika',
#  'Rabies Exposure in Hamilton',
#  'Rabies Hits Madrid',
#  'Rabies Outbreak in Altus',
#  'Respiratory Syncytial Virus Hits Henderson',
#  'Respiratory Syncytial Virus Keeps Spreading in Masaya',
#  'Respiratory Syncytial Virus Vaccine is now Required in Tulsa',
#  'Rhinovirus Comes to San Jose',
#  'Rhinovirus Hits Bakersfield',
#  'Rhinovirus has Arrived in Athens',
#  'Rhinovirus re-emerges in Storrs',
#  'Richland Center is infested with Hepatitis B',
#  'Rochester authorities confirmed the spread of Dengue',
#  'Ronkonkoma is infested with Chickenpox',
#  'Rotavirus Vaccine is now Required in Labasa',
#  'Rotavirus Vaccine is now Required in Las Cumbres',
#  'Rotavirus Vaccine is now Required in Starkville',
#  'Rumors about Bronchitis spreading in Bundaberg have been refuted',
#  'Rumors about Chlamydia spreading in Redmond have been refuted',
#  'Rumors about Dengue Spreading in Syracuse have been Refuted',
#  'Rumors about HIV spreading in Montpellier have been refuted',
#  'Rumors about Hepatitis C spreading in Darien have been refuted',
#  'Rumors about Hepatitis D Spreading in Montreal have been Refuted',
#  'Rumors about Hepatitis D Spreading in San Juan Capistrano have been Refuted',
#  'Rumors about Hepatitis D spreading in Albany have been refuted',
#  'Rumors about Hepatitis E Spreading in Morristown have been Refuted',
#  'Rumors about Influenza Spreading in Dobbs Ferry have been Refuted',
#  'Rumors about Mad Cow Disease Brighton have been Refuted',
#  'Rumors about Meningitis spreading in Guatemala City have been refuted',
#  'Rumors about Mumps Spreading in New Bedford have been Refuted',
#  'Rumors about Pneumonia spreading in Ottawa have been refuted',
#  'Rumors about Rabies Spreading in Khartoum have been Refuted',
#  'Rumors about Rabies spreading in Jerusalem have been refuted',
#  'Rumors about Rotavirus Spreading in Joliet have been Refuted',
#  'Rumors about Rotavirus spreading in Huntsville have been refuted',
#  'Rumors about Rotavirus spreading in North Platte have been refuted',
#  'Rumors about Swine Flu spreading in Suzhou have been refuted',
#  'Rumors about Syphilis spreading in Penal have been refuted',
#  'Rumors about Tuberculosis Spreading in Baud have been Refuted',
#  'Rumors about Varicella spreading in Carlsbad have been refuted',
#  'Rumors about West Nile Virus Spreading in Salem have been Refuted',
#  'Saint Croix under Zika threat',
#  'Salt Lake City tests new cure for Respiratory Syncytial Virus',
#  'San Juan reports 1st U.S. Zika-related death amid outbreak',
#  'Sangre Grande Residents Recieve Gonorrhea vaccine',
#  'Santa Barbara tests new cure for Hepatitis C',
#  'Schools in Bentonville Closed Due to Hepatitis B Outbreak',
#  'Schools in Birmingham Closed Due to Measles Outbreak',
#  'Schools in Bridgeton Closed Due to Mumps Outbreak',
#  'Schools in Coamo Closed Due to Rhinovirus Outbreak',
#  'Schools in Danville Closed Due to Tuberculosis Outbreak',
#  'Schools in Glasgow Closed Due to Hepatitis B Outbreak',
#  'Schools in Huntington Closed Due to Rotavirus Outbreak',
#  'Schools in Shenzhen Closed Due to Malaria Outbreak',
#  'Schools in Sydney Closed Due to Respiratory Syncytial Virus Outbreak',
#  'Schools in Tulare Closed Due to Mumps Outbreak',
#  'Schools in Yaounde Closed Due to Mumps Outbreak',
#  'Scientists in Paris to look for answers',
#  'Scranton authorities confirmed the spread of Gonorrhea',
#  'Seattle scientists get $500,000 grant to pursue Zika vaccine New 7:50 pm',
#  'Second Zika Paitient in Brasilia',
#  'Seoul confirms 14th Zika infection',
#  'Sick Livestock Leads to Serious Trouble for Belfort',
#  'Southampton Patient in Critical Condition after Contracting Tuberculosis',
#  'Spanish Flu Outbreak in Barcelona',
#  'Spanish Flu Outbreak in Lisbon',
#  'Spanish Flu Outbreak in Lisbon',
#  'Spanish Flu Sighted in Antigua',
#  'Spanish Flu Spreading through Madrid',
#  'Spanish Flu Spreading through Madrid',
#  'Spanish flu spreading in Madrid',
#  'Spike of Chlamydia Cases in Berlin',
#  'Spike of Chlamydia Cases in Farmington',
#  'Spike of Dengue Cases in Stockholm',
#  'Spike of Hepatitis B Cases in Greenville',
#  'Spike of Hepatitis C Cases in Golden',
#  'Spike of Hepatitis E Cases in Morehead City',
#  'Spike of Herpes Cases in Meriden',
#  'Spike of Meningitis Cases in Druid Hills',
#  'Spike of Norovirus Cases in Canberra',
#  'Spike of Norovirus Cases in Huddersfield',
#  'Spike of Pneumonia Cases in Springfield',
#  'Spike of Pneumonia Cases in The Bronx',
#  'Spike of Rabies Cases in Managua',
#  'Spike of Respiratory Syncytial Virus Cases in Mandalay',
#  'Spike of Rhinovirus Cases in Sevierville',
#  'Spike of Rotavirus Cases in Omaha',
#  'Spike of Syphilis Cases in West Monroe',
#  'Spike of Tuberculosis Cases in Albuquerque',
#  'Spreading Zika reaches Bacoor',
#  'Spreading Zika ruining Cancun fun',
#  'Spring break ruined by Zika in Fort Lauderdale',
#  'St. Catharines Patient in Critical Condition after Contracting Dengue',
#  'Stony Brook University experts discuss Zika virus',
#  'Student sick in Campinas, Brazil',
#  'Sulu, Zamboanga brace for Zika',
#  'Suva authorities confirmed the spread of Rotavirus',
#  'Swine Flu re-emerges in La Jolla',
#  'Syphilis Hits Jefferson',
#  'Syphilis Outbreak in Harrisburg',
#  'Tallahassee Doctors Discuss Zika Virus',
#  'Tampa Bay Area Zika Case Count Climbs',
#  'Tests negative on Windsor Zika carriers',
#  'Thailand-Zika Virus in Bangkok',
#  'The CDC in Atlanta is Growing Worried',
#  'The Spread of Chikungunya in Arcadia has been Confirmed',
#  'The Spread of Chikungunya in Davidson has been Confirmed',
#  'The Spread of Dengue in Yakima has been Confirmed',
#  'The Spread of Gonorrhea in Reno has been Confirmed',
#  'The Spread of Hepatitis E in Fargo has been Confirmed',
#  'The Spread of Hepatitis E in Lansing has been Confirmed',
#  'The Spread of Herpes in Baku has been Confirmed',
#  'The Spread of Malaria in Brazzaville has been Confirmed',
#  'The Spread of Malaria in Zanzibar has been Confirmed',
#  'The Spread of Measles in Spokane has been Confirmed',
#  'The Spread of Meningitis in Imperial has been Confirmed',
#  'The Spread of Respiratory Syncytial Virus in Monroe has been Confirmed',
#  'The Spread of Rhinovirus in Boardman has been Confirmed',
#  'The Spread of West Nile Virus in Fairfield has been Confirmed',
#  'Tocumen tests new cure for Hepatitis A',
#  'Tokyo Encounters Severe Symptoms of Meningitis',
#  'Toms River Encounters Severe Symptoms of Respiratory Syncytial Virus',
#  'Tourist Perishes from Malaria in Arusha',
#  'Townsville Zika tests inconclusive',
#  'Trinidad confirms first Zika case',
#  'Tuberculosis Hits Luanda',
#  'Tuberculosis Outbreak in Hartford',
#  'Tuberculosis Outbreak in Newark',
#  'Tuberculosis Symptoms Spread all over Caguas',
#  'Tuberculosis has Arrived in Fairfield',
#  'Tuberculosis re-emerges in Silver Springs',
#  'Tupelo Residents Recieve Syphilis vaccine',
#  'Two more Zika cases confirmed in Laredo',
#  'Urbana Encounters Severe Symptoms of Meningitis',
#  'Varicella Exposure in Cambridge',
#  'Varicella Keeps Spreading in Detroit',
#  'Varicella Outbreak in Minot',
#  'Varicella has Arrived in Milton',
#  'Varicella re-emerges in Lagos',
#  'Veracruz hit by Zika Concerns',
#  'Vericella spreading in Ibadan',
#  'Villavicencio under Zika threat',
#  'Vineland authorities confirmed the spread of Chlamydia',
#  'Visitor to Cucuta contracts Zika',
#  'West Nile Virus Exposure in Alpharetta',
#  'West Nile Virus Exposure in Racine',
#  'West Nile Virus Hits Monroe',
#  'West Nile Virus Hits Yogyakarta',
#  'West Nile Virus Keeps Spreading in Hauppauge',
#  'West Nile Virus Outbreak in Louisville',
#  'West Nile Virus Outbreak in Saint Johns',
#  'West Nile Virus Symptoms Spread all over Yerevan',
#  'West Nile Virus has Arrived in Dongguan',
#  'West Nile Virus re-emerges in Wellington',
#  'Will Gonorrhea vaccine help East Moline?',
#  'Will HIV vaccine help Las Vegas?',
#  'Will Hepatitis B vaccine help La Paz?',
#  'Will Herpes vaccine help Newcastle?',
#  'Will MCD vaccine help Strasbourg?',
#  'Will Mad Cow Vaccine Help Bristol?',
#  'Will Measles vaccine help Milford?',
#  'Will Measles vaccine help Sochi?',
#  'Will Meningitis vaccine help Hamburg?',
#  'Will Norovirus vaccine help Raleigh?',
#  'Will Rabies vaccine help Tangier?',
#  'Will Rotavirus vaccine help Addis Ababa?',
#  'Will Swine Flu vaccine help Annapolis?',
#  'Will Swine Flu vaccine help Ljubljana?',
#  'Will Tuberculosis vaccine help Cherry Creek?',
#  'Will Tuberculosis vaccine help Rockville?',
#  'Will West Nile Virus vaccine help Coronado?',
#  'Will West Nile Virus vaccine help Dumai?',
#  'Will West Nile Virus vaccine help Parsons?',
#  'Will the Mad Cow Outbreak Reach Vienna?',
#  'Wisconsin Rapids Patient in Critical Condition after Contracting Chickenpox',
#  'Wuhan is infested with Varicella',
#  'Yulee takes a hit from Spreading Sickness',
#  'Zika Arrives in North Miami',
#  'Zika Concerns are Spreading in Houston',
#  'Zika Infested Monkeys in Sao Paulo',
#  'Zika Mosquitoes May Have Bred in Bromeliads, Florida Officials Say',
#  'Zika Outbreak Hits Miami',
#  'Zika Outbreak in Hyderabad',
#  'Zika Outbreak in Manaus',
#  'Zika Outbreak in Mexicali',
#  'Zika Outbreak in Pinewood',
#  'Zika Outbreak in Puducherry',
#  'Zika Outbreak in Sincelejo',
#  'Zika Outbreak in South Miami',
#  'Zika Outbreak in Weslaco',
#  'Zika Outbreak in Wichita Falls',
#  'Zika Outbreak in Yurimaguas',
#  'Zika Patient in Seminole, Florida',
#  'Zika Reported in Ciudad Acuna',
#  'Zika Reported in Ilopango',
#  'Zika Reported in North Miami Beach',
#  'Zika Reported in Sao Jose',
#  'Zika San Antonio Patient Speaks Out',
#  'Zika Spreads to Palm Beach Gardens',
#  'Zika Strikes St. Petersburg',
#  'Zika Troubles come to Delray Beach',
#  'Zika Troubles come to Greater Noida',
#  'Zika Troubles come to Harlingen',
#  'Zika Troubles come to Jaen',
#  'Zika Troubles come to Kampong Cham',
#  'Zika Troubles come to La Libertad',
#  'Zika Troubles come to Niteroi',
#  'Zika Troubles come to Padre Las Casas',
#  'Zika Virus Arrives in Ontario',
#  'Zika Virus Detected in Lubbock',
#  'Zika Virus Reaches San Francisco',
#  "Zika Virus Sparks 'International Concern'",
#  'Zika Virus Transmission Detected in Havana',
#  'Zika afflicts 7 in Iloilo City',
#  'Zika afflicts patient in Calamba',
#  'Zika alert for Rio Grande Valley residents',
#  'Zika alert â€“ Manila now threatened',
#  'Zika arrives in Belmopan',
#  'Zika arrives in Boca Raton',
#  'Zika arrives in Dangriga',
#  'Zika arrives in Miri',
#  'Zika arrives in Natal',
#  'Zika arrives in Oaxaca',
#  'Zika arrives in Orange City',
#  'Zika arrives in Quezon',
#  'Zika arrives in San Benito',
#  'Zika arrives in San Onofre',
#  'Zika arrives in Santos',
#  'Zika arrives in Tegucigalpa',
#  'Zika arrives in Udon Thani',
#  'Zika arrives in West Palm Beach',
#  'Zika battle outlined at Valdosta meeting',
#  'Zika case confirmed in Lorain',
#  'Zika case recorded in Tunapuna Â»',
#  'Zika case reported in Abilene',
#  'Zika case reported in Antioquia',
#  'Zika case reported in Coral Gables',
#  'Zika case reported in Jacobina',
#  'Zika case reported in Jupiter',
#  'Zika case reported in Limoeiro',
#  'Zika case reported in Los Fresnos',
#  'Zika case reported in Medellin',
#  'Zika case reported in Oton',
#  'Zika case reported in Phetchabun',
#  'Zika case reported in Reynosa',
#  'Zika case reported in Rizal',
#  'Zika cases concern Charlotte residents',
#  'Zika cases in Singapore reach 393',
#  "Zika cases in Vietnam's Ho Chi Minh City surge",
#  'Zika in Belmont, Belmont worry',
#  'Zika in Tamarac!',
#  'Zika infects pregnant woman in Cebu',
#  'Zika investigators coming to Mankato',
#  'Zika now spreading through Jakarta',
#  'Zika only the latest mosquito-borne threat to New Orleans',
#  'Zika outbreak in Piracicaba, Brazil',
#  'Zika outbreak spreads to Mexico City',
#  'Zika reaches Johor Bahru, Malaysia',
#  'Zika reported in Fort Pierce',
#  'Zika seminars in Yuma County',
#  'Zika spreading to Salvador',
#  'Zika spreads to Barranquilla',
#  'Zika spreads to Caucasia',
#  'Zika spreads to Daytona Beach',
#  'Zika spreads to Kamphaeng Phet',
#  'Zika spreads to Kissimmee',
#  'Zika spreads to Kuching',
#  'Zika spreads to La Joya',
#  'Zika spreads to Lewisville',
#  'Zika spreads to Olinda',
#  'Zika spreads to Plant City',
#  'Zika spreads to San Luis Potosi',
#  'Zika spreads to Winter Park',
#  'Zika surfaces in Klang, Malaysia',
#  'Zika symptoms spotted in Arlington',
#  'Zika symptoms spotted in Bello',
#  'Zika symptoms spotted in Bonita Springs',
#  'Zika symptoms spotted in Boynton Beach',
#  'Zika symptoms spotted in Colombo',
#  'Zika symptoms spotted in Fortaleza',
#  'Zika symptoms spotted in Hollywood',
#  'Zika symptoms spotted in Iquitos',
#  'Zika symptoms spotted in Quisqueya',
#  'Zika symptoms spotted in Quito',
#  'Zika symptoms spotted in Quixere',
#  'Zika symptoms spotted in Sibu',
#  'Zika symptoms spotted in Surat',
#  'Zika symtomps spotted in Key West',
#  'Zika virus case reported in Rockland',
#  'Zika virus confirmed in Westchester',
#  'Zika virus reported in Cleveland',
#  'Zika worries in San Salvador',
#  'Zika-carrying mosquitoes discovered in Ardmore',
#  'Zika: Delhi for strict monitoring']

# %% [markdown]
# Comments on the cities appearing in each headline:
#
# - Has to rely on external data (with accent marks removed) to identify city names from headlines
# - There are city names with multiple words
# - City name requires case-insensitve matching
# - Not all headlines have country name

# %% [markdown]
# ## Workflow #2 ##
# Using regular expressions and the cities and countries within the geonamescache library, match any cities/countries within each headline.

# %% [markdown]
# - Make sure to normalize headlines and city/country names by removing accent marks. This can be done with the unidecode library.

# %%
from unidecode import unidecode
import re

def name_to_regex(name):
    decoded_name = unidecode(name)
    if name != decoded_name:
        regex = fr'\b({name}|{decoded_name})\b'
    else:
        regex = fr'\b{name}\b'
    return re.compile(regex, flags=re.IGNORECASE)

# %%
unidecode('Shibirghān')
# Out:
# 'Shibirghan'

# %% [markdown]
# External data - GeonamesCache: for city names and country names

# %%
from geonamescache import GeonamesCache
gc = GeonamesCache()

countries = [country['name'] for country in gc.get_countries().values()]
country_to_name = {name_to_regex(name): name for name in countries}

cities = [city['name'] for city in gc.get_cities().values()]
city_to_name = {name_to_regex(name): name for name in cities}

# %%
countries
# Out:
# ['Andorra',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Antigua and Barbuda',
#  'Anguilla',
#  'Albania',
#  'Armenia',
#  'Angola',
#  'Antarctica',
#  'Argentina',
#  'American Samoa',
#  'Austria',
#  'Australia',
#  'Aruba',
#  'Aland Islands',
#  'Azerbaijan',
#  'Bosnia and Herzegovina',
#  'Barbados',
#  'Bangladesh',
#  'Belgium',
#  'Burkina Faso',
#  'Bulgaria',
#  'Bahrain',
#  'Burundi',
#  'Benin',
#  'Saint Barthelemy',
#  'Bermuda',
#  'Brunei',
#  'Bolivia',
#  'Bonaire, Saint Eustatius and Saba ',
#  'Brazil',
#  'Bahamas',
#  'Bhutan',
#  'Bouvet Island',
#  'Botswana',
#  'Belarus',
#  'Belize',
#  'Canada',
#  'Cocos Islands',
#  'Democratic Republic of the Congo',
#  'Central African Republic',
#  'Republic of the Congo',
#  'Switzerland',
#  'Ivory Coast',
#  'Cook Islands',
#  'Chile',
#  'Cameroon',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Cabo Verde',
#  'Curacao',
#  'Christmas Island',
#  'Cyprus',
#  'Czechia',
#  'Germany',
#  'Djibouti',
#  'Denmark',
#  'Dominica',
#  'Dominican Republic',
#  'Algeria',
#  'Ecuador',
#  'Estonia',
#  'Egypt',
#  'Western Sahara',
#  'Eritrea',
#  'Spain',
#  'Ethiopia',
#  'Finland',
#  'Fiji',
#  'Falkland Islands',
#  'Micronesia',
#  'Faroe Islands',
#  'France',
#  'Gabon',
#  'United Kingdom',
#  'Grenada',
#  'Georgia',
#  'French Guiana',
#  'Guernsey',
#  'Ghana',
#  'Gibraltar',
#  'Greenland',
#  'Gambia',
#  'Guinea',
#  'Guadeloupe',
#  'Equatorial Guinea',
#  'Greece',
#  'South Georgia and the South Sandwich Islands',
#  'Guatemala',
#  'Guam',
#  'Guinea-Bissau',
#  'Guyana',
#  'Hong Kong',
#  'Heard Island and McDonald Islands',
#  'Honduras',
#  'Croatia',
#  'Haiti',
#  'Hungary',
#  'Indonesia',
#  'Ireland',
#  'Israel',
#  'Isle of Man',
#  'India',
#  'British Indian Ocean Territory',
#  'Iraq',
#  'Iran',
#  'Iceland',
#  'Italy',
#  'Jersey',
#  'Jamaica',
#  'Jordan',
#  'Japan',
#  'Kenya',
#  'Kyrgyzstan',
#  'Cambodia',
#  'Kiribati',
#  'Comoros',
#  'Saint Kitts and Nevis',
#  'North Korea',
#  'South Korea',
#  'Kosovo',
#  'Kuwait',
#  'Cayman Islands',
#  'Kazakhstan',
#  'Laos',
#  'Lebanon',
#  'Saint Lucia',
#  'Liechtenstein',
#  'Sri Lanka',
#  'Liberia',
#  'Lesotho',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'Libya',
#  'Morocco',
#  'Monaco',
#  'Moldova',
#  'Montenegro',
#  'Saint Martin',
#  'Madagascar',
#  'Marshall Islands',
#  'North Macedonia',
#  'Mali',
#  'Myanmar',
#  'Mongolia',
#  'Macao',
#  'Northern Mariana Islands',
#  'Martinique',
#  'Mauritania',
#  'Montserrat',
#  'Malta',
#  'Mauritius',
#  'Maldives',
#  'Malawi',
#  'Mexico',
#  'Malaysia',
#  'Mozambique',
#  'Namibia',
#  'New Caledonia',
#  'Niger',
#  'Norfolk Island',
#  'Nigeria',
#  'Nicaragua',
#  'Netherlands',
#  'Norway',
#  'Nepal',
#  'Nauru',
#  'Niue',
#  'New Zealand',
#  'Oman',
#  'Panama',
#  'Peru',
#  'French Polynesia',
#  'Papua New Guinea',
#  'Philippines',
#  'Pakistan',
#  'Poland',
#  'Saint Pierre and Miquelon',
#  'Pitcairn',
#  'Puerto Rico',
#  'Palestinian Territory',
#  'Portugal',
#  'Palau',
#  'Paraguay',
#  'Qatar',
#  'Reunion',
#  'Romania',
#  'Serbia',
#  'Russia',
#  'Rwanda',
#  'Saudi Arabia',
#  'Solomon Islands',
#  'Seychelles',
#  'Sudan',
#  'South Sudan',
#  'Sweden',
#  'Singapore',
#  'Saint Helena',
#  'Slovenia',
#  'Svalbard and Jan Mayen',
#  'Slovakia',
#  'Sierra Leone',
#  'San Marino',
#  'Senegal',
#  'Somalia',
#  'Suriname',
#  'Sao Tome and Principe',
#  'El Salvador',
#  'Sint Maarten',
#  'Syria',
#  'Eswatini',
#  'Turks and Caicos Islands',
#  'Chad',
#  'French Southern Territories',
#  'Togo',
#  'Thailand',
#  'Tajikistan',
#  'Tokelau',
#  'Timor Leste',
#  'Turkmenistan',
#  'Tunisia',
#  'Tonga',
#  'Turkey',
#  'Trinidad and Tobago',
#  'Tuvalu',
#  'Taiwan',
#  'Tanzania',
#  'Ukraine',
#  'Uganda',
#  'United States Minor Outlying Islands',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Vatican',
#  'Saint Vincent and the Grenadines',
#  'Venezuela',
#  'British Virgin Islands',
#  'U.S. Virgin Islands',
#  'Vietnam',
#  'Vanuatu',
#  'Wallis and Futuna',
#  'Samoa',
#  'Yemen',
#  'Mayotte',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe',
#  'Serbia and Montenegro',
#  'Netherlands Antilles']

# %%
country_to_name
# Out:
# {re.compile(r'\bAndorra\b', re.IGNORECASE|re.UNICODE): 'Andorra',
#  re.compile(r'\bUnited Arab Emirates\b',
#  re.IGNORECASE|re.UNICODE): 'United Arab Emirates',
#  re.compile(r'\bAfghanistan\b', re.IGNORECASE|re.UNICODE): 'Afghanistan',
#  re.compile(r'\bAntigua and Barbuda\b',
#  re.IGNORECASE|re.UNICODE): 'Antigua and Barbuda',
#  re.compile(r'\bAnguilla\b', re.IGNORECASE|re.UNICODE): 'Anguilla',
#  re.compile(r'\bAlbania\b', re.IGNORECASE|re.UNICODE): 'Albania',
#  re.compile(r'\bArmenia\b', re.IGNORECASE|re.UNICODE): 'Armenia',
#  re.compile(r'\bAngola\b', re.IGNORECASE|re.UNICODE): 'Angola',
#  re.compile(r'\bAntarctica\b', re.IGNORECASE|re.UNICODE): 'Antarctica',
#  re.compile(r'\bArgentina\b', re.IGNORECASE|re.UNICODE): 'Argentina',
#  re.compile(r'\bAmerican Samoa\b', re.IGNORECASE|re.UNICODE): 'American Samoa',
#  re.compile(r'\bAustria\b', re.IGNORECASE|re.UNICODE): 'Austria',
#  re.compile(r'\bAustralia\b', re.IGNORECASE|re.UNICODE): 'Australia',
#  re.compile(r'\bAruba\b', re.IGNORECASE|re.UNICODE): 'Aruba',
#  re.compile(r'\bAland Islands\b', re.IGNORECASE|re.UNICODE): 'Aland Islands',
#  re.compile(r'\bAzerbaijan\b', re.IGNORECASE|re.UNICODE): 'Azerbaijan',
#  re.compile(r'\bBosnia and Herzegovina\b',
#  re.IGNORECASE|re.UNICODE): 'Bosnia and Herzegovina',
#  re.compile(r'\bBarbados\b', re.IGNORECASE|re.UNICODE): 'Barbados',
#  re.compile(r'\bBangladesh\b', re.IGNORECASE|re.UNICODE): 'Bangladesh',
#  re.compile(r'\bBelgium\b', re.IGNORECASE|re.UNICODE): 'Belgium',
#  re.compile(r'\bBurkina Faso\b', re.IGNORECASE|re.UNICODE): 'Burkina Faso',
#  re.compile(r'\bBulgaria\b', re.IGNORECASE|re.UNICODE): 'Bulgaria',
#  re.compile(r'\bBahrain\b', re.IGNORECASE|re.UNICODE): 'Bahrain',
#  re.compile(r'\bBurundi\b', re.IGNORECASE|re.UNICODE): 'Burundi',
#  re.compile(r'\bBenin\b', re.IGNORECASE|re.UNICODE): 'Benin',
#  re.compile(r'\bSaint Barthelemy\b',
#  re.IGNORECASE|re.UNICODE): 'Saint Barthelemy',
#  re.compile(r'\bBermuda\b', re.IGNORECASE|re.UNICODE): 'Bermuda',
#  re.compile(r'\bBrunei\b', re.IGNORECASE|re.UNICODE): 'Brunei',
#  re.compile(r'\bBolivia\b', re.IGNORECASE|re.UNICODE): 'Bolivia',
#  re.compile(r'\bBonaire, Saint Eustatius and Saba \b',
#  re.IGNORECASE|re.UNICODE): 'Bonaire, Saint Eustatius and Saba ',
#  re.compile(r'\bBrazil\b', re.IGNORECASE|re.UNICODE): 'Brazil',
#  re.compile(r'\bBahamas\b', re.IGNORECASE|re.UNICODE): 'Bahamas',
#  re.compile(r'\bBhutan\b', re.IGNORECASE|re.UNICODE): 'Bhutan',
#  re.compile(r'\bBouvet Island\b', re.IGNORECASE|re.UNICODE): 'Bouvet Island',
#  re.compile(r'\bBotswana\b', re.IGNORECASE|re.UNICODE): 'Botswana',
#  re.compile(r'\bBelarus\b', re.IGNORECASE|re.UNICODE): 'Belarus',
#  re.compile(r'\bBelize\b', re.IGNORECASE|re.UNICODE): 'Belize',
#  re.compile(r'\bCanada\b', re.IGNORECASE|re.UNICODE): 'Canada',
#  re.compile(r'\bCocos Islands\b', re.IGNORECASE|re.UNICODE): 'Cocos Islands',
#  re.compile(r'\bDemocratic Republic of the Congo\b',
#  re.IGNORECASE|re.UNICODE): 'Democratic Republic of the Congo',
#  re.compile(r'\bCentral African Republic\b',
#  re.IGNORECASE|re.UNICODE): 'Central African Republic',
#  re.compile(r'\bRepublic of the Congo\b',
#  re.IGNORECASE|re.UNICODE): 'Republic of the Congo',
#  re.compile(r'\bSwitzerland\b', re.IGNORECASE|re.UNICODE): 'Switzerland',
#  re.compile(r'\bIvory Coast\b', re.IGNORECASE|re.UNICODE): 'Ivory Coast',
#  re.compile(r'\bCook Islands\b', re.IGNORECASE|re.UNICODE): 'Cook Islands',
#  re.compile(r'\bChile\b', re.IGNORECASE|re.UNICODE): 'Chile',
#  re.compile(r'\bCameroon\b', re.IGNORECASE|re.UNICODE): 'Cameroon',
#  re.compile(r'\bChina\b', re.IGNORECASE|re.UNICODE): 'China',
#  re.compile(r'\bColombia\b', re.IGNORECASE|re.UNICODE): 'Colombia',
#  re.compile(r'\bCosta Rica\b', re.IGNORECASE|re.UNICODE): 'Costa Rica',
#  re.compile(r'\bCuba\b', re.IGNORECASE|re.UNICODE): 'Cuba',
#  re.compile(r'\bCabo Verde\b', re.IGNORECASE|re.UNICODE): 'Cabo Verde',
#  re.compile(r'\bCuracao\b', re.IGNORECASE|re.UNICODE): 'Curacao',
#  re.compile(r'\bChristmas Island\b',
#  re.IGNORECASE|re.UNICODE): 'Christmas Island',
#  re.compile(r'\bCyprus\b', re.IGNORECASE|re.UNICODE): 'Cyprus',
#  re.compile(r'\bCzechia\b', re.IGNORECASE|re.UNICODE): 'Czechia',
#  re.compile(r'\bGermany\b', re.IGNORECASE|re.UNICODE): 'Germany',
#  re.compile(r'\bDjibouti\b', re.IGNORECASE|re.UNICODE): 'Djibouti',
#  re.compile(r'\bDenmark\b', re.IGNORECASE|re.UNICODE): 'Denmark',
#  re.compile(r'\bDominica\b', re.IGNORECASE|re.UNICODE): 'Dominica',
#  re.compile(r'\bDominican Republic\b',
#  re.IGNORECASE|re.UNICODE): 'Dominican Republic',
#  re.compile(r'\bAlgeria\b', re.IGNORECASE|re.UNICODE): 'Algeria',
#  re.compile(r'\bEcuador\b', re.IGNORECASE|re.UNICODE): 'Ecuador',
#  re.compile(r'\bEstonia\b', re.IGNORECASE|re.UNICODE): 'Estonia',
#  re.compile(r'\bEgypt\b', re.IGNORECASE|re.UNICODE): 'Egypt',
#  re.compile(r'\bWestern Sahara\b', re.IGNORECASE|re.UNICODE): 'Western Sahara',
#  re.compile(r'\bEritrea\b', re.IGNORECASE|re.UNICODE): 'Eritrea',
#  re.compile(r'\bSpain\b', re.IGNORECASE|re.UNICODE): 'Spain',
#  re.compile(r'\bEthiopia\b', re.IGNORECASE|re.UNICODE): 'Ethiopia',
#  re.compile(r'\bFinland\b', re.IGNORECASE|re.UNICODE): 'Finland',
#  re.compile(r'\bFiji\b', re.IGNORECASE|re.UNICODE): 'Fiji',
#  re.compile(r'\bFalkland Islands\b',
#  re.IGNORECASE|re.UNICODE): 'Falkland Islands',
#  re.compile(r'\bMicronesia\b', re.IGNORECASE|re.UNICODE): 'Micronesia',
#  re.compile(r'\bFaroe Islands\b', re.IGNORECASE|re.UNICODE): 'Faroe Islands',
#  re.compile(r'\bFrance\b', re.IGNORECASE|re.UNICODE): 'France',
#  re.compile(r'\bGabon\b', re.IGNORECASE|re.UNICODE): 'Gabon',
#  re.compile(r'\bUnited Kingdom\b', re.IGNORECASE|re.UNICODE): 'United Kingdom',
#  re.compile(r'\bGrenada\b', re.IGNORECASE|re.UNICODE): 'Grenada',
#  re.compile(r'\bGeorgia\b', re.IGNORECASE|re.UNICODE): 'Georgia',
#  re.compile(r'\bFrench Guiana\b', re.IGNORECASE|re.UNICODE): 'French Guiana',
#  re.compile(r'\bGuernsey\b', re.IGNORECASE|re.UNICODE): 'Guernsey',
#  re.compile(r'\bGhana\b', re.IGNORECASE|re.UNICODE): 'Ghana',
#  re.compile(r'\bGibraltar\b', re.IGNORECASE|re.UNICODE): 'Gibraltar',
#  re.compile(r'\bGreenland\b', re.IGNORECASE|re.UNICODE): 'Greenland',
#  re.compile(r'\bGambia\b', re.IGNORECASE|re.UNICODE): 'Gambia',
#  re.compile(r'\bGuinea\b', re.IGNORECASE|re.UNICODE): 'Guinea',
#  re.compile(r'\bGuadeloupe\b', re.IGNORECASE|re.UNICODE): 'Guadeloupe',
#  re.compile(r'\bEquatorial Guinea\b',
#  re.IGNORECASE|re.UNICODE): 'Equatorial Guinea',
#  re.compile(r'\bGreece\b', re.IGNORECASE|re.UNICODE): 'Greece',
#  re.compile(r'\bSouth Georgia and the South Sandwich Islands\b',
#  re.IGNORECASE|re.UNICODE): 'South Georgia and the South Sandwich Islands',
#  re.compile(r'\bGuatemala\b', re.IGNORECASE|re.UNICODE): 'Guatemala',
#  re.compile(r'\bGuam\b', re.IGNORECASE|re.UNICODE): 'Guam',
#  re.compile(r'\bGuinea-Bissau\b', re.IGNORECASE|re.UNICODE): 'Guinea-Bissau',
#  re.compile(r'\bGuyana\b', re.IGNORECASE|re.UNICODE): 'Guyana',
#  re.compile(r'\bHong Kong\b', re.IGNORECASE|re.UNICODE): 'Hong Kong',
#  re.compile(r'\bHeard Island and McDonald Islands\b',
#  re.IGNORECASE|re.UNICODE): 'Heard Island and McDonald Islands',
#  re.compile(r'\bHonduras\b', re.IGNORECASE|re.UNICODE): 'Honduras',
#  re.compile(r'\bCroatia\b', re.IGNORECASE|re.UNICODE): 'Croatia',
#  re.compile(r'\bHaiti\b', re.IGNORECASE|re.UNICODE): 'Haiti',
#  re.compile(r'\bHungary\b', re.IGNORECASE|re.UNICODE): 'Hungary',
#  re.compile(r'\bIndonesia\b', re.IGNORECASE|re.UNICODE): 'Indonesia',
#  re.compile(r'\bIreland\b', re.IGNORECASE|re.UNICODE): 'Ireland',
#  re.compile(r'\bIsrael\b', re.IGNORECASE|re.UNICODE): 'Israel',
#  re.compile(r'\bIsle of Man\b', re.IGNORECASE|re.UNICODE): 'Isle of Man',
#  re.compile(r'\bIndia\b', re.IGNORECASE|re.UNICODE): 'India',
#  re.compile(r'\bBritish Indian Ocean Territory\b',
#  re.IGNORECASE|re.UNICODE): 'British Indian Ocean Territory',
#  re.compile(r'\bIraq\b', re.IGNORECASE|re.UNICODE): 'Iraq',
#  re.compile(r'\bIran\b', re.IGNORECASE|re.UNICODE): 'Iran',
#  re.compile(r'\bIceland\b', re.IGNORECASE|re.UNICODE): 'Iceland',
#  re.compile(r'\bItaly\b', re.IGNORECASE|re.UNICODE): 'Italy',
#  re.compile(r'\bJersey\b', re.IGNORECASE|re.UNICODE): 'Jersey',
#  re.compile(r'\bJamaica\b', re.IGNORECASE|re.UNICODE): 'Jamaica',
#  re.compile(r'\bJordan\b', re.IGNORECASE|re.UNICODE): 'Jordan',
#  re.compile(r'\bJapan\b', re.IGNORECASE|re.UNICODE): 'Japan',
#  re.compile(r'\bKenya\b', re.IGNORECASE|re.UNICODE): 'Kenya',
#  re.compile(r'\bKyrgyzstan\b', re.IGNORECASE|re.UNICODE): 'Kyrgyzstan',
#  re.compile(r'\bCambodia\b', re.IGNORECASE|re.UNICODE): 'Cambodia',
#  re.compile(r'\bKiribati\b', re.IGNORECASE|re.UNICODE): 'Kiribati',
#  re.compile(r'\bComoros\b', re.IGNORECASE|re.UNICODE): 'Comoros',
#  re.compile(r'\bSaint Kitts and Nevis\b',
#  re.IGNORECASE|re.UNICODE): 'Saint Kitts and Nevis',
#  re.compile(r'\bNorth Korea\b', re.IGNORECASE|re.UNICODE): 'North Korea',
#  re.compile(r'\bSouth Korea\b', re.IGNORECASE|re.UNICODE): 'South Korea',
#  re.compile(r'\bKosovo\b', re.IGNORECASE|re.UNICODE): 'Kosovo',
#  re.compile(r'\bKuwait\b', re.IGNORECASE|re.UNICODE): 'Kuwait',
#  re.compile(r'\bCayman Islands\b', re.IGNORECASE|re.UNICODE): 'Cayman Islands',
#  re.compile(r'\bKazakhstan\b', re.IGNORECASE|re.UNICODE): 'Kazakhstan',
#  re.compile(r'\bLaos\b', re.IGNORECASE|re.UNICODE): 'Laos',
#  re.compile(r'\bLebanon\b', re.IGNORECASE|re.UNICODE): 'Lebanon',
#  re.compile(r'\bSaint Lucia\b', re.IGNORECASE|re.UNICODE): 'Saint Lucia',
#  re.compile(r'\bLiechtenstein\b', re.IGNORECASE|re.UNICODE): 'Liechtenstein',
#  re.compile(r'\bSri Lanka\b', re.IGNORECASE|re.UNICODE): 'Sri Lanka',
#  re.compile(r'\bLiberia\b', re.IGNORECASE|re.UNICODE): 'Liberia',
#  re.compile(r'\bLesotho\b', re.IGNORECASE|re.UNICODE): 'Lesotho',
#  re.compile(r'\bLithuania\b', re.IGNORECASE|re.UNICODE): 'Lithuania',
#  re.compile(r'\bLuxembourg\b', re.IGNORECASE|re.UNICODE): 'Luxembourg',
#  re.compile(r'\bLatvia\b', re.IGNORECASE|re.UNICODE): 'Latvia',
#  re.compile(r'\bLibya\b', re.IGNORECASE|re.UNICODE): 'Libya',
#  re.compile(r'\bMorocco\b', re.IGNORECASE|re.UNICODE): 'Morocco',
#  re.compile(r'\bMonaco\b', re.IGNORECASE|re.UNICODE): 'Monaco',
#  re.compile(r'\bMoldova\b', re.IGNORECASE|re.UNICODE): 'Moldova',
#  re.compile(r'\bMontenegro\b', re.IGNORECASE|re.UNICODE): 'Montenegro',
#  re.compile(r'\bSaint Martin\b', re.IGNORECASE|re.UNICODE): 'Saint Martin',
#  re.compile(r'\bMadagascar\b', re.IGNORECASE|re.UNICODE): 'Madagascar',
#  re.compile(r'\bMarshall Islands\b',
#  re.IGNORECASE|re.UNICODE): 'Marshall Islands',
#  re.compile(r'\bNorth Macedonia\b',
#  re.IGNORECASE|re.UNICODE): 'North Macedonia',
#  re.compile(r'\bMali\b', re.IGNORECASE|re.UNICODE): 'Mali',
#  re.compile(r'\bMyanmar\b', re.IGNORECASE|re.UNICODE): 'Myanmar',
#  re.compile(r'\bMongolia\b', re.IGNORECASE|re.UNICODE): 'Mongolia',
#  re.compile(r'\bMacao\b', re.IGNORECASE|re.UNICODE): 'Macao',
#  re.compile(r'\bNorthern Mariana Islands\b',
#  re.IGNORECASE|re.UNICODE): 'Northern Mariana Islands',
#  re.compile(r'\bMartinique\b', re.IGNORECASE|re.UNICODE): 'Martinique',
#  re.compile(r'\bMauritania\b', re.IGNORECASE|re.UNICODE): 'Mauritania',
#  re.compile(r'\bMontserrat\b', re.IGNORECASE|re.UNICODE): 'Montserrat',
#  re.compile(r'\bMalta\b', re.IGNORECASE|re.UNICODE): 'Malta',
#  re.compile(r'\bMauritius\b', re.IGNORECASE|re.UNICODE): 'Mauritius',
#  re.compile(r'\bMaldives\b', re.IGNORECASE|re.UNICODE): 'Maldives',
#  re.compile(r'\bMalawi\b', re.IGNORECASE|re.UNICODE): 'Malawi',
#  re.compile(r'\bMexico\b', re.IGNORECASE|re.UNICODE): 'Mexico',
#  re.compile(r'\bMalaysia\b', re.IGNORECASE|re.UNICODE): 'Malaysia',
#  re.compile(r'\bMozambique\b', re.IGNORECASE|re.UNICODE): 'Mozambique',
#  re.compile(r'\bNamibia\b', re.IGNORECASE|re.UNICODE): 'Namibia',
#  re.compile(r'\bNew Caledonia\b', re.IGNORECASE|re.UNICODE): 'New Caledonia',
#  re.compile(r'\bNiger\b', re.IGNORECASE|re.UNICODE): 'Niger',
#  re.compile(r'\bNorfolk Island\b', re.IGNORECASE|re.UNICODE): 'Norfolk Island',
#  re.compile(r'\bNigeria\b', re.IGNORECASE|re.UNICODE): 'Nigeria',
#  re.compile(r'\bNicaragua\b', re.IGNORECASE|re.UNICODE): 'Nicaragua',
#  re.compile(r'\bNetherlands\b', re.IGNORECASE|re.UNICODE): 'Netherlands',
#  re.compile(r'\bNorway\b', re.IGNORECASE|re.UNICODE): 'Norway',
#  re.compile(r'\bNepal\b', re.IGNORECASE|re.UNICODE): 'Nepal',
#  re.compile(r'\bNauru\b', re.IGNORECASE|re.UNICODE): 'Nauru',
#  re.compile(r'\bNiue\b', re.IGNORECASE|re.UNICODE): 'Niue',
#  re.compile(r'\bNew Zealand\b', re.IGNORECASE|re.UNICODE): 'New Zealand',
#  re.compile(r'\bOman\b', re.IGNORECASE|re.UNICODE): 'Oman',
#  re.compile(r'\bPanama\b', re.IGNORECASE|re.UNICODE): 'Panama',
#  re.compile(r'\bPeru\b', re.IGNORECASE|re.UNICODE): 'Peru',
#  re.compile(r'\bFrench Polynesia\b',
#  re.IGNORECASE|re.UNICODE): 'French Polynesia',
#  re.compile(r'\bPapua New Guinea\b',
#  re.IGNORECASE|re.UNICODE): 'Papua New Guinea',
#  re.compile(r'\bPhilippines\b', re.IGNORECASE|re.UNICODE): 'Philippines',
#  re.compile(r'\bPakistan\b', re.IGNORECASE|re.UNICODE): 'Pakistan',
#  re.compile(r'\bPoland\b', re.IGNORECASE|re.UNICODE): 'Poland',
#  re.compile(r'\bSaint Pierre and Miquelon\b',
#  re.IGNORECASE|re.UNICODE): 'Saint Pierre and Miquelon',
#  re.compile(r'\bPitcairn\b', re.IGNORECASE|re.UNICODE): 'Pitcairn',
#  re.compile(r'\bPuerto Rico\b', re.IGNORECASE|re.UNICODE): 'Puerto Rico',
#  re.compile(r'\bPalestinian Territory\b',
#  re.IGNORECASE|re.UNICODE): 'Palestinian Territory',
#  re.compile(r'\bPortugal\b', re.IGNORECASE|re.UNICODE): 'Portugal',
#  re.compile(r'\bPalau\b', re.IGNORECASE|re.UNICODE): 'Palau',
#  re.compile(r'\bParaguay\b', re.IGNORECASE|re.UNICODE): 'Paraguay',
#  re.compile(r'\bQatar\b', re.IGNORECASE|re.UNICODE): 'Qatar',
#  re.compile(r'\bReunion\b', re.IGNORECASE|re.UNICODE): 'Reunion',
#  re.compile(r'\bRomania\b', re.IGNORECASE|re.UNICODE): 'Romania',
#  re.compile(r'\bSerbia\b', re.IGNORECASE|re.UNICODE): 'Serbia',
#  re.compile(r'\bRussia\b', re.IGNORECASE|re.UNICODE): 'Russia',
#  re.compile(r'\bRwanda\b', re.IGNORECASE|re.UNICODE): 'Rwanda',
#  re.compile(r'\bSaudi Arabia\b', re.IGNORECASE|re.UNICODE): 'Saudi Arabia',
#  re.compile(r'\bSolomon Islands\b',
#  re.IGNORECASE|re.UNICODE): 'Solomon Islands',
#  re.compile(r'\bSeychelles\b', re.IGNORECASE|re.UNICODE): 'Seychelles',
#  re.compile(r'\bSudan\b', re.IGNORECASE|re.UNICODE): 'Sudan',
#  re.compile(r'\bSouth Sudan\b', re.IGNORECASE|re.UNICODE): 'South Sudan',
#  re.compile(r'\bSweden\b', re.IGNORECASE|re.UNICODE): 'Sweden',
#  re.compile(r'\bSingapore\b', re.IGNORECASE|re.UNICODE): 'Singapore',
#  re.compile(r'\bSaint Helena\b', re.IGNORECASE|re.UNICODE): 'Saint Helena',
#  re.compile(r'\bSlovenia\b', re.IGNORECASE|re.UNICODE): 'Slovenia',
#  re.compile(r'\bSvalbard and Jan Mayen\b',
#  re.IGNORECASE|re.UNICODE): 'Svalbard and Jan Mayen',
#  re.compile(r'\bSlovakia\b', re.IGNORECASE|re.UNICODE): 'Slovakia',
#  re.compile(r'\bSierra Leone\b', re.IGNORECASE|re.UNICODE): 'Sierra Leone',
#  re.compile(r'\bSan Marino\b', re.IGNORECASE|re.UNICODE): 'San Marino',
#  re.compile(r'\bSenegal\b', re.IGNORECASE|re.UNICODE): 'Senegal',
#  re.compile(r'\bSomalia\b', re.IGNORECASE|re.UNICODE): 'Somalia',
#  re.compile(r'\bSuriname\b', re.IGNORECASE|re.UNICODE): 'Suriname',
#  re.compile(r'\bSao Tome and Principe\b',
#  re.IGNORECASE|re.UNICODE): 'Sao Tome and Principe',
#  re.compile(r'\bEl Salvador\b', re.IGNORECASE|re.UNICODE): 'El Salvador',
#  re.compile(r'\bSint Maarten\b', re.IGNORECASE|re.UNICODE): 'Sint Maarten',
#  re.compile(r'\bSyria\b', re.IGNORECASE|re.UNICODE): 'Syria',
#  re.compile(r'\bEswatini\b', re.IGNORECASE|re.UNICODE): 'Eswatini',
#  re.compile(r'\bTurks and Caicos Islands\b',
#  re.IGNORECASE|re.UNICODE): 'Turks and Caicos Islands',
#  re.compile(r'\bChad\b', re.IGNORECASE|re.UNICODE): 'Chad',
#  re.compile(r'\bFrench Southern Territories\b',
#  re.IGNORECASE|re.UNICODE): 'French Southern Territories',
#  re.compile(r'\bTogo\b', re.IGNORECASE|re.UNICODE): 'Togo',
#  re.compile(r'\bThailand\b', re.IGNORECASE|re.UNICODE): 'Thailand',
#  re.compile(r'\bTajikistan\b', re.IGNORECASE|re.UNICODE): 'Tajikistan',
#  re.compile(r'\bTokelau\b', re.IGNORECASE|re.UNICODE): 'Tokelau',
#  re.compile(r'\bTimor Leste\b', re.IGNORECASE|re.UNICODE): 'Timor Leste',
#  re.compile(r'\bTurkmenistan\b', re.IGNORECASE|re.UNICODE): 'Turkmenistan',
#  re.compile(r'\bTunisia\b', re.IGNORECASE|re.UNICODE): 'Tunisia',
#  re.compile(r'\bTonga\b', re.IGNORECASE|re.UNICODE): 'Tonga',
#  re.compile(r'\bTurkey\b', re.IGNORECASE|re.UNICODE): 'Turkey',
#  re.compile(r'\bTrinidad and Tobago\b',
#  re.IGNORECASE|re.UNICODE): 'Trinidad and Tobago',
#  re.compile(r'\bTuvalu\b', re.IGNORECASE|re.UNICODE): 'Tuvalu',
#  re.compile(r'\bTaiwan\b', re.IGNORECASE|re.UNICODE): 'Taiwan',
#  re.compile(r'\bTanzania\b', re.IGNORECASE|re.UNICODE): 'Tanzania',
#  re.compile(r'\bUkraine\b', re.IGNORECASE|re.UNICODE): 'Ukraine',
#  re.compile(r'\bUganda\b', re.IGNORECASE|re.UNICODE): 'Uganda',
#  re.compile(r'\bUnited States Minor Outlying Islands\b',
#  re.IGNORECASE|re.UNICODE): 'United States Minor Outlying Islands',
#  re.compile(r'\bUnited States\b', re.IGNORECASE|re.UNICODE): 'United States',
#  re.compile(r'\bUruguay\b', re.IGNORECASE|re.UNICODE): 'Uruguay',
#  re.compile(r'\bUzbekistan\b', re.IGNORECASE|re.UNICODE): 'Uzbekistan',
#  re.compile(r'\bVatican\b', re.IGNORECASE|re.UNICODE): 'Vatican',
#  re.compile(r'\bSaint Vincent and the Grenadines\b',
#  re.IGNORECASE|re.UNICODE): 'Saint Vincent and the Grenadines',
#  re.compile(r'\bVenezuela\b', re.IGNORECASE|re.UNICODE): 'Venezuela',
#  re.compile(r'\bBritish Virgin Islands\b',
#  re.IGNORECASE|re.UNICODE): 'British Virgin Islands',
#  re.compile(r'\bU.S. Virgin Islands\b',
#  re.IGNORECASE|re.UNICODE): 'U.S. Virgin Islands',
#  re.compile(r'\bVietnam\b', re.IGNORECASE|re.UNICODE): 'Vietnam',
#  re.compile(r'\bVanuatu\b', re.IGNORECASE|re.UNICODE): 'Vanuatu',
#  re.compile(r'\bWallis and Futuna\b',
#  re.IGNORECASE|re.UNICODE): 'Wallis and Futuna',
#  re.compile(r'\bSamoa\b', re.IGNORECASE|re.UNICODE): 'Samoa',
#  re.compile(r'\bYemen\b', re.IGNORECASE|re.UNICODE): 'Yemen',
#  re.compile(r'\bMayotte\b', re.IGNORECASE|re.UNICODE): 'Mayotte',
#  re.compile(r'\bSouth Africa\b', re.IGNORECASE|re.UNICODE): 'South Africa',
#  re.compile(r'\bZambia\b', re.IGNORECASE|re.UNICODE): 'Zambia',
#  re.compile(r'\bZimbabwe\b', re.IGNORECASE|re.UNICODE): 'Zimbabwe',
#  re.compile(r'\bSerbia and Montenegro\b',
#  re.IGNORECASE|re.UNICODE): 'Serbia and Montenegro',
#  re.compile(r'\bNetherlands Antilles\b',
#  re.IGNORECASE|re.UNICODE): 'Netherlands Antilles'}

# %%
cities
# Out:
# ['Andorra la Vella',
#  'Umm Al Quwain City',
#  'Ras Al Khaimah City',
#  'Zayed City',
#  'Khawr Fakkān',
#  'Dubai',
#  'Dibba Al-Fujairah',
#  'Dibba Al-Hisn',
#  'Sharjah',
#  'Ar Ruways',
#  'Al Fujairah City',
#  'Al Ain City',
#  'Ajman City',
#  'Adh Dhayd',
#  'Abu Dhabi',
#  'Khalifah A City',
#  'Bani Yas City',
#  'Musaffah',
#  'Al Shamkhah City',
#  'Reef Al Fujairah City',
#  'Zaranj',
#  'Taloqan',
#  'Shīnḏanḏ',
#  'Shibirghān',
#  'Shahrak',
#  'Sar-e Pul',
#  'Sang-e Chārak',
#  'Aībak',
#  'Rustāq',
#  'Qarqīn',
#  'Qarāwul',
#  'Pul-e Khumrī',
#  'Paghmān',
#  'Nahrīn',
#  'Maymana',
#  'Mehtar Lām',
#  'Mazār-e Sharīf',
#  'Lashkar Gāh',
#  'Kushk',
#  'Kunduz',
#  'Khōst',
#  'Khulm',
#  'Khāsh',
#  'Khanabad',
#  'Karukh',
#  'Kandahār',
#  'Kabul',
#  'Jalālābād',
#  'Jabal os Saraj',
#  'Herāt',
#  'Ghormach',
#  'Ghazni',
#  'Gereshk',
#  'Gardez',
#  'Fayzabad',
#  'Farah',
#  'Kafir Qala',
#  'Charikar',
#  'Baraki Barak',
#  'Bāmyān',
#  'Balkh',
#  'Baghlān',
#  'Ārt Khwājah',
#  'Āsmār',
#  'Asadābād',
#  'Andkhōy',
#  'Bāzārak',
#  'Markaz-e Woluswalī-ye Āchīn',
#  'Saint John’s',
#  'The Valley',
#  'Sarandë',
#  'Pogradec',
#  'Kukës',
#  'Korçë',
#  'Gjirokastër',
#  'Elbasan',
#  'Burrel',
#  'Vlorë',
#  'Tirana',
#  'Shkodër',
#  'Patos Fshat',
#  'Patos',
#  'Lushnjë',
#  'Lezhë',
#  'Laç',
#  'Kuçovë',
#  'Krujë',
#  'Kavajë',
#  'Fier-Çifçi',
#  'Fier',
#  'Durrës',
#  'Berat',
#  'Kapan',
#  'Goris',
#  'Hats’avan',
#  'Artashat',
#  'Ararat',
#  'Yerevan',
#  'Vagharshapat',
#  'Step’anavan',
#  'Spitak',
#  'Sevan',
#  'Masis',
#  'Vanadzor',
#  'Gavarr',
#  'Hrazdan',
#  'Armavir',
#  'Gyumri',
#  'Ashtarak',
#  'Abovyan',
#  'Saurimo',
#  'Lucapa',
#  'Luau',
#  'Uíge',
#  'Soio',
#  "N'zeto",
#  'N’dalatando',
#  'Mbanza Congo',
#  'Malanje',
#  'Luanda',
#  'Caxito',
#  'Cabinda',
#  'Sumbe',
#  'Namibe',
#  'Menongue',
#  'Luena',
#  'Lubango',
#  'Longonjo',
#  'Lobito',
#  'Cuito',
#  'Huambo',
#  'Catumbela',
#  'Catabola',
#  'Camacupa',
#  'Caála',
#  'Benguela',
#  'Zárate',
#  'Wanda',
#  'Villa Ortúzar',
#  'Villa Ocampo',
#  'Villa Lugano',
#  'Villaguay',
#  'Villa Gesell',
#  'Villa de Mayo',
#  'Tortuguitas',
#  'Tigre',
#  'Tandil',
#  'San Vicente',
#  'Santo Tomé',
#  'Santa Elena',
#  'San Pedro',
#  'San Pedro',
#  'San Luis del Palmar',
#  'San Lorenzo',
#  'San Javier',
#  'San Isidro',
#  'Saladas',
#  'Retiro',
#  'Resistencia',
#  'Reconquista',
#  'Quilmes',
#  'Puerto Rico',
#  'Puerto Iguazú',
#  'Puerto Esperanza',
#  'Puerto Eldorado',
#  'Posadas',
#  'Pontevedra',
#  'Pirané',
#  'Pilar',
#  'Paso de los Libres',
#  'Oberá',
#  'Necochea',
#  'Muñiz',
#  'Morón',
#  'Monte Caseros',
#  'Montecarlo',
#  'Merlo',
#  'Mercedes',
#  'Mercedes',
#  'Mar del Plata',
#  'Luján',
#  'Los Polvorines',
#  'La Plata',
#  'La Paz',
#  'Jardín América',
#  'Hurlingham',
#  'Gualeguaychú',
#  'Gualeguay',
#  'Goya',
#  'Gobernador Virasora',
#  'General Pacheco',
#  'General José de San Martín',
#  'Garupá',
#  'Formosa',
#  'Fontana',
#  'Federal',
#  'Esquina',
#  'El Soberbio',
#  'Don Torcuato',
#  'Dolores',
#  'Curuzú Cuatiá',
#  'Corrientes',
#  'Concordia',
#  'Concepción del Uruguay',
#  'Colegiales',
#  'Chajarí',
#  'Campana',
#  'Buenos Aires',
#  'Boedo',
#  'Berazategui',
#  'Belgrano',
#  'Barranqueras',
#  'Barracas',
#  'Balcarce',
#  'Azul',
#  'Avellaneda',
#  'Aristóbulo del Valle',
#  'Zapala',
#  'Yerba Buena',
#  'Villa Regina',
#  'Villa Paula de Sarmiento',
#  'Villa Nueva',
#  'Villa María',
#  'Villa Dolores',
#  'Villa Constitución',
#  'Villa Carlos Paz',
#  'Villa Ángela',
#  'Villa Allende',
#  'Viedma',
#  'Victoria',
#  'Vera',
#  'Venado Tuerto',
#  'Veinticinco de Mayo',
#  'Ushuaia',
#  'Unquillo',
#  'Tres Isletas',
#  'Tres Arroyos',
#  'Trelew',
#  'Termas de Río Hondo',
#  'Tartagal',
#  'Tafí Viejo',
#  'Sunchales',
#  'Santo Tomé',
#  'Santiago del Estero',
#  'Santa Rosa',
#  'Santa Lucía',
#  'Santa Fe',
#  'San Salvador de Jujuy',
#  'San Ramón de la Nueva Orán',
#  'San Rafael',
#  'San Pedro de Jujuy',
#  'San Nicolás de los Arroyos',
#  'San Miguel de Tucumán',
#  'San Martín de los Andes',
#  'San Martín',
#  'San Luis',
#  'San Justo',
#  'San Juan',
#  'San José de Jáchal',
#  'San Jorge',
#  'San Francisco',
#  'San Fernando del Valle de Catamarca',
#  'San Antonio Oeste',
#  'Salta',
#  'Rufino',
#  'Rosario',
#  'Río Tercero',
#  'Río Segundo',
#  'Río Grande',
#  'Río Gallegos',
#  'Río Cuarto',
#  'Río Ceballos',
#  'Rawson',
#  'Rafaela',
#  'Quitilipi',
#  'Punta Alta',
#  'Puerto Madryn',
#  'Presidencia Roque Sáenz Peña',
#  'Pocito',
#  'Plottier',
#  'Pergamino',
#  'Pérez',
#  'Paraná',
#  'Palpalá',
#  'Olavarría',
#  'Nueve de Julio',
#  'Neuquén',
#  'Morteros',
#  'Monteros',
#  'Mendoza',
#  'Marcos Juárez',
#  'Machagai',
#  'Lincoln',
#  'Libertador General San Martín',
#  'Las Breñas',
#  'La Rioja',
#  'La Falda',
#  'La Calera',
#  'Laboulaye',
#  'Junín',
#  'Joaquín V. González',
#  'Jesús María',
#  'Granadero Baigorria',
#  'Gobernador Gálvez',
#  'General Villegas',
#  'General Roca',
#  'General Pinedo',
#  'General Pico',
#  'General Enrique Mosconi',
#  'Gálvez',
#  'Firmat',
#  'Famaillá',
#  'Esquel',
#  'Esperanza',
#  'Embarcación',
#  'Embalse',
#  'El Bolsón',
#  'Diamante',
#  'Deán Funes',
#  'Cutral-Có',
#  'Cruz del Eje',
#  'Crespo',
#  'Cosquín',
#  'Coronel Suárez',
#  'Coronda',
#  'Córdoba',
#  'Comodoro Rivadavia',
#  'Cipolletti',
#  'Cinco Saltos',
#  'Chivilcoy',
#  'Chimbas',
#  'Chilecito',
#  'Charata',
#  'Chacabuco',
#  'Centenario',
#  'Caucete',
#  'Catriel',
#  'Castelli',
#  'Casilda',
#  'Carcarañá',
#  'Capitán Bermúdez',
#  'Cañada de Gómez',
#  'Caleta Olivia',
#  'Bell Ville',
#  'Bella Vista',
#  'Bahía Blanca',
#  'Arroyo Seco',
#  'Arroyito',
#  'Añatuya',
#  'Alta Gracia',
#  'Allen',
#  'Alderetes',
#  'Albardón',
#  'Aguilares',
#  'Balvanera',
#  'Villa Santa Rita',
#  'Villa Mercedes',
#  'San Miguel',
#  'San Carlos de Bariloche',
#  'Adrogué',
#  'Ingeniero Pablo Nogués',
#  'José C. Paz',
#  'Pago Pago',
#  'Wilten',
#  'Wiener Neustadt',
#  'Vienna',
#  'Wetzelsdorf',
#  'Wels',
#  'Weinzierl bei Krems',
#  'Villach',
#  'Telfs',
#  'Straßgang',
#  'Stockerau',
#  'Steyr',
#  'Simmering',
#  'Sankt Pölten',
#  'Sankt Peter',
#  'Sankt Peter',
#  'Sankt Martin',
#  'Salzburg',
#  'Pradl',
#  'Perchtoldsdorf',
#  'Ottakring',
#  'Mödling',
#  'Meidling',
#  'Lustenau',
#  'Linz',
#  'Klosterneuburg',
#  'Klagenfurt am Wörthersee',
#  'Innsbruck',
#  'Innere Stadt',
#  'Hötting',
#  'Hohenems',
#  'Hietzing',
#  'Hernals',
#  'Graz',
#  'Floridsdorf',
#  'Feldkirch',
#  'Eggenberg',
#  'Dornbirn',
#  'Bregenz',
#  'Baden',
#  'Amstetten',
#  'Favoriten',
#  'Donaustadt',
#  'Jakomini',
#  'Lend',
#  'Geidorf',
#  'Sankt Leonhard',
#  'Andritz',
#  'Gries',
#  'Scarborough',
#  'Rockingham',
#  'Perth',
#  'Mount Isa',
#  'Morphett Vale',
#  'Mandurah',
#  'Kwinana',
#  'Gosnells',
#  'Geraldton',
#  'Gawler',
#  'Darwin',
#  'Busselton',
#  'Bunbury',
#  'Alice Springs',
#  'Albany',
#  'Adelaide',
#  'Wodonga',
#  'Wheelers Hill',
#  'Westmead',
#  'Werribee',
#  'Warrnambool',
#  'Warragul',
#  'Wantirna South',
#  'Wangaratta',
#  'Wahroonga',
#  'Upper Coomera',
#  'Truganina',
#  'Traralgon',
#  'Townsville',
#  'Toowoomba',
#  'Thornbury',
#  'Thomastown',
#  'Templestowe',
#  'Tarneit',
#  'Taree',
#  'Tamworth',
#  'Sydney',
#  'Surry Hills',
#  'Surfers Paradise',
#  'Sunbury',
#  'Strathfield',
#  'Springvale',
#  'South Yarra',
#  'Southport',
#  'Shepparton',
#  'Seven Hills',
#  'Seaford',
#  'Saint Kilda',
#  'Saint Ives',
#  'Saint Albans',
#  'Ryde',
#  'Rowville',
#  'Rockhampton',
#  'Rockdale',
#  'Ringwood',
#  'Richmond',
#  'Reservoir',
#  'Quakers Hill',
#  'Preston',
#  'Port Melbourne',
#  'Port Macquarie',
#  'Point Cook',
#  'Pascoe Vale',
#  'Palm Beach',
#  'Pakenham',
#  'Orange',
#  'North Melbourne',
#  'Northcote',
#  'Noble Park',
#  'Newcastle',
#  'Nerang',
#  'Narre Warren',
#  'Narangba',
#  'Mulgrave',
#  'Mount Waverley',
#  'Mount Martha',
#  'Mount Gambier',
#  'Mount Eliza',
#  'Mount Druitt',
#  'Mosman',
#  'Mornington',
#  'Morayfield',
#  'South Morang',
#  'Mooroolbark',
#  'Mitcham',
#  'Miranda',
#  'Mill Park',
#  'Mildura',
#  'Merrylands',
#  'Mernda',
#  'Melbourne',
#  'Mascot',
#  'Maryborough',
#  'Marrickville',
#  'Maroubra',
#  'Manly',
#  'Maitland',
#  'Mackay',
#  'Liverpool',
#  'Lilydale',
#  'Lidcombe',
#  'Launceston',
#  'Lara',
#  'Langwarrin',
#  'Lalor',
#  'Lakemba',
#  'Kogarah',
#  'Keysborough',
#  'Kew',
#  'Kensington',
#  'Hornsby',
#  'Hobart',
#  'Hawthorn South',
#  'Hawthorn',
#  'Hampton Park',
#  'Griffith',
#  'Greenvale',
#  'Greensborough',
#  'Granville',
#  'Goulburn',
#  'Gold Coast',
#  'Glen Waverley',
#  'Glenroy',
#  'Glen Iris',
#  'Glenferrie',
#  'Gladstone',
#  'Geelong',
#  'Frankston East',
#  'Frankston',
#  'Footscray',
#  'Fairfield',
#  'Essendon',
#  'Epping',
#  'Epping',
#  'Engadine',
#  'Eltham',
#  'Eight Mile Plains',
#  'Eastwood',
#  'Earlwood',
#  'Dubbo',
#  'Doreen',
#  'Doncaster East',
#  'Doncaster',
#  'Deer Park',
#  'Deception Bay',
#  'Dandenong',
#  'Croydon',
#  'Cronulla',
#  'Cranbourne',
#  'Craigieburn',
#  'Corio',
#  'Coorparoo',
#  'Coogee',
#  'Coffs Harbour',
#  'Coburg',
#  'Clayton',
#  'Wollongong',
#  'Chatswood',
#  'Cessnock',
#  'Castle Hill',
#  'Carrum Downs',
#  'Carnegie',
#  'Carlton',
#  'Carlingford',
#  'Capalaba',
#  'Canberra',
#  'Camberwell',
#  'Cairns',
#  'Caboolture',
#  'Burwood',
#  'Burnie',
#  'Bundaberg',
#  'Buderim',
#  'Brunswick',
#  'Broken Hill',
#  'Brisbane',
#  'Brighton',
#  'Boronia',
#  'Blacktown',
#  'Bexley',
#  'Berwick',
#  'Bentleigh East',
#  'Bentleigh',
#  'Bendigo',
#  'Baulkham Hills',
#  'Bathurst',
#  'Banora Point',
#  'Bankstown',
#  'Ballarat',
#  'Auburn',
#  'Ashfield',
#  'Armidale',
#  'Albany Creek',
#  'Maroochydore',
#  'Cheltenham',
#  'Randwick',
#  'Dee Why',
#  'Umina Beach',
#  'Palmerston',
#  'Hervey Bay',
#  'Sydney Central Business District',
#  'Kingsford',
#  'Springfield Lakes',
#  'Bracken Ridge',
#  'Kallangur',
#  'North Lakes',
#  'The Gap',
#  'Caroline Springs',
#  'Hoppers Crossing',
#  'Logan City',
#  'Carindale',
#  'Parramatta',
#  'Ferntree Gully',
#  'Adelaide Hills',
#  'Canning Vale',
#  'Glenmore Park',
#  'Southbank',
#  'Helensvale',
#  'Melton West',
#  'Elwood',
#  'Balwyn North',
#  'Malvern East',
#  'Brighton East',
#  'Redbank Plains',
#  'Labrador',
#  'St Albans',
#  'Endeavour Hills',
#  'Kellyville',
#  'Taylors Lakes',
#  'Cherrybrook',
#  'Roxburgh Park',
#  'Prestons',
#  'Wyndham Vale',
#  'Ballajura',
#  'Willetton',
#  'Glenwood',
#  'Cabramatta',
#  'Campsie',
#  'Casula',
#  'Cranebrook',
#  'Greenacre',
#  'Greystanes',
#  'Ellenbrook',
#  'Alexandra Hills',
#  'Calamvale',
#  'Yagoona',
#  'Highton',
#  'Pacific Pines',
#  'Robina',
#  'Paralowie',
#  'Baldivis',
#  'Dianella',
#  'Morley',
#  'Thornlie',
#  'Punchbowl',
#  'Parafield Gardens',
#  'Hillside',
#  'St Clair',
#  'Kirwan',
#  'Bundoora',
#  'Forest Lake',
#  'Sunnybank Hills',
#  'Rochedale South',
#  'Cranbourne East',
#  'Cranbourne North',
#  'Narre Warren South',
#  'Dandenong North',
#  'Frankston South',
#  'Sunshine West',
#  'Altona Meadows',
#  'Hurstville',
#  'West Pennant Hills',
#  'Melbourne City Centre',
#  'Adelaide city centre',
#  'Wollongong city centre',
#  'Tanki Leendert',
#  'San Nicolas',
#  'Oranjestad',
#  'Mariehamn',
#  'Xankandi',
#  'Əhmədbəyli',
#  'Shushi',
#  'Salyan',
#  'Saatlı',
#  'Neftçala',
#  'Nakhchivan',
#  'Lankaran',
#  'Imishli',
#  'Fizuli',
#  'Jalilabad',
#  'Pushkino',
#  'Beylagan',
#  'Astara',
#  'Şirvan',
#  'Ağdam',
#  'Zaqatala',
#  'Zabrat',
#  'Yevlakh',
#  'Yelenendorf',
#  'Xaçmaz',
#  'Ujar',
#  'Terter',
#  'Sumqayıt',
#  'Qaraçuxur',
#  'Shamkhor',
#  'Shamakhi',
#  'Sheki',
#  'Sabunçu',
#  'Sabirabad',
#  'Qusar',
#  'Quba',
#  'Hacıqabul',
#  'Qazax',
#  'Hacı Zeynalabdin',
#  'Mingelchaur',
#  'Maştağa',
#  'Mardakan',
#  'Lökbatan',
#  'Kyurdarmir',
#  'Khirdalan',
#  'Yeni Suraxanı',
#  'Geoktschai',
#  'Hövsan',
#  'Ganja',
#  'Divichibazar',
#  'Buzovna',
#  'Biny Selo',
#  'Barda',
#  'Bilajari',
#  'Baku',
#  'Amirdzhan',
#  'Aghsu',
#  'Ağdaş',
#  'Agdzhabedy',
#  'Bakıxanov',
#  'Zenica',
#  'Visoko',
#  'Velika Kladuša',
#  'Tuzla',
#  'Trebinje',
#  'Travnik',
#  'Sarajevo',
#  'Prijedor',
#  'Mostar',
#  'Gradačac',
#  'Gračanica',
#  'Goražde',
#  'Doboj',
#  'Cazin',
#  'Bugojno',
#  'Brčko',
#  'Bosanska Krupa',
#  'Bijeljina',
#  'Bihać',
#  'Banja Luka',
#  'Konjic',
#  'Bridgetown',
#  'Thākurgaon',
#  'Teknāf',
#  'Tungi',
#  'Sylhet',
#  'Dohār',
#  'Jamālpur',
#  'Shibganj',
#  'Shibganj',
#  'Sātkhira',
#  'Sirajganj',
#  'Netrakona',
#  'Narsingdi',
#  'Sandwīp',
#  'Shāhzādpur',
#  'Rāmganj',
#  'Rājshāhi',
#  'Pirojpur',
#  'Panchagarh',
#  'Patiya',
#  'Parbatipur',
#  'Nārāyanganj',
#  'Nālchiti',
#  'Nāgarpur',
#  'Nageswari',
#  'Mymensingh',
#  'Muktāgācha',
#  'Mirzāpur',
#  'Maulavi Bāzār',
#  'Morrelgonj',
#  'Mehendiganj',
#  'Mathba',
#  'Lalmonirhat',
#  'Lākshām',
#  'Comilla',
#  'Rangpur',
#  'Kushtia',
#  'Kālīganj',
#  'Jhingergācha',
#  'Joypur Hāt',
#  'Ishurdi',
#  'Habiganj',
#  'Gaurnadi',
#  'Gafargaon',
#  'Feni',
#  'Rāipur',
#  'Sarankhola',
#  'Dhaka',
#  'Chilmāri',
#  'Chhāgalnāiya',
#  'Lālmohan',
#  'Khagrachhari',
#  'Chhātak',
#  'Bhātpāra Abhaynagar',
#  'Bherāmāra',
#  'Bhairab Bāzār',
#  'Bāndarban',
#  'Kālia',
#  'Baniachang',
#  'Bājitpur',
#  'Bagerhat',
#  'Badarganj',
#  'Narail',
#  'Tungipāra',
#  'Sonārgaon',
#  'Sarishābāri',
#  'Sakhipur',
#  'Raojān',
#  'Phultala',
#  'Pālang',
#  'Pār Naogaon',
#  'Nabīnagar',
#  'Lakshmīpur',
#  'Kesabpur',
#  'Hājīganj',
#  'Farīdpur',
#  'Dinājpur',
#  'Uttar Char Fasson',
#  'Chittagong',
#  'Char Bhadrāsan',
#  'Bera',
#  'Burhānuddin',
#  'Sātkania',
#  'Cox’s Bāzār',
#  'Khulna',
#  'Bhola',
#  'Barisāl',
#  'Jessore',
#  'Pābna',
#  'Tāngāil',
#  'Bogra',
#  'Pīrgaaj',
#  'Nawābganj',
#  'Mādārīpur',
#  'Sherpur',
#  'Kishorganj',
#  'Manikchari',
#  'Bhāndāria',
#  'Bibir Hat',
#  'Saidpur',
#  'Puthia',
#  'Natore',
#  'Azimpur',
#  'Paltan',
#  'Joymontop',
#  'Zwijndrecht',
#  'Zwevegem',
#  'Zottegem',
#  'Zonhoven',
#  'Zoersel',
#  'Zemst',
#  'Zele',
#  'Zedelgem',
#  'Zaventem',
#  'Wuustwezel',
#  'Willebroek',
#  'Wevelgem',
#  'Wetteren',
#  'Westerlo',
#  'Wervik',
#  'Wavre',
#  'Waterloo',
#  'Waregem',
#  'Walcourt',
#  'Visé',
#  'Vilvoorde',
#  'Verviers',
#  'Turnhout',
#  'Tubize',
#  'Tournai',
#  'Torhout',
#  'Tongeren',
#  'Tienen',
#  'Tielt',
#  'Tessenderlo',
#  'Tervuren',
#  'Temse',
#  'Stekene',
#  'Stabroek',
#  'Soumagne',
#  'Soignies',
#  'Sint-Truiden',
#  'Sint-Pieters-Leeuw',
#  'Sint-Niklaas',
#  'Sint-Kruis',
#  'Sint-Katelijne-Waver',
#  'Sint-Gillis-Waas',
#  'Sint-Genesius-Rode',
#  'Seraing',
#  'Schoten',
#  'Schilde',
#  'Saint-Nicolas',
#  'Saint-Ghislain',
#  'Rotselaar',
#  'Ronse',
#  'Roeselare',
#  'Rixensart',
#  'Riemst',
#  'Ranst',
#  'Quaregnon',
#  'Puurs',
#  'Putte',
#  'Poperinge',
#  'Pont-à-Celles',
#  'Péruwelz',
#  'Peer',
#  'Overijse',
#  'Oupeye',
#  'Oudenaarde',
#  'Oostkamp',
#  'Ostend',
#  'Nivelles',
#  'Ninove',
#  'Nijlen',
#  'Neerpelt',
#  'Namur',
#  'Mouscron',
#  'Mortsel',
#  'Morlanwelz-Mariemont',
#  'Mons',
#  'Mol',
#  'Middelkerke',
#  'Merelbeke',
#  'Menen',
#  'Meise',
#  'Mechelen',
#  'Marche-en-Famenne',
#  'Manage',
#  'Maldegem',
#  'Maasmechelen',
#  'Maaseik',
#  'Louvain-la-Neuve',
#  'Londerzeel',
#  'Lommel',
#  'Lokeren',
#  'Lochristi',
#  'Lille',
#  'Lier',
#  'Liège',
#  'Leuven',
#  'Lessines',
#  'Lede',
#  'Lebbeke',
#  'Lanaken',
#  'La Louvière',
#  'Kortrijk',
#  'Kortenberg',
#  'Kontich',
#  'Koksijde',
#  'Knokke-Heist',
#  'Kasterlee',
#  'Kapellen',
#  'Kalmthout',
#  'Izegem',
#  'Ieper',
#  'Huy',
#  'Houthalen',
#  'Hoogstraten',
#  'Hoboken',
#  'Heusden',
#  'Herzele',
#  'Herve',
#  'Herstal',
#  'Herentals',
#  'Herent',
#  'Helchteren',
#  'Heist-op-den-Berg',
#  'Hasselt',
#  'Harelbeke',
#  'Hamme',
#  'Halle',
#  'Haaltert',
#  'Grimbergen',
#  ...]

# %%
city_to_name
# Out:
# {re.compile(r'\bAndorra la Vella\b',
#  re.IGNORECASE|re.UNICODE): 'Andorra la Vella',
#  re.compile(r'\bUmm Al Quwain City\b',
#  re.IGNORECASE|re.UNICODE): 'Umm Al Quwain City',
#  re.compile(r'\bRas Al Khaimah City\b',
#  re.IGNORECASE|re.UNICODE): 'Ras Al Khaimah City',
#  re.compile(r'\bZayed City\b', re.IGNORECASE|re.UNICODE): 'Zayed City',
#  re.compile(r'\b(Khawr Fakkān|Khawr Fakkan)\b',
#  re.IGNORECASE|re.UNICODE): 'Khawr Fakkān',
#  re.compile(r'\bDubai\b', re.IGNORECASE|re.UNICODE): 'Dubai',
#  re.compile(r'\bDibba Al-Fujairah\b',
#  re.IGNORECASE|re.UNICODE): 'Dibba Al-Fujairah',
#  re.compile(r'\bDibba Al-Hisn\b', re.IGNORECASE|re.UNICODE): 'Dibba Al-Hisn',
#  re.compile(r'\bSharjah\b', re.IGNORECASE|re.UNICODE): 'Sharjah',
#  re.compile(r'\bAr Ruways\b', re.IGNORECASE|re.UNICODE): 'Ar Ruways',
#  re.compile(r'\bAl Fujairah City\b',
#  re.IGNORECASE|re.UNICODE): 'Al Fujairah City',
#  re.compile(r'\bAl Ain City\b', re.IGNORECASE|re.UNICODE): 'Al Ain City',
#  re.compile(r'\bAjman City\b', re.IGNORECASE|re.UNICODE): 'Ajman City',
#  re.compile(r'\bAdh Dhayd\b', re.IGNORECASE|re.UNICODE): 'Adh Dhayd',
#  re.compile(r'\bAbu Dhabi\b', re.IGNORECASE|re.UNICODE): 'Abu Dhabi',
#  re.compile(r'\bKhalifah A City\b',
#  re.IGNORECASE|re.UNICODE): 'Khalifah A City',
#  re.compile(r'\bBani Yas City\b', re.IGNORECASE|re.UNICODE): 'Bani Yas City',
#  re.compile(r'\bMusaffah\b', re.IGNORECASE|re.UNICODE): 'Musaffah',
#  re.compile(r'\bAl Shamkhah City\b',
#  re.IGNORECASE|re.UNICODE): 'Al Shamkhah City',
#  re.compile(r'\bReef Al Fujairah City\b',
#  re.IGNORECASE|re.UNICODE): 'Reef Al Fujairah City',
#  re.compile(r'\bZaranj\b', re.IGNORECASE|re.UNICODE): 'Zaranj',
#  re.compile(r'\bTaloqan\b', re.IGNORECASE|re.UNICODE): 'Taloqan',
#  re.compile(r'\b(Shīnḏanḏ|Shindand)\b', re.IGNORECASE|re.UNICODE): 'Shīnḏanḏ',
#  re.compile(r'\b(Shibirghān|Shibirghan)\b',
#  re.IGNORECASE|re.UNICODE): 'Shibirghān',
#  re.compile(r'\bShahrak\b', re.IGNORECASE|re.UNICODE): 'Shahrak',
#  re.compile(r'\bSar-e Pul\b', re.IGNORECASE|re.UNICODE): 'Sar-e Pul',
#  re.compile(r'\b(Sang-e Chārak|Sang-e Charak)\b',
#  re.IGNORECASE|re.UNICODE): 'Sang-e Chārak',
#  re.compile(r'\b(Aībak|Aibak)\b', re.IGNORECASE|re.UNICODE): 'Aībak',
#  re.compile(r'\b(Rustāq|Rustaq)\b', re.IGNORECASE|re.UNICODE): 'Rustāq',
#  re.compile(r'\b(Qarqīn|Qarqin)\b', re.IGNORECASE|re.UNICODE): 'Qarqīn',
#  re.compile(r'\b(Qarāwul|Qarawul)\b', re.IGNORECASE|re.UNICODE): 'Qarāwul',
#  re.compile(r'\b(Pul-e Khumrī|Pul-e Khumri)\b',
#  re.IGNORECASE|re.UNICODE): 'Pul-e Khumrī',
#  re.compile(r'\b(Paghmān|Paghman)\b', re.IGNORECASE|re.UNICODE): 'Paghmān',
#  re.compile(r'\b(Nahrīn|Nahrin)\b', re.IGNORECASE|re.UNICODE): 'Nahrīn',
#  re.compile(r'\bMaymana\b', re.IGNORECASE|re.UNICODE): 'Maymana',
#  re.compile(r'\b(Mehtar Lām|Mehtar Lam)\b',
#  re.IGNORECASE|re.UNICODE): 'Mehtar Lām',
#  re.compile(r'\b(Mazār-e Sharīf|Mazar-e Sharif)\b',
#  re.IGNORECASE|re.UNICODE): 'Mazār-e Sharīf',
#  re.compile(r'\b(Lashkar Gāh|Lashkar Gah)\b',
#  re.IGNORECASE|re.UNICODE): 'Lashkar Gāh',
#  re.compile(r'\bKushk\b', re.IGNORECASE|re.UNICODE): 'Kushk',
#  re.compile(r'\bKunduz\b', re.IGNORECASE|re.UNICODE): 'Kunduz',
#  re.compile(r'\b(Khōst|Khost)\b', re.IGNORECASE|re.UNICODE): 'Khōst',
#  re.compile(r'\bKhulm\b', re.IGNORECASE|re.UNICODE): 'Khulm',
#  re.compile(r'\b(Khāsh|Khash)\b', re.IGNORECASE|re.UNICODE): 'Khāsh',
#  re.compile(r'\bKhanabad\b', re.IGNORECASE|re.UNICODE): 'Khanabad',
#  re.compile(r'\bKarukh\b', re.IGNORECASE|re.UNICODE): 'Karukh',
#  re.compile(r'\b(Kandahār|Kandahar)\b', re.IGNORECASE|re.UNICODE): 'Kandahār',
#  re.compile(r'\bKabul\b', re.IGNORECASE|re.UNICODE): 'Kabul',
#  re.compile(r'\b(Jalālābād|Jalalabad)\b',
#  re.IGNORECASE|re.UNICODE): 'Jalālābād',
#  re.compile(r'\bJabal os Saraj\b', re.IGNORECASE|re.UNICODE): 'Jabal os Saraj',
#  re.compile(r'\b(Herāt|Herat)\b', re.IGNORECASE|re.UNICODE): 'Herāt',
#  re.compile(r'\bGhormach\b', re.IGNORECASE|re.UNICODE): 'Ghormach',
#  re.compile(r'\bGhazni\b', re.IGNORECASE|re.UNICODE): 'Ghazni',
#  re.compile(r'\bGereshk\b', re.IGNORECASE|re.UNICODE): 'Gereshk',
#  re.compile(r'\bGardez\b', re.IGNORECASE|re.UNICODE): 'Gardez',
#  re.compile(r'\bFayzabad\b', re.IGNORECASE|re.UNICODE): 'Fayzabad',
#  re.compile(r'\bFarah\b', re.IGNORECASE|re.UNICODE): 'Farah',
#  re.compile(r'\bKafir Qala\b', re.IGNORECASE|re.UNICODE): 'Kafir Qala',
#  re.compile(r'\bCharikar\b', re.IGNORECASE|re.UNICODE): 'Charikar',
#  re.compile(r'\bBaraki Barak\b', re.IGNORECASE|re.UNICODE): 'Baraki Barak',
#  re.compile(r'\b(Bāmyān|Bamyan)\b', re.IGNORECASE|re.UNICODE): 'Bāmyān',
#  re.compile(r'\bBalkh\b', re.IGNORECASE|re.UNICODE): 'Balkh',
#  re.compile(r'\b(Baghlān|Baghlan)\b', re.IGNORECASE|re.UNICODE): 'Baghlān',
#  re.compile(r'\b(Ārt Khwājah|Art Khwajah)\b',
#  re.IGNORECASE|re.UNICODE): 'Ārt Khwājah',
#  re.compile(r'\b(Āsmār|Asmar)\b', re.IGNORECASE|re.UNICODE): 'Āsmār',
#  re.compile(r'\b(Asadābād|Asadabad)\b', re.IGNORECASE|re.UNICODE): 'Asadābād',
#  re.compile(r'\b(Andkhōy|Andkhoy)\b', re.IGNORECASE|re.UNICODE): 'Andkhōy',
#  re.compile(r'\b(Bāzārak|Bazarak)\b', re.IGNORECASE|re.UNICODE): 'Bāzārak',
#  re.compile(r'\b(Markaz-e Woluswalī-ye Āchīn|Markaz-e Woluswali-ye Achin)\b',
#  re.IGNORECASE|re.UNICODE): 'Markaz-e Woluswalī-ye Āchīn',
#  re.compile(r"\b(Saint John’s|Saint John's)\b",
#  re.IGNORECASE|re.UNICODE): 'Saint John’s',
#  re.compile(r'\bThe Valley\b', re.IGNORECASE|re.UNICODE): 'The Valley',
#  re.compile(r'\b(Sarandë|Sarande)\b', re.IGNORECASE|re.UNICODE): 'Sarandë',
#  re.compile(r'\bPogradec\b', re.IGNORECASE|re.UNICODE): 'Pogradec',
#  re.compile(r'\b(Kukës|Kukes)\b', re.IGNORECASE|re.UNICODE): 'Kukës',
#  re.compile(r'\b(Korçë|Korce)\b', re.IGNORECASE|re.UNICODE): 'Korçë',
#  re.compile(r'\b(Gjirokastër|Gjirokaster)\b',
#  re.IGNORECASE|re.UNICODE): 'Gjirokastër',
#  re.compile(r'\bElbasan\b', re.IGNORECASE|re.UNICODE): 'Elbasan',
#  re.compile(r'\bBurrel\b', re.IGNORECASE|re.UNICODE): 'Burrel',
#  re.compile(r'\b(Vlorë|Vlore)\b', re.IGNORECASE|re.UNICODE): 'Vlorë',
#  re.compile(r'\bTirana\b', re.IGNORECASE|re.UNICODE): 'Tirana',
#  re.compile(r'\b(Shkodër|Shkoder)\b', re.IGNORECASE|re.UNICODE): 'Shkodër',
#  re.compile(r'\bPatos Fshat\b', re.IGNORECASE|re.UNICODE): 'Patos Fshat',
#  re.compile(r'\bPatos\b', re.IGNORECASE|re.UNICODE): 'Patos',
#  re.compile(r'\b(Lushnjë|Lushnje)\b', re.IGNORECASE|re.UNICODE): 'Lushnjë',
#  re.compile(r'\b(Lezhë|Lezhe)\b', re.IGNORECASE|re.UNICODE): 'Lezhë',
#  re.compile(r'\b(Laç|Lac)\b', re.IGNORECASE|re.UNICODE): 'Laç',
#  re.compile(r'\b(Kuçovë|Kucove)\b', re.IGNORECASE|re.UNICODE): 'Kuçovë',
#  re.compile(r'\b(Krujë|Kruje)\b', re.IGNORECASE|re.UNICODE): 'Krujë',
#  re.compile(r'\b(Kavajë|Kavaje)\b', re.IGNORECASE|re.UNICODE): 'Kavajë',
#  re.compile(r'\b(Fier-Çifçi|Fier-Cifci)\b',
#  re.IGNORECASE|re.UNICODE): 'Fier-Çifçi',
#  re.compile(r'\bFier\b', re.IGNORECASE|re.UNICODE): 'Fier',
#  re.compile(r'\b(Durrës|Durres)\b', re.IGNORECASE|re.UNICODE): 'Durrës',
#  re.compile(r'\bBerat\b', re.IGNORECASE|re.UNICODE): 'Berat',
#  re.compile(r'\bKapan\b', re.IGNORECASE|re.UNICODE): 'Kapan',
#  re.compile(r'\bGoris\b', re.IGNORECASE|re.UNICODE): 'Goris',
#  re.compile(r"\b(Hats’avan|Hats'avan)\b",
#  re.IGNORECASE|re.UNICODE): 'Hats’avan',
#  re.compile(r'\bArtashat\b', re.IGNORECASE|re.UNICODE): 'Artashat',
#  re.compile(r'\bArarat\b', re.IGNORECASE|re.UNICODE): 'Ararat',
#  re.compile(r'\bYerevan\b', re.IGNORECASE|re.UNICODE): 'Yerevan',
#  re.compile(r'\bVagharshapat\b', re.IGNORECASE|re.UNICODE): 'Vagharshapat',
#  re.compile(r"\b(Step’anavan|Step'anavan)\b",
#  re.IGNORECASE|re.UNICODE): 'Step’anavan',
#  re.compile(r'\bSpitak\b', re.IGNORECASE|re.UNICODE): 'Spitak',
#  re.compile(r'\bSevan\b', re.IGNORECASE|re.UNICODE): 'Sevan',
#  re.compile(r'\bMasis\b', re.IGNORECASE|re.UNICODE): 'Masis',
#  re.compile(r'\bVanadzor\b', re.IGNORECASE|re.UNICODE): 'Vanadzor',
#  re.compile(r'\bGavarr\b', re.IGNORECASE|re.UNICODE): 'Gavarr',
#  re.compile(r'\bHrazdan\b', re.IGNORECASE|re.UNICODE): 'Hrazdan',
#  re.compile(r'\bArmavir\b', re.IGNORECASE|re.UNICODE): 'Armavir',
#  re.compile(r'\bGyumri\b', re.IGNORECASE|re.UNICODE): 'Gyumri',
#  re.compile(r'\bAshtarak\b', re.IGNORECASE|re.UNICODE): 'Ashtarak',
#  re.compile(r'\bAbovyan\b', re.IGNORECASE|re.UNICODE): 'Abovyan',
#  re.compile(r'\bSaurimo\b', re.IGNORECASE|re.UNICODE): 'Saurimo',
#  re.compile(r'\bLucapa\b', re.IGNORECASE|re.UNICODE): 'Lucapa',
#  re.compile(r'\bLuau\b', re.IGNORECASE|re.UNICODE): 'Luau',
#  re.compile(r'\b(Uíge|Uige)\b', re.IGNORECASE|re.UNICODE): 'Uíge',
#  re.compile(r'\bSoio\b', re.IGNORECASE|re.UNICODE): 'Soio',
#  re.compile(r"\bN'zeto\b", re.IGNORECASE|re.UNICODE): "N'zeto",
#  re.compile(r"\b(N’dalatando|N'dalatando)\b",
#  re.IGNORECASE|re.UNICODE): 'N’dalatando',
#  re.compile(r'\bMbanza Congo\b', re.IGNORECASE|re.UNICODE): 'Mbanza Congo',
#  re.compile(r'\bMalanje\b', re.IGNORECASE|re.UNICODE): 'Malanje',
#  re.compile(r'\bLuanda\b', re.IGNORECASE|re.UNICODE): 'Luanda',
#  re.compile(r'\bCaxito\b', re.IGNORECASE|re.UNICODE): 'Caxito',
#  re.compile(r'\bCabinda\b', re.IGNORECASE|re.UNICODE): 'Cabinda',
#  re.compile(r'\bSumbe\b', re.IGNORECASE|re.UNICODE): 'Sumbe',
#  re.compile(r'\bNamibe\b', re.IGNORECASE|re.UNICODE): 'Namibe',
#  re.compile(r'\bMenongue\b', re.IGNORECASE|re.UNICODE): 'Menongue',
#  re.compile(r'\bLuena\b', re.IGNORECASE|re.UNICODE): 'Luena',
#  re.compile(r'\bLubango\b', re.IGNORECASE|re.UNICODE): 'Lubango',
#  re.compile(r'\bLongonjo\b', re.IGNORECASE|re.UNICODE): 'Longonjo',
#  re.compile(r'\bLobito\b', re.IGNORECASE|re.UNICODE): 'Lobito',
#  re.compile(r'\bCuito\b', re.IGNORECASE|re.UNICODE): 'Cuito',
#  re.compile(r'\bHuambo\b', re.IGNORECASE|re.UNICODE): 'Huambo',
#  re.compile(r'\bCatumbela\b', re.IGNORECASE|re.UNICODE): 'Catumbela',
#  re.compile(r'\bCatabola\b', re.IGNORECASE|re.UNICODE): 'Catabola',
#  re.compile(r'\bCamacupa\b', re.IGNORECASE|re.UNICODE): 'Camacupa',
#  re.compile(r'\b(Caála|Caala)\b', re.IGNORECASE|re.UNICODE): 'Caála',
#  re.compile(r'\bBenguela\b', re.IGNORECASE|re.UNICODE): 'Benguela',
#  re.compile(r'\b(Zárate|Zarate)\b', re.IGNORECASE|re.UNICODE): 'Zárate',
#  re.compile(r'\bWanda\b', re.IGNORECASE|re.UNICODE): 'Wanda',
#  re.compile(r'\b(Villa Ortúzar|Villa Ortuzar)\b',
#  re.IGNORECASE|re.UNICODE): 'Villa Ortúzar',
#  re.compile(r'\bVilla Ocampo\b', re.IGNORECASE|re.UNICODE): 'Villa Ocampo',
#  re.compile(r'\bVilla Lugano\b', re.IGNORECASE|re.UNICODE): 'Villa Lugano',
#  re.compile(r'\bVillaguay\b', re.IGNORECASE|re.UNICODE): 'Villaguay',
#  re.compile(r'\bVilla Gesell\b', re.IGNORECASE|re.UNICODE): 'Villa Gesell',
#  re.compile(r'\bVilla de Mayo\b', re.IGNORECASE|re.UNICODE): 'Villa de Mayo',
#  re.compile(r'\bTortuguitas\b', re.IGNORECASE|re.UNICODE): 'Tortuguitas',
#  re.compile(r'\bTigre\b', re.IGNORECASE|re.UNICODE): 'Tigre',
#  re.compile(r'\bTandil\b', re.IGNORECASE|re.UNICODE): 'Tandil',
#  re.compile(r'\bSan Vicente\b', re.IGNORECASE|re.UNICODE): 'San Vicente',
#  re.compile(r'\b(Santo Tomé|Santo Tome)\b',
#  re.IGNORECASE|re.UNICODE): 'Santo Tomé',
#  re.compile(r'\bSanta Elena\b', re.IGNORECASE|re.UNICODE): 'Santa Elena',
#  re.compile(r'\bSan Pedro\b', re.IGNORECASE|re.UNICODE): 'San Pedro',
#  re.compile(r'\bSan Luis del Palmar\b',
#  re.IGNORECASE|re.UNICODE): 'San Luis del Palmar',
#  re.compile(r'\bSan Lorenzo\b', re.IGNORECASE|re.UNICODE): 'San Lorenzo',
#  re.compile(r'\bSan Javier\b', re.IGNORECASE|re.UNICODE): 'San Javier',
#  re.compile(r'\bSan Isidro\b', re.IGNORECASE|re.UNICODE): 'San Isidro',
#  re.compile(r'\bSaladas\b', re.IGNORECASE|re.UNICODE): 'Saladas',
#  re.compile(r'\bRetiro\b', re.IGNORECASE|re.UNICODE): 'Retiro',
#  re.compile(r'\bResistencia\b', re.IGNORECASE|re.UNICODE): 'Resistencia',
#  re.compile(r'\bReconquista\b', re.IGNORECASE|re.UNICODE): 'Reconquista',
#  re.compile(r'\bQuilmes\b', re.IGNORECASE|re.UNICODE): 'Quilmes',
#  re.compile(r'\bPuerto Rico\b', re.IGNORECASE|re.UNICODE): 'Puerto Rico',
#  re.compile(r'\b(Puerto Iguazú|Puerto Iguazu)\b',
#  re.IGNORECASE|re.UNICODE): 'Puerto Iguazú',
#  re.compile(r'\bPuerto Esperanza\b',
#  re.IGNORECASE|re.UNICODE): 'Puerto Esperanza',
#  re.compile(r'\bPuerto Eldorado\b',
#  re.IGNORECASE|re.UNICODE): 'Puerto Eldorado',
#  re.compile(r'\bPosadas\b', re.IGNORECASE|re.UNICODE): 'Posadas',
#  re.compile(r'\bPontevedra\b', re.IGNORECASE|re.UNICODE): 'Pontevedra',
#  re.compile(r'\b(Pirané|Pirane)\b', re.IGNORECASE|re.UNICODE): 'Pirané',
#  re.compile(r'\bPilar\b', re.IGNORECASE|re.UNICODE): 'Pilar',
#  re.compile(r'\bPaso de los Libres\b',
#  re.IGNORECASE|re.UNICODE): 'Paso de los Libres',
#  re.compile(r'\b(Oberá|Obera)\b', re.IGNORECASE|re.UNICODE): 'Oberá',
#  re.compile(r'\bNecochea\b', re.IGNORECASE|re.UNICODE): 'Necochea',
#  re.compile(r'\b(Muñiz|Muniz)\b', re.IGNORECASE|re.UNICODE): 'Muñiz',
#  re.compile(r'\b(Morón|Moron)\b', re.IGNORECASE|re.UNICODE): 'Morón',
#  re.compile(r'\bMonte Caseros\b', re.IGNORECASE|re.UNICODE): 'Monte Caseros',
#  re.compile(r'\bMontecarlo\b', re.IGNORECASE|re.UNICODE): 'Montecarlo',
#  re.compile(r'\bMerlo\b', re.IGNORECASE|re.UNICODE): 'Merlo',
#  re.compile(r'\bMercedes\b', re.IGNORECASE|re.UNICODE): 'Mercedes',
#  re.compile(r'\bMar del Plata\b', re.IGNORECASE|re.UNICODE): 'Mar del Plata',
#  re.compile(r'\b(Luján|Lujan)\b', re.IGNORECASE|re.UNICODE): 'Luján',
#  re.compile(r'\bLos Polvorines\b', re.IGNORECASE|re.UNICODE): 'Los Polvorines',
#  re.compile(r'\bLa Plata\b', re.IGNORECASE|re.UNICODE): 'La Plata',
#  re.compile(r'\bLa Paz\b', re.IGNORECASE|re.UNICODE): 'La Paz',
#  re.compile(r'\b(Jardín América|Jardin America)\b',
#  re.IGNORECASE|re.UNICODE): 'Jardín América',
#  re.compile(r'\bHurlingham\b', re.IGNORECASE|re.UNICODE): 'Hurlingham',
#  re.compile(r'\b(Gualeguaychú|Gualeguaychu)\b',
#  re.IGNORECASE|re.UNICODE): 'Gualeguaychú',
#  re.compile(r'\bGualeguay\b', re.IGNORECASE|re.UNICODE): 'Gualeguay',
#  re.compile(r'\bGoya\b', re.IGNORECASE|re.UNICODE): 'Goya',
#  re.compile(r'\bGobernador Virasora\b',
#  re.IGNORECASE|re.UNICODE): 'Gobernador Virasora',
#  re.compile(r'\bGeneral Pacheco\b',
#  re.IGNORECASE|re.UNICODE): 'General Pacheco',
#  re.compile(r'\b(General José de San Martín|General Jose de San Martin)\b',
#  re.IGNORECASE|re.UNICODE): 'General José de San Martín',
#  re.compile(r'\b(Garupá|Garupa)\b', re.IGNORECASE|re.UNICODE): 'Garupá',
#  re.compile(r'\bFormosa\b', re.IGNORECASE|re.UNICODE): 'Formosa',
#  re.compile(r'\bFontana\b', re.IGNORECASE|re.UNICODE): 'Fontana',
#  re.compile(r'\bFederal\b', re.IGNORECASE|re.UNICODE): 'Federal',
#  re.compile(r'\bEsquina\b', re.IGNORECASE|re.UNICODE): 'Esquina',
#  re.compile(r'\bEl Soberbio\b', re.IGNORECASE|re.UNICODE): 'El Soberbio',
#  re.compile(r'\bDon Torcuato\b', re.IGNORECASE|re.UNICODE): 'Don Torcuato',
#  re.compile(r'\bDolores\b', re.IGNORECASE|re.UNICODE): 'Dolores',
#  re.compile(r'\b(Curuzú Cuatiá|Curuzu Cuatia)\b',
#  re.IGNORECASE|re.UNICODE): 'Curuzú Cuatiá',
#  re.compile(r'\bCorrientes\b', re.IGNORECASE|re.UNICODE): 'Corrientes',
#  re.compile(r'\bConcordia\b', re.IGNORECASE|re.UNICODE): 'Concordia',
#  re.compile(r'\b(Concepción del Uruguay|Concepcion del Uruguay)\b',
#  re.IGNORECASE|re.UNICODE): 'Concepción del Uruguay',
#  re.compile(r'\bColegiales\b', re.IGNORECASE|re.UNICODE): 'Colegiales',
#  re.compile(r'\b(Chajarí|Chajari)\b', re.IGNORECASE|re.UNICODE): 'Chajarí',
#  re.compile(r'\bCampana\b', re.IGNORECASE|re.UNICODE): 'Campana',
#  re.compile(r'\bBuenos Aires\b', re.IGNORECASE|re.UNICODE): 'Buenos Aires',
#  re.compile(r'\bBoedo\b', re.IGNORECASE|re.UNICODE): 'Boedo',
#  re.compile(r'\bBerazategui\b', re.IGNORECASE|re.UNICODE): 'Berazategui',
#  re.compile(r'\bBelgrano\b', re.IGNORECASE|re.UNICODE): 'Belgrano',
#  re.compile(r'\bBarranqueras\b', re.IGNORECASE|re.UNICODE): 'Barranqueras',
#  re.compile(r'\bBarracas\b', re.IGNORECASE|re.UNICODE): 'Barracas',
#  re.compile(r'\bBalcarce\b', re.IGNORECASE|re.UNICODE): 'Balcarce',
#  re.compile(r'\bAzul\b', re.IGNORECASE|re.UNICODE): 'Azul',
#  re.compile(r'\bAvellaneda\b', re.IGNORECASE|re.UNICODE): 'Avellaneda',
#  re.compile(r'\b(Aristóbulo del Valle|Aristobulo del Valle)\b',
#  re.IGNORECASE|re.UNICODE): 'Aristóbulo del Valle',
#  re.compile(r'\bZapala\b', re.IGNORECASE|re.UNICODE): 'Zapala',
#  re.compile(r'\bYerba Buena\b', re.IGNORECASE|re.UNICODE): 'Yerba Buena',
#  re.compile(r'\bVilla Regina\b', re.IGNORECASE|re.UNICODE): 'Villa Regina',
#  re.compile(r'\bVilla Paula de Sarmiento\b',
#  re.IGNORECASE|re.UNICODE): 'Villa Paula de Sarmiento',
#  re.compile(r'\bVilla Nueva\b', re.IGNORECASE|re.UNICODE): 'Villa Nueva',
#  re.compile(r'\b(Villa María|Villa Maria)\b',
#  re.IGNORECASE|re.UNICODE): 'Villa María',
#  re.compile(r'\bVilla Dolores\b', re.IGNORECASE|re.UNICODE): 'Villa Dolores',
#  re.compile(r'\b(Villa Constitución|Villa Constitucion)\b',
#  re.IGNORECASE|re.UNICODE): 'Villa Constitución',
#  re.compile(r'\bVilla Carlos Paz\b',
#  re.IGNORECASE|re.UNICODE): 'Villa Carlos Paz',
#  re.compile(r'\b(Villa Ángela|Villa Angela)\b',
#  re.IGNORECASE|re.UNICODE): 'Villa Ángela',
#  re.compile(r'\bVilla Allende\b', re.IGNORECASE|re.UNICODE): 'Villa Allende',
#  re.compile(r'\bViedma\b', re.IGNORECASE|re.UNICODE): 'Viedma',
#  re.compile(r'\bVictoria\b', re.IGNORECASE|re.UNICODE): 'Victoria',
#  re.compile(r'\bVera\b', re.IGNORECASE|re.UNICODE): 'Vera',
#  re.compile(r'\bVenado Tuerto\b', re.IGNORECASE|re.UNICODE): 'Venado Tuerto',
#  re.compile(r'\bVeinticinco de Mayo\b',
#  re.IGNORECASE|re.UNICODE): 'Veinticinco de Mayo',
#  re.compile(r'\bUshuaia\b', re.IGNORECASE|re.UNICODE): 'Ushuaia',
#  re.compile(r'\bUnquillo\b', re.IGNORECASE|re.UNICODE): 'Unquillo',
#  re.compile(r'\bTres Isletas\b', re.IGNORECASE|re.UNICODE): 'Tres Isletas',
#  re.compile(r'\bTres Arroyos\b', re.IGNORECASE|re.UNICODE): 'Tres Arroyos',
#  re.compile(r'\bTrelew\b', re.IGNORECASE|re.UNICODE): 'Trelew',
#  re.compile(r'\b(Termas de Río Hondo|Termas de Rio Hondo)\b',
#  re.IGNORECASE|re.UNICODE): 'Termas de Río Hondo',
#  re.compile(r'\bTartagal\b', re.IGNORECASE|re.UNICODE): 'Tartagal',
#  re.compile(r'\b(Tafí Viejo|Tafi Viejo)\b',
#  re.IGNORECASE|re.UNICODE): 'Tafí Viejo',
#  re.compile(r'\bSunchales\b', re.IGNORECASE|re.UNICODE): 'Sunchales',
#  re.compile(r'\bSantiago del Estero\b',
#  re.IGNORECASE|re.UNICODE): 'Santiago del Estero',
#  re.compile(r'\bSanta Rosa\b', re.IGNORECASE|re.UNICODE): 'Santa Rosa',
#  re.compile(r'\b(Santa Lucía|Santa Lucia)\b',
#  re.IGNORECASE|re.UNICODE): 'Santa Lucía',
#  re.compile(r'\bSanta Fe\b', re.IGNORECASE|re.UNICODE): 'Santa Fe',
#  re.compile(r'\bSan Salvador de Jujuy\b',
#  re.IGNORECASE|re.UNICODE): 'San Salvador de Jujuy',
#  re.compile(r'\b(San Ramón de la Nueva Orán|San Ramon de la Nueva Oran)\b',
#  re.IGNORECASE|re.UNICODE): 'San Ramón de la Nueva Orán',
#  re.compile(r'\bSan Rafael\b', re.IGNORECASE|re.UNICODE): 'San Rafael',
#  re.compile(r'\bSan Pedro de Jujuy\b',
#  re.IGNORECASE|re.UNICODE): 'San Pedro de Jujuy',
#  re.compile(r'\b(San Nicolás de los Arroyos|San Nicolas de los Arroyos)\b',
#  re.IGNORECASE|re.UNICODE): 'San Nicolás de los Arroyos',
#  re.compile(r'\b(San Miguel de Tucumán|San Miguel de Tucuman)\b',
#  re.IGNORECASE|re.UNICODE): 'San Miguel de Tucumán',
#  re.compile(r'\b(San Martín de los Andes|San Martin de los Andes)\b',
#  re.IGNORECASE|re.UNICODE): 'San Martín de los Andes',
#  re.compile(r'\b(San Martín|San Martin)\b',
#  re.IGNORECASE|re.UNICODE): 'San Martín',
#  re.compile(r'\bSan Luis\b', re.IGNORECASE|re.UNICODE): 'San Luis',
#  re.compile(r'\bSan Justo\b', re.IGNORECASE|re.UNICODE): 'San Justo',
#  re.compile(r'\bSan Juan\b', re.IGNORECASE|re.UNICODE): 'San Juan',
#  re.compile(r'\b(San José de Jáchal|San Jose de Jachal)\b',
#  re.IGNORECASE|re.UNICODE): 'San José de Jáchal',
#  re.compile(r'\bSan Jorge\b', re.IGNORECASE|re.UNICODE): 'San Jorge',
#  re.compile(r'\bSan Francisco\b', re.IGNORECASE|re.UNICODE): 'San Francisco',
#  re.compile(r'\bSan Fernando del Valle de Catamarca\b',
#  re.IGNORECASE|re.UNICODE): 'San Fernando del Valle de Catamarca',
#  re.compile(r'\bSan Antonio Oeste\b',
#  re.IGNORECASE|re.UNICODE): 'San Antonio Oeste',
#  re.compile(r'\bSalta\b', re.IGNORECASE|re.UNICODE): 'Salta',
#  re.compile(r'\bRufino\b', re.IGNORECASE|re.UNICODE): 'Rufino',
#  re.compile(r'\bRosario\b', re.IGNORECASE|re.UNICODE): 'Rosario',
#  re.compile(r'\b(Río Tercero|Rio Tercero)\b',
#  re.IGNORECASE|re.UNICODE): 'Río Tercero',
#  re.compile(r'\b(Río Segundo|Rio Segundo)\b',
#  re.IGNORECASE|re.UNICODE): 'Río Segundo',
#  re.compile(r'\b(Río Grande|Rio Grande)\b',
#  re.IGNORECASE|re.UNICODE): 'Río Grande',
#  re.compile(r'\b(Río Gallegos|Rio Gallegos)\b',
#  re.IGNORECASE|re.UNICODE): 'Río Gallegos',
#  re.compile(r'\b(Río Cuarto|Rio Cuarto)\b',
#  re.IGNORECASE|re.UNICODE): 'Río Cuarto',
#  re.compile(r'\b(Río Ceballos|Rio Ceballos)\b',
#  re.IGNORECASE|re.UNICODE): 'Río Ceballos',
#  re.compile(r'\bRawson\b', re.IGNORECASE|re.UNICODE): 'Rawson',
#  re.compile(r'\bRafaela\b', re.IGNORECASE|re.UNICODE): 'Rafaela',
#  re.compile(r'\bQuitilipi\b', re.IGNORECASE|re.UNICODE): 'Quitilipi',
#  re.compile(r'\bPunta Alta\b', re.IGNORECASE|re.UNICODE): 'Punta Alta',
#  re.compile(r'\bPuerto Madryn\b', re.IGNORECASE|re.UNICODE): 'Puerto Madryn',
#  re.compile(r'\b(Presidencia Roque Sáenz Peña|Presidencia Roque Saenz Pena)\b',
#  re.IGNORECASE|re.UNICODE): 'Presidencia Roque Sáenz Peña',
#  re.compile(r'\bPocito\b', re.IGNORECASE|re.UNICODE): 'Pocito',
#  re.compile(r'\bPlottier\b', re.IGNORECASE|re.UNICODE): 'Plottier',
#  re.compile(r'\bPergamino\b', re.IGNORECASE|re.UNICODE): 'Pergamino',
#  re.compile(r'\b(Pérez|Perez)\b', re.IGNORECASE|re.UNICODE): 'Pérez',
#  re.compile(r'\b(Paraná|Parana)\b', re.IGNORECASE|re.UNICODE): 'Paraná',
#  re.compile(r'\b(Palpalá|Palpala)\b', re.IGNORECASE|re.UNICODE): 'Palpalá',
#  re.compile(r'\b(Olavarría|Olavarria)\b',
#  re.IGNORECASE|re.UNICODE): 'Olavarría',
#  re.compile(r'\bNueve de Julio\b', re.IGNORECASE|re.UNICODE): 'Nueve de Julio',
#  re.compile(r'\b(Neuquén|Neuquen)\b', re.IGNORECASE|re.UNICODE): 'Neuquén',
#  re.compile(r'\bMorteros\b', re.IGNORECASE|re.UNICODE): 'Morteros',
#  re.compile(r'\bMonteros\b', re.IGNORECASE|re.UNICODE): 'Monteros',
#  re.compile(r'\bMendoza\b', re.IGNORECASE|re.UNICODE): 'Mendoza',
#  re.compile(r'\b(Marcos Juárez|Marcos Juarez)\b',
#  re.IGNORECASE|re.UNICODE): 'Marcos Juárez',
#  re.compile(r'\bMachagai\b', re.IGNORECASE|re.UNICODE): 'Machagai',
#  re.compile(r'\bLincoln\b', re.IGNORECASE|re.UNICODE): 'Lincoln',
#  re.compile(r'\b(Libertador General San Martín|Libertador General San Martin)\b',
#  re.IGNORECASE|re.UNICODE): 'Libertador General San Martín',
#  re.compile(r'\b(Las Breñas|Las Brenas)\b',
#  re.IGNORECASE|re.UNICODE): 'Las Breñas',
#  re.compile(r'\bLa Rioja\b', re.IGNORECASE|re.UNICODE): 'La Rioja',
#  re.compile(r'\bLa Falda\b', re.IGNORECASE|re.UNICODE): 'La Falda',
#  re.compile(r'\bLa Calera\b', re.IGNORECASE|re.UNICODE): 'La Calera',
#  re.compile(r'\bLaboulaye\b', re.IGNORECASE|re.UNICODE): 'Laboulaye',
#  re.compile(r'\b(Junín|Junin)\b', re.IGNORECASE|re.UNICODE): 'Junín',
#  re.compile(r'\b(Joaquín V. González|Joaquin V. Gonzalez)\b',
#  re.IGNORECASE|re.UNICODE): 'Joaquín V. González',
#  re.compile(r'\b(Jesús María|Jesus Maria)\b',
#  re.IGNORECASE|re.UNICODE): 'Jesús María',
#  re.compile(r'\bGranadero Baigorria\b',
#  re.IGNORECASE|re.UNICODE): 'Granadero Baigorria',
#  re.compile(r'\b(Gobernador Gálvez|Gobernador Galvez)\b',
#  re.IGNORECASE|re.UNICODE): 'Gobernador Gálvez',
#  re.compile(r'\bGeneral Villegas\b',
#  re.IGNORECASE|re.UNICODE): 'General Villegas',
#  re.compile(r'\bGeneral Roca\b', re.IGNORECASE|re.UNICODE): 'General Roca',
#  re.compile(r'\bGeneral Pinedo\b', re.IGNORECASE|re.UNICODE): 'General Pinedo',
#  re.compile(r'\bGeneral Pico\b', re.IGNORECASE|re.UNICODE): 'General Pico',
#  re.compile(r'\bGeneral Enrique Mosconi\b',
#  re.IGNORECASE|re.UNICODE): 'General Enrique Mosconi',
#  re.compile(r'\b(Gálvez|Galvez)\b', re.IGNORECASE|re.UNICODE): 'Gálvez',
#  re.compile(r'\bFirmat\b', re.IGNORECASE|re.UNICODE): 'Firmat',
#  re.compile(r'\b(Famaillá|Famailla)\b', re.IGNORECASE|re.UNICODE): 'Famaillá',
#  re.compile(r'\bEsquel\b', re.IGNORECASE|re.UNICODE): 'Esquel',
#  re.compile(r'\bEsperanza\b', re.IGNORECASE|re.UNICODE): 'Esperanza',
#  re.compile(r'\b(Embarcación|Embarcacion)\b',
#  re.IGNORECASE|re.UNICODE): 'Embarcación',
#  re.compile(r'\bEmbalse\b', re.IGNORECASE|re.UNICODE): 'Embalse',
#  re.compile(r'\b(El Bolsón|El Bolson)\b',
#  re.IGNORECASE|re.UNICODE): 'El Bolsón',
#  re.compile(r'\bDiamante\b', re.IGNORECASE|re.UNICODE): 'Diamante',
#  re.compile(r'\b(Deán Funes|Dean Funes)\b',
#  re.IGNORECASE|re.UNICODE): 'Deán Funes',
#  re.compile(r'\b(Cutral-Có|Cutral-Co)\b',
#  re.IGNORECASE|re.UNICODE): 'Cutral-Có',
#  re.compile(r'\bCruz del Eje\b', re.IGNORECASE|re.UNICODE): 'Cruz del Eje',
#  re.compile(r'\bCrespo\b', re.IGNORECASE|re.UNICODE): 'Crespo',
#  re.compile(r'\b(Cosquín|Cosquin)\b', re.IGNORECASE|re.UNICODE): 'Cosquín',
#  re.compile(r'\b(Coronel Suárez|Coronel Suarez)\b',
#  re.IGNORECASE|re.UNICODE): 'Coronel Suárez',
#  re.compile(r'\bCoronda\b', re.IGNORECASE|re.UNICODE): 'Coronda',
#  re.compile(r'\b(Córdoba|Cordoba)\b', re.IGNORECASE|re.UNICODE): 'Córdoba',
#  re.compile(r'\bComodoro Rivadavia\b',
#  re.IGNORECASE|re.UNICODE): 'Comodoro Rivadavia',
#  re.compile(r'\bCipolletti\b', re.IGNORECASE|re.UNICODE): 'Cipolletti',
#  re.compile(r'\bCinco Saltos\b', re.IGNORECASE|re.UNICODE): 'Cinco Saltos',
#  re.compile(r'\bChivilcoy\b', re.IGNORECASE|re.UNICODE): 'Chivilcoy',
#  re.compile(r'\bChimbas\b', re.IGNORECASE|re.UNICODE): 'Chimbas',
#  re.compile(r'\bChilecito\b', re.IGNORECASE|re.UNICODE): 'Chilecito',
#  re.compile(r'\bCharata\b', re.IGNORECASE|re.UNICODE): 'Charata',
#  re.compile(r'\bChacabuco\b', re.IGNORECASE|re.UNICODE): 'Chacabuco',
#  re.compile(r'\bCentenario\b', re.IGNORECASE|re.UNICODE): 'Centenario',
#  re.compile(r'\bCaucete\b', re.IGNORECASE|re.UNICODE): 'Caucete',
#  re.compile(r'\bCatriel\b', re.IGNORECASE|re.UNICODE): 'Catriel',
#  re.compile(r'\bCastelli\b', re.IGNORECASE|re.UNICODE): 'Castelli',
#  re.compile(r'\bCasilda\b', re.IGNORECASE|re.UNICODE): 'Casilda',
#  re.compile(r'\b(Carcarañá|Carcarana)\b',
#  re.IGNORECASE|re.UNICODE): 'Carcarañá',
#  re.compile(r'\b(Capitán Bermúdez|Capitan Bermudez)\b',
#  re.IGNORECASE|re.UNICODE): 'Capitán Bermúdez',
#  re.compile(r'\b(Cañada de Gómez|Canada de Gomez)\b',
#  re.IGNORECASE|re.UNICODE): 'Cañada de Gómez',
#  re.compile(r'\bCaleta Olivia\b', re.IGNORECASE|re.UNICODE): 'Caleta Olivia',
#  re.compile(r'\bBell Ville\b', re.IGNORECASE|re.UNICODE): 'Bell Ville',
#  re.compile(r'\bBella Vista\b', re.IGNORECASE|re.UNICODE): 'Bella Vista',
#  re.compile(r'\b(Bahía Blanca|Bahia Blanca)\b',
#  re.IGNORECASE|re.UNICODE): 'Bahía Blanca',
#  re.compile(r'\bArroyo Seco\b', re.IGNORECASE|re.UNICODE): 'Arroyo Seco',
#  re.compile(r'\bArroyito\b', re.IGNORECASE|re.UNICODE): 'Arroyito',
#  re.compile(r'\b(Añatuya|Anatuya)\b', re.IGNORECASE|re.UNICODE): 'Añatuya',
#  re.compile(r'\bAlta Gracia\b', re.IGNORECASE|re.UNICODE): 'Alta Gracia',
#  re.compile(r'\bAllen\b', re.IGNORECASE|re.UNICODE): 'Allen',
#  re.compile(r'\bAlderetes\b', re.IGNORECASE|re.UNICODE): 'Alderetes',
#  re.compile(r'\b(Albardón|Albardon)\b', re.IGNORECASE|re.UNICODE): 'Albardón',
#  re.compile(r'\bAguilares\b', re.IGNORECASE|re.UNICODE): 'Aguilares',
#  re.compile(r'\bBalvanera\b', re.IGNORECASE|re.UNICODE): 'Balvanera',
#  re.compile(r'\bVilla Santa Rita\b',
#  re.IGNORECASE|re.UNICODE): 'Villa Santa Rita',
#  re.compile(r'\bVilla Mercedes\b', re.IGNORECASE|re.UNICODE): 'Villa Mercedes',
#  re.compile(r'\bSan Miguel\b', re.IGNORECASE|re.UNICODE): 'San Miguel',
#  re.compile(r'\bSan Carlos de Bariloche\b',
#  re.IGNORECASE|re.UNICODE): 'San Carlos de Bariloche',
#  re.compile(r'\b(Adrogué|Adrogue)\b', re.IGNORECASE|re.UNICODE): 'Adrogué',
#  re.compile(r'\b(Ingeniero Pablo Nogués|Ingeniero Pablo Nogues)\b',
#  re.IGNORECASE|re.UNICODE): 'Ingeniero Pablo Nogués',
#  re.compile(r'\b(José C. Paz|Jose C. Paz)\b',
#  re.IGNORECASE|re.UNICODE): 'José C. Paz',
#  re.compile(r'\bPago Pago\b', re.IGNORECASE|re.UNICODE): 'Pago Pago',
#  re.compile(r'\bWilten\b', re.IGNORECASE|re.UNICODE): 'Wilten',
#  re.compile(r'\bWiener Neustadt\b',
#  re.IGNORECASE|re.UNICODE): 'Wiener Neustadt',
#  re.compile(r'\bVienna\b', re.IGNORECASE|re.UNICODE): 'Vienna',
#  re.compile(r'\bWetzelsdorf\b', re.IGNORECASE|re.UNICODE): 'Wetzelsdorf',
#  re.compile(r'\bWels\b', re.IGNORECASE|re.UNICODE): 'Wels',
#  re.compile(r'\bWeinzierl bei Krems\b',
#  re.IGNORECASE|re.UNICODE): 'Weinzierl bei Krems',
#  re.compile(r'\bVillach\b', re.IGNORECASE|re.UNICODE): 'Villach',
#  re.compile(r'\bTelfs\b', re.IGNORECASE|re.UNICODE): 'Telfs',
#  re.compile(r'\b(Straßgang|Strassgang)\b',
#  re.IGNORECASE|re.UNICODE): 'Straßgang',
#  re.compile(r'\bStockerau\b', re.IGNORECASE|re.UNICODE): 'Stockerau',
#  re.compile(r'\bSteyr\b', re.IGNORECASE|re.UNICODE): 'Steyr',
#  re.compile(r'\bSimmering\b', re.IGNORECASE|re.UNICODE): 'Simmering',
#  re.compile(r'\b(Sankt Pölten|Sankt Polten)\b',
#  re.IGNORECASE|re.UNICODE): 'Sankt Pölten',
#  re.compile(r'\bSankt Peter\b', re.IGNORECASE|re.UNICODE): 'Sankt Peter',
#  re.compile(r'\bSankt Martin\b', re.IGNORECASE|re.UNICODE): 'Sankt Martin',
#  re.compile(r'\bSalzburg\b', re.IGNORECASE|re.UNICODE): 'Salzburg',
#  re.compile(r'\bPradl\b', re.IGNORECASE|re.UNICODE): 'Pradl',
#  re.compile(r'\bPerchtoldsdorf\b', re.IGNORECASE|re.UNICODE): 'Perchtoldsdorf',
#  re.compile(r'\bOttakring\b', re.IGNORECASE|re.UNICODE): 'Ottakring',
#  re.compile(r'\b(Mödling|Modling)\b', re.IGNORECASE|re.UNICODE): 'Mödling',
#  re.compile(r'\bMeidling\b', re.IGNORECASE|re.UNICODE): 'Meidling',
#  re.compile(r'\bLustenau\b', re.IGNORECASE|re.UNICODE): 'Lustenau',
#  re.compile(r'\bLinz\b', re.IGNORECASE|re.UNICODE): 'Linz',
#  re.compile(r'\bKlosterneuburg\b', re.IGNORECASE|re.UNICODE): 'Klosterneuburg',
#  re.compile(r'\b(Klagenfurt am Wörthersee|Klagenfurt am Worthersee)\b',
#  re.IGNORECASE|re.UNICODE): 'Klagenfurt am Wörthersee',
#  re.compile(r'\bInnsbruck\b', re.IGNORECASE|re.UNICODE): 'Innsbruck',
#  re.compile(r'\bInnere Stadt\b', re.IGNORECASE|re.UNICODE): 'Innere Stadt',
#  re.compile(r'\b(Hötting|Hotting)\b', re.IGNORECASE|re.UNICODE): 'Hötting',
#  re.compile(r'\bHohenems\b', re.IGNORECASE|re.UNICODE): 'Hohenems',
#  re.compile(r'\bHietzing\b', re.IGNORECASE|re.UNICODE): 'Hietzing',
#  re.compile(r'\bHernals\b', re.IGNORECASE|re.UNICODE): 'Hernals',
#  re.compile(r'\bGraz\b', re.IGNORECASE|re.UNICODE): 'Graz',
#  re.compile(r'\bFloridsdorf\b', re.IGNORECASE|re.UNICODE): 'Floridsdorf',
#  re.compile(r'\bFeldkirch\b', re.IGNORECASE|re.UNICODE): 'Feldkirch',
#  re.compile(r'\bEggenberg\b', re.IGNORECASE|re.UNICODE): 'Eggenberg',
#  re.compile(r'\bDornbirn\b', re.IGNORECASE|re.UNICODE): 'Dornbirn',
#  re.compile(r'\bBregenz\b', re.IGNORECASE|re.UNICODE): 'Bregenz',
#  re.compile(r'\bBaden\b', re.IGNORECASE|re.UNICODE): 'Baden',
#  re.compile(r'\bAmstetten\b', re.IGNORECASE|re.UNICODE): 'Amstetten',
#  re.compile(r'\bFavoriten\b', re.IGNORECASE|re.UNICODE): 'Favoriten',
#  re.compile(r'\bDonaustadt\b', re.IGNORECASE|re.UNICODE): 'Donaustadt',
#  re.compile(r'\bJakomini\b', re.IGNORECASE|re.UNICODE): 'Jakomini',
#  re.compile(r'\bLend\b', re.IGNORECASE|re.UNICODE): 'Lend',
#  re.compile(r'\bGeidorf\b', re.IGNORECASE|re.UNICODE): 'Geidorf',
#  re.compile(r'\bSankt Leonhard\b', re.IGNORECASE|re.UNICODE): 'Sankt Leonhard',
#  re.compile(r'\bAndritz\b', re.IGNORECASE|re.UNICODE): 'Andritz',
#  re.compile(r'\bGries\b', re.IGNORECASE|re.UNICODE): 'Gries',
#  re.compile(r'\bScarborough\b', re.IGNORECASE|re.UNICODE): 'Scarborough',
#  re.compile(r'\bRockingham\b', re.IGNORECASE|re.UNICODE): 'Rockingham',
#  re.compile(r'\bPerth\b', re.IGNORECASE|re.UNICODE): 'Perth',
#  re.compile(r'\bMount Isa\b', re.IGNORECASE|re.UNICODE): 'Mount Isa',
#  re.compile(r'\bMorphett Vale\b', re.IGNORECASE|re.UNICODE): 'Morphett Vale',
#  re.compile(r'\bMandurah\b', re.IGNORECASE|re.UNICODE): 'Mandurah',
#  re.compile(r'\bKwinana\b', re.IGNORECASE|re.UNICODE): 'Kwinana',
#  re.compile(r'\bGosnells\b', re.IGNORECASE|re.UNICODE): 'Gosnells',
#  re.compile(r'\bGeraldton\b', re.IGNORECASE|re.UNICODE): 'Geraldton',
#  re.compile(r'\bGawler\b', re.IGNORECASE|re.UNICODE): 'Gawler',
#  re.compile(r'\bDarwin\b', re.IGNORECASE|re.UNICODE): 'Darwin',
#  re.compile(r'\bBusselton\b', re.IGNORECASE|re.UNICODE): 'Busselton',
#  re.compile(r'\bBunbury\b', re.IGNORECASE|re.UNICODE): 'Bunbury',
#  re.compile(r'\bAlice Springs\b', re.IGNORECASE|re.UNICODE): 'Alice Springs',
#  re.compile(r'\bAlbany\b', re.IGNORECASE|re.UNICODE): 'Albany',
#  re.compile(r'\bAdelaide\b', re.IGNORECASE|re.UNICODE): 'Adelaide',
#  re.compile(r'\bWodonga\b', re.IGNORECASE|re.UNICODE): 'Wodonga',
#  re.compile(r'\bWheelers Hill\b', re.IGNORECASE|re.UNICODE): 'Wheelers Hill',
#  re.compile(r'\bWestmead\b', re.IGNORECASE|re.UNICODE): 'Westmead',
#  re.compile(r'\bWerribee\b', re.IGNORECASE|re.UNICODE): 'Werribee',
#  re.compile(r'\bWarrnambool\b', re.IGNORECASE|re.UNICODE): 'Warrnambool',
#  re.compile(r'\bWarragul\b', re.IGNORECASE|re.UNICODE): 'Warragul',
#  re.compile(r'\bWantirna South\b', re.IGNORECASE|re.UNICODE): 'Wantirna South',
#  re.compile(r'\bWangaratta\b', re.IGNORECASE|re.UNICODE): 'Wangaratta',
#  re.compile(r'\bWahroonga\b', re.IGNORECASE|re.UNICODE): 'Wahroonga',
#  re.compile(r'\bUpper Coomera\b', re.IGNORECASE|re.UNICODE): 'Upper Coomera',
#  re.compile(r'\bTruganina\b', re.IGNORECASE|re.UNICODE): 'Truganina',
#  re.compile(r'\bTraralgon\b', re.IGNORECASE|re.UNICODE): 'Traralgon',
#  re.compile(r'\bTownsville\b', re.IGNORECASE|re.UNICODE): 'Townsville',
#  re.compile(r'\bToowoomba\b', re.IGNORECASE|re.UNICODE): 'Toowoomba',
#  re.compile(r'\bThornbury\b', re.IGNORECASE|re.UNICODE): 'Thornbury',
#  re.compile(r'\bThomastown\b', re.IGNORECASE|re.UNICODE): 'Thomastown',
#  re.compile(r'\bTemplestowe\b', re.IGNORECASE|re.UNICODE): 'Templestowe',
#  re.compile(r'\bTarneit\b', re.IGNORECASE|re.UNICODE): 'Tarneit',
#  re.compile(r'\bTaree\b', re.IGNORECASE|re.UNICODE): 'Taree',
#  re.compile(r'\bTamworth\b', re.IGNORECASE|re.UNICODE): 'Tamworth',
#  re.compile(r'\bSydney\b', re.IGNORECASE|re.UNICODE): 'Sydney',
#  re.compile(r'\bSurry Hills\b', re.IGNORECASE|re.UNICODE): 'Surry Hills',
#  re.compile(r'\bSurfers Paradise\b',
#  re.IGNORECASE|re.UNICODE): 'Surfers Paradise',
#  re.compile(r'\bSunbury\b', re.IGNORECASE|re.UNICODE): 'Sunbury',
#  re.compile(r'\bStrathfield\b', re.IGNORECASE|re.UNICODE): 'Strathfield',
#  re.compile(r'\bSpringvale\b', re.IGNORECASE|re.UNICODE): 'Springvale',
#  re.compile(r'\bSouth Yarra\b', re.IGNORECASE|re.UNICODE): 'South Yarra',
#  re.compile(r'\bSouthport\b', re.IGNORECASE|re.UNICODE): 'Southport',
#  re.compile(r'\bShepparton\b', re.IGNORECASE|re.UNICODE): 'Shepparton',
#  re.compile(r'\bSeven Hills\b', re.IGNORECASE|re.UNICODE): 'Seven Hills',
#  re.compile(r'\bSeaford\b', re.IGNORECASE|re.UNICODE): 'Seaford',
#  re.compile(r'\bSaint Kilda\b', re.IGNORECASE|re.UNICODE): 'Saint Kilda',
#  re.compile(r'\bSaint Ives\b', re.IGNORECASE|re.UNICODE): 'Saint Ives',
#  re.compile(r'\bSaint Albans\b', re.IGNORECASE|re.UNICODE): 'Saint Albans',
#  re.compile(r'\bRyde\b', re.IGNORECASE|re.UNICODE): 'Ryde',
#  re.compile(r'\bRowville\b', re.IGNORECASE|re.UNICODE): 'Rowville',
#  re.compile(r'\bRockhampton\b', re.IGNORECASE|re.UNICODE): 'Rockhampton',
#  re.compile(r'\bRockdale\b', re.IGNORECASE|re.UNICODE): 'Rockdale',
#  re.compile(r'\bRingwood\b', re.IGNORECASE|re.UNICODE): 'Ringwood',
#  re.compile(r'\bRichmond\b', re.IGNORECASE|re.UNICODE): 'Richmond',
#  re.compile(r'\bReservoir\b', re.IGNORECASE|re.UNICODE): 'Reservoir',
#  re.compile(r'\bQuakers Hill\b', re.IGNORECASE|re.UNICODE): 'Quakers Hill',
#  re.compile(r'\bPreston\b', re.IGNORECASE|re.UNICODE): 'Preston',
#  re.compile(r'\bPort Melbourne\b', re.IGNORECASE|re.UNICODE): 'Port Melbourne',
#  re.compile(r'\bPort Macquarie\b', re.IGNORECASE|re.UNICODE): 'Port Macquarie',
#  re.compile(r'\bPoint Cook\b', re.IGNORECASE|re.UNICODE): 'Point Cook',
#  re.compile(r'\bPascoe Vale\b', re.IGNORECASE|re.UNICODE): 'Pascoe Vale',
#  re.compile(r'\bPalm Beach\b', re.IGNORECASE|re.UNICODE): 'Palm Beach',
#  re.compile(r'\bPakenham\b', re.IGNORECASE|re.UNICODE): 'Pakenham',
#  re.compile(r'\bOrange\b', re.IGNORECASE|re.UNICODE): 'Orange',
#  re.compile(r'\bNorth Melbourne\b',
#  re.IGNORECASE|re.UNICODE): 'North Melbourne',
#  re.compile(r'\bNorthcote\b', re.IGNORECASE|re.UNICODE): 'Northcote',
#  re.compile(r'\bNoble Park\b', re.IGNORECASE|re.UNICODE): 'Noble Park',
#  re.compile(r'\bNewcastle\b', re.IGNORECASE|re.UNICODE): 'Newcastle',
#  re.compile(r'\bNerang\b', re.IGNORECASE|re.UNICODE): 'Nerang',
#  re.compile(r'\bNarre Warren\b', re.IGNORECASE|re.UNICODE): 'Narre Warren',
#  re.compile(r'\bNarangba\b', re.IGNORECASE|re.UNICODE): 'Narangba',
#  re.compile(r'\bMulgrave\b', re.IGNORECASE|re.UNICODE): 'Mulgrave',
#  re.compile(r'\bMount Waverley\b', re.IGNORECASE|re.UNICODE): 'Mount Waverley',
#  re.compile(r'\bMount Martha\b', re.IGNORECASE|re.UNICODE): 'Mount Martha',
#  re.compile(r'\bMount Gambier\b', re.IGNORECASE|re.UNICODE): 'Mount Gambier',
#  re.compile(r'\bMount Eliza\b', re.IGNORECASE|re.UNICODE): 'Mount Eliza',
#  re.compile(r'\bMount Druitt\b', re.IGNORECASE|re.UNICODE): 'Mount Druitt',
#  re.compile(r'\bMosman\b', re.IGNORECASE|re.UNICODE): 'Mosman',
#  re.compile(r'\bMornington\b', re.IGNORECASE|re.UNICODE): 'Mornington',
#  re.compile(r'\bMorayfield\b', re.IGNORECASE|re.UNICODE): 'Morayfield',
#  re.compile(r'\bSouth Morang\b', re.IGNORECASE|re.UNICODE): 'South Morang',
#  re.compile(r'\bMooroolbark\b', re.IGNORECASE|re.UNICODE): 'Mooroolbark',
#  re.compile(r'\bMitcham\b', re.IGNORECASE|re.UNICODE): 'Mitcham',
#  re.compile(r'\bMiranda\b', re.IGNORECASE|re.UNICODE): 'Miranda',
#  re.compile(r'\bMill Park\b', re.IGNORECASE|re.UNICODE): 'Mill Park',
#  re.compile(r'\bMildura\b', re.IGNORECASE|re.UNICODE): 'Mildura',
#  re.compile(r'\bMerrylands\b', re.IGNORECASE|re.UNICODE): 'Merrylands',
#  re.compile(r'\bMernda\b', re.IGNORECASE|re.UNICODE): 'Mernda',
#  re.compile(r'\bMelbourne\b', re.IGNORECASE|re.UNICODE): 'Melbourne',
#  re.compile(r'\bMascot\b', re.IGNORECASE|re.UNICODE): 'Mascot',
#  re.compile(r'\bMaryborough\b', re.IGNORECASE|re.UNICODE): 'Maryborough',
#  re.compile(r'\bMarrickville\b', re.IGNORECASE|re.UNICODE): 'Marrickville',
#  re.compile(r'\bMaroubra\b', re.IGNORECASE|re.UNICODE): 'Maroubra',
#  re.compile(r'\bManly\b', re.IGNORECASE|re.UNICODE): 'Manly',
#  re.compile(r'\bMaitland\b', re.IGNORECASE|re.UNICODE): 'Maitland',
#  re.compile(r'\bMackay\b', re.IGNORECASE|re.UNICODE): 'Mackay',
#  re.compile(r'\bLiverpool\b', re.IGNORECASE|re.UNICODE): 'Liverpool',
#  re.compile(r'\bLilydale\b', re.IGNORECASE|re.UNICODE): 'Lilydale',
#  re.compile(r'\bLidcombe\b', re.IGNORECASE|re.UNICODE): 'Lidcombe',
#  re.compile(r'\bLaunceston\b', re.IGNORECASE|re.UNICODE): 'Launceston',
#  re.compile(r'\bLara\b', re.IGNORECASE|re.UNICODE): 'Lara',
#  re.compile(r'\bLangwarrin\b', re.IGNORECASE|re.UNICODE): 'Langwarrin',
#  re.compile(r'\bLalor\b', re.IGNORECASE|re.UNICODE): 'Lalor',
#  re.compile(r'\bLakemba\b', re.IGNORECASE|re.UNICODE): 'Lakemba',
#  re.compile(r'\bKogarah\b', re.IGNORECASE|re.UNICODE): 'Kogarah',
#  re.compile(r'\bKeysborough\b', re.IGNORECASE|re.UNICODE): 'Keysborough',
#  re.compile(r'\bKew\b', re.IGNORECASE|re.UNICODE): 'Kew',
#  re.compile(r'\bKensington\b', re.IGNORECASE|re.UNICODE): 'Kensington',
#  re.compile(r'\bHornsby\b', re.IGNORECASE|re.UNICODE): 'Hornsby',
#  re.compile(r'\bHobart\b', re.IGNORECASE|re.UNICODE): 'Hobart',
#  re.compile(r'\bHawthorn South\b', re.IGNORECASE|re.UNICODE): 'Hawthorn South',
#  re.compile(r'\bHawthorn\b', re.IGNORECASE|re.UNICODE): 'Hawthorn',
#  re.compile(r'\bHampton Park\b', re.IGNORECASE|re.UNICODE): 'Hampton Park',
#  re.compile(r'\bGriffith\b', re.IGNORECASE|re.UNICODE): 'Griffith',
#  re.compile(r'\bGreenvale\b', re.IGNORECASE|re.UNICODE): 'Greenvale',
#  re.compile(r'\bGreensborough\b', re.IGNORECASE|re.UNICODE): 'Greensborough',
#  re.compile(r'\bGranville\b', re.IGNORECASE|re.UNICODE): 'Granville',
#  re.compile(r'\bGoulburn\b', re.IGNORECASE|re.UNICODE): 'Goulburn',
#  re.compile(r'\bGold Coast\b', re.IGNORECASE|re.UNICODE): 'Gold Coast',
#  re.compile(r'\bGlen Waverley\b', re.IGNORECASE|re.UNICODE): 'Glen Waverley',
#  re.compile(r'\bGlenroy\b', re.IGNORECASE|re.UNICODE): 'Glenroy',
#  re.compile(r'\bGlen Iris\b', re.IGNORECASE|re.UNICODE): 'Glen Iris',
#  re.compile(r'\bGlenferrie\b', re.IGNORECASE|re.UNICODE): 'Glenferrie',
#  re.compile(r'\bGladstone\b', re.IGNORECASE|re.UNICODE): 'Gladstone',
#  re.compile(r'\bGeelong\b', re.IGNORECASE|re.UNICODE): 'Geelong',
#  re.compile(r'\bFrankston East\b', re.IGNORECASE|re.UNICODE): 'Frankston East',
#  re.compile(r'\bFrankston\b', re.IGNORECASE|re.UNICODE): 'Frankston',
#  re.compile(r'\bFootscray\b', re.IGNORECASE|re.UNICODE): 'Footscray',
#  re.compile(r'\bFairfield\b', re.IGNORECASE|re.UNICODE): 'Fairfield',
#  re.compile(r'\bEssendon\b', re.IGNORECASE|re.UNICODE): 'Essendon',
#  re.compile(r'\bEpping\b', re.IGNORECASE|re.UNICODE): 'Epping',
#  re.compile(r'\bEngadine\b', re.IGNORECASE|re.UNICODE): 'Engadine',
#  re.compile(r'\bEltham\b', re.IGNORECASE|re.UNICODE): 'Eltham',
#  re.compile(r'\bEight Mile Plains\b',
#  re.IGNORECASE|re.UNICODE): 'Eight Mile Plains',
#  re.compile(r'\bEastwood\b', re.IGNORECASE|re.UNICODE): 'Eastwood',
#  re.compile(r'\bEarlwood\b', re.IGNORECASE|re.UNICODE): 'Earlwood',
#  re.compile(r'\bDubbo\b', re.IGNORECASE|re.UNICODE): 'Dubbo',
#  re.compile(r'\bDoreen\b', re.IGNORECASE|re.UNICODE): 'Doreen',
#  re.compile(r'\bDoncaster East\b', re.IGNORECASE|re.UNICODE): 'Doncaster East',
#  re.compile(r'\bDoncaster\b', re.IGNORECASE|re.UNICODE): 'Doncaster',
#  re.compile(r'\bDeer Park\b', re.IGNORECASE|re.UNICODE): 'Deer Park',
#  re.compile(r'\bDeception Bay\b', re.IGNORECASE|re.UNICODE): 'Deception Bay',
#  re.compile(r'\bDandenong\b', re.IGNORECASE|re.UNICODE): 'Dandenong',
#  re.compile(r'\bCroydon\b', re.IGNORECASE|re.UNICODE): 'Croydon',
#  re.compile(r'\bCronulla\b', re.IGNORECASE|re.UNICODE): 'Cronulla',
#  re.compile(r'\bCranbourne\b', re.IGNORECASE|re.UNICODE): 'Cranbourne',
#  re.compile(r'\bCraigieburn\b', re.IGNORECASE|re.UNICODE): 'Craigieburn',
#  re.compile(r'\bCorio\b', re.IGNORECASE|re.UNICODE): 'Corio',
#  re.compile(r'\bCoorparoo\b', re.IGNORECASE|re.UNICODE): 'Coorparoo',
#  re.compile(r'\bCoogee\b', re.IGNORECASE|re.UNICODE): 'Coogee',
#  re.compile(r'\bCoffs Harbour\b', re.IGNORECASE|re.UNICODE): 'Coffs Harbour',
#  re.compile(r'\bCoburg\b', re.IGNORECASE|re.UNICODE): 'Coburg',
#  re.compile(r'\bClayton\b', re.IGNORECASE|re.UNICODE): 'Clayton',
#  re.compile(r'\bWollongong\b', re.IGNORECASE|re.UNICODE): 'Wollongong',
#  re.compile(r'\bChatswood\b', re.IGNORECASE|re.UNICODE): 'Chatswood',
#  re.compile(r'\bCessnock\b', re.IGNORECASE|re.UNICODE): 'Cessnock',
#  re.compile(r'\bCastle Hill\b', re.IGNORECASE|re.UNICODE): 'Castle Hill',
#  re.compile(r'\bCarrum Downs\b', re.IGNORECASE|re.UNICODE): 'Carrum Downs',
#  re.compile(r'\bCarnegie\b', re.IGNORECASE|re.UNICODE): 'Carnegie',
#  re.compile(r'\bCarlton\b', re.IGNORECASE|re.UNICODE): 'Carlton',
#  re.compile(r'\bCarlingford\b', re.IGNORECASE|re.UNICODE): 'Carlingford',
#  re.compile(r'\bCapalaba\b', re.IGNORECASE|re.UNICODE): 'Capalaba',
#  re.compile(r'\bCanberra\b', re.IGNORECASE|re.UNICODE): 'Canberra',
#  re.compile(r'\bCamberwell\b', re.IGNORECASE|re.UNICODE): 'Camberwell',
#  re.compile(r'\bCairns\b', re.IGNORECASE|re.UNICODE): 'Cairns',
#  re.compile(r'\bCaboolture\b', re.IGNORECASE|re.UNICODE): 'Caboolture',
#  re.compile(r'\bBurwood\b', re.IGNORECASE|re.UNICODE): 'Burwood',
#  re.compile(r'\bBurnie\b', re.IGNORECASE|re.UNICODE): 'Burnie',
#  re.compile(r'\bBundaberg\b', re.IGNORECASE|re.UNICODE): 'Bundaberg',
#  re.compile(r'\bBuderim\b', re.IGNORECASE|re.UNICODE): 'Buderim',
#  re.compile(r'\bBrunswick\b', re.IGNORECASE|re.UNICODE): 'Brunswick',
#  re.compile(r'\bBroken Hill\b', re.IGNORECASE|re.UNICODE): 'Broken Hill',
#  re.compile(r'\bBrisbane\b', re.IGNORECASE|re.UNICODE): 'Brisbane',
#  re.compile(r'\bBrighton\b', re.IGNORECASE|re.UNICODE): 'Brighton',
#  re.compile(r'\bBoronia\b', re.IGNORECASE|re.UNICODE): 'Boronia',
#  re.compile(r'\bBlacktown\b', re.IGNORECASE|re.UNICODE): 'Blacktown',
#  re.compile(r'\bBexley\b', re.IGNORECASE|re.UNICODE): 'Bexley',
#  re.compile(r'\bBerwick\b', re.IGNORECASE|re.UNICODE): 'Berwick',
#  re.compile(r'\bBentleigh East\b', re.IGNORECASE|re.UNICODE): 'Bentleigh East',
#  re.compile(r'\bBentleigh\b', re.IGNORECASE|re.UNICODE): 'Bentleigh',
#  re.compile(r'\bBendigo\b', re.IGNORECASE|re.UNICODE): 'Bendigo',
#  re.compile(r'\bBaulkham Hills\b', re.IGNORECASE|re.UNICODE): 'Baulkham Hills',
#  re.compile(r'\bBathurst\b', re.IGNORECASE|re.UNICODE): 'Bathurst',
#  re.compile(r'\bBanora Point\b', re.IGNORECASE|re.UNICODE): 'Banora Point',
#  re.compile(r'\bBankstown\b', re.IGNORECASE|re.UNICODE): 'Bankstown',
#  re.compile(r'\bBallarat\b', re.IGNORECASE|re.UNICODE): 'Ballarat',
#  re.compile(r'\bAuburn\b', re.IGNORECASE|re.UNICODE): 'Auburn',
#  re.compile(r'\bAshfield\b', re.IGNORECASE|re.UNICODE): 'Ashfield',
#  re.compile(r'\bArmidale\b', re.IGNORECASE|re.UNICODE): 'Armidale',
#  re.compile(r'\bAlbany Creek\b', re.IGNORECASE|re.UNICODE): 'Albany Creek',
#  re.compile(r'\bMaroochydore\b', re.IGNORECASE|re.UNICODE): 'Maroochydore',
#  re.compile(r'\bCheltenham\b', re.IGNORECASE|re.UNICODE): 'Cheltenham',
#  re.compile(r'\bRandwick\b', re.IGNORECASE|re.UNICODE): 'Randwick',
#  re.compile(r'\bDee Why\b', re.IGNORECASE|re.UNICODE): 'Dee Why',
#  re.compile(r'\bUmina Beach\b', re.IGNORECASE|re.UNICODE): 'Umina Beach',
#  re.compile(r'\bPalmerston\b', re.IGNORECASE|re.UNICODE): 'Palmerston',
#  re.compile(r'\bHervey Bay\b', re.IGNORECASE|re.UNICODE): 'Hervey Bay',
#  re.compile(r'\bSydney Central Business District\b',
#  re.IGNORECASE|re.UNICODE): 'Sydney Central Business District',
#  re.compile(r'\bKingsford\b', re.IGNORECASE|re.UNICODE): 'Kingsford',
#  re.compile(r'\bSpringfield Lakes\b',
#  re.IGNORECASE|re.UNICODE): 'Springfield Lakes',
#  re.compile(r'\bBracken Ridge\b', re.IGNORECASE|re.UNICODE): 'Bracken Ridge',
#  re.compile(r'\bKallangur\b', re.IGNORECASE|re.UNICODE): 'Kallangur',
#  re.compile(r'\bNorth Lakes\b', re.IGNORECASE|re.UNICODE): 'North Lakes',
#  re.compile(r'\bThe Gap\b', re.IGNORECASE|re.UNICODE): 'The Gap',
#  re.compile(r'\bCaroline Springs\b',
#  re.IGNORECASE|re.UNICODE): 'Caroline Springs',
#  re.compile(r'\bHoppers Crossing\b',
#  re.IGNORECASE|re.UNICODE): 'Hoppers Crossing',
#  re.compile(r'\bLogan City\b', re.IGNORECASE|re.UNICODE): 'Logan City',
#  re.compile(r'\bCarindale\b', re.IGNORECASE|re.UNICODE): 'Carindale',
#  re.compile(r'\bParramatta\b', re.IGNORECASE|re.UNICODE): 'Parramatta',
#  re.compile(r'\bFerntree Gully\b', re.IGNORECASE|re.UNICODE): 'Ferntree Gully',
#  re.compile(r'\bAdelaide Hills\b', re.IGNORECASE|re.UNICODE): 'Adelaide Hills',
#  re.compile(r'\bCanning Vale\b', re.IGNORECASE|re.UNICODE): 'Canning Vale',
#  re.compile(r'\bGlenmore Park\b', re.IGNORECASE|re.UNICODE): 'Glenmore Park',
#  re.compile(r'\bSouthbank\b', re.IGNORECASE|re.UNICODE): 'Southbank',
#  re.compile(r'\bHelensvale\b', re.IGNORECASE|re.UNICODE): 'Helensvale',
#  re.compile(r'\bMelton West\b', re.IGNORECASE|re.UNICODE): 'Melton West',
#  re.compile(r'\bElwood\b', re.IGNORECASE|re.UNICODE): 'Elwood',
#  re.compile(r'\bBalwyn North\b', re.IGNORECASE|re.UNICODE): 'Balwyn North',
#  re.compile(r'\bMalvern East\b', re.IGNORECASE|re.UNICODE): 'Malvern East',
#  re.compile(r'\bBrighton East\b', re.IGNORECASE|re.UNICODE): 'Brighton East',
#  re.compile(r'\bRedbank Plains\b', re.IGNORECASE|re.UNICODE): 'Redbank Plains',
#  re.compile(r'\bLabrador\b', re.IGNORECASE|re.UNICODE): 'Labrador',
#  re.compile(r'\bSt Albans\b', re.IGNORECASE|re.UNICODE): 'St Albans',
#  re.compile(r'\bEndeavour Hills\b',
#  re.IGNORECASE|re.UNICODE): 'Endeavour Hills',
#  re.compile(r'\bKellyville\b', re.IGNORECASE|re.UNICODE): 'Kellyville',
#  re.compile(r'\bTaylors Lakes\b', re.IGNORECASE|re.UNICODE): 'Taylors Lakes',
#  re.compile(r'\bCherrybrook\b', re.IGNORECASE|re.UNICODE): 'Cherrybrook',
#  re.compile(r'\bRoxburgh Park\b', re.IGNORECASE|re.UNICODE): 'Roxburgh Park',
#  re.compile(r'\bPrestons\b', re.IGNORECASE|re.UNICODE): 'Prestons',
#  re.compile(r'\bWyndham Vale\b', re.IGNORECASE|re.UNICODE): 'Wyndham Vale',
#  re.compile(r'\bBallajura\b', re.IGNORECASE|re.UNICODE): 'Ballajura',
#  re.compile(r'\bWilletton\b', re.IGNORECASE|re.UNICODE): 'Willetton',
#  re.compile(r'\bGlenwood\b', re.IGNORECASE|re.UNICODE): 'Glenwood',
#  re.compile(r'\bCabramatta\b', re.IGNORECASE|re.UNICODE): 'Cabramatta',
#  re.compile(r'\bCampsie\b', re.IGNORECASE|re.UNICODE): 'Campsie',
#  re.compile(r'\bCasula\b', re.IGNORECASE|re.UNICODE): 'Casula',
#  re.compile(r'\bCranebrook\b', re.IGNORECASE|re.UNICODE): 'Cranebrook',
#  re.compile(r'\bGreenacre\b', re.IGNORECASE|re.UNICODE): 'Greenacre',
#  re.compile(r'\bGreystanes\b', re.IGNORECASE|re.UNICODE): 'Greystanes',
#  re.compile(r'\bEllenbrook\b', re.IGNORECASE|re.UNICODE): 'Ellenbrook',
#  re.compile(r'\bAlexandra Hills\b',
# ...
#  re.compile(r'\b(Rājshāhi|Rajshahi)\b', re.IGNORECASE|re.UNICODE): 'Rājshāhi',
#  re.compile(r'\bPirojpur\b', re.IGNORECASE|re.UNICODE): 'Pirojpur',
#  re.compile(r'\bPanchagarh\b', re.IGNORECASE|re.UNICODE): 'Panchagarh',
#  re.compile(r'\bPatiya\b', re.IGNORECASE|re.UNICODE): 'Patiya',
#  re.compile(r'\bParbatipur\b', re.IGNORECASE|re.UNICODE): 'Parbatipur',
#  re.compile(r'\b(Nārāyanganj|Narayanganj)\b',
#  re.IGNORECASE|re.UNICODE): 'Nārāyanganj',
#  re.compile(r'\b(Nālchiti|Nalchiti)\b', re.IGNORECASE|re.UNICODE): 'Nālchiti',
#  re.compile(r'\b(Nāgarpur|Nagarpur)\b', re.IGNORECASE|re.UNICODE): 'Nāgarpur',
#  re.compile(r'\bNageswari\b', re.IGNORECASE|re.UNICODE): 'Nageswari',
#  re.compile(r'\bMymensingh\b', re.IGNORECASE|re.UNICODE): 'Mymensingh',
#  re.compile(r'\b(Muktāgācha|Muktagacha)\b',
#  re.IGNORECASE|re.UNICODE): 'Muktāgācha',
#  re.compile(r'\b(Mirzāpur|Mirzapur)\b', re.IGNORECASE|re.UNICODE): 'Mirzāpur',
#  re.compile(r'\b(Maulavi Bāzār|Maulavi Bazar)\b',
#  re.IGNORECASE|re.UNICODE): 'Maulavi Bāzār',
#  re.compile(r'\bMorrelgonj\b', re.IGNORECASE|re.UNICODE): 'Morrelgonj',
#  re.compile(r'\bMehendiganj\b', re.IGNORECASE|re.UNICODE): 'Mehendiganj',
#  re.compile(r'\bMathba\b', re.IGNORECASE|re.UNICODE): 'Mathba',
#  re.compile(r'\bLalmonirhat\b', re.IGNORECASE|re.UNICODE): 'Lalmonirhat',
#  re.compile(r'\b(Lākshām|Laksham)\b', re.IGNORECASE|re.UNICODE): 'Lākshām',
#  re.compile(r'\bComilla\b', re.IGNORECASE|re.UNICODE): 'Comilla',
#  re.compile(r'\bRangpur\b', re.IGNORECASE|re.UNICODE): 'Rangpur',
#  re.compile(r'\bKushtia\b', re.IGNORECASE|re.UNICODE): 'Kushtia',
#  re.compile(r'\b(Kālīganj|Kaliganj)\b', re.IGNORECASE|re.UNICODE): 'Kālīganj',
#  re.compile(r'\b(Jhingergācha|Jhingergacha)\b',
#  re.IGNORECASE|re.UNICODE): 'Jhingergācha',
#  re.compile(r'\b(Joypur Hāt|Joypur Hat)\b',
#  re.IGNORECASE|re.UNICODE): 'Joypur Hāt',
#  re.compile(r'\bIshurdi\b', re.IGNORECASE|re.UNICODE): 'Ishurdi',
#  re.compile(r'\bHabiganj\b', re.IGNORECASE|re.UNICODE): 'Habiganj',
#  re.compile(r'\bGaurnadi\b', re.IGNORECASE|re.UNICODE): 'Gaurnadi',
#  re.compile(r'\bGafargaon\b', re.IGNORECASE|re.UNICODE): 'Gafargaon',
#  re.compile(r'\bFeni\b', re.IGNORECASE|re.UNICODE): 'Feni',
#  re.compile(r'\b(Rāipur|Raipur)\b', re.IGNORECASE|re.UNICODE): 'Rāipur',
#  re.compile(r'\bSarankhola\b', re.IGNORECASE|re.UNICODE): 'Sarankhola',
#  re.compile(r'\bDhaka\b', re.IGNORECASE|re.UNICODE): 'Dhaka',
#  re.compile(r'\b(Chilmāri|Chilmari)\b', re.IGNORECASE|re.UNICODE): 'Chilmāri',
#  re.compile(r'\b(Chhāgalnāiya|Chhagalnaiya)\b',
#  re.IGNORECASE|re.UNICODE): 'Chhāgalnāiya',
#  re.compile(r'\b(Lālmohan|Lalmohan)\b', re.IGNORECASE|re.UNICODE): 'Lālmohan',
#  re.compile(r'\bKhagrachhari\b', re.IGNORECASE|re.UNICODE): 'Khagrachhari',
#  re.compile(r'\b(Chhātak|Chhatak)\b', re.IGNORECASE|re.UNICODE): 'Chhātak',
#  re.compile(r'\b(Bhātpāra Abhaynagar|Bhatpara Abhaynagar)\b',
#  re.IGNORECASE|re.UNICODE): 'Bhātpāra Abhaynagar',
#  re.compile(r'\b(Bherāmāra|Bheramara)\b',
#  re.IGNORECASE|re.UNICODE): 'Bherāmāra',
#  re.compile(r'\b(Bhairab Bāzār|Bhairab Bazar)\b',
#  re.IGNORECASE|re.UNICODE): 'Bhairab Bāzār',
#  re.compile(r'\b(Bāndarban|Bandarban)\b',
#  re.IGNORECASE|re.UNICODE): 'Bāndarban',
#  re.compile(r'\b(Kālia|Kalia)\b', re.IGNORECASE|re.UNICODE): 'Kālia',
#  re.compile(r'\bBaniachang\b', re.IGNORECASE|re.UNICODE): 'Baniachang',
#  re.compile(r'\b(Bājitpur|Bajitpur)\b', re.IGNORECASE|re.UNICODE): 'Bājitpur',
#  re.compile(r'\bBagerhat\b', re.IGNORECASE|re.UNICODE): 'Bagerhat',
#  re.compile(r'\bBadarganj\b', re.IGNORECASE|re.UNICODE): 'Badarganj',
#  re.compile(r'\bNarail\b', re.IGNORECASE|re.UNICODE): 'Narail',
#  re.compile(r'\b(Tungipāra|Tungipara)\b',
#  re.IGNORECASE|re.UNICODE): 'Tungipāra',
#  re.compile(r'\b(Sonārgaon|Sonargaon)\b',
#  re.IGNORECASE|re.UNICODE): 'Sonārgaon',
#  re.compile(r'\b(Sarishābāri|Sarishabari)\b',
#  re.IGNORECASE|re.UNICODE): 'Sarishābāri',
#  re.compile(r'\bSakhipur\b', re.IGNORECASE|re.UNICODE): 'Sakhipur',
#  re.compile(r'\b(Raojān|Raojan)\b', re.IGNORECASE|re.UNICODE): 'Raojān',
#  re.compile(r'\bPhultala\b', re.IGNORECASE|re.UNICODE): 'Phultala',
#  re.compile(r'\b(Pālang|Palang)\b', re.IGNORECASE|re.UNICODE): 'Pālang',
#  re.compile(r'\b(Pār Naogaon|Par Naogaon)\b',
#  re.IGNORECASE|re.UNICODE): 'Pār Naogaon',
#  re.compile(r'\b(Nabīnagar|Nabinagar)\b',
#  re.IGNORECASE|re.UNICODE): 'Nabīnagar',
#  re.compile(r'\b(Lakshmīpur|Lakshmipur)\b',
#  re.IGNORECASE|re.UNICODE): 'Lakshmīpur',
#  re.compile(r'\bKesabpur\b', re.IGNORECASE|re.UNICODE): 'Kesabpur',
#  re.compile(r'\b(Hājīganj|Hajiganj)\b', re.IGNORECASE|re.UNICODE): 'Hājīganj',
#  re.compile(r'\b(Farīdpur|Faridpur)\b', re.IGNORECASE|re.UNICODE): 'Farīdpur',
#  re.compile(r'\b(Dinājpur|Dinajpur)\b', re.IGNORECASE|re.UNICODE): 'Dinājpur',
#  re.compile(r'\bUttar Char Fasson\b',
#  re.IGNORECASE|re.UNICODE): 'Uttar Char Fasson',
#  re.compile(r'\bChittagong\b', re.IGNORECASE|re.UNICODE): 'Chittagong',
#  re.compile(r'\b(Char Bhadrāsan|Char Bhadrasan)\b',
#  re.IGNORECASE|re.UNICODE): 'Char Bhadrāsan',
#  re.compile(r'\bBera\b', re.IGNORECASE|re.UNICODE): 'Bera',
#  re.compile(r'\b(Burhānuddin|Burhanuddin)\b',
#  re.IGNORECASE|re.UNICODE): 'Burhānuddin',
#  re.compile(r'\b(Sātkania|Satkania)\b', re.IGNORECASE|re.UNICODE): 'Sātkania',
#  re.compile(r"\b(Cox’s Bāzār|Cox's Bazar)\b",
#  re.IGNORECASE|re.UNICODE): 'Cox’s Bāzār',
#  re.compile(r'\bKhulna\b', re.IGNORECASE|re.UNICODE): 'Khulna',
#  re.compile(r'\bBhola\b', re.IGNORECASE|re.UNICODE): 'Bhola',
#  re.compile(r'\b(Barisāl|Barisal)\b', re.IGNORECASE|re.UNICODE): 'Barisāl',
#  re.compile(r'\bJessore\b', re.IGNORECASE|re.UNICODE): 'Jessore',
#  re.compile(r'\b(Pābna|Pabna)\b', re.IGNORECASE|re.UNICODE): 'Pābna',
#  re.compile(r'\b(Tāngāil|Tangail)\b', re.IGNORECASE|re.UNICODE): 'Tāngāil',
#  re.compile(r'\bBogra\b', re.IGNORECASE|re.UNICODE): 'Bogra',
#  re.compile(r'\b(Pīrgaaj|Pirgaaj)\b', re.IGNORECASE|re.UNICODE): 'Pīrgaaj',
#  re.compile(r'\b(Nawābganj|Nawabganj)\b',
#  re.IGNORECASE|re.UNICODE): 'Nawābganj',
#  re.compile(r'\b(Mādārīpur|Madaripur)\b',
#  re.IGNORECASE|re.UNICODE): 'Mādārīpur',
#  re.compile(r'\bSherpur\b', re.IGNORECASE|re.UNICODE): 'Sherpur',
#  re.compile(r'\bKishorganj\b', re.IGNORECASE|re.UNICODE): 'Kishorganj',
#  re.compile(r'\bManikchari\b', re.IGNORECASE|re.UNICODE): 'Manikchari',
#  re.compile(r'\b(Bhāndāria|Bhandaria)\b',
#  re.IGNORECASE|re.UNICODE): 'Bhāndāria',
#  re.compile(r'\bBibir Hat\b', re.IGNORECASE|re.UNICODE): 'Bibir Hat',
#  re.compile(r'\bSaidpur\b', re.IGNORECASE|re.UNICODE): 'Saidpur',
#  re.compile(r'\bPuthia\b', re.IGNORECASE|re.UNICODE): 'Puthia',
#  re.compile(r'\bNatore\b', re.IGNORECASE|re.UNICODE): 'Natore',
#  re.compile(r'\bAzimpur\b', re.IGNORECASE|re.UNICODE): 'Azimpur',
#  re.compile(r'\bPaltan\b', re.IGNORECASE|re.UNICODE): 'Paltan',
#  re.compile(r'\bJoymontop\b', re.IGNORECASE|re.UNICODE): 'Joymontop',
#  re.compile(r'\bZwijndrecht\b', re.IGNORECASE|re.UNICODE): 'Zwijndrecht',
#  re.compile(r'\bZwevegem\b', re.IGNORECASE|re.UNICODE): 'Zwevegem',
#  re.compile(r'\bZottegem\b', re.IGNORECASE|re.UNICODE): 'Zottegem',
#  re.compile(r'\bZonhoven\b', re.IGNORECASE|re.UNICODE): 'Zonhoven',
#  re.compile(r'\bZoersel\b', re.IGNORECASE|re.UNICODE): 'Zoersel',
#  re.compile(r'\bZemst\b', re.IGNORECASE|re.UNICODE): 'Zemst',
#  re.compile(r'\bZele\b', re.IGNORECASE|re.UNICODE): 'Zele',
#  re.compile(r'\bZedelgem\b', re.IGNORECASE|re.UNICODE): 'Zedelgem',
#  re.compile(r'\bZaventem\b', re.IGNORECASE|re.UNICODE): 'Zaventem',
#  re.compile(r'\bWuustwezel\b', re.IGNORECASE|re.UNICODE): 'Wuustwezel',
#  re.compile(r'\bWillebroek\b', re.IGNORECASE|re.UNICODE): 'Willebroek',
#  re.compile(r'\bWevelgem\b', re.IGNORECASE|re.UNICODE): 'Wevelgem',
#  re.compile(r'\bWetteren\b', re.IGNORECASE|re.UNICODE): 'Wetteren',
#  re.compile(r'\bWesterlo\b', re.IGNORECASE|re.UNICODE): 'Westerlo',
#  re.compile(r'\bWervik\b', re.IGNORECASE|re.UNICODE): 'Wervik',
#  re.compile(r'\bWavre\b', re.IGNORECASE|re.UNICODE): 'Wavre',
#  re.compile(r'\bWaterloo\b', re.IGNORECASE|re.UNICODE): 'Waterloo',
#  re.compile(r'\bWaregem\b', re.IGNORECASE|re.UNICODE): 'Waregem',
#  re.compile(r'\bWalcourt\b', re.IGNORECASE|re.UNICODE): 'Walcourt',
#  re.compile(r'\b(Visé|Vise)\b', re.IGNORECASE|re.UNICODE): 'Visé',
#  re.compile(r'\bVilvoorde\b', re.IGNORECASE|re.UNICODE): 'Vilvoorde',
#  re.compile(r'\bVerviers\b', re.IGNORECASE|re.UNICODE): 'Verviers',
#  re.compile(r'\bTurnhout\b', re.IGNORECASE|re.UNICODE): 'Turnhout',
#  re.compile(r'\bTubize\b', re.IGNORECASE|re.UNICODE): 'Tubize',
#  re.compile(r'\bTournai\b', re.IGNORECASE|re.UNICODE): 'Tournai',
#  re.compile(r'\bTorhout\b', re.IGNORECASE|re.UNICODE): 'Torhout',
#  re.compile(r'\bTongeren\b', re.IGNORECASE|re.UNICODE): 'Tongeren',
#  re.compile(r'\bTienen\b', re.IGNORECASE|re.UNICODE): 'Tienen',
#  re.compile(r'\bTielt\b', re.IGNORECASE|re.UNICODE): 'Tielt',
#  re.compile(r'\bTessenderlo\b', re.IGNORECASE|re.UNICODE): 'Tessenderlo',
#  re.compile(r'\bTervuren\b', re.IGNORECASE|re.UNICODE): 'Tervuren',
#  re.compile(r'\bTemse\b', re.IGNORECASE|re.UNICODE): 'Temse',
#  re.compile(r'\bStekene\b', re.IGNORECASE|re.UNICODE): 'Stekene',
#  re.compile(r'\bStabroek\b', re.IGNORECASE|re.UNICODE): 'Stabroek',
#  re.compile(r'\bSoumagne\b', re.IGNORECASE|re.UNICODE): 'Soumagne',
#  re.compile(r'\bSoignies\b', re.IGNORECASE|re.UNICODE): 'Soignies',
#  re.compile(r'\bSint-Truiden\b', re.IGNORECASE|re.UNICODE): 'Sint-Truiden',
#  re.compile(r'\bSint-Pieters-Leeuw\b',
#  re.IGNORECASE|re.UNICODE): 'Sint-Pieters-Leeuw',
#  re.compile(r'\bSint-Niklaas\b', re.IGNORECASE|re.UNICODE): 'Sint-Niklaas',
#  re.compile(r'\bSint-Kruis\b', re.IGNORECASE|re.UNICODE): 'Sint-Kruis',
#  re.compile(r'\bSint-Katelijne-Waver\b',
#  re.IGNORECASE|re.UNICODE): 'Sint-Katelijne-Waver',
#  re.compile(r'\bSint-Gillis-Waas\b',
#  re.IGNORECASE|re.UNICODE): 'Sint-Gillis-Waas',
#  re.compile(r'\bSint-Genesius-Rode\b',
#  re.IGNORECASE|re.UNICODE): 'Sint-Genesius-Rode',
#  re.compile(r'\bSeraing\b', re.IGNORECASE|re.UNICODE): 'Seraing',
#  re.compile(r'\bSchoten\b', re.IGNORECASE|re.UNICODE): 'Schoten',
#  re.compile(r'\bSchilde\b', re.IGNORECASE|re.UNICODE): 'Schilde',
#  re.compile(r'\bSaint-Nicolas\b', re.IGNORECASE|re.UNICODE): 'Saint-Nicolas',
#  re.compile(r'\bSaint-Ghislain\b', re.IGNORECASE|re.UNICODE): 'Saint-Ghislain',
#  re.compile(r'\bRotselaar\b', re.IGNORECASE|re.UNICODE): 'Rotselaar',
#  re.compile(r'\bRonse\b', re.IGNORECASE|re.UNICODE): 'Ronse',
#  re.compile(r'\bRoeselare\b', re.IGNORECASE|re.UNICODE): 'Roeselare',
#  re.compile(r'\bRixensart\b', re.IGNORECASE|re.UNICODE): 'Rixensart',
#  re.compile(r'\bRiemst\b', re.IGNORECASE|re.UNICODE): 'Riemst',
#  re.compile(r'\bRanst\b', re.IGNORECASE|re.UNICODE): 'Ranst',
#  re.compile(r'\bQuaregnon\b', re.IGNORECASE|re.UNICODE): 'Quaregnon',
#  re.compile(r'\bPuurs\b', re.IGNORECASE|re.UNICODE): 'Puurs',
#  re.compile(r'\bPutte\b', re.IGNORECASE|re.UNICODE): 'Putte',
#  re.compile(r'\bPoperinge\b', re.IGNORECASE|re.UNICODE): 'Poperinge',
#  re.compile(r'\b(Pont-à-Celles|Pont-a-Celles)\b',
#  re.IGNORECASE|re.UNICODE): 'Pont-à-Celles',
#  re.compile(r'\b(Péruwelz|Peruwelz)\b', re.IGNORECASE|re.UNICODE): 'Péruwelz',
#  re.compile(r'\bPeer\b', re.IGNORECASE|re.UNICODE): 'Peer',
#  re.compile(r'\bOverijse\b', re.IGNORECASE|re.UNICODE): 'Overijse',
#  re.compile(r'\bOupeye\b', re.IGNORECASE|re.UNICODE): 'Oupeye',
#  re.compile(r'\bOudenaarde\b', re.IGNORECASE|re.UNICODE): 'Oudenaarde',
#  re.compile(r'\bOostkamp\b', re.IGNORECASE|re.UNICODE): 'Oostkamp',
#  re.compile(r'\bOstend\b', re.IGNORECASE|re.UNICODE): 'Ostend',
#  re.compile(r'\bNivelles\b', re.IGNORECASE|re.UNICODE): 'Nivelles',
#  re.compile(r'\bNinove\b', re.IGNORECASE|re.UNICODE): 'Ninove',
#  re.compile(r'\bNijlen\b', re.IGNORECASE|re.UNICODE): 'Nijlen',
#  re.compile(r'\bNeerpelt\b', re.IGNORECASE|re.UNICODE): 'Neerpelt',
#  re.compile(r'\bNamur\b', re.IGNORECASE|re.UNICODE): 'Namur',
#  re.compile(r'\bMouscron\b', re.IGNORECASE|re.UNICODE): 'Mouscron',
#  re.compile(r'\bMortsel\b', re.IGNORECASE|re.UNICODE): 'Mortsel',
#  re.compile(r'\bMorlanwelz-Mariemont\b',
#  re.IGNORECASE|re.UNICODE): 'Morlanwelz-Mariemont',
#  re.compile(r'\bMons\b', re.IGNORECASE|re.UNICODE): 'Mons',
#  re.compile(r'\bMol\b', re.IGNORECASE|re.UNICODE): 'Mol',
#  re.compile(r'\bMiddelkerke\b', re.IGNORECASE|re.UNICODE): 'Middelkerke',
#  re.compile(r'\bMerelbeke\b', re.IGNORECASE|re.UNICODE): 'Merelbeke',
#  re.compile(r'\bMenen\b', re.IGNORECASE|re.UNICODE): 'Menen',
#  re.compile(r'\bMeise\b', re.IGNORECASE|re.UNICODE): 'Meise',
#  re.compile(r'\bMechelen\b', re.IGNORECASE|re.UNICODE): 'Mechelen',
#  re.compile(r'\bMarche-en-Famenne\b',
#  re.IGNORECASE|re.UNICODE): 'Marche-en-Famenne',
#  re.compile(r'\bManage\b', re.IGNORECASE|re.UNICODE): 'Manage',
#  re.compile(r'\bMaldegem\b', re.IGNORECASE|re.UNICODE): 'Maldegem',
#  re.compile(r'\bMaasmechelen\b', re.IGNORECASE|re.UNICODE): 'Maasmechelen',
#  re.compile(r'\bMaaseik\b', re.IGNORECASE|re.UNICODE): 'Maaseik',
#  re.compile(r'\bLouvain-la-Neuve\b',
#  re.IGNORECASE|re.UNICODE): 'Louvain-la-Neuve',
#  re.compile(r'\bLonderzeel\b', re.IGNORECASE|re.UNICODE): 'Londerzeel',
#  re.compile(r'\bLommel\b', re.IGNORECASE|re.UNICODE): 'Lommel',
#  re.compile(r'\bLokeren\b', re.IGNORECASE|re.UNICODE): 'Lokeren',
#  re.compile(r'\bLochristi\b', re.IGNORECASE|re.UNICODE): 'Lochristi',
#  re.compile(r'\bLille\b', re.IGNORECASE|re.UNICODE): 'Lille',
#  re.compile(r'\bLier\b', re.IGNORECASE|re.UNICODE): 'Lier',
#  re.compile(r'\b(Liège|Liege)\b', re.IGNORECASE|re.UNICODE): 'Liège',
#  re.compile(r'\bLeuven\b', re.IGNORECASE|re.UNICODE): 'Leuven',
#  re.compile(r'\bLessines\b', re.IGNORECASE|re.UNICODE): 'Lessines',
#  re.compile(r'\bLede\b', re.IGNORECASE|re.UNICODE): 'Lede',
#  re.compile(r'\bLebbeke\b', re.IGNORECASE|re.UNICODE): 'Lebbeke',
#  re.compile(r'\bLanaken\b', re.IGNORECASE|re.UNICODE): 'Lanaken',
#  re.compile(r'\b(La Louvière|La Louviere)\b',
#  re.IGNORECASE|re.UNICODE): 'La Louvière',
#  re.compile(r'\bKortrijk\b', re.IGNORECASE|re.UNICODE): 'Kortrijk',
#  re.compile(r'\bKortenberg\b', re.IGNORECASE|re.UNICODE): 'Kortenberg',
#  re.compile(r'\bKontich\b', re.IGNORECASE|re.UNICODE): 'Kontich',
#  re.compile(r'\bKoksijde\b', re.IGNORECASE|re.UNICODE): 'Koksijde',
#  re.compile(r'\bKnokke-Heist\b', re.IGNORECASE|re.UNICODE): 'Knokke-Heist',
#  re.compile(r'\bKasterlee\b', re.IGNORECASE|re.UNICODE): 'Kasterlee',
#  re.compile(r'\bKapellen\b', re.IGNORECASE|re.UNICODE): 'Kapellen',
#  re.compile(r'\bKalmthout\b', re.IGNORECASE|re.UNICODE): 'Kalmthout',
#  re.compile(r'\bIzegem\b', re.IGNORECASE|re.UNICODE): 'Izegem',
#  re.compile(r'\bIeper\b', re.IGNORECASE|re.UNICODE): 'Ieper',
#  re.compile(r'\bHuy\b', re.IGNORECASE|re.UNICODE): 'Huy',
#  re.compile(r'\bHouthalen\b', re.IGNORECASE|re.UNICODE): 'Houthalen',
#  re.compile(r'\bHoogstraten\b', re.IGNORECASE|re.UNICODE): 'Hoogstraten',
#  re.compile(r'\bHoboken\b', re.IGNORECASE|re.UNICODE): 'Hoboken',
#  re.compile(r'\bHeusden\b', re.IGNORECASE|re.UNICODE): 'Heusden',
#  re.compile(r'\bHerzele\b', re.IGNORECASE|re.UNICODE): 'Herzele',
#  re.compile(r'\bHerve\b', re.IGNORECASE|re.UNICODE): 'Herve',
#  re.compile(r'\bHerstal\b', re.IGNORECASE|re.UNICODE): 'Herstal',
#  re.compile(r'\bHerentals\b', re.IGNORECASE|re.UNICODE): 'Herentals',
#  re.compile(r'\bHerent\b', re.IGNORECASE|re.UNICODE): 'Herent',
#  re.compile(r'\bHelchteren\b', re.IGNORECASE|re.UNICODE): 'Helchteren',
#  re.compile(r'\bHeist-op-den-Berg\b',
#  re.IGNORECASE|re.UNICODE): 'Heist-op-den-Berg',
#  re.compile(r'\bHasselt\b', re.IGNORECASE|re.UNICODE): 'Hasselt',
#  re.compile(r'\bHarelbeke\b', re.IGNORECASE|re.UNICODE): 'Harelbeke',
#  re.compile(r'\bHamme\b', re.IGNORECASE|re.UNICODE): 'Hamme',
#  re.compile(r'\bHalle\b', re.IGNORECASE|re.UNICODE): 'Halle',
#  re.compile(r'\bHaaltert\b', re.IGNORECASE|re.UNICODE): 'Haaltert',
#  re.compile(r'\bGrimbergen\b', re.IGNORECASE|re.UNICODE): 'Grimbergen',
#  re.compile(r'\bGeraardsbergen\b', re.IGNORECASE|re.UNICODE): 'Geraardsbergen',
#  re.compile(r'\bGent\b', re.IGNORECASE|re.UNICODE): 'Gent',
#  re.compile(r'\bGenk\b', re.IGNORECASE|re.UNICODE): 'Genk',
#  re.compile(r'\bGembloux\b', re.IGNORECASE|re.UNICODE): 'Gembloux',
#  re.compile(r'\bGeel\b', re.IGNORECASE|re.UNICODE): 'Geel',
#  re.compile(r'\bFrameries\b', re.IGNORECASE|re.UNICODE): 'Frameries',
#  ...}

# %% [markdown]
# ## Workflow #3, 4 ##
#
# Put the extracted data into a pandas DataFrame with three columns: headline, city, country.

# %% [markdown]
# Watch out for multiple cities in a headline and matches on short words! We want the match to be on the entire city—for example San Marino—and not a partial match—San.

# %% [markdown]
# Make sure there were no issues with the extraction by sampling some of the headlines and examining the city and country names. One method for finding problems is to look for the most common names and see if there are any issues.

# %%
def get_name_in_text(text, dictionary):
    for regex, name in sorted(dictionary.items(), key=lambda x: x[1]):
        if regex.search(text):
            return name
    return None

# %%
import pandas as pd

matched_countries = [get_name_in_text(headline, country_to_name) for headline in headlines] 
matched_cities = [get_name_in_text(headline, city_to_name) for headline in headlines]  # single city per headline

headline_city_country_data = {'Headline': headlines, 'City': matched_cities, 'Country': matched_countries}
df_headline_city_country = pd.DataFrame(headline_city_country_data)
df_headline_city_country
# Out:
#                                               Headline         City Country
# 0                          18 new Zika Cases in Bogota       Bogotá    None
# 1                        19 new Zika Cases in Sengkang     Sengkang    None
# 2             Alameda Residents Recieve Rabies vaccine      Alameda    None
# 3    Albany Residents Recieve Respiratory Syncytial...       Albany    None
# 4                Antipolo under threat from Zika Virus     Antipolo    None
# ..                                                 ...          ...     ...
# 645                Zika virus confirmed in Westchester  Westchester    None
# 646                   Zika virus reported in Cleveland    Cleveland    None
# 647                       Zika worries in San Salvador     Salvador    None
# 648     Zika-carrying mosquitoes discovered in Ardmore      Ardmore    None
# 649                  Zika: Delhi for strict monitoring        Delhi    None
#
# [650 rows x 3 columns]

# %%
summary = df_headline_city_country[['City', 'Country']].describe()
print(summary)
# Out:
#        City Country
# count   619      15
# unique  510      10
# top      Of  Brazil
# freq     45       3

# %% [markdown]
# "Of" is the most common city name, but it is incorrect.

# %%
of_cities = df_headline_city_country[df_headline_city_country.City == 'Of'][['City', 'Headline']]
print(of_cities.to_string(index=False))
# Out:
# City                                           Headline
#   Of  Authorities are Worried about the Spread of Br...
#   Of  Authorities are Worried about the Spread of Ch...
#   Of  Authorities are Worried about the Spread of Go...
#   Of  Authorities are Worried about the Spread of He...
#   Of  Authorities are Worried about the Spread of In...
#   Of  Authorities are Worried about the Spread of Ma...
#   Of  Authorities are Worried about the Spread of Ro...
#   Of  Authorities are Worried about the Spread of Sy...
#   Of             Case of Measles Reported in Springdale
#   Of              Case of Measles Reported in Vancouver
#   Of            Case of Norovirus Reported in Stratford
#   Of              Case of Swine Flu Reported in Tbilisi
#   Of      Case of West Nile Virus Reported in Riverside
#   Of                       Outbreak of Zika in Alvorada
#   Of                         Outbreak of Zika in Destin
#   Of                       Outbreak of Zika in Hutchins
#   Of                   Outbreak of Zika in Palm Springs
#   Of                    Outbreak of Zika in Panama City
#   Of                     Outbreak of Zika in Pasig City
#   Of                     Outbreak of Zika in Portoviejo
#   Of                    Outbreak of Zika in Santa Elena
#   Of                   Outbreak of Zika in Stephenville
#   Of  Pedro Juan Caballero Encounters Severe Symptom...
#   Of       Pilsen Encounters Severe Symptoms of Malaria
#   Of     Princeton Encounters Severe Symptoms of Dengue
#   Of    Providence Encounters Severe Symptoms of Dengue
#   Of  Rochester authorities confirmed the spread of ...
#   Of  Scranton authorities confirmed the spread of G...
#   Of                 Spike of Dengue Cases in Stockholm
#   Of        Spike of Hepatitis E Cases in Morehead City
#   Of           Spike of Meningitis Cases in Druid Hills
#   Of            Spike of Pneumonia Cases in Springfield
#   Of              Spike of Pneumonia Cases in The Bronx
#   Of           Spike of Rhinovirus Cases in Sevierville
#   Of                  Spike of Rotavirus Cases in Omaha
#   Of  Suva authorities confirmed the spread of Rotav...
#   Of  The Spread of Chikungunya in Davidson has been...
#   Of  The Spread of Dengue in Yakima has been Confirmed
#   Of  The Spread of Gonorrhea in Reno has been Confi...
#   Of  The Spread of Malaria in Zanzibar has been Con...
#   Of  The Spread of Measles in Spokane has been Conf...
#   Of     Tokyo Encounters Severe Symptoms of Meningitis
#   Of  Toms River Encounters Severe Symptoms of Respi...
#   Of    Urbana Encounters Severe Symptoms of Meningitis
#   Of  Vineland authorities confirmed the spread of C...

# %%
def get_cities_in_headline(headline):
    cities_in_headline = set()
    for regex, name in city_to_name.items():
        match = regex.search(headline)
        if match:
            if headline[match.start()].isupper():
                cities_in_headline.add(name)
                
    return list(cities_in_headline)

# %%
df_headline_city_country['Cities'] = df_headline_city_country['Headline'].apply(get_cities_in_headline)  # return multiple cities (if any) per headline
df_headline_city_country['Num_cities'] = df_headline_city_country['Cities'].apply(len)

# %%
df_headline_city_country[df_headline_city_country.Num_cities > 1].sort_values('Num_cities', ascending=False)
# Out:
#                                               Headline            City  \
# 627                    Zika spreads to San Luis Potosi          Potosí
# 551                 Zika Reported in North Miami Beach           Miami
# 647                       Zika worries in San Salvador        Salvador
# 348                     Pneumonia Exposure in San Jose             San
# 379  Rumors about Hepatitis D Spreading in San Juan...             San
# ..                                                 ...             ...
# 296               New Los Angeles Hairstyle goes Viral            Goes
# 297  New Milford Patient in Critical Condition afte...         Milford
# 299          New Zika Case Confirmed in Belo Horizonte  Belo Horizonte
# 314                            Nha Trang Zika Outbreak       Nha Trang
# 333                    Outbreak of Zika in Panama City              Of
#
#     Country                                             Cities  Num_cities
# 627    None           [San Luis, San Luis Potosí, San, Potosí]           4
# 551    None  [Miami, North Miami, North Miami Beach, Miami ...           4
# 647    None                      [San, San Salvador, Salvador]           3
# 348    None                          [San Jose, San, San José]           3
# 379    None               [San Juan Capistrano, San, San Juan]           3
# ..      ...                                                ...         ...
# 296    None                         [Los Angeles, Los Ángeles]           2
# 297    None                             [Milford, New Milford]           2
# 299    None                        [Horizonte, Belo Horizonte]           2
# 314    None                                 [Trang, Nha Trang]           2
# 333  Panama                              [Panama City, Panamá]           2
#
# [68 rows x 5 columns]

# %%
# Choose a single city with the longest name when multiple cities are matched in one headline 

def get_longest_city(cities):
    if cities:
        return max(cities, key=len)
    return None

df_headline_city_country['City'] = df_headline_city_country['Cities'].apply(get_longest_city)

# %%
df_headline_city_country[df_headline_city_country.Num_cities > 1].sort_values('Num_cities', ascending=False)
# Out:
#                                               Headline                 City  \
# 627                    Zika spreads to San Luis Potosi      San Luis Potosí
# 551                 Zika Reported in North Miami Beach    North Miami Beach
# 647                       Zika worries in San Salvador         San Salvador
# 348                     Pneumonia Exposure in San Jose             San Jose
# 379  Rumors about Hepatitis D Spreading in San Juan...  San Juan Capistrano
# ..                                                 ...                  ...
# 296               New Los Angeles Hairstyle goes Viral          Los Angeles
# 297  New Milford Patient in Critical Condition afte...          New Milford
# 299          New Zika Case Confirmed in Belo Horizonte       Belo Horizonte
# 314                            Nha Trang Zika Outbreak            Nha Trang
# 333                    Outbreak of Zika in Panama City          Panama City
#
#     Country                                             Cities  Num_cities
# 627    None           [San Luis, San Luis Potosí, San, Potosí]           4
# 551    None  [Miami, North Miami, North Miami Beach, Miami ...           4
# 647    None                      [San, San Salvador, Salvador]           3
# 348    None                          [San Jose, San, San José]           3
# 379    None               [San Juan Capistrano, San, San Juan]           3
# ..      ...                                                ...         ...
# 296    None                         [Los Angeles, Los Ángeles]           2
# 297    None                             [Milford, New Milford]           2
# 299    None                        [Horizonte, Belo Horizonte]           2
# 314    None                                 [Trang, Nha Trang]           2
# 333  Panama                              [Panama City, Panamá]           2
#
# [68 rows x 5 columns]

# %% [markdown]
# Confirm that no erroneous short city-name (4 characters or less) is getting assigned to one of our headlines.

# %%
short_cities = df_headline_city_country[df_headline_city_country.City.str.len() <= 4][['City', 'Headline']]
print(short_cities.to_string(index=False))
# Out:
#  City                                           Headline
#  Yiwu  Authorities are Worried about the Spread of He...
#  Rome  Authorities are Worried about the Spread of Ma...
#  Kobe                     Chikungunya re-emerges in Kobe
#  Bonn  Contaminated Meat Brings Trouble for Bonn Farmers
#  Erie                        Erie County sets Zika traps
#  Kent                       Kent is infested with Rabies
#  Lima                Lima tries to address Zika Concerns
#  Lyon                   Mad Cow Disease Detected in Lyon
#  Molo                Molo Cholera Spread Causing Concern
#  Waco                More Zika patients reported in Waco
#  Nadi  More people in Nadi are infected with HIV ever...
#  Pune                     Pune woman diagnosed with Zika
#  Baud  Rumors about Tuberculosis Spreading in Baud ha...
#  Suva  Suva authorities confirmed the spread of Rotav...
#  Reno  The Spread of Gonorrhea in Reno has been Confi...
#  Baku    The Spread of Herpes in Baku has been Confirmed
#  Jaén                         Zika Troubles come to Jaen
#  Miri                               Zika arrives in Miri
#  Yuma                       Zika seminars in Yuma County
#  Sibu                      Zika symptoms spotted in Sibu

# %% [markdown]
# Headlines with matched country value

# %%
df_countries = df_headline_city_country[df_headline_city_country.Country.notnull()][['City', 'Country', 'Headline']]
print(df_countries.to_string(index=False))
print(f"{len(df_countries)} headlines with country matches.")
# Out:
#              City    Country                                           Headline
#       Belize City     Belize                 Belize City under threat from Zika
#            Recife     Brazil            Mystery Virus Spreads in Recife, Brazil
#     Kota Kinabalu   Malaysia           New Zika Case in Kota Kinabalu, Malaysia
#         Hong Kong  Hong Kong                    Norovirus Exposure in Hong Kong
#       Panama City     Panama                    Outbreak of Zika in Panama City
#            Panamá     Panama           Panama Cityâ€™s first Zika related death
#    Guatemala City  Guatemala  Rumors about Meningitis spreading in Guatemala...
#          Campinas     Brazil                   Student sick in Campinas, Brazil
#           Bangkok   Thailand                     Thailand-Zika Virus in Bangkok
#         Singapore  Singapore                  Zika cases in Singapore reach 393
#  Ho Chi Minh City    Vietnam     Zika cases in Vietnam's Ho Chi Minh City surge
#        Piracicaba     Brazil                Zika outbreak in Piracicaba, Brazil
#       Mexico City     Mexico               Zika outbreak spreads to Mexico City
#       Johor Bahru   Malaysia                 Zika reaches Johor Bahru, Malaysia
#             Klang   Malaysia                   Zika surfaces in Klang, Malaysia
# 15 headlines with country matches.

# %% [markdown]
# Look for the most common city and country names and see if there are any issues

# %%
df_headline_city_country[['City', 'Country']].describe()
# Out:
#           City Country
# count      611      15
# unique     577      10
# top     Madrid  Brazil
# freq         4       3

# %% [markdown]
# Headlines with no city matched

# %%
df_unmatched = df_headline_city_country[df_headline_city_country.City.isnull()]
num_unmatched = len(df_unmatched)
print(f"{num_unmatched} headlines contain no city matches.")
df_unmatched
# Out:
# 39 headlines contain no city matches.
#                                               Headline  City Country Cities  \
# 45                    Bronchitis Outbreak in Manhasset  None    None     []
# 72                Chikungunya has not Left Pismo Beach  None    None     []
# 99         Fort Belvoir tests new cure for Hepatitis C  None    None     []
# 111              Greenwich Establishes Zika Task Force  None    None     []
# 113  Gympie Patient in Critical Condition after Con...  None    None     []
# 145  Hillsborough uses innovative trap against Zika...  None    None     []
# 182       Longwood volunteers spreading Zika awareness  None    None     []
# 183                      Louisiana Zika cases up to 26  None    None     []
# 207           Maka City Experiences Influenza Outbreak  None    None     []
# 208                         Malaria Exposure in Sussex  None    None     []
# 222            Martinsville tests new cure for Measles  None    None     []
# 223                                 Measles Hits Davos  None    None     []
# 243  More Patients in Magnolia are Getting Diagnose...  None    None     []
# 244  More Patients in Maynard are Getting Diagnosed...  None    None     []
# 274  More people in Boucau are infected with HIV ev...  None    None     []
# 277  More people in Huron are infected with Dengue ...  None    None     []
# 282  More people in Oak Brook are infected with Res...  None    None     []
# 324                       Outbreak of Zika in Alvorada  None    None     []
# 328                         Outbreak of Zika in Destin  None    None     []
# 329                       Outbreak of Zika in Hutchins  None    None     []
# 382  Rumors about Influenza Spreading in Dobbs Ferr...  None    None     []
# 393  Rumors about Syphilis spreading in Penal have ...  None    None     []
# 405  Schools in Coamo Closed Due to Rhinovirus Outb...  None    None     []
# 423                     Spanish Flu Sighted in Antigua  None    None     []
# 432        Spike of Hepatitis E Cases in Morehead City  None    None     []
# 434           Spike of Meningitis Cases in Druid Hills  None    None     []
# 462  The Spread of Chikungunya in Davidson has been...  None    None     []
# 506            West Nile Virus Outbreak in Saint Johns  None    None     []
# 524       Will Tuberculosis vaccine help Cherry Creek?  None    None     []
# 528         Will West Nile Virus vaccine help Parsons?  None    None     []
# 532          Yulee takes a hit from Spreading Sickness  None    None     []
# 563              Zika Troubles come to Padre Las Casas  None    None     []
# 575                           Zika arrives in Dangriga  None    None     []
# 591                    Zika case reported in Antioquia  None    None     []
# 596                  Zika case reported in Los Fresnos  None    None     []
# 598                         Zika case reported in Oton  None    None     []
# 607                Zika infects pregnant woman in Cebu  None    None     []
# 623                            Zika spreads to La Joya  None    None     []
# 640                   Zika symptoms spotted in Quixere  None    None     []
#
#      Num_cities
# 45            0
# 72            0
# 99            0
# 111           0
# 113           0
# 145           0
# 182           0
# 183           0
# 207           0
# 208           0
# 222           0
# 223           0
# 243           0
# 244           0
# 274           0
# 277           0
# 282           0
# 324           0
# 328           0
# 329           0
# 382           0
# 393           0
# 405           0
# 423           0
# 432           0
# 434           0
# 462           0
# 506           0
# 524           0
# 528           0
# 532           0
# 563           0
# 575           0
# 591           0
# 596           0
# 598           0
# 607           0
# 623           0
# 640           0

# %% [markdown]
# Try to map country by city using external data - GeonamesCache

# %%
from geonamescache import GeonamesCache
gc = GeonamesCache()

city_list = [city['name'] for city in gc.get_cities().values()]
country_code_list = [city['countrycode'] for city in gc.get_cities().values()]
country_list = [gc.get_countries()[country_code].get('name') for country_code in country_code_list]

city_country_data = {'City': city_list, 'Country': country_list}
df_city_country = pd.DataFrame(city_country_data)

df_city_country
# Out:
#                       City               Country
# 0         Andorra la Vella               Andorra
# 1       Umm Al Quwain City  United Arab Emirates
# 2      Ras Al Khaimah City  United Arab Emirates
# 3               Zayed City  United Arab Emirates
# 4             Khawr Fakkān  United Arab Emirates
# ...                    ...                   ...
# 24331             Bulawayo              Zimbabwe
# 24332              Bindura              Zimbabwe
# 24333           Beitbridge              Zimbabwe
# 24334              Epworth              Zimbabwe
# 24335          Chitungwiza              Zimbabwe
#
# [24336 rows x 2 columns]

# %%
dict_city_country = df_city_country.set_index('City').T.to_dict('list')
# Out:
# C:\Anaconda3\envs\discovering-disease-outbreaks\lib\site-packages\ipykernel_launcher.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   """Entry point for launching an IPython kernel.

# %%
headline_country_list = [''.join(dict_city_country.get(city_name, "")) for city_name in df_headline_city_country['City'].to_list()]
df_headline_city_country['Mapped Country'] = headline_country_list

df_headline_city_country
# Out:
#                                               Headline          City Country  \
# 0                          18 new Zika Cases in Bogota        Bogotá    None
# 1                        19 new Zika Cases in Sengkang      Sengkang    None
# 2             Alameda Residents Recieve Rabies vaccine       Alameda    None
# 3    Albany Residents Recieve Respiratory Syncytial...        Albany    None
# 4                Antipolo under threat from Zika Virus      Antipolo    None
# ..                                                 ...           ...     ...
# 645                Zika virus confirmed in Westchester   Westchester    None
# 646                   Zika virus reported in Cleveland     Cleveland    None
# 647                       Zika worries in San Salvador  San Salvador    None
# 648     Zika-carrying mosquitoes discovered in Ardmore       Ardmore    None
# 649                  Zika: Delhi for strict monitoring         Delhi    None
#
#                             Cities  Num_cities Mapped Country
# 0                         [Bogotá]           1       Colombia
# 1                       [Sengkang]           1      Indonesia
# 2                        [Alameda]           1  United States
# 3                         [Albany]           1  United States
# 4                       [Antipolo]           1    Philippines
# ..                             ...         ...            ...
# 645                  [Westchester]           1  United States
# 646                    [Cleveland]           1  United States
# 647  [San, San Salvador, Salvador]           3    El Salvador
# 648                      [Ardmore]           1  United States
# 649                        [Delhi]           1          India
#
# [650 rows x 6 columns]

# %%
df_headline_city_country[df_headline_city_country.Country.notnull()][['City', 'Country', 'Mapped Country', 'Headline']]
# Out:
#                  City    Country Mapped Country  \
# 36        Belize City     Belize         Belize
# 293            Recife     Brazil         Brazil
# 301     Kota Kinabalu   Malaysia       Malaysia
# 316         Hong Kong  Hong Kong      Hong Kong
# 333       Panama City     Panama  United States
# 339            Panamá     Panama         Panama
# 384    Guatemala City  Guatemala      Guatemala
# 450          Campinas     Brazil         Brazil
# 459           Bangkok   Thailand       Thailand
# 603         Singapore  Singapore      Singapore
# 604  Ho Chi Minh City    Vietnam        Vietnam
# 611        Piracicaba     Brazil         Brazil
# 612       Mexico City     Mexico         Mexico
# 613       Johor Bahru   Malaysia       Malaysia
# 629             Klang   Malaysia       Malaysia
#
#                                               Headline
# 36                  Belize City under threat from Zika
# 293            Mystery Virus Spreads in Recife, Brazil
# 301           New Zika Case in Kota Kinabalu, Malaysia
# 316                    Norovirus Exposure in Hong Kong
# 333                    Outbreak of Zika in Panama City
# 339           Panama Cityâ€™s first Zika related death
# 384  Rumors about Meningitis spreading in Guatemala...
# 450                   Student sick in Campinas, Brazil
# 459                     Thailand-Zika Virus in Bangkok
# 603                  Zika cases in Singapore reach 393
# 604     Zika cases in Vietnam's Ho Chi Minh City surge
# 611                Zika outbreak in Piracicaba, Brazil
# 612               Zika outbreak spreads to Mexico City
# 613                 Zika reaches Johor Bahru, Malaysia
# 629                   Zika surfaces in Klang, Malaysia

# %% [markdown]
# ## Workflow #5 ##
# Once you are confident you’ve found all the cities/countries in each headline, save the DataFrame for the next part.

# %%
df_cleaned_headline_city_country = df_headline_city_country[['City', 'Country', 'Headline']]
